# %%
# =========================================================
# Setup
# =========================================================

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import numpy as np
import random
import pandas as pd
import scipy.stats as stats
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =========================================================
# Reproducibility
# =========================================================

def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

print("Device:", device)
print("Seed function ready.")
# Out:
# Device: cuda
# Seed function ready.

# %%
# =========================================================
# Data Transforms
# =========================================================

class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)


ssl_base_transform = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

supervised_transform = T.ToTensor()

# %%
# =========================================================
# Encoder
# =========================================================

class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        backbone = resnet18(weights=None)
        backbone.fc = nn.Identity()
        self.backbone = backbone

    def forward(self, x):
        return self.backbone(x)

# %%
# =========================================================
# BYOL
# =========================================================

class MLP(nn.Module):
    def __init__(self, in_dim, hidden_dim=2048, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )

    def forward(self, x):
        return self.net(x)


class BYOL(nn.Module):
    def __init__(self):
        super().__init__()
        self.online_encoder = Encoder()
        self.online_projector = MLP(512)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder = Encoder()
        self.target_projector = MLP(512)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for online, target in zip(self.online_encoder.parameters(),
                                  self.target_encoder.parameters()):
            target.data = tau * target.data + (1 - tau) * online.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(
            self.online_projector(self.online_encoder(x1))
        )

        with torch.no_grad():
            t2 = self.target_projector(
                self.target_encoder(x2)
            )

        loss = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        return loss.mean()

# %%
# =========================================================
# SimCLR
# =========================================================

class SimCLR(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.projector = MLP(512)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        z = F.normalize(z, dim=1)
        return z


def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)

    sim = torch.mm(z, z.t()) / temperature
    mask = torch.eye(2*N, device=z.device).bool()
    sim.masked_fill_(mask, -9e15)

    positives = torch.cat([torch.arange(N, 2*N),
                           torch.arange(0, N)]).to(z.device)

    loss = F.cross_entropy(sim, positives)
    return loss

# %%
# =========================================================
# Training
# =========================================================

def train_byol(model, train_loader, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for (x1, x2), _ in train_loader:
            x1 = x1.to(device)
            x2 = x2.to(device)

            loss = model(x1, x2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            model.update_target()

            total_loss += loss.item()

        print(f"[BYOL] Epoch {epoch+1:03d}/{epochs} | Loss: {total_loss/len(train_loader):.4f}")

    return model.online_encoder


def train_simclr(model, train_loader, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for (x1, x2), _ in train_loader:
            x1 = x1.to(device)
            x2 = x2.to(device)

            z1 = model(x1)
            z2 = model(x2)

            loss = nt_xent_loss(z1, z2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"[SimCLR] Epoch {epoch+1:03d}/{epochs} | Loss: {total_loss/len(train_loader):.4f}")

    return model.encoder

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(512, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    return correct / total

# %%
# =========================================================
# Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
])

def jacobian_frobenius(model, x):
    x = x.clone().detach().to(device).requires_grad_(True)
    y = model(x)
    v = torch.randn_like(y)

    Jv = torch.autograd.grad(
        outputs=y,
        inputs=x,
        grad_outputs=v,
        retain_graph=False
    )[0]

    return torch.sqrt(Jv.pow(2).sum() / x.size(0))


def compute_metrics(encoder, loader):
    encoder = encoder.to(device)
    encoder.eval()

    jac_vals = []
    aug_vals = []
    noise_vals = []

    for i, (x, _) in enumerate(loader):
        if i == 5:
            break

        x = x.to(device)

        jac_vals.append(jacobian_frobenius(encoder, x).item())

        x_aug = torch.stack([tensor_aug(img.cpu()) for img in x]).to(device)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        noise = torch.randn_like(x) * 0.1
        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x + noise)
            noise_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

    return np.mean(jac_vals), np.mean(aug_vals), np.mean(noise_vals)

# %%
# =========================================================
# V2 Multi-Seed Experiment (With Timing)
# =========================================================

seeds = [4,5,6]
all_results = []

overall_start = time.time()

for seed in seeds:

    seed_start = time.time()

    print("\n====================================")
    print(f"Running Seed: {seed}")
    print("====================================")

    set_seed(seed)

    train_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=ssl_transform
    )

    supervised_train_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=False,
        transform=supervised_transform
    )

    test_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=False,
        download=True,
        transform=supervised_transform
    )

    train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
    supervised_train_loader = DataLoader(supervised_train_dataset, batch_size=128, shuffle=True, num_workers=2)
    supervised_test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)

    byol_encoder = train_byol(BYOL(), train_loader, epochs=100)
    simclr_encoder = train_simclr(SimCLR(), train_loader, epochs=100)

    byol_acc = train_probe(byol_encoder, supervised_train_loader, supervised_test_loader)
    simclr_acc = train_probe(simclr_encoder, supervised_train_loader, supervised_test_loader)

    byol_jac, byol_aug, byol_noise = compute_metrics(byol_encoder, supervised_test_loader)
    simclr_jac, simclr_aug, simclr_noise = compute_metrics(simclr_encoder, supervised_test_loader)

    seed_time = (time.time() - seed_start) / 60

    all_results.append({
        "Seed": seed,
        "BYOL_Jacobian": byol_jac,
        "SimCLR_Jacobian": simclr_jac,
        "BYOL_Aug": byol_aug,
        "SimCLR_Aug": simclr_aug,
        "BYOL_Noise": byol_noise,
        "SimCLR_Noise": simclr_noise,
        "BYOL_Acc": byol_acc,
        "SimCLR_Acc": simclr_acc,
        "Seed_Time_Min": seed_time
    })

    print(f"\nSeed {seed} finished in {seed_time:.2f} minutes.")

total_time = (time.time() - overall_start) / 60

results_df = pd.DataFrame(all_results)

print("\nPer-Seed Results:")
print(results_df)

print("\nMean Across Seeds:")
print(results_df.mean(numeric_only=True))

print("\nStd Across Seeds:")
print(results_df.std(numeric_only=True))

print(f"\nTotal Experiment Time: {total_time:.2f} minutes.")
# Out:
# ====================================
# Running Seed: 4
# ====================================
# 100%|██████████| 170M/170M [00:05<00:00, 29.4MB/s]
# [BYOL] Epoch 001/100 | Loss: 0.7238
# [BYOL] Epoch 002/100 | Loss: 0.5617
# [BYOL] Epoch 003/100 | Loss: 0.5084
# [BYOL] Epoch 004/100 | Loss: 0.4806
# [BYOL] Epoch 005/100 | Loss: 0.4605
# [BYOL] Epoch 006/100 | Loss: 0.4498
# [BYOL] Epoch 007/100 | Loss: 0.4421
# [BYOL] Epoch 008/100 | Loss: 0.4332
# [BYOL] Epoch 009/100 | Loss: 0.4278
# [BYOL] Epoch 010/100 | Loss: 0.4221
# [BYOL] Epoch 011/100 | Loss: 0.4180
# [BYOL] Epoch 012/100 | Loss: 0.4161
# [BYOL] Epoch 013/100 | Loss: 0.4166
# [BYOL] Epoch 014/100 | Loss: 0.4136
# [BYOL] Epoch 015/100 | Loss: 0.4133
# [BYOL] Epoch 016/100 | Loss: 0.4111
# [BYOL] Epoch 017/100 | Loss: 0.4077
# [BYOL] Epoch 018/100 | Loss: 0.4081
# [BYOL] Epoch 019/100 | Loss: 0.4053
# [BYOL] Epoch 020/100 | Loss: 0.4045
# [BYOL] Epoch 021/100 | Loss: 0.4032
# [BYOL] Epoch 022/100 | Loss: 0.4020
# [BYOL] Epoch 023/100 | Loss: 0.3980
# [BYOL] Epoch 024/100 | Loss: 0.3957
# [BYOL] Epoch 025/100 | Loss: 0.3960
# [BYOL] Epoch 026/100 | Loss: 0.3962
# [BYOL] Epoch 027/100 | Loss: 0.3954
# [BYOL] Epoch 028/100 | Loss: 0.3945
# [BYOL] Epoch 029/100 | Loss: 0.3917
# [BYOL] Epoch 030/100 | Loss: 0.3910
# [BYOL] Epoch 031/100 | Loss: 0.3893
# [BYOL] Epoch 032/100 | Loss: 0.3917
# [BYOL] Epoch 033/100 | Loss: 0.3896
# [BYOL] Epoch 034/100 | Loss: 0.3919
# [BYOL] Epoch 035/100 | Loss: 0.3884
# [BYOL] Epoch 036/100 | Loss: 0.3882
# [BYOL] Epoch 037/100 | Loss: 0.3892
# [BYOL] Epoch 038/100 | Loss: 0.3883
# [BYOL] Epoch 039/100 | Loss: 0.3858
# [BYOL] Epoch 040/100 | Loss: 0.3837
# [BYOL] Epoch 041/100 | Loss: 0.3826
# [BYOL] Epoch 042/100 | Loss: 0.3845
# [BYOL] Epoch 043/100 | Loss: 0.3834
# [BYOL] Epoch 044/100 | Loss: 0.3829
# [BYOL] Epoch 045/100 | Loss: 0.3816
# [BYOL] Epoch 046/100 | Loss: 0.3820
# [BYOL] Epoch 047/100 | Loss: 0.3836
# [BYOL] Epoch 048/100 | Loss: 0.3828
# [BYOL] Epoch 049/100 | Loss: 0.3822
# [BYOL] Epoch 050/100 | Loss: 0.3858
# [BYOL] Epoch 051/100 | Loss: 0.3826
# [BYOL] Epoch 052/100 | Loss: 0.3822
# [BYOL] Epoch 053/100 | Loss: 0.3816
# [BYOL] Epoch 054/100 | Loss: 0.3814
# [BYOL] Epoch 055/100 | Loss: 0.3806
# [BYOL] Epoch 056/100 | Loss: 0.3822
# [BYOL] Epoch 057/100 | Loss: 0.3819
# [BYOL] Epoch 058/100 | Loss: 0.3795
# [BYOL] Epoch 059/100 | Loss: 0.3808
# [BYOL] Epoch 060/100 | Loss: 0.3811
# [BYOL] Epoch 061/100 | Loss: 0.3812
# [BYOL] Epoch 062/100 | Loss: 0.3796
# [BYOL] Epoch 063/100 | Loss: 0.3763
# [BYOL] Epoch 064/100 | Loss: 0.3771
# [BYOL] Epoch 065/100 | Loss: 0.3763
# [BYOL] Epoch 066/100 | Loss: 0.3773
# [BYOL] Epoch 067/100 | Loss: 0.3777
# [BYOL] Epoch 068/100 | Loss: 0.3748
# [BYOL] Epoch 069/100 | Loss: 0.3749
# [BYOL] Epoch 070/100 | Loss: 0.3739
# [BYOL] Epoch 071/100 | Loss: 0.3752
# [BYOL] Epoch 072/100 | Loss: 0.3740
# [BYOL] Epoch 073/100 | Loss: 0.3744
# [BYOL] Epoch 074/100 | Loss: 0.3729
# [BYOL] Epoch 075/100 | Loss: 0.3726
# [BYOL] Epoch 076/100 | Loss: 0.3711
# [BYOL] Epoch 077/100 | Loss: 0.3722
# [BYOL] Epoch 078/100 | Loss: 0.3707
# [BYOL] Epoch 079/100 | Loss: 0.3717
# [BYOL] Epoch 080/100 | Loss: 0.3722
# [BYOL] Epoch 081/100 | Loss: 0.3730
# [BYOL] Epoch 082/100 | Loss: 0.3730
# [BYOL] Epoch 083/100 | Loss: 0.3711
# [BYOL] Epoch 084/100 | Loss: 0.3711
# [BYOL] Epoch 085/100 | Loss: 0.3696
# [BYOL] Epoch 086/100 | Loss: 0.3704
# [BYOL] Epoch 087/100 | Loss: 0.3712
# [BYOL] Epoch 088/100 | Loss: 0.3700
# [BYOL] Epoch 089/100 | Loss: 0.3704
# [BYOL] Epoch 090/100 | Loss: 0.3716
# [BYOL] Epoch 091/100 | Loss: 0.3708
# [BYOL] Epoch 092/100 | Loss: 0.3688
# [BYOL] Epoch 093/100 | Loss: 0.3695
# [BYOL] Epoch 094/100 | Loss: 0.3703
# [BYOL] Epoch 095/100 | Loss: 0.3693
# [BYOL] Epoch 096/100 | Loss: 0.3697
# [BYOL] Epoch 097/100 | Loss: 0.3700
# [BYOL] Epoch 098/100 | Loss: 0.3693
# [BYOL] Epoch 099/100 | Loss: 0.3689
# [BYOL] Epoch 100/100 | Loss: 0.3692
# [SimCLR] Epoch 001/100 | Loss: 4.6710
# [SimCLR] Epoch 002/100 | Loss: 4.4935
# [SimCLR] Epoch 003/100 | Loss: 4.4268
# [SimCLR] Epoch 004/100 | Loss: 4.3879
# [SimCLR] Epoch 005/100 | Loss: 4.3578
# [SimCLR] Epoch 006/100 | Loss: 4.3349
# [SimCLR] Epoch 007/100 | Loss: 4.3124
# [SimCLR] Epoch 008/100 | Loss: 4.2972
# [SimCLR] Epoch 009/100 | Loss: 4.2741
# [SimCLR] Epoch 010/100 | Loss: 4.2636
# [SimCLR] Epoch 011/100 | Loss: 4.2492
# [SimCLR] Epoch 012/100 | Loss: 4.2343
# [SimCLR] Epoch 013/100 | Loss: 4.2251
# [SimCLR] Epoch 014/100 | Loss: 4.2149
# [SimCLR] Epoch 015/100 | Loss: 4.2052
# [SimCLR] Epoch 016/100 | Loss: 4.1969
# [SimCLR] Epoch 017/100 | Loss: 4.1863
# [SimCLR] Epoch 018/100 | Loss: 4.1821
# [SimCLR] Epoch 019/100 | Loss: 4.1729
# [SimCLR] Epoch 020/100 | Loss: 4.1672
# [SimCLR] Epoch 021/100 | Loss: 4.1588
# [SimCLR] Epoch 022/100 | Loss: 4.1538
# [SimCLR] Epoch 023/100 | Loss: 4.1519
# [SimCLR] Epoch 024/100 | Loss: 4.1415
# [SimCLR] Epoch 025/100 | Loss: 4.1438
# [SimCLR] Epoch 026/100 | Loss: 4.1376
# [SimCLR] Epoch 027/100 | Loss: 4.1329
# [SimCLR] Epoch 028/100 | Loss: 4.1312
# [SimCLR] Epoch 029/100 | Loss: 4.1248
# [SimCLR] Epoch 030/100 | Loss: 4.1201
# [SimCLR] Epoch 031/100 | Loss: 4.1174
# [SimCLR] Epoch 032/100 | Loss: 4.1160
# [SimCLR] Epoch 033/100 | Loss: 4.1107
# [SimCLR] Epoch 034/100 | Loss: 4.1123
# [SimCLR] Epoch 035/100 | Loss: 4.1065
# [SimCLR] Epoch 036/100 | Loss: 4.1057
# [SimCLR] Epoch 037/100 | Loss: 4.1015
# [SimCLR] Epoch 038/100 | Loss: 4.0985
# [SimCLR] Epoch 039/100 | Loss: 4.0970
# [SimCLR] Epoch 040/100 | Loss: 4.0949
# [SimCLR] Epoch 041/100 | Loss: 4.0891
# [SimCLR] Epoch 042/100 | Loss: 4.0921
# [SimCLR] Epoch 043/100 | Loss: 4.0869
# [SimCLR] Epoch 044/100 | Loss: 4.0826
# [SimCLR] Epoch 045/100 | Loss: 4.0810
# [SimCLR] Epoch 046/100 | Loss: 4.0791
# [SimCLR] Epoch 047/100 | Loss: 4.0767
# [SimCLR] Epoch 048/100 | Loss: 4.0742
# [SimCLR] Epoch 049/100 | Loss: 4.0707
# [SimCLR] Epoch 050/100 | Loss: 4.0676
# [SimCLR] Epoch 051/100 | Loss: 4.0708
# [SimCLR] Epoch 052/100 | Loss: 4.0642
# [SimCLR] Epoch 053/100 | Loss: 4.0655
# [SimCLR] Epoch 054/100 | Loss: 4.0637
# [SimCLR] Epoch 055/100 | Loss: 4.0620
# [SimCLR] Epoch 056/100 | Loss: 4.0564
# [SimCLR] Epoch 057/100 | Loss: 4.0575
# [SimCLR] Epoch 058/100 | Loss: 4.0547
# [SimCLR] Epoch 059/100 | Loss: 4.0527
# [SimCLR] Epoch 060/100 | Loss: 4.0483
# [SimCLR] Epoch 061/100 | Loss: 4.0499
# [SimCLR] Epoch 062/100 | Loss: 4.0453
# [SimCLR] Epoch 063/100 | Loss: 4.0465
# [SimCLR] Epoch 064/100 | Loss: 4.0470
# [SimCLR] Epoch 065/100 | Loss: 4.0405
# [SimCLR] Epoch 066/100 | Loss: 4.0422
# [SimCLR] Epoch 067/100 | Loss: 4.0395
# [SimCLR] Epoch 068/100 | Loss: 4.0387
# [SimCLR] Epoch 069/100 | Loss: 4.0355
# [SimCLR] Epoch 070/100 | Loss: 4.0338
# [SimCLR] Epoch 071/100 | Loss: 4.0354
# [SimCLR] Epoch 072/100 | Loss: 4.0326
# [SimCLR] Epoch 073/100 | Loss: 4.0336
# [SimCLR] Epoch 074/100 | Loss: 4.0313
# [SimCLR] Epoch 075/100 | Loss: 4.0313
# [SimCLR] Epoch 076/100 | Loss: 4.0313
# [SimCLR] Epoch 077/100 | Loss: 4.0252
# [SimCLR] Epoch 078/100 | Loss: 4.0249
# [SimCLR] Epoch 079/100 | Loss: 4.0262
# [SimCLR] Epoch 080/100 | Loss: 4.0233
# [SimCLR] Epoch 081/100 | Loss: 4.0231
# [SimCLR] Epoch 082/100 | Loss: 4.0184
# [SimCLR] Epoch 083/100 | Loss: 4.0202
# [SimCLR] Epoch 084/100 | Loss: 4.0174
# [SimCLR] Epoch 085/100 | Loss: 4.0193
# [SimCLR] Epoch 086/100 | Loss: 4.0161
# [SimCLR] Epoch 087/100 | Loss: 4.0154
# [SimCLR] Epoch 088/100 | Loss: 4.0139
# [SimCLR] Epoch 089/100 | Loss: 4.0132
# [SimCLR] Epoch 090/100 | Loss: 4.0127
# [SimCLR] Epoch 091/100 | Loss: 4.0132
# [SimCLR] Epoch 092/100 | Loss: 4.0129
# [SimCLR] Epoch 093/100 | Loss: 4.0095
# [SimCLR] Epoch 094/100 | Loss: 4.0090
# [SimCLR] Epoch 095/100 | Loss: 4.0089
# [SimCLR] Epoch 096/100 | Loss: 4.0079
# [SimCLR] Epoch 097/100 | Loss: 4.0070
# [SimCLR] Epoch 098/100 | Loss: 4.0073
# [SimCLR] Epoch 099/100 | Loss: 4.0042
# [SimCLR] Epoch 100/100 | Loss: 4.0046
#
# Seed 4 finished in 155.30 minutes.
#
# ====================================
# Running Seed: 5
# ====================================
# [BYOL] Epoch 001/100 | Loss: 0.8310
# [BYOL] Epoch 002/100 | Loss: 0.6216
# [BYOL] Epoch 003/100 | Loss: 0.5455
# [BYOL] Epoch 004/100 | Loss: 0.5138
# [BYOL] Epoch 005/100 | Loss: 0.4921
# [BYOL] Epoch 006/100 | Loss: 0.4813
# [BYOL] Epoch 007/100 | Loss: 0.4687
# [BYOL] Epoch 008/100 | Loss: 0.4630
# [BYOL] Epoch 009/100 | Loss: 0.4559
# [BYOL] Epoch 010/100 | Loss: 0.4526
# [BYOL] Epoch 011/100 | Loss: 0.4499
# [BYOL] Epoch 012/100 | Loss: 0.4466
# [BYOL] Epoch 013/100 | Loss: 0.4423
# [BYOL] Epoch 014/100 | Loss: 0.4409
# [BYOL] Epoch 015/100 | Loss: 0.4344
# [BYOL] Epoch 016/100 | Loss: 0.4317
# [BYOL] Epoch 017/100 | Loss: 0.4308
# [BYOL] Epoch 018/100 | Loss: 0.4302
# [BYOL] Epoch 019/100 | Loss: 0.4275
# [BYOL] Epoch 020/100 | Loss: 0.4256
# [BYOL] Epoch 021/100 | Loss: 0.4248
# [BYOL] Epoch 022/100 | Loss: 0.4227
# [BYOL] Epoch 023/100 | Loss: 0.4231
# [BYOL] Epoch 024/100 | Loss: 0.4234
# [BYOL] Epoch 025/100 | Loss: 0.4206
# [BYOL] Epoch 026/100 | Loss: 0.4185
# [BYOL] Epoch 027/100 | Loss: 0.4214
# [BYOL] Epoch 028/100 | Loss: 0.4193
# [BYOL] Epoch 029/100 | Loss: 0.4210
# [BYOL] Epoch 030/100 | Loss: 0.4193
# [BYOL] Epoch 031/100 | Loss: 0.4184
# [BYOL] Epoch 032/100 | Loss: 0.4171
# [BYOL] Epoch 033/100 | Loss: 0.4157
# [BYOL] Epoch 034/100 | Loss: 0.4143
# [BYOL] Epoch 035/100 | Loss: 0.4149
# [BYOL] Epoch 036/100 | Loss: 0.4160
# [BYOL] Epoch 037/100 | Loss: 0.4135
# [BYOL] Epoch 038/100 | Loss: 0.4126
# [BYOL] Epoch 039/100 | Loss: 0.4114
# [BYOL] Epoch 040/100 | Loss: 0.4096
# [BYOL] Epoch 041/100 | Loss: 0.4084
# [BYOL] Epoch 042/100 | Loss: 0.4100
# [BYOL] Epoch 043/100 | Loss: 0.4085
# [BYOL] Epoch 044/100 | Loss: 0.4059
# [BYOL] Epoch 045/100 | Loss: 0.4061
# [BYOL] Epoch 046/100 | Loss: 0.4057
# [BYOL] Epoch 047/100 | Loss: 0.4063
# [BYOL] Epoch 048/100 | Loss: 0.4056
# [BYOL] Epoch 049/100 | Loss: 0.4047
# [BYOL] Epoch 050/100 | Loss: 0.4044
# [BYOL] Epoch 051/100 | Loss: 0.4033
# [BYOL] Epoch 052/100 | Loss: 0.4032
# [BYOL] Epoch 053/100 | Loss: 0.4040
# [BYOL] Epoch 054/100 | Loss: 0.4029
# [BYOL] Epoch 055/100 | Loss: 0.4036
# [BYOL] Epoch 056/100 | Loss: 0.4016
# [BYOL] Epoch 057/100 | Loss: 0.4040
# [BYOL] Epoch 058/100 | Loss: 0.4026
# [BYOL] Epoch 059/100 | Loss: 0.4042
# [BYOL] Epoch 060/100 | Loss: 0.4035
# [BYOL] Epoch 061/100 | Loss: 0.4018
# [BYOL] Epoch 062/100 | Loss: 0.4030
# [BYOL] Epoch 063/100 | Loss: 0.4017
# [BYOL] Epoch 064/100 | Loss: 0.4040
# [BYOL] Epoch 065/100 | Loss: 0.4021
# [BYOL] Epoch 066/100 | Loss: 0.4012
# [BYOL] Epoch 067/100 | Loss: 0.4033
# [BYOL] Epoch 068/100 | Loss: 0.4018
# [BYOL] Epoch 069/100 | Loss: 0.4043
# [BYOL] Epoch 070/100 | Loss: 0.4019
# [BYOL] Epoch 071/100 | Loss: 0.3998
# [BYOL] Epoch 072/100 | Loss: 0.3994
# [BYOL] Epoch 073/100 | Loss: 0.3995
# [BYOL] Epoch 074/100 | Loss: 0.3997
# [BYOL] Epoch 075/100 | Loss: 0.4013
# [BYOL] Epoch 076/100 | Loss: 0.4019
# [BYOL] Epoch 077/100 | Loss: 0.3996
# [BYOL] Epoch 078/100 | Loss: 0.4014
# [BYOL] Epoch 079/100 | Loss: 0.4002
# [BYOL] Epoch 080/100 | Loss: 0.3972
# [BYOL] Epoch 081/100 | Loss: 0.4000
# [BYOL] Epoch 082/100 | Loss: 0.4000
# [BYOL] Epoch 083/100 | Loss: 0.3994
# [BYOL] Epoch 084/100 | Loss: 0.4010
# [BYOL] Epoch 085/100 | Loss: 0.3979
# [BYOL] Epoch 086/100 | Loss: 0.4000
# [BYOL] Epoch 087/100 | Loss: 0.3990
# [BYOL] Epoch 088/100 | Loss: 0.3989
# [BYOL] Epoch 089/100 | Loss: 0.3983
# [BYOL] Epoch 090/100 | Loss: 0.3987
# [BYOL] Epoch 091/100 | Loss: 0.3973
# [BYOL] Epoch 092/100 | Loss: 0.3968
# [BYOL] Epoch 093/100 | Loss: 0.3981
# [BYOL] Epoch 094/100 | Loss: 0.3966
# [BYOL] Epoch 095/100 | Loss: 0.3971
# [BYOL] Epoch 096/100 | Loss: 0.3975
# [BYOL] Epoch 097/100 | Loss: 0.3944
# [BYOL] Epoch 098/100 | Loss: 0.3949
# [BYOL] Epoch 099/100 | Loss: 0.3949
# [BYOL] Epoch 100/100 | Loss: 0.3947
# [SimCLR] Epoch 001/100 | Loss: 4.6721
# [SimCLR] Epoch 002/100 | Loss: 4.4936
# [SimCLR] Epoch 003/100 | Loss: 4.4345
# [SimCLR] Epoch 004/100 | Loss: 4.3874
# [SimCLR] Epoch 005/100 | Loss: 4.3545
# [SimCLR] Epoch 006/100 | Loss: 4.3315
# [SimCLR] Epoch 007/100 | Loss: 4.3124
# [SimCLR] Epoch 008/100 | Loss: 4.2921
# [SimCLR] Epoch 009/100 | Loss: 4.2761
# [SimCLR] Epoch 010/100 | Loss: 4.2603
# [SimCLR] Epoch 011/100 | Loss: 4.2508
# [SimCLR] Epoch 012/100 | Loss: 4.2323
# [SimCLR] Epoch 013/100 | Loss: 4.2252
# [SimCLR] Epoch 014/100 | Loss: 4.2158
# [SimCLR] Epoch 015/100 | Loss: 4.2059
# [SimCLR] Epoch 016/100 | Loss: 4.1986
# [SimCLR] Epoch 017/100 | Loss: 4.1870
# [SimCLR] Epoch 018/100 | Loss: 4.1821
# [SimCLR] Epoch 019/100 | Loss: 4.1765
# [SimCLR] Epoch 020/100 | Loss: 4.1683
# [SimCLR] Epoch 021/100 | Loss: 4.1661
# [SimCLR] Epoch 022/100 | Loss: 4.1600
# [SimCLR] Epoch 023/100 | Loss: 4.1520
# [SimCLR] Epoch 024/100 | Loss: 4.1455
# [SimCLR] Epoch 025/100 | Loss: 4.1381
# [SimCLR] Epoch 026/100 | Loss: 4.1385
# [SimCLR] Epoch 027/100 | Loss: 4.1347
# [SimCLR] Epoch 028/100 | Loss: 4.1276
# [SimCLR] Epoch 029/100 | Loss: 4.1282
# [SimCLR] Epoch 030/100 | Loss: 4.1220
# [SimCLR] Epoch 031/100 | Loss: 4.1191
# [SimCLR] Epoch 032/100 | Loss: 4.1174
# [SimCLR] Epoch 033/100 | Loss: 4.1131
# [SimCLR] Epoch 034/100 | Loss: 4.1067
# [SimCLR] Epoch 035/100 | Loss: 4.1031
# [SimCLR] Epoch 036/100 | Loss: 4.1033
# [SimCLR] Epoch 037/100 | Loss: 4.0983
# [SimCLR] Epoch 038/100 | Loss: 4.1014
# [SimCLR] Epoch 039/100 | Loss: 4.0954
# [SimCLR] Epoch 040/100 | Loss: 4.0898
# [SimCLR] Epoch 041/100 | Loss: 4.0880
# [SimCLR] Epoch 042/100 | Loss: 4.0897
# [SimCLR] Epoch 043/100 | Loss: 4.0851
# [SimCLR] Epoch 044/100 | Loss: 4.0815
# [SimCLR] Epoch 045/100 | Loss: 4.0790
# [SimCLR] Epoch 046/100 | Loss: 4.0763
# [SimCLR] Epoch 047/100 | Loss: 4.0777
# [SimCLR] Epoch 048/100 | Loss: 4.0690
# [SimCLR] Epoch 049/100 | Loss: 4.0708
# [SimCLR] Epoch 050/100 | Loss: 4.0692
# [SimCLR] Epoch 051/100 | Loss: 4.0668
# [SimCLR] Epoch 052/100 | Loss: 4.0668
# [SimCLR] Epoch 053/100 | Loss: 4.0612
# [SimCLR] Epoch 054/100 | Loss: 4.0597
# [SimCLR] Epoch 055/100 | Loss: 4.0592
# [SimCLR] Epoch 056/100 | Loss: 4.0573
# [SimCLR] Epoch 057/100 | Loss: 4.0516
# [SimCLR] Epoch 058/100 | Loss: 4.0517
# [SimCLR] Epoch 059/100 | Loss: 4.0493
# [SimCLR] Epoch 060/100 | Loss: 4.0503
# [SimCLR] Epoch 061/100 | Loss: 4.0467
# [SimCLR] Epoch 062/100 | Loss: 4.0458
# [SimCLR] Epoch 063/100 | Loss: 4.0469
# [SimCLR] Epoch 064/100 | Loss: 4.0417
# [SimCLR] Epoch 065/100 | Loss: 4.0395
# [SimCLR] Epoch 066/100 | Loss: 4.0377
# [SimCLR] Epoch 067/100 | Loss: 4.0395
# [SimCLR] Epoch 068/100 | Loss: 4.0331
# [SimCLR] Epoch 069/100 | Loss: 4.0363
# [SimCLR] Epoch 070/100 | Loss: 4.0339
# [SimCLR] Epoch 071/100 | Loss: 4.0334
# [SimCLR] Epoch 072/100 | Loss: 4.0340
# [SimCLR] Epoch 073/100 | Loss: 4.0316
# [SimCLR] Epoch 074/100 | Loss: 4.0293
# [SimCLR] Epoch 075/100 | Loss: 4.0287
# [SimCLR] Epoch 076/100 | Loss: 4.0254
# [SimCLR] Epoch 077/100 | Loss: 4.0250
# [SimCLR] Epoch 078/100 | Loss: 4.0229
# [SimCLR] Epoch 079/100 | Loss: 4.0244
# [SimCLR] Epoch 080/100 | Loss: 4.0214
# [SimCLR] Epoch 081/100 | Loss: 4.0234
# [SimCLR] Epoch 082/100 | Loss: 4.0195
# [SimCLR] Epoch 083/100 | Loss: 4.0183
# [SimCLR] Epoch 084/100 | Loss: 4.0182
# [SimCLR] Epoch 085/100 | Loss: 4.0186
# [SimCLR] Epoch 086/100 | Loss: 4.0159
# [SimCLR] Epoch 087/100 | Loss: 4.0155
# [SimCLR] Epoch 088/100 | Loss: 4.0124
# [SimCLR] Epoch 089/100 | Loss: 4.0130
# [SimCLR] Epoch 090/100 | Loss: 4.0108
# [SimCLR] Epoch 091/100 | Loss: 4.0131
# [SimCLR] Epoch 092/100 | Loss: 4.0079
# [SimCLR] Epoch 093/100 | Loss: 4.0127
# [SimCLR] Epoch 094/100 | Loss: 4.0100
# [SimCLR] Epoch 095/100 | Loss: 4.0086
# [SimCLR] Epoch 096/100 | Loss: 4.0047
# [SimCLR] Epoch 097/100 | Loss: 4.0068
# [SimCLR] Epoch 098/100 | Loss: 4.0056
# [SimCLR] Epoch 099/100 | Loss: 4.0025
# [SimCLR] Epoch 100/100 | Loss: 4.0031
#
# Seed 5 finished in 154.01 minutes.
#
# ====================================
# Running Seed: 6
# ====================================
# [BYOL] Epoch 001/100 | Loss: 0.7437
# [BYOL] Epoch 002/100 | Loss: 0.5870
# [BYOL] Epoch 003/100 | Loss: 0.5303
# [BYOL] Epoch 004/100 | Loss: 0.5000
# [BYOL] Epoch 005/100 | Loss: 0.4769
# [BYOL] Epoch 006/100 | Loss: 0.4649
# [BYOL] Epoch 007/100 | Loss: 0.4564
# [BYOL] Epoch 008/100 | Loss: 0.4476
# [BYOL] Epoch 009/100 | Loss: 0.4431
# [BYOL] Epoch 010/100 | Loss: 0.4378
# [BYOL] Epoch 011/100 | Loss: 0.4344
# [BYOL] Epoch 012/100 | Loss: 0.4323
# [BYOL] Epoch 013/100 | Loss: 0.4282
# [BYOL] Epoch 014/100 | Loss: 0.4232
# [BYOL] Epoch 015/100 | Loss: 0.4203
# [BYOL] Epoch 016/100 | Loss: 0.4162
# [BYOL] Epoch 017/100 | Loss: 0.4139
# [BYOL] Epoch 018/100 | Loss: 0.4144
# [BYOL] Epoch 019/100 | Loss: 0.4138
# [BYOL] Epoch 020/100 | Loss: 0.4141
# [BYOL] Epoch 021/100 | Loss: 0.4129
# [BYOL] Epoch 022/100 | Loss: 0.4132
# [BYOL] Epoch 023/100 | Loss: 0.4137
# [BYOL] Epoch 024/100 | Loss: 0.4117
# [BYOL] Epoch 025/100 | Loss: 0.4107
# [BYOL] Epoch 026/100 | Loss: 0.4097
# [BYOL] Epoch 027/100 | Loss: 0.4092
# [BYOL] Epoch 028/100 | Loss: 0.4050
# [BYOL] Epoch 029/100 | Loss: 0.4038
# [BYOL] Epoch 030/100 | Loss: 0.4042
# [BYOL] Epoch 031/100 | Loss: 0.4025
# [BYOL] Epoch 032/100 | Loss: 0.3998
# [BYOL] Epoch 033/100 | Loss: 0.4018
# [BYOL] Epoch 034/100 | Loss: 0.4008
# [BYOL] Epoch 035/100 | Loss: 0.3999
# [BYOL] Epoch 036/100 | Loss: 0.3985
# [BYOL] Epoch 037/100 | Loss: 0.3969
# [BYOL] Epoch 038/100 | Loss: 0.3973
# [BYOL] Epoch 039/100 | Loss: 0.3952
# [BYOL] Epoch 040/100 | Loss: 0.3953
# [BYOL] Epoch 041/100 | Loss: 0.3949
# [BYOL] Epoch 042/100 | Loss: 0.3948
# [BYOL] Epoch 043/100 | Loss: 0.3929
# [BYOL] Epoch 044/100 | Loss: 0.3919
# [BYOL] Epoch 045/100 | Loss: 0.3894
# [BYOL] Epoch 046/100 | Loss: 0.3881
# [BYOL] Epoch 047/100 | Loss: 0.3893
# [BYOL] Epoch 048/100 | Loss: 0.3884
# [BYOL] Epoch 049/100 | Loss: 0.3876
# [BYOL] Epoch 050/100 | Loss: 0.3869
# [BYOL] Epoch 051/100 | Loss: 0.3869
# [BYOL] Epoch 052/100 | Loss: 0.3860
# [BYOL] Epoch 053/100 | Loss: 0.3864
# [BYOL] Epoch 054/100 | Loss: 0.3868
# [BYOL] Epoch 055/100 | Loss: 0.3858
# [BYOL] Epoch 056/100 | Loss: 0.3862
# [BYOL] Epoch 057/100 | Loss: 0.3843
# [BYOL] Epoch 058/100 | Loss: 0.3844
# [BYOL] Epoch 059/100 | Loss: 0.3854
# [BYOL] Epoch 060/100 | Loss: 0.3822
# [BYOL] Epoch 061/100 | Loss: 0.3850
# [BYOL] Epoch 062/100 | Loss: 0.3843
# [BYOL] Epoch 063/100 | Loss: 0.3841
# [BYOL] Epoch 064/100 | Loss: 0.3835
# [BYOL] Epoch 065/100 | Loss: 0.3835
# [BYOL] Epoch 066/100 | Loss: 0.3824
# [BYOL] Epoch 067/100 | Loss: 0.3834
# [BYOL] Epoch 068/100 | Loss: 0.3838
# [BYOL] Epoch 069/100 | Loss: 0.3837
# [BYOL] Epoch 070/100 | Loss: 0.3827
# [BYOL] Epoch 071/100 | Loss: 0.3824
# [BYOL] Epoch 072/100 | Loss: 0.3828
# [BYOL] Epoch 073/100 | Loss: 0.3826
# [BYOL] Epoch 074/100 | Loss: 0.3823
# [BYOL] Epoch 075/100 | Loss: 0.3825
# [BYOL] Epoch 076/100 | Loss: 0.3800
# [BYOL] Epoch 077/100 | Loss: 0.3829
# [BYOL] Epoch 078/100 | Loss: 0.3823
# [BYOL] Epoch 079/100 | Loss: 0.3831
# [BYOL] Epoch 080/100 | Loss: 0.3817
# [BYOL] Epoch 081/100 | Loss: 0.3817
# [BYOL] Epoch 082/100 | Loss: 0.3843
# [BYOL] Epoch 083/100 | Loss: 0.3815
# [BYOL] Epoch 084/100 | Loss: 0.3813
# [BYOL] Epoch 085/100 | Loss: 0.3823
# [BYOL] Epoch 086/100 | Loss: 0.3814
# [BYOL] Epoch 087/100 | Loss: 0.3785
# [BYOL] Epoch 088/100 | Loss: 0.3795
# [BYOL] Epoch 089/100 | Loss: 0.3798
# [BYOL] Epoch 090/100 | Loss: 0.3818
# [BYOL] Epoch 091/100 | Loss: 0.3811
# [BYOL] Epoch 092/100 | Loss: 0.3820
# [BYOL] Epoch 093/100 | Loss: 0.3818
# [BYOL] Epoch 094/100 | Loss: 0.3806
# [BYOL] Epoch 095/100 | Loss: 0.3809
# [BYOL] Epoch 096/100 | Loss: 0.3804
# [BYOL] Epoch 097/100 | Loss: 0.3800
# [BYOL] Epoch 098/100 | Loss: 0.3794
# [BYOL] Epoch 099/100 | Loss: 0.3809
# [BYOL] Epoch 100/100 | Loss: 0.3820
# [SimCLR] Epoch 001/100 | Loss: 4.6595
# [SimCLR] Epoch 002/100 | Loss: 4.4898
# [SimCLR] Epoch 003/100 | Loss: 4.4201
# [SimCLR] Epoch 004/100 | Loss: 4.3844
# [SimCLR] Epoch 005/100 | Loss: 4.3572
# [SimCLR] Epoch 006/100 | Loss: 4.3307
# [SimCLR] Epoch 007/100 | Loss: 4.3112
# [SimCLR] Epoch 008/100 | Loss: 4.2935
# [SimCLR] Epoch 009/100 | Loss: 4.2805
# [SimCLR] Epoch 010/100 | Loss: 4.2603
# [SimCLR] Epoch 011/100 | Loss: 4.2444
# [SimCLR] Epoch 012/100 | Loss: 4.2364
# [SimCLR] Epoch 013/100 | Loss: 4.2233
# [SimCLR] Epoch 014/100 | Loss: 4.2128
# [SimCLR] Epoch 015/100 | Loss: 4.2077
# [SimCLR] Epoch 016/100 | Loss: 4.1966
# [SimCLR] Epoch 017/100 | Loss: 4.1861
# [SimCLR] Epoch 018/100 | Loss: 4.1822
# [SimCLR] Epoch 019/100 | Loss: 4.1764
# [SimCLR] Epoch 020/100 | Loss: 4.1673
# [SimCLR] Epoch 021/100 | Loss: 4.1660
# [SimCLR] Epoch 022/100 | Loss: 4.1566
# [SimCLR] Epoch 023/100 | Loss: 4.1540
# [SimCLR] Epoch 024/100 | Loss: 4.1472
# [SimCLR] Epoch 025/100 | Loss: 4.1441
# [SimCLR] Epoch 026/100 | Loss: 4.1380
# [SimCLR] Epoch 027/100 | Loss: 4.1368
# [SimCLR] Epoch 028/100 | Loss: 4.1304
# [SimCLR] Epoch 029/100 | Loss: 4.1279
# [SimCLR] Epoch 030/100 | Loss: 4.1214
# [SimCLR] Epoch 031/100 | Loss: 4.1166
# [SimCLR] Epoch 032/100 | Loss: 4.1150
# [SimCLR] Epoch 033/100 | Loss: 4.1107
# [SimCLR] Epoch 034/100 | Loss: 4.1083
# [SimCLR] Epoch 035/100 | Loss: 4.1035
# [SimCLR] Epoch 036/100 | Loss: 4.1048
# [SimCLR] Epoch 037/100 | Loss: 4.0989
# [SimCLR] Epoch 038/100 | Loss: 4.0964
# [SimCLR] Epoch 039/100 | Loss: 4.0930
# [SimCLR] Epoch 040/100 | Loss: 4.0908
# [SimCLR] Epoch 041/100 | Loss: 4.0849
# [SimCLR] Epoch 042/100 | Loss: 4.0840
# [SimCLR] Epoch 043/100 | Loss: 4.0838
# [SimCLR] Epoch 044/100 | Loss: 4.0797
# [SimCLR] Epoch 045/100 | Loss: 4.0800
# [SimCLR] Epoch 046/100 | Loss: 4.0767
# [SimCLR] Epoch 047/100 | Loss: 4.0741
# [SimCLR] Epoch 048/100 | Loss: 4.0706
# [SimCLR] Epoch 049/100 | Loss: 4.0680
# [SimCLR] Epoch 050/100 | Loss: 4.0678
# [SimCLR] Epoch 051/100 | Loss: 4.0656
# [SimCLR] Epoch 052/100 | Loss: 4.0628
# [SimCLR] Epoch 053/100 | Loss: 4.0630
# [SimCLR] Epoch 054/100 | Loss: 4.0603
# [SimCLR] Epoch 055/100 | Loss: 4.0564
# [SimCLR] Epoch 056/100 | Loss: 4.0566
# [SimCLR] Epoch 057/100 | Loss: 4.0550
# [SimCLR] Epoch 058/100 | Loss: 4.0533
# [SimCLR] Epoch 059/100 | Loss: 4.0494
# [SimCLR] Epoch 060/100 | Loss: 4.0484
# [SimCLR] Epoch 061/100 | Loss: 4.0472
# [SimCLR] Epoch 062/100 | Loss: 4.0445
# [SimCLR] Epoch 063/100 | Loss: 4.0452
# [SimCLR] Epoch 064/100 | Loss: 4.0403
# [SimCLR] Epoch 065/100 | Loss: 4.0406
# [SimCLR] Epoch 066/100 | Loss: 4.0375
# [SimCLR] Epoch 067/100 | Loss: 4.0378
# [SimCLR] Epoch 068/100 | Loss: 4.0369
# [SimCLR] Epoch 069/100 | Loss: 4.0351
# [SimCLR] Epoch 070/100 | Loss: 4.0321
# [SimCLR] Epoch 071/100 | Loss: 4.0329
# [SimCLR] Epoch 072/100 | Loss: 4.0334
# [SimCLR] Epoch 073/100 | Loss: 4.0287
# [SimCLR] Epoch 074/100 | Loss: 4.0267
# [SimCLR] Epoch 075/100 | Loss: 4.0283
# [SimCLR] Epoch 076/100 | Loss: 4.0265
# [SimCLR] Epoch 077/100 | Loss: 4.0251
# [SimCLR] Epoch 078/100 | Loss: 4.0220
# [SimCLR] Epoch 079/100 | Loss: 4.0234
# [SimCLR] Epoch 080/100 | Loss: 4.0213
# [SimCLR] Epoch 081/100 | Loss: 4.0214
# [SimCLR] Epoch 082/100 | Loss: 4.0189
# [SimCLR] Epoch 083/100 | Loss: 4.0182
# [SimCLR] Epoch 084/100 | Loss: 4.0165
# [SimCLR] Epoch 085/100 | Loss: 4.0158
# [SimCLR] Epoch 086/100 | Loss: 4.0124
# [SimCLR] Epoch 087/100 | Loss: 4.0141
# [SimCLR] Epoch 088/100 | Loss: 4.0131
# [SimCLR] Epoch 089/100 | Loss: 4.0115
# [SimCLR] Epoch 090/100 | Loss: 4.0108
# [SimCLR] Epoch 091/100 | Loss: 4.0092
# [SimCLR] Epoch 092/100 | Loss: 4.0096
# [SimCLR] Epoch 093/100 | Loss: 4.0085
# [SimCLR] Epoch 094/100 | Loss: 4.0059
# [SimCLR] Epoch 095/100 | Loss: 4.0054
# [SimCLR] Epoch 096/100 | Loss: 4.0065
# [SimCLR] Epoch 097/100 | Loss: 4.0054
# [SimCLR] Epoch 098/100 | Loss: 4.0017
# [SimCLR] Epoch 099/100 | Loss: 4.0059
# [SimCLR] Epoch 100/100 | Loss: 4.0015
#
# Seed 6 finished in 150.42 minutes.
#
# Per-Seed Results:
#    Seed  BYOL_Jacobian  SimCLR_Jacobian   BYOL_Aug  SimCLR_Aug  BYOL_Noise  \
# 0     4      54.996993        77.271474  14.105726   16.429427   13.775838
# 1     5      54.381964        78.959885  13.554992   17.790437   12.826300
# 2     6      58.443736        78.696295  14.912739   17.401464   12.940673
#
#    SimCLR_Noise  BYOL_Acc  SimCLR_Acc  Seed_Time_Min
# 0     18.430941    0.6446      0.6901     155.298891
# 1     17.758799    0.6488      0.6929     154.014547
# 2     18.105796    0.6491      0.6805     150.422207
#
# Mean Across Seeds:
# Seed                 5.000000
# BYOL_Jacobian       55.940898
# SimCLR_Jacobian     78.309218
# BYOL_Aug            14.191152
# SimCLR_Aug          17.207109
# BYOL_Noise          13.180937
# SimCLR_Noise        18.098512
# BYOL_Acc             0.647500
# SimCLR_Acc           0.687833
# Seed_Time_Min      153.245215
# dtype: float64
#
# Std Across Seeds:
# Seed               1.000000
# BYOL_Jacobian      2.189227
# SimCLR_Jacobian    0.908325
# BYOL_Aug           0.682893
# SimCLR_Aug         0.701011
# BYOL_Noise         0.518363
# SimCLR_Noise       0.336130
# BYOL_Acc           0.002516
# SimCLR_Acc         0.006503
# Seed_Time_Min      2.527729
# dtype: float64
#
# Total Experiment Time: 459.74 minutes.

# %%
results_df.to_csv("/kaggle/working/results.csv", index=False)
