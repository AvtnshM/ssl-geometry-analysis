# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import numpy as np
import random
import pandas as pd
import time
import scipy.stats as stats

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def set_seed(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
# Out:
# Device: cuda

# %%
class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform
    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)

ssl_base_transform = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2,1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=ssl_transform
)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=T.ToTensor()
)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)
# Out:
# 100%|██████████| 170M/170M [05:10<00:00, 548kB/s]

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        backbone = resnet18(weights=None)
        backbone.fc = nn.Identity()
        self.backbone = backbone
    def forward(self, x):
        return self.backbone(x)

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, hidden_dim=2048, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )
    def forward(self, x):
        return self.net(x)

class BYOL(nn.Module):
    def __init__(self):
        super().__init__()
        self.online_encoder = Encoder()
        self.online_projector = MLP(512)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder = Encoder()
        self.target_projector = MLP(512)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for o, t in zip(self.online_encoder.parameters(),
                        self.target_encoder.parameters()):
            t.data = tau * t.data + (1 - tau) * o.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(
            self.online_projector(self.online_encoder(x1))
        )

        with torch.no_grad():
            t2 = self.target_projector(
                self.target_encoder(x2)
            )

        loss = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        return loss.mean()

# %%
class SimCLR(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.projector = MLP(512)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)

def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)

    sim = torch.mm(z, z.t()) / temperature
    mask = torch.eye(2*N, device=z.device).bool()
    sim.masked_fill_(mask, -9e15)

    positives = torch.cat([
        torch.arange(N,2*N),
        torch.arange(0,N)
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
def jacobian_penalty(model, x):
    x = x.clone().detach().requires_grad_(True)
    z = model(x)

    v = torch.randn_like(z)

    Jv = torch.autograd.grad(
        outputs=z,
        inputs=x,
        grad_outputs=v,
        create_graph=True
    )[0]

    return Jv.pow(2).sum(dim=[1,2,3]).mean()

# %%
def train_byol(model, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            loss = model(x1,x2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            model.update_target()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[BYOL] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.online_encoder


def train_simclr(model, epochs=100, lambda_jac=0.0):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            z1 = model(x1)
            z2 = model(x2)
            loss = nt_xent_loss(z1,z2)

            if lambda_jac > 0:
                jac = jacobian_penalty(model, x1)
                loss = loss + lambda_jac * jac

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[SimCLR] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.encoder

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(512, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    return correct / total

# %%
# =========================================================
# Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
])


def jacobian_frobenius(model, x):
    model.eval()
    x = x.clone().detach().requires_grad_(True)

    y = model(x)

    v = torch.randn_like(y)

    Jv = torch.autograd.grad(
        outputs=y,
        inputs=x,
        grad_outputs=v,
        create_graph=False,
        retain_graph=False
    )[0]

    # Proper per-sample Frobenius estimate
    per_sample = Jv.pow(2).flatten(1).sum(dim=1)

    return torch.sqrt(per_sample.mean())


def compute_metrics(encoder, loader):
    encoder = encoder.to(device)
    encoder.eval()

    jac_vals = []
    aug_vals = []
    noise_vals = []

    for i, (x, _) in enumerate(loader):
        if i == 5:  # limit batches
            break

        x = x.to(device)

        # ---- Jacobian ----
        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # ---- Augmentation Sensitivity ----
        x_aug = torch.stack([
            tensor_aug(img.cpu()) for img in x
        ]).to(device)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        # ---- Noise Sensitivity ----
        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x + noise)
            noise_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

    return (
        np.mean(jac_vals),
        np.mean(aug_vals),
        np.mean(noise_vals)
    )

# %%
# =========================================================
# Supervised Data (for Linear Probe)
# =========================================================

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=False,
    transform=T.ToTensor()
)

supervised_test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=False,
    transform=T.ToTensor()
)

supervised_train_loader = DataLoader(
    supervised_train_dataset,
    batch_size=128,
    shuffle=True,
    num_workers=2
)

supervised_test_loader = DataLoader(
    supervised_test_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=2
)

print("Supervised loaders ready.")
# Out:
# Supervised loaders ready.

# %%
import os

# =========================================================
# CONFIG
# =========================================================

csv_path = "/kaggle/working/byol_simclr_results.csv"
target_seeds = [4, ]  
# =========================================================
# RESUME LOGIC
# =========================================================

if os.path.exists(csv_path):
    existing_df = pd.read_csv(csv_path)
    completed_seeds = set(existing_df["Seed"].unique())
    all_results = existing_df.to_dict("records")
    print("Loaded existing results. Completed seeds:", completed_seeds)
else:
    completed_seeds = set()
    all_results = []
    print("No existing CSV found. Starting fresh.")

seeds = [s for s in target_seeds if s not in completed_seeds]

print("Seeds to run now:", seeds)

global_start = time.time()

# =========================================================
# MAIN LOOP
# =========================================================

for seed in seeds:

    print("\n====================================")
    print(f"Running Seed: {seed}")
    print("====================================")

    seed_start = time.time()
    set_seed(seed)

    # ------------------------
    # Train Models
    # ------------------------

    byol_encoder = train_byol(BYOL(), epochs=100)

    simclr_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=0.0
    )

    simclr_jac_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=1e-3
    )

    # ------------------------
    # Compute Metrics
    # ------------------------

    byol_metrics = compute_metrics(byol_encoder, test_loader)
    simclr_metrics = compute_metrics(simclr_encoder, test_loader)
    simclr_jac_metrics = compute_metrics(simclr_jac_encoder, test_loader)

    # ------------------------
    # Linear Probe
    # ------------------------

    byol_acc = train_probe(
        byol_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_acc = train_probe(
        simclr_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_jac_acc = train_probe(
        simclr_jac_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    # ------------------------
    # Store Results
    # ------------------------

    seed_results = [
        {
            "Seed": seed,
            "Method": "BYOL",
            "Jacobian": byol_metrics[0],
            "Aug_Sensitivity": byol_metrics[1],
            "Noise_Sensitivity": byol_metrics[2],
            "Linear_Probe_Acc": byol_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR",
            "Jacobian": simclr_metrics[0],
            "Aug_Sensitivity": simclr_metrics[1],
            "Noise_Sensitivity": simclr_metrics[2],
            "Linear_Probe_Acc": simclr_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR+Jac",
            "Jacobian": simclr_jac_metrics[0],
            "Aug_Sensitivity": simclr_jac_metrics[1],
            "Noise_Sensitivity": simclr_jac_metrics[2],
            "Linear_Probe_Acc": simclr_jac_acc
        }
    ]

    all_results.extend(seed_results)

    # ------------------------
    # SAVE AFTER EACH SEED
    # ------------------------

    results_df = pd.DataFrame(all_results)
    results_df.to_csv(csv_path, index=False)

    print("Saved results to:", csv_path)

    # ------------------------
    # Running Summary
    # ------------------------

    summary = results_df.groupby("Method").mean(numeric_only=True)
    print("\nRunning Mean Summary:")
    print(summary)

    # ------------------------
    # GPU Cleanup
    # ------------------------

    del byol_encoder, simclr_encoder, simclr_jac_encoder
    torch.cuda.empty_cache()

    seed_time = (time.time() - seed_start) / 60
    print(f"\nSeed {seed} finished in {seed_time:.2f} minutes")

# =========================================================
# FINAL SUMMARY
# =========================================================

final_df = pd.read_csv(csv_path)

print("\n================ FINAL RESULTS ================")
print(final_df)

total_time = (time.time() - global_start) / 60
print(f"\nTotal experiment time (this session): {total_time:.2f} minutes")
# Out:
# No existing CSV found. Starting fresh.
# Seeds to run now: [4]
#
# ====================================
# Running Seed: 4
# ====================================
# [BYOL] 001/100 | Loss: 0.7151 | Epoch Time: 0.84m | Total Time: 0.84m
# [BYOL] 002/100 | Loss: 0.5479 | Epoch Time: 0.77m | Total Time: 1.61m
# [BYOL] 003/100 | Loss: 0.5067 | Epoch Time: 0.78m | Total Time: 2.39m
# [BYOL] 004/100 | Loss: 0.4791 | Epoch Time: 0.77m | Total Time: 3.16m
# [BYOL] 005/100 | Loss: 0.4586 | Epoch Time: 0.77m | Total Time: 3.93m
# [BYOL] 006/100 | Loss: 0.4482 | Epoch Time: 0.76m | Total Time: 4.69m
# [BYOL] 007/100 | Loss: 0.4403 | Epoch Time: 0.78m | Total Time: 5.47m
# [BYOL] 008/100 | Loss: 0.4327 | Epoch Time: 0.77m | Total Time: 6.24m
# [BYOL] 009/100 | Loss: 0.4260 | Epoch Time: 0.77m | Total Time: 7.01m
# [BYOL] 010/100 | Loss: 0.4200 | Epoch Time: 0.77m | Total Time: 7.78m
# [BYOL] 011/100 | Loss: 0.4134 | Epoch Time: 0.76m | Total Time: 8.54m
# [BYOL] 012/100 | Loss: 0.4104 | Epoch Time: 0.77m | Total Time: 9.31m
# [BYOL] 013/100 | Loss: 0.4121 | Epoch Time: 0.77m | Total Time: 10.08m
# [BYOL] 014/100 | Loss: 0.4080 | Epoch Time: 0.77m | Total Time: 10.85m
# [BYOL] 015/100 | Loss: 0.4084 | Epoch Time: 0.77m | Total Time: 11.63m
# [BYOL] 016/100 | Loss: 0.4076 | Epoch Time: 0.76m | Total Time: 12.39m
# [BYOL] 017/100 | Loss: 0.4047 | Epoch Time: 0.77m | Total Time: 13.16m
# [BYOL] 018/100 | Loss: 0.4058 | Epoch Time: 0.76m | Total Time: 13.92m
# [BYOL] 019/100 | Loss: 0.4042 | Epoch Time: 0.76m | Total Time: 14.68m
# [BYOL] 020/100 | Loss: 0.4037 | Epoch Time: 0.76m | Total Time: 15.44m
# [BYOL] 021/100 | Loss: 0.4046 | Epoch Time: 0.77m | Total Time: 16.21m
# [BYOL] 022/100 | Loss: 0.4029 | Epoch Time: 0.77m | Total Time: 16.98m
# [BYOL] 023/100 | Loss: 0.4015 | Epoch Time: 0.76m | Total Time: 17.74m
# [BYOL] 024/100 | Loss: 0.4008 | Epoch Time: 0.76m | Total Time: 18.49m
# [BYOL] 025/100 | Loss: 0.4016 | Epoch Time: 0.76m | Total Time: 19.26m
# [BYOL] 026/100 | Loss: 0.4026 | Epoch Time: 0.76m | Total Time: 20.02m
# [BYOL] 027/100 | Loss: 0.4003 | Epoch Time: 0.77m | Total Time: 20.79m
# [BYOL] 028/100 | Loss: 0.4007 | Epoch Time: 0.76m | Total Time: 21.55m
# [BYOL] 029/100 | Loss: 0.3984 | Epoch Time: 0.76m | Total Time: 22.31m
# [BYOL] 030/100 | Loss: 0.3975 | Epoch Time: 0.75m | Total Time: 23.07m
# [BYOL] 031/100 | Loss: 0.3956 | Epoch Time: 0.77m | Total Time: 23.84m
# [BYOL] 032/100 | Loss: 0.3960 | Epoch Time: 0.75m | Total Time: 24.59m
# [BYOL] 033/100 | Loss: 0.3949 | Epoch Time: 0.77m | Total Time: 25.36m
# [BYOL] 034/100 | Loss: 0.3964 | Epoch Time: 0.76m | Total Time: 26.12m
# [BYOL] 035/100 | Loss: 0.3931 | Epoch Time: 0.75m | Total Time: 26.88m
# [BYOL] 036/100 | Loss: 0.3924 | Epoch Time: 0.75m | Total Time: 27.63m
# [BYOL] 037/100 | Loss: 0.3917 | Epoch Time: 0.75m | Total Time: 28.39m
# [BYOL] 038/100 | Loss: 0.3911 | Epoch Time: 0.75m | Total Time: 29.14m
# [BYOL] 039/100 | Loss: 0.3884 | Epoch Time: 0.76m | Total Time: 29.90m
# [BYOL] 040/100 | Loss: 0.3873 | Epoch Time: 0.75m | Total Time: 30.64m
# [BYOL] 041/100 | Loss: 0.3858 | Epoch Time: 0.76m | Total Time: 31.40m
# [BYOL] 042/100 | Loss: 0.3883 | Epoch Time: 0.77m | Total Time: 32.17m
# [BYOL] 043/100 | Loss: 0.3876 | Epoch Time: 0.75m | Total Time: 32.92m
# [BYOL] 044/100 | Loss: 0.3886 | Epoch Time: 0.76m | Total Time: 33.67m
# [BYOL] 045/100 | Loss: 0.3877 | Epoch Time: 0.76m | Total Time: 34.43m
# [BYOL] 046/100 | Loss: 0.3870 | Epoch Time: 0.76m | Total Time: 35.19m
# [BYOL] 047/100 | Loss: 0.3874 | Epoch Time: 0.75m | Total Time: 35.94m
# [BYOL] 048/100 | Loss: 0.3878 | Epoch Time: 0.75m | Total Time: 36.69m
# [BYOL] 049/100 | Loss: 0.3878 | Epoch Time: 0.75m | Total Time: 37.44m
# [BYOL] 050/100 | Loss: 0.3902 | Epoch Time: 0.75m | Total Time: 38.19m
# [BYOL] 051/100 | Loss: 0.3857 | Epoch Time: 0.74m | Total Time: 38.93m
# [BYOL] 052/100 | Loss: 0.3872 | Epoch Time: 0.75m | Total Time: 39.68m
# [BYOL] 053/100 | Loss: 0.3867 | Epoch Time: 0.75m | Total Time: 40.43m
# [BYOL] 054/100 | Loss: 0.3864 | Epoch Time: 0.74m | Total Time: 41.18m
# [BYOL] 055/100 | Loss: 0.3850 | Epoch Time: 0.75m | Total Time: 41.93m
# [BYOL] 056/100 | Loss: 0.3856 | Epoch Time: 0.76m | Total Time: 42.69m
# [BYOL] 057/100 | Loss: 0.3854 | Epoch Time: 0.75m | Total Time: 43.45m
# [BYOL] 058/100 | Loss: 0.3854 | Epoch Time: 0.75m | Total Time: 44.19m
# [BYOL] 059/100 | Loss: 0.3867 | Epoch Time: 0.75m | Total Time: 44.95m
# [BYOL] 060/100 | Loss: 0.3872 | Epoch Time: 0.77m | Total Time: 45.72m
# [BYOL] 061/100 | Loss: 0.3873 | Epoch Time: 0.76m | Total Time: 46.49m
# [BYOL] 062/100 | Loss: 0.3855 | Epoch Time: 0.77m | Total Time: 47.26m
# [BYOL] 063/100 | Loss: 0.3830 | Epoch Time: 0.76m | Total Time: 48.02m
# [BYOL] 064/100 | Loss: 0.3849 | Epoch Time: 0.75m | Total Time: 48.76m
# [BYOL] 065/100 | Loss: 0.3848 | Epoch Time: 0.75m | Total Time: 49.51m
# [BYOL] 066/100 | Loss: 0.3855 | Epoch Time: 0.76m | Total Time: 50.27m
# [BYOL] 067/100 | Loss: 0.3850 | Epoch Time: 0.75m | Total Time: 51.02m
# [BYOL] 068/100 | Loss: 0.3821 | Epoch Time: 0.75m | Total Time: 51.77m
# [BYOL] 069/100 | Loss: 0.3825 | Epoch Time: 0.75m | Total Time: 52.52m
# [BYOL] 070/100 | Loss: 0.3814 | Epoch Time: 0.75m | Total Time: 53.27m
# [BYOL] 071/100 | Loss: 0.3827 | Epoch Time: 0.76m | Total Time: 54.03m
# [BYOL] 072/100 | Loss: 0.3823 | Epoch Time: 0.75m | Total Time: 54.78m
# [BYOL] 073/100 | Loss: 0.3843 | Epoch Time: 0.77m | Total Time: 55.55m
# [BYOL] 074/100 | Loss: 0.3815 | Epoch Time: 0.80m | Total Time: 56.35m
# [BYOL] 075/100 | Loss: 0.3808 | Epoch Time: 0.81m | Total Time: 57.16m
# [BYOL] 076/100 | Loss: 0.3797 | Epoch Time: 0.83m | Total Time: 57.98m
# [BYOL] 077/100 | Loss: 0.3810 | Epoch Time: 0.84m | Total Time: 58.83m
# [BYOL] 078/100 | Loss: 0.3789 | Epoch Time: 0.83m | Total Time: 59.65m
# [BYOL] 079/100 | Loss: 0.3798 | Epoch Time: 0.82m | Total Time: 60.47m
# [BYOL] 080/100 | Loss: 0.3802 | Epoch Time: 0.82m | Total Time: 61.29m
# [BYOL] 081/100 | Loss: 0.3804 | Epoch Time: 0.82m | Total Time: 62.11m
# [BYOL] 082/100 | Loss: 0.3804 | Epoch Time: 0.81m | Total Time: 62.92m
# [BYOL] 083/100 | Loss: 0.3783 | Epoch Time: 0.82m | Total Time: 63.75m
# [BYOL] 084/100 | Loss: 0.3786 | Epoch Time: 0.86m | Total Time: 64.61m
# [BYOL] 085/100 | Loss: 0.3767 | Epoch Time: 0.87m | Total Time: 65.48m
# [BYOL] 086/100 | Loss: 0.3776 | Epoch Time: 0.86m | Total Time: 66.34m
# [BYOL] 087/100 | Loss: 0.3781 | Epoch Time: 0.86m | Total Time: 67.20m
# [BYOL] 088/100 | Loss: 0.3760 | Epoch Time: 0.86m | Total Time: 68.06m
# [BYOL] 089/100 | Loss: 0.3754 | Epoch Time: 0.86m | Total Time: 68.92m
# [BYOL] 090/100 | Loss: 0.3759 | Epoch Time: 0.86m | Total Time: 69.78m
# [BYOL] 091/100 | Loss: 0.3764 | Epoch Time: 0.86m | Total Time: 70.64m
# [BYOL] 092/100 | Loss: 0.3727 | Epoch Time: 0.87m | Total Time: 71.51m
# [BYOL] 093/100 | Loss: 0.3739 | Epoch Time: 0.87m | Total Time: 72.37m
# [BYOL] 094/100 | Loss: 0.3749 | Epoch Time: 0.85m | Total Time: 73.23m
# [BYOL] 095/100 | Loss: 0.3740 | Epoch Time: 0.86m | Total Time: 74.08m
# [BYOL] 096/100 | Loss: 0.3742 | Epoch Time: 0.85m | Total Time: 74.94m
# [BYOL] 097/100 | Loss: 0.3754 | Epoch Time: 0.86m | Total Time: 75.79m
# [BYOL] 098/100 | Loss: 0.3741 | Epoch Time: 0.85m | Total Time: 76.65m
# [BYOL] 099/100 | Loss: 0.3731 | Epoch Time: 0.86m | Total Time: 77.50m
# [BYOL] 100/100 | Loss: 0.3738 | Epoch Time: 0.85m | Total Time: 78.35m
# [SimCLR] 001/100 | Loss: 4.6605 | Epoch Time: 0.91m | Total Time: 0.91m
# [SimCLR] 002/100 | Loss: 4.4814 | Epoch Time: 0.87m | Total Time: 1.78m
# [SimCLR] 003/100 | Loss: 4.4218 | Epoch Time: 0.86m | Total Time: 2.65m
# [SimCLR] 004/100 | Loss: 4.3870 | Epoch Time: 0.88m | Total Time: 3.53m
# [SimCLR] 005/100 | Loss: 4.3557 | Epoch Time: 0.86m | Total Time: 4.39m
# [SimCLR] 006/100 | Loss: 4.3358 | Epoch Time: 0.87m | Total Time: 5.26m
# [SimCLR] 007/100 | Loss: 4.3140 | Epoch Time: 0.88m | Total Time: 6.14m
# [SimCLR] 008/100 | Loss: 4.2968 | Epoch Time: 0.87m | Total Time: 7.02m
# [SimCLR] 009/100 | Loss: 4.2755 | Epoch Time: 0.86m | Total Time: 7.87m
# [SimCLR] 010/100 | Loss: 4.2635 | Epoch Time: 0.87m | Total Time: 8.74m
# [SimCLR] 011/100 | Loss: 4.2478 | Epoch Time: 0.87m | Total Time: 9.62m
# [SimCLR] 012/100 | Loss: 4.2368 | Epoch Time: 0.86m | Total Time: 10.48m
# [SimCLR] 013/100 | Loss: 4.2262 | Epoch Time: 0.88m | Total Time: 11.36m
# [SimCLR] 014/100 | Loss: 4.2177 | Epoch Time: 0.88m | Total Time: 12.24m
# [SimCLR] 015/100 | Loss: 4.2048 | Epoch Time: 0.87m | Total Time: 13.11m
# [SimCLR] 016/100 | Loss: 4.1990 | Epoch Time: 0.88m | Total Time: 14.00m
# [SimCLR] 017/100 | Loss: 4.1861 | Epoch Time: 0.88m | Total Time: 14.88m
# [SimCLR] 018/100 | Loss: 4.1832 | Epoch Time: 0.88m | Total Time: 15.76m
# [SimCLR] 019/100 | Loss: 4.1743 | Epoch Time: 0.88m | Total Time: 16.64m
# [SimCLR] 020/100 | Loss: 4.1682 | Epoch Time: 0.87m | Total Time: 17.51m
# [SimCLR] 021/100 | Loss: 4.1590 | Epoch Time: 0.86m | Total Time: 18.37m
# [SimCLR] 022/100 | Loss: 4.1541 | Epoch Time: 0.87m | Total Time: 19.24m
# [SimCLR] 023/100 | Loss: 4.1525 | Epoch Time: 0.86m | Total Time: 20.10m
# [SimCLR] 024/100 | Loss: 4.1426 | Epoch Time: 0.87m | Total Time: 20.96m
# [SimCLR] 025/100 | Loss: 4.1443 | Epoch Time: 0.88m | Total Time: 21.84m
# [SimCLR] 026/100 | Loss: 4.1385 | Epoch Time: 0.88m | Total Time: 22.72m
# [SimCLR] 027/100 | Loss: 4.1324 | Epoch Time: 0.88m | Total Time: 23.60m
# [SimCLR] 028/100 | Loss: 4.1285 | Epoch Time: 0.91m | Total Time: 24.51m
# [SimCLR] 029/100 | Loss: 4.1244 | Epoch Time: 0.89m | Total Time: 25.40m
# [SimCLR] 030/100 | Loss: 4.1206 | Epoch Time: 0.89m | Total Time: 26.29m
# [SimCLR] 031/100 | Loss: 4.1165 | Epoch Time: 0.89m | Total Time: 27.18m
# [SimCLR] 032/100 | Loss: 4.1160 | Epoch Time: 0.89m | Total Time: 28.07m
# [SimCLR] 033/100 | Loss: 4.1101 | Epoch Time: 0.88m | Total Time: 28.95m
# [SimCLR] 034/100 | Loss: 4.1108 | Epoch Time: 0.89m | Total Time: 29.84m
# [SimCLR] 035/100 | Loss: 4.1057 | Epoch Time: 0.91m | Total Time: 30.75m
# [SimCLR] 036/100 | Loss: 4.1041 | Epoch Time: 0.91m | Total Time: 31.65m
# [SimCLR] 037/100 | Loss: 4.1007 | Epoch Time: 0.92m | Total Time: 32.57m
# [SimCLR] 038/100 | Loss: 4.0973 | Epoch Time: 0.90m | Total Time: 33.47m
# [SimCLR] 039/100 | Loss: 4.0951 | Epoch Time: 0.91m | Total Time: 34.38m
# [SimCLR] 040/100 | Loss: 4.0934 | Epoch Time: 0.90m | Total Time: 35.28m
# [SimCLR] 041/100 | Loss: 4.0882 | Epoch Time: 0.90m | Total Time: 36.18m
# [SimCLR] 042/100 | Loss: 4.0898 | Epoch Time: 0.90m | Total Time: 37.08m
# [SimCLR] 043/100 | Loss: 4.0863 | Epoch Time: 0.91m | Total Time: 37.99m
# [SimCLR] 044/100 | Loss: 4.0809 | Epoch Time: 0.90m | Total Time: 38.89m
# [SimCLR] 045/100 | Loss: 4.0791 | Epoch Time: 0.90m | Total Time: 39.79m
# [SimCLR] 046/100 | Loss: 4.0753 | Epoch Time: 0.90m | Total Time: 40.70m
# [SimCLR] 047/100 | Loss: 4.0734 | Epoch Time: 0.91m | Total Time: 41.61m
# [SimCLR] 048/100 | Loss: 4.0703 | Epoch Time: 0.91m | Total Time: 42.52m
# [SimCLR] 049/100 | Loss: 4.0668 | Epoch Time: 0.90m | Total Time: 43.42m
# [SimCLR] 050/100 | Loss: 4.0655 | Epoch Time: 0.92m | Total Time: 44.33m
# [SimCLR] 051/100 | Loss: 4.0674 | Epoch Time: 0.91m | Total Time: 45.24m
# [SimCLR] 052/100 | Loss: 4.0626 | Epoch Time: 0.88m | Total Time: 46.12m
# [SimCLR] 053/100 | Loss: 4.0627 | Epoch Time: 0.88m | Total Time: 47.01m
# [SimCLR] 054/100 | Loss: 4.0607 | Epoch Time: 0.90m | Total Time: 47.91m
# [SimCLR] 055/100 | Loss: 4.0597 | Epoch Time: 0.89m | Total Time: 48.80m
# [SimCLR] 056/100 | Loss: 4.0551 | Epoch Time: 0.88m | Total Time: 49.69m
# [SimCLR] 057/100 | Loss: 4.0544 | Epoch Time: 0.89m | Total Time: 50.57m
# [SimCLR] 058/100 | Loss: 4.0511 | Epoch Time: 0.87m | Total Time: 51.44m
# [SimCLR] 059/100 | Loss: 4.0502 | Epoch Time: 0.87m | Total Time: 52.31m
# [SimCLR] 060/100 | Loss: 4.0458 | Epoch Time: 0.89m | Total Time: 53.20m
# [SimCLR] 061/100 | Loss: 4.0479 | Epoch Time: 0.87m | Total Time: 54.07m
# [SimCLR] 062/100 | Loss: 4.0430 | Epoch Time: 0.88m | Total Time: 54.95m
# [SimCLR] 063/100 | Loss: 4.0433 | Epoch Time: 0.88m | Total Time: 55.83m
# [SimCLR] 064/100 | Loss: 4.0450 | Epoch Time: 0.87m | Total Time: 56.70m
# [SimCLR] 065/100 | Loss: 4.0385 | Epoch Time: 0.86m | Total Time: 57.56m
# [SimCLR] 066/100 | Loss: 4.0409 | Epoch Time: 0.84m | Total Time: 58.40m
# [SimCLR] 067/100 | Loss: 4.0370 | Epoch Time: 0.84m | Total Time: 59.24m
# [SimCLR] 068/100 | Loss: 4.0373 | Epoch Time: 0.87m | Total Time: 60.11m
# [SimCLR] 069/100 | Loss: 4.0337 | Epoch Time: 0.88m | Total Time: 60.99m
# [SimCLR] 070/100 | Loss: 4.0334 | Epoch Time: 0.89m | Total Time: 61.88m
# [SimCLR] 071/100 | Loss: 4.0332 | Epoch Time: 0.86m | Total Time: 62.75m
# [SimCLR] 072/100 | Loss: 4.0307 | Epoch Time: 0.90m | Total Time: 63.65m
# [SimCLR] 073/100 | Loss: 4.0312 | Epoch Time: 0.86m | Total Time: 64.51m
# [SimCLR] 074/100 | Loss: 4.0303 | Epoch Time: 0.87m | Total Time: 65.38m
# [SimCLR] 075/100 | Loss: 4.0271 | Epoch Time: 0.86m | Total Time: 66.24m
# [SimCLR] 076/100 | Loss: 4.0289 | Epoch Time: 0.88m | Total Time: 67.11m
# [SimCLR] 077/100 | Loss: 4.0241 | Epoch Time: 0.87m | Total Time: 67.99m
# [SimCLR] 078/100 | Loss: 4.0229 | Epoch Time: 0.89m | Total Time: 68.87m
# [SimCLR] 079/100 | Loss: 4.0238 | Epoch Time: 0.88m | Total Time: 69.76m
# [SimCLR] 080/100 | Loss: 4.0214 | Epoch Time: 0.88m | Total Time: 70.64m
# [SimCLR] 081/100 | Loss: 4.0216 | Epoch Time: 0.89m | Total Time: 71.52m
# [SimCLR] 082/100 | Loss: 4.0175 | Epoch Time: 0.90m | Total Time: 72.43m
# [SimCLR] 083/100 | Loss: 4.0187 | Epoch Time: 0.90m | Total Time: 73.33m
# [SimCLR] 084/100 | Loss: 4.0162 | Epoch Time: 0.89m | Total Time: 74.22m
# [SimCLR] 085/100 | Loss: 4.0161 | Epoch Time: 0.87m | Total Time: 75.09m
# [SimCLR] 086/100 | Loss: 4.0136 | Epoch Time: 0.84m | Total Time: 75.93m
# [SimCLR] 087/100 | Loss: 4.0136 | Epoch Time: 0.83m | Total Time: 76.76m
# [SimCLR] 088/100 | Loss: 4.0120 | Epoch Time: 0.83m | Total Time: 77.60m
# [SimCLR] 089/100 | Loss: 4.0124 | Epoch Time: 0.84m | Total Time: 78.43m
# [SimCLR] 090/100 | Loss: 4.0113 | Epoch Time: 0.83m | Total Time: 79.27m
# [SimCLR] 091/100 | Loss: 4.0115 | Epoch Time: 0.84m | Total Time: 80.10m
# [SimCLR] 092/100 | Loss: 4.0111 | Epoch Time: 0.84m | Total Time: 80.94m
# [SimCLR] 093/100 | Loss: 4.0078 | Epoch Time: 0.83m | Total Time: 81.77m
# [SimCLR] 094/100 | Loss: 4.0068 | Epoch Time: 0.83m | Total Time: 82.60m
# [SimCLR] 095/100 | Loss: 4.0075 | Epoch Time: 0.83m | Total Time: 83.44m
# [SimCLR] 096/100 | Loss: 4.0064 | Epoch Time: 0.84m | Total Time: 84.27m
# [SimCLR] 097/100 | Loss: 4.0070 | Epoch Time: 0.83m | Total Time: 85.10m
# [SimCLR] 098/100 | Loss: 4.0062 | Epoch Time: 0.84m | Total Time: 85.94m
# [SimCLR] 099/100 | Loss: 4.0025 | Epoch Time: 0.83m | Total Time: 86.78m
# [SimCLR] 100/100 | Loss: 4.0036 | Epoch Time: 0.83m | Total Time: 87.61m
# [SimCLR] 001/100 | Loss: 4.7772 | Epoch Time: 1.45m | Total Time: 1.45m
# [SimCLR] 002/100 | Loss: 4.5224 | Epoch Time: 1.45m | Total Time: 2.90m
# [SimCLR] 003/100 | Loss: 4.4331 | Epoch Time: 1.43m | Total Time: 4.33m
# [SimCLR] 004/100 | Loss: 4.3927 | Epoch Time: 1.43m | Total Time: 5.77m
# [SimCLR] 005/100 | Loss: 4.3617 | Epoch Time: 1.43m | Total Time: 7.20m
# [SimCLR] 006/100 | Loss: 4.3405 | Epoch Time: 1.43m | Total Time: 8.63m
# [SimCLR] 007/100 | Loss: 4.3179 | Epoch Time: 1.43m | Total Time: 10.07m
# [SimCLR] 008/100 | Loss: 4.3037 | Epoch Time: 1.43m | Total Time: 11.50m
# [SimCLR] 009/100 | Loss: 4.2854 | Epoch Time: 1.43m | Total Time: 12.93m
# [SimCLR] 010/100 | Loss: 4.2764 | Epoch Time: 1.43m | Total Time: 14.37m
# [SimCLR] 011/100 | Loss: 4.2595 | Epoch Time: 1.43m | Total Time: 15.80m
# [SimCLR] 012/100 | Loss: 4.2490 | Epoch Time: 1.43m | Total Time: 17.23m
# [SimCLR] 013/100 | Loss: 4.2382 | Epoch Time: 1.43m | Total Time: 18.67m
# [SimCLR] 014/100 | Loss: 4.2276 | Epoch Time: 1.43m | Total Time: 20.10m
# [SimCLR] 015/100 | Loss: 4.2185 | Epoch Time: 1.43m | Total Time: 21.53m
# [SimCLR] 016/100 | Loss: 4.2129 | Epoch Time: 1.44m | Total Time: 22.97m
# [SimCLR] 017/100 | Loss: 4.2058 | Epoch Time: 1.44m | Total Time: 24.41m
# [SimCLR] 018/100 | Loss: 4.1975 | Epoch Time: 1.44m | Total Time: 25.86m
# [SimCLR] 019/100 | Loss: 4.1892 | Epoch Time: 1.44m | Total Time: 27.29m
# [SimCLR] 020/100 | Loss: 4.1868 | Epoch Time: 1.44m | Total Time: 28.73m
# [SimCLR] 021/100 | Loss: 4.1793 | Epoch Time: 1.44m | Total Time: 30.16m
# [SimCLR] 022/100 | Loss: 4.1751 | Epoch Time: 1.43m | Total Time: 31.60m
# [SimCLR] 023/100 | Loss: 4.1673 | Epoch Time: 1.44m | Total Time: 33.04m
# [SimCLR] 024/100 | Loss: 4.1678 | Epoch Time: 1.44m | Total Time: 34.47m
# [SimCLR] 025/100 | Loss: 4.1613 | Epoch Time: 1.44m | Total Time: 35.91m
# [SimCLR] 026/100 | Loss: 4.1561 | Epoch Time: 1.44m | Total Time: 37.36m
# [SimCLR] 027/100 | Loss: 4.1505 | Epoch Time: 1.44m | Total Time: 38.80m
# [SimCLR] 028/100 | Loss: 4.1508 | Epoch Time: 1.44m | Total Time: 40.24m
# [SimCLR] 029/100 | Loss: 4.1433 | Epoch Time: 1.44m | Total Time: 41.69m
# [SimCLR] 030/100 | Loss: 4.1427 | Epoch Time: 1.44m | Total Time: 43.13m
# [SimCLR] 031/100 | Loss: 4.1366 | Epoch Time: 1.44m | Total Time: 44.57m
# [SimCLR] 032/100 | Loss: 4.1344 | Epoch Time: 1.44m | Total Time: 46.01m
# [SimCLR] 033/100 | Loss: 4.1333 | Epoch Time: 1.44m | Total Time: 47.45m
# [SimCLR] 034/100 | Loss: 4.1274 | Epoch Time: 1.44m | Total Time: 48.89m
# [SimCLR] 035/100 | Loss: 4.1287 | Epoch Time: 1.44m | Total Time: 50.32m
# [SimCLR] 036/100 | Loss: 4.1250 | Epoch Time: 1.44m | Total Time: 51.76m
# [SimCLR] 037/100 | Loss: 4.1188 | Epoch Time: 1.44m | Total Time: 53.20m
# [SimCLR] 038/100 | Loss: 4.1183 | Epoch Time: 1.44m | Total Time: 54.64m
# [SimCLR] 039/100 | Loss: 4.1166 | Epoch Time: 1.44m | Total Time: 56.07m
# [SimCLR] 040/100 | Loss: 4.1144 | Epoch Time: 1.44m | Total Time: 57.52m
# [SimCLR] 041/100 | Loss: 4.1085 | Epoch Time: 1.44m | Total Time: 58.96m
# [SimCLR] 042/100 | Loss: 4.1075 | Epoch Time: 1.44m | Total Time: 60.40m
# [SimCLR] 043/100 | Loss: 4.1043 | Epoch Time: 1.44m | Total Time: 61.85m
# [SimCLR] 044/100 | Loss: 4.1074 | Epoch Time: 1.45m | Total Time: 63.30m
# [SimCLR] 045/100 | Loss: 4.1035 | Epoch Time: 1.44m | Total Time: 64.74m
# [SimCLR] 046/100 | Loss: 4.0976 | Epoch Time: 1.44m | Total Time: 66.18m
# [SimCLR] 047/100 | Loss: 4.0980 | Epoch Time: 1.44m | Total Time: 67.62m
# [SimCLR] 048/100 | Loss: 4.0962 | Epoch Time: 1.44m | Total Time: 69.06m
# [SimCLR] 049/100 | Loss: 4.0906 | Epoch Time: 1.44m | Total Time: 70.51m
# [SimCLR] 050/100 | Loss: 4.0914 | Epoch Time: 1.44m | Total Time: 71.95m
# [SimCLR] 051/100 | Loss: 4.0909 | Epoch Time: 1.44m | Total Time: 73.39m
# [SimCLR] 052/100 | Loss: 4.0879 | Epoch Time: 1.45m | Total Time: 74.84m
# [SimCLR] 053/100 | Loss: 4.0861 | Epoch Time: 1.45m | Total Time: 76.28m
# [SimCLR] 054/100 | Loss: 4.0843 | Epoch Time: 1.44m | Total Time: 77.73m
# [SimCLR] 055/100 | Loss: 4.0827 | Epoch Time: 1.44m | Total Time: 79.17m
# [SimCLR] 056/100 | Loss: 4.0807 | Epoch Time: 1.45m | Total Time: 80.62m
# [SimCLR] 057/100 | Loss: 4.0801 | Epoch Time: 1.44m | Total Time: 82.06m
# [SimCLR] 058/100 | Loss: 4.0776 | Epoch Time: 1.44m | Total Time: 83.50m
# [SimCLR] 059/100 | Loss: 4.0762 | Epoch Time: 1.44m | Total Time: 84.94m
# [SimCLR] 060/100 | Loss: 4.0750 | Epoch Time: 1.44m | Total Time: 86.38m
# [SimCLR] 061/100 | Loss: 4.0711 | Epoch Time: 1.44m | Total Time: 87.82m
# [SimCLR] 062/100 | Loss: 4.0708 | Epoch Time: 1.44m | Total Time: 89.26m
# [SimCLR] 063/100 | Loss: 4.0721 | Epoch Time: 1.44m | Total Time: 90.70m
# [SimCLR] 064/100 | Loss: 4.0676 | Epoch Time: 1.44m | Total Time: 92.14m
# [SimCLR] 065/100 | Loss: 4.0661 | Epoch Time: 1.44m | Total Time: 93.57m
# [SimCLR] 066/100 | Loss: 4.0651 | Epoch Time: 1.44m | Total Time: 95.01m
# [SimCLR] 067/100 | Loss: 4.0669 | Epoch Time: 1.44m | Total Time: 96.45m
# [SimCLR] 068/100 | Loss: 4.0624 | Epoch Time: 1.44m | Total Time: 97.88m
# [SimCLR] 069/100 | Loss: 4.0655 | Epoch Time: 1.44m | Total Time: 99.32m
# [SimCLR] 070/100 | Loss: 4.0622 | Epoch Time: 1.44m | Total Time: 100.76m
# [SimCLR] 071/100 | Loss: 4.0600 | Epoch Time: 1.43m | Total Time: 102.19m
# [SimCLR] 072/100 | Loss: 4.0587 | Epoch Time: 1.43m | Total Time: 103.62m
# [SimCLR] 073/100 | Loss: 4.0567 | Epoch Time: 1.43m | Total Time: 105.06m
# [SimCLR] 074/100 | Loss: 4.0555 | Epoch Time: 1.43m | Total Time: 106.49m
# [SimCLR] 075/100 | Loss: 4.0552 | Epoch Time: 1.43m | Total Time: 107.92m
# [SimCLR] 076/100 | Loss: 4.0514 | Epoch Time: 1.44m | Total Time: 109.36m
# [SimCLR] 077/100 | Loss: 4.0550 | Epoch Time: 1.43m | Total Time: 110.79m
# [SimCLR] 078/100 | Loss: 4.0507 | Epoch Time: 1.44m | Total Time: 112.23m
# [SimCLR] 079/100 | Loss: 4.0531 | Epoch Time: 1.43m | Total Time: 113.66m
# [SimCLR] 080/100 | Loss: 4.0533 | Epoch Time: 1.44m | Total Time: 115.10m
# [SimCLR] 081/100 | Loss: 4.0505 | Epoch Time: 1.43m | Total Time: 116.53m
# [SimCLR] 082/100 | Loss: 4.0464 | Epoch Time: 1.44m | Total Time: 117.96m
# [SimCLR] 083/100 | Loss: 4.0502 | Epoch Time: 1.44m | Total Time: 119.40m
# [SimCLR] 084/100 | Loss: 4.0469 | Epoch Time: 1.44m | Total Time: 120.84m
# [SimCLR] 085/100 | Loss: 4.0475 | Epoch Time: 1.44m | Total Time: 122.27m
# [SimCLR] 086/100 | Loss: 4.0431 | Epoch Time: 1.44m | Total Time: 123.71m
# [SimCLR] 087/100 | Loss: 4.0449 | Epoch Time: 1.44m | Total Time: 125.15m
# [SimCLR] 088/100 | Loss: 4.0470 | Epoch Time: 1.44m | Total Time: 126.58m
# [SimCLR] 089/100 | Loss: 4.0436 | Epoch Time: 1.44m | Total Time: 128.02m
# [SimCLR] 090/100 | Loss: 4.0427 | Epoch Time: 1.44m | Total Time: 129.45m
# [SimCLR] 091/100 | Loss: 4.0417 | Epoch Time: 1.44m | Total Time: 130.90m
# [SimCLR] 092/100 | Loss: 4.0401 | Epoch Time: 1.44m | Total Time: 132.33m
# [SimCLR] 093/100 | Loss: 4.0370 | Epoch Time: 1.44m | Total Time: 133.77m
# [SimCLR] 094/100 | Loss: 4.0365 | Epoch Time: 1.43m | Total Time: 135.20m
# [SimCLR] 095/100 | Loss: 4.0360 | Epoch Time: 1.43m | Total Time: 136.64m
# [SimCLR] 096/100 | Loss: 4.0365 | Epoch Time: 1.43m | Total Time: 138.07m
# [SimCLR] 097/100 | Loss: 4.0372 | Epoch Time: 1.43m | Total Time: 139.50m
# [SimCLR] 098/100 | Loss: 4.0332 | Epoch Time: 1.43m | Total Time: 140.94m
# [SimCLR] 099/100 | Loss: 4.0354 | Epoch Time: 1.43m | Total Time: 142.37m
# [SimCLR] 100/100 | Loss: 4.0353 | Epoch Time: 1.43m | Total Time: 143.80m
# Saved results to: /kaggle/working/byol_simclr_results.csv
#
# Running Mean Summary:
#             Seed   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# Method
# BYOL         4.0  58.561503        12.394563          12.531448
# SimCLR       4.0  88.842462        16.148688          19.969277
# SimCLR+Jac   4.0  66.918729        16.089483          16.308668
#
#             Linear_Probe_Acc
# Method
# BYOL                  0.6540
# SimCLR                0.6962
# SimCLR+Jac            0.6730
#
# Seed 4 finished in 312.42 minutes
#
# ================ FINAL RESULTS ================
#    Seed      Method   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# 0     4        BYOL  58.561503        12.394563          12.531448
# 1     4      SimCLR  88.842462        16.148688          19.969277
# 2     4  SimCLR+Jac  66.918729        16.089483          16.308668
#
#    Linear_Probe_Acc
# 0            0.6540
# 1            0.6962
# 2            0.6730
#
# Total experiment time (this session): 312.42 minutes
