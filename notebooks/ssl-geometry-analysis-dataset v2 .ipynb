# %%
import pandas as pd

rows = []

############################################
# CORE EXPERIMENT
# CIFAR10 + ResNet18
############################################

core = [
(0,"BYOL",64.739576,13.125267,13.745380,0.6474),
(0,"SimCLR",89.379337,15.684288,19.091714,0.6905),
(0,"SimCLR+Jac",66.768893,15.795745,15.709850,0.6760),

(1,"BYOL",63.238374,12.338819,12.546963,0.6530),
(1,"SimCLR",87.060588,15.589313,18.490107,0.6975),
(1,"SimCLR+Jac",66.772942,15.542347,16.561101,0.6772),

(2,"BYOL",64.825742,12.813510,13.276976,0.6580),
(2,"SimCLR",86.643990,15.600620,18.544576,0.7018),
(2,"SimCLR+Jac",66.116948,15.781106,15.577176,0.6700),

(3,"BYOL",64.798750,13.324272,14.237532,0.6548),
(3,"SimCLR",85.331009,15.220275,17.785767,0.6987),
(3,"SimCLR+Jac",64.525089,14.436964,15.501014,0.6755),

(4,"BYOL",58.561503,12.394563,12.531448,0.6540),
(4,"SimCLR",88.842462,16.148688,19.969277,0.6962),
(4,"SimCLR+Jac",66.918729,16.089483,16.308668,0.6730),

(5,"BYOL",58.849894,11.934261,12.663976,0.6536),
(5,"SimCLR",86.131786,15.632587,17.653579,0.6961),
(5,"SimCLR+Jac",65.770773,16.416672,16.363256,0.6746),

(6,"BYOL",61.887311,13.626039,14.518287,0.6571),
(6,"SimCLR",89.363847,15.015509,18.349785,0.6832),
(6,"SimCLR+Jac",65.949622,15.731129,16.418068,0.6712),

(7,"BYOL",55.341792,12.427256,11.542867,0.6452),
(7,"SimCLR",85.027936,15.777627,18.471111,0.6919),
(7,"SimCLR+Jac",65.287511,15.211410,16.421584,0.6772),

(8,"BYOL",62.915661,12.623823,13.481307,0.6479),
(8,"SimCLR",87.384987,15.848061,18.661306,0.6976),
(8,"SimCLR+Jac",67.217578,15.782323,15.923306,0.6747),

(9,"BYOL",68.018796,13.002658,14.134727,0.6622),
(9,"SimCLR",90.046928,15.785530,19.482696,0.6939),
(9,"SimCLR+Jac",64.400887,14.605758,15.853318,0.6819),
]

for seed,method,j,a,n,acc in core:
    rows.append(["Core","CIFAR10","ResNet18",seed,method,None,j,a,n,acc,None])

############################################
# TAU EXPERIMENT
############################################

tau_rows = [

(0.1,0,103.744371,18.529007),
(0.1,1,103.285001,19.987349),
(0.1,2,105.027203,20.335806),
(0.1,3,106.728987,20.474623),
(0.1,4,106.234956,20.124298),
(0.1,5,102.814050,19.325505),
(0.1,6,105.558594,18.945007),
(0.1,7,104.094621,19.680384),
(0.1,8,106.107857,19.689766),
(0.1,9,105.366417,19.240178),

(0.5,0,91.051254,18.102534),
(0.5,1,89.588185,19.135866),
(0.5,2,89.435988,19.426159),
(0.5,3,89.930428,20.193879),
(0.5,4,87.361125,18.982584),
(0.5,5,89.323351,19.054257),
(0.5,6,88.254750,19.000106),
(0.5,7,86.113179,19.388073),
(0.5,8,87.666386,18.892843),
(0.5,9,88.850436,18.688172),

(1.0,0,76.823169,18.102741),
(1.0,1,75.440114,17.723047),
(1.0,2,80.499153,18.563218),
(1.0,3,76.942575,20.319879),
(1.0,4,78.680356,18.880798),
(1.0,5,77.780695,17.949611),
(1.0,6,80.068794,17.160821),
(1.0,7,76.284332,17.971965),
(1.0,8,78.463168,17.879443),
(1.0,9,75.776111,17.218259),
]

for tau,seed,j,n in tau_rows:
    rows.append(["Tau","CIFAR10","ResNet18",seed,"SimCLR",tau,j,None,n,None,None])

############################################
# STL10 + RESNET EXTENSION
############################################

stl = [

(0,"BYOL",8.060182762,6.806664562,7.510628223,0.464125,49.00646733),
(0,"SimCLR",23.63281631,8.843026733,19.3513504,0.56,49.00646733),
(0,"SimCLR+Jac",24.49821014,8.932660866,19.73140335,0.56575,26.88584208),

(1,"BYOL",11.35267658,6.506292534,7.206493092,0.4455,42.61530124),
(1,"SimCLR",24.48171234,8.576403236,21.2368515,0.54625,42.61530124),
(1,"SimCLR+Jac",22.86571083,9.047606659,17.95158424,0.552875,19.76454608),

(2,"BYOL",9.348303413,6.830543423,6.863175488,0.44425,40.68882864),
(2,"SimCLR",24.02716942,8.752124596,21.90744781,0.55775,40.68882864),
(2,"SimCLR+Jac",24.69915276,9.011798096,19.72706871,0.5735,19.74122382),

(3,"BYOL",10.14332294,6.676081467,9.253421211,0.468375,41.07579859),
(3,"SimCLR",22.93207283,9.27288475,21.53046799,0.573375,41.07579859),
(3,"SimCLR+Jac",24.76007919,8.594046974,19.58338547,0.5685,19.77740491),

(4,"BYOL",10.03558598,6.73471241,7.923536491,0.462875,42.18551775),
(4,"SimCLR",22.98328972,8.941238403,19.86025085,0.56375,42.18551775),
(4,"SimCLR+Jac",24.15675545,8.62812252,18.4959404,0.57225,19.46451366),
]

for seed,method,j,a,n,acc,time in stl:
    rows.append(["Extension","STL10","ResNet18",seed,method,None,j,a,n,acc,time])

############################################
# CIFAR10 + VIT EXTENSION
############################################

vit = [

(0,"BYOL",1.4900,3.5122,0.1495,0.4906),
(0,"SimCLR",5.6087,6.7722,0.7644,0.7660),
(0,"SimCLR+Jac",5.6350,6.7723,0.7518,0.7671),

(1,"BYOL",1.3424,3.1024,0.1309,0.4879),
(1,"SimCLR",5.5748,6.8314,0.7413,0.7696),
(1,"SimCLR+Jac",5.7697,6.6681,0.7858,0.7709),

(2,"BYOL",1.1781,2.5847,0.1190,0.4784),
(2,"SimCLR",5.9114,7.0848,0.7717,0.7636),
(2,"SimCLR+Jac",5.5409,6.5294,0.7411,0.7644),

(3,"BYOL",1.0390,2.5994,0.0999,0.4779),
(3,"SimCLR",5.5844,6.7486,0.7582,0.7711),
(3,"SimCLR+Jac",5.7250,7.1492,0.7548,0.7674),

(4,"BYOL",1.3020,3.2233,0.1244,0.4783),
(4,"SimCLR",5.7402,6.9042,0.7598,0.7687),
(4,"SimCLR+Jac",5.7493,6.9065,0.7660,0.7657),
]

for seed,method,j,a,n,acc in vit:
    rows.append(["Extension","CIFAR10","ViT",seed,method,None,j,a,n,acc,None])

############################################
# CREATE DATASET
############################################

df = pd.DataFrame(rows,columns=[
"Experiment",
"Dataset",
"Architecture",
"Seed",
"Method",
"Tau",
"Jacobian",
"Aug_Sensitivity",
"Noise_Sensitivity",
"Accuracy",
"Train_Time_Min"
])

df.to_csv("ssl_master_dataset.csv",index=False)

print("Dataset saved")
print("Total rows:",len(df))
print(df.head())
# Out:
# Dataset saved
# Total rows: 90
#   Experiment  Dataset Architecture  Seed      Method  Tau   Jacobian  \
# 0       Core  CIFAR10     ResNet18     0        BYOL  NaN  64.739576
# 1       Core  CIFAR10     ResNet18     0      SimCLR  NaN  89.379337
# 2       Core  CIFAR10     ResNet18     0  SimCLR+Jac  NaN  66.768893
# 3       Core  CIFAR10     ResNet18     1        BYOL  NaN  63.238374
# 4       Core  CIFAR10     ResNet18     1      SimCLR  NaN  87.060588
#
#    Aug_Sensitivity  Noise_Sensitivity  Accuracy  Train_Time_Min
# 0        13.125267          13.745380    0.6474             NaN
# 1        15.684288          19.091714    0.6905             NaN
# 2        15.795745          15.709850    0.6760             NaN
# 3        12.338819          12.546963    0.6530             NaN
# 4        15.589313          18.490107    0.6975             NaN

# %%
df.tail()
# Out:
#    Experiment  Dataset Architecture  Seed      Method  Tau  Jacobian  \
# 85  Extension  CIFAR10          ViT     3      SimCLR  NaN    5.5844
# 86  Extension  CIFAR10          ViT     3  SimCLR+Jac  NaN    5.7250
# 87  Extension  CIFAR10          ViT     4        BYOL  NaN    1.3020
# 88  Extension  CIFAR10          ViT     4      SimCLR  NaN    5.7402
# 89  Extension  CIFAR10          ViT     4  SimCLR+Jac  NaN    5.7493
#
#     Aug_Sensitivity  Noise_Sensitivity  Accuracy  Train_Time_Min
# 85           6.7486             0.7582    0.7711             NaN
# 86           7.1492             0.7548    0.7674             NaN
# 87           3.2233             0.1244    0.4783             NaN
# 88           6.9042             0.7598    0.7687             NaN
# 89           6.9065             0.7660    0.7657             NaN

# %%
import pandas as pd

# Load existing dataset
df = pd.read_csv("ssl_master_dataset.csv")

rows = []

############################################
# TRANSFER (100 Epochs)
############################################

transfer_100 = [
(0,0.6441,0.6870,0.6801),
(1,0.6462,0.6821,0.6842),
(2,0.6420,0.6826,0.6836),
(3,0.6525,0.6807,0.6827),
(4,0.6422,0.6820,0.6800),
]

for seed,byol,simclr,jac in transfer_100:
    rows.append(["Transfer_100E","CIFAR10","ResNet18",seed,"BYOL",None,None,None,None,byol,None])
    rows.append(["Transfer_100E","CIFAR10","ResNet18",seed,"SimCLR",None,None,None,None,simclr,None])
    rows.append(["Transfer_100E","CIFAR10","ResNet18",seed,"SimCLR+Jac",None,None,None,None,jac,None])

############################################
# TRANSFER (20 Epoch Probe)
############################################

transfer_20 = [
(0,0.4988,0.6059,0.5981),
(1,0.5008,0.6052,0.6059),
(2,0.4932,0.6004,0.5956),
(3,0.4930,0.5901,0.6006),
(4,0.4977,0.5951,0.6061),
]

for seed,byol,simclr,jac in transfer_20:
    rows.append(["Transfer_20E","CIFAR10","ResNet18",seed,"BYOL",None,None,None,None,byol,None])
    rows.append(["Transfer_20E","CIFAR10","ResNet18",seed,"SimCLR",None,None,None,None,simclr,None])
    rows.append(["Transfer_20E","CIFAR10","ResNet18",seed,"SimCLR+Jac",None,None,None,None,jac,None])

############################################
# CIFAR100 LINEAR PROBE (200E pretrain, 100E probe)
############################################

probe = [
(0,0.3902,0.3926),
(1,0.3960,0.3948),
(2,0.3979,0.4023),
(3,0.3933,0.4008),
(4,0.3933,0.3965),
]

for seed,simclr,jac in probe:
    rows.append(["Probe_CIFAR100","CIFAR100","ResNet18",seed,"SimCLR",None,None,None,None,simclr,None])
    rows.append(["Probe_CIFAR100","CIFAR100","ResNet18",seed,"SimCLR+Jac",None,None,None,None,jac,None])

############################################
# APPEND TO EXISTING DATAFRAME
############################################

new_df = pd.DataFrame(rows, columns=df.columns)

df = pd.concat([df, new_df], ignore_index=True)

############################################
# SAVE (OVERWRITE SAME FILE)
############################################

df.to_csv("ssl_master_dataset.csv", index=False)

print("Dataset updated successfully")
print("Total rows:", len(df))
# Out:
# Dataset updated successfully
# Total rows: 130
# /tmp/ipykernel_55/1343999671.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_df], ignore_index=True)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df)
# Out:
#          Experiment   Dataset Architecture  Seed      Method  Tau    Jacobian  \
# 0              Core   CIFAR10     ResNet18     0        BYOL  NaN   64.739576
# 1              Core   CIFAR10     ResNet18     0      SimCLR  NaN   89.379337
# 2              Core   CIFAR10     ResNet18     0  SimCLR+Jac  NaN   66.768893
# 3              Core   CIFAR10     ResNet18     1        BYOL  NaN   63.238374
# 4              Core   CIFAR10     ResNet18     1      SimCLR  NaN   87.060588
# 5              Core   CIFAR10     ResNet18     1  SimCLR+Jac  NaN   66.772942
# 6              Core   CIFAR10     ResNet18     2        BYOL  NaN   64.825742
# 7              Core   CIFAR10     ResNet18     2      SimCLR  NaN   86.643990
# 8              Core   CIFAR10     ResNet18     2  SimCLR+Jac  NaN   66.116948
# 9              Core   CIFAR10     ResNet18     3        BYOL  NaN   64.798750
# 10             Core   CIFAR10     ResNet18     3      SimCLR  NaN   85.331009
# ...
