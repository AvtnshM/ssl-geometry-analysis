# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import numpy as np
import random
import pandas as pd
import time
import scipy.stats as stats

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def set_seed(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
# Out:
# Device: cuda

# %%
class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform
    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)

ssl_base_transform = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2,1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=ssl_transform
)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=T.ToTensor()
)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)
# Out:
# 100%|██████████| 170M/170M [00:07<00:00, 23.8MB/s]

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        backbone = resnet18(weights=None)
        backbone.fc = nn.Identity()
        self.backbone = backbone
    def forward(self, x):
        return self.backbone(x)

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, hidden_dim=2048, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )
    def forward(self, x):
        return self.net(x)

class BYOL(nn.Module):
    def __init__(self):
        super().__init__()
        self.online_encoder = Encoder()
        self.online_projector = MLP(512)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder = Encoder()
        self.target_projector = MLP(512)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for o, t in zip(self.online_encoder.parameters(),
                        self.target_encoder.parameters()):
            t.data = tau * t.data + (1 - tau) * o.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(
            self.online_projector(self.online_encoder(x1))
        )

        with torch.no_grad():
            t2 = self.target_projector(
                self.target_encoder(x2)
            )

        loss = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        return loss.mean()

# %%
class SimCLR(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.projector = MLP(512)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)

def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)

    sim = torch.mm(z, z.t()) / temperature
    mask = torch.eye(2*N, device=z.device).bool()
    sim.masked_fill_(mask, -9e15)

    positives = torch.cat([
        torch.arange(N,2*N),
        torch.arange(0,N)
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
def jacobian_penalty(model, x):
    x = x.clone().detach().requires_grad_(True)
    z = model(x)

    v = torch.randn_like(z)

    Jv = torch.autograd.grad(
        outputs=z,
        inputs=x,
        grad_outputs=v,
        create_graph=True
    )[0]

    return Jv.pow(2).sum(dim=[1,2,3]).mean()

# %%
def train_byol(model, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            loss = model(x1,x2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            model.update_target()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[BYOL] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.online_encoder


def train_simclr(model, epochs=100, lambda_jac=0.0):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            z1 = model(x1)
            z2 = model(x2)
            loss = nt_xent_loss(z1,z2)

            if lambda_jac > 0:
                jac = jacobian_penalty(model, x1)
                loss = loss + lambda_jac * jac

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[SimCLR] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.encoder

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(512, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    return correct / total

# %%
# =========================================================
# Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
])


def jacobian_frobenius(model, x):
    model.eval()
    x = x.clone().detach().requires_grad_(True)

    y = model(x)

    v = torch.randn_like(y)

    Jv = torch.autograd.grad(
        outputs=y,
        inputs=x,
        grad_outputs=v,
        create_graph=False,
        retain_graph=False
    )[0]

    # Proper per-sample Frobenius estimate
    per_sample = Jv.pow(2).flatten(1).sum(dim=1)

    return torch.sqrt(per_sample.mean())


def compute_metrics(encoder, loader):
    encoder = encoder.to(device)
    encoder.eval()

    jac_vals = []
    aug_vals = []
    noise_vals = []

    for i, (x, _) in enumerate(loader):
        if i == 5:  # limit batches
            break

        x = x.to(device)

        # ---- Jacobian ----
        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # ---- Augmentation Sensitivity ----
        x_aug = torch.stack([
            tensor_aug(img.cpu()) for img in x
        ]).to(device)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        # ---- Noise Sensitivity ----
        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x + noise)
            noise_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

    return (
        np.mean(jac_vals),
        np.mean(aug_vals),
        np.mean(noise_vals)
    )

# %%
# =========================================================
# Supervised Data (for Linear Probe)
# =========================================================

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=False,
    transform=T.ToTensor()
)

supervised_test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=False,
    transform=T.ToTensor()
)

supervised_train_loader = DataLoader(
    supervised_train_dataset,
    batch_size=128,
    shuffle=True,
    num_workers=2
)

supervised_test_loader = DataLoader(
    supervised_test_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=2
)

print("Supervised loaders ready.")
# Out:
# Supervised loaders ready.

# %%
import os

# =========================================================
# CONFIG
# =========================================================

csv_path = "/kaggle/working/byol_simclr_results.csv"
target_seeds = [2, 3]   # <-- change to range(10) when ready

# =========================================================
# RESUME LOGIC
# =========================================================

if os.path.exists(csv_path):
    existing_df = pd.read_csv(csv_path)
    completed_seeds = set(existing_df["Seed"].unique())
    all_results = existing_df.to_dict("records")
    print("Loaded existing results. Completed seeds:", completed_seeds)
else:
    completed_seeds = set()
    all_results = []
    print("No existing CSV found. Starting fresh.")

seeds = [s for s in target_seeds if s not in completed_seeds]

print("Seeds to run now:", seeds)

global_start = time.time()

# =========================================================
# MAIN LOOP
# =========================================================

for seed in seeds:

    print("\n====================================")
    print(f"Running Seed: {seed}")
    print("====================================")

    seed_start = time.time()
    set_seed(seed)

    # ------------------------
    # Train Models
    # ------------------------

    byol_encoder = train_byol(BYOL(), epochs=100)

    simclr_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=0.0
    )

    simclr_jac_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=1e-3
    )

    # ------------------------
    # Compute Metrics
    # ------------------------

    byol_metrics = compute_metrics(byol_encoder, test_loader)
    simclr_metrics = compute_metrics(simclr_encoder, test_loader)
    simclr_jac_metrics = compute_metrics(simclr_jac_encoder, test_loader)

    # ------------------------
    # Linear Probe
    # ------------------------

    byol_acc = train_probe(
        byol_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_acc = train_probe(
        simclr_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_jac_acc = train_probe(
        simclr_jac_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    # ------------------------
    # Store Results
    # ------------------------

    seed_results = [
        {
            "Seed": seed,
            "Method": "BYOL",
            "Jacobian": byol_metrics[0],
            "Aug_Sensitivity": byol_metrics[1],
            "Noise_Sensitivity": byol_metrics[2],
            "Linear_Probe_Acc": byol_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR",
            "Jacobian": simclr_metrics[0],
            "Aug_Sensitivity": simclr_metrics[1],
            "Noise_Sensitivity": simclr_metrics[2],
            "Linear_Probe_Acc": simclr_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR+Jac",
            "Jacobian": simclr_jac_metrics[0],
            "Aug_Sensitivity": simclr_jac_metrics[1],
            "Noise_Sensitivity": simclr_jac_metrics[2],
            "Linear_Probe_Acc": simclr_jac_acc
        }
    ]

    all_results.extend(seed_results)

    # ------------------------
    # SAVE AFTER EACH SEED
    # ------------------------

    results_df = pd.DataFrame(all_results)
    results_df.to_csv(csv_path, index=False)

    print("Saved results to:", csv_path)

    # ------------------------
    # Running Summary
    # ------------------------

    summary = results_df.groupby("Method").mean(numeric_only=True)
    print("\nRunning Mean Summary:")
    print(summary)

    # ------------------------
    # GPU Cleanup
    # ------------------------

    del byol_encoder, simclr_encoder, simclr_jac_encoder
    torch.cuda.empty_cache()

    seed_time = (time.time() - seed_start) / 60
    print(f"\nSeed {seed} finished in {seed_time:.2f} minutes")

# =========================================================
# FINAL SUMMARY
# =========================================================

final_df = pd.read_csv(csv_path)

print("\n================ FINAL RESULTS ================")
print(final_df)

total_time = (time.time() - global_start) / 60
print(f"\nTotal experiment time (this session): {total_time:.2f} minutes")
# Out:
# No existing CSV found. Starting fresh.
# Seeds to run now: [2, 3]
#
# ====================================
# Running Seed: 2
# ====================================
# [BYOL] 001/100 | Loss: 0.7438 | Epoch Time: 0.84m | Total Time: 0.84m
# [BYOL] 002/100 | Loss: 0.5699 | Epoch Time: 0.79m | Total Time: 1.62m
# [BYOL] 003/100 | Loss: 0.5164 | Epoch Time: 0.81m | Total Time: 2.43m
# [BYOL] 004/100 | Loss: 0.4894 | Epoch Time: 0.79m | Total Time: 3.22m
# [BYOL] 005/100 | Loss: 0.4711 | Epoch Time: 0.79m | Total Time: 4.01m
# [BYOL] 006/100 | Loss: 0.4612 | Epoch Time: 0.79m | Total Time: 4.80m
# [BYOL] 007/100 | Loss: 0.4513 | Epoch Time: 0.79m | Total Time: 5.59m
# [BYOL] 008/100 | Loss: 0.4454 | Epoch Time: 0.79m | Total Time: 6.37m
# [BYOL] 009/100 | Loss: 0.4376 | Epoch Time: 0.78m | Total Time: 7.15m
# [BYOL] 010/100 | Loss: 0.4338 | Epoch Time: 0.78m | Total Time: 7.93m
# [BYOL] 011/100 | Loss: 0.4282 | Epoch Time: 0.79m | Total Time: 8.72m
# [BYOL] 012/100 | Loss: 0.4220 | Epoch Time: 0.79m | Total Time: 9.51m
# [BYOL] 013/100 | Loss: 0.4174 | Epoch Time: 0.78m | Total Time: 10.29m
# [BYOL] 014/100 | Loss: 0.4174 | Epoch Time: 0.78m | Total Time: 11.07m
# [BYOL] 015/100 | Loss: 0.4158 | Epoch Time: 0.80m | Total Time: 11.87m
# [BYOL] 016/100 | Loss: 0.4128 | Epoch Time: 0.78m | Total Time: 12.65m
# [BYOL] 017/100 | Loss: 0.4105 | Epoch Time: 0.77m | Total Time: 13.42m
# [BYOL] 018/100 | Loss: 0.4111 | Epoch Time: 0.78m | Total Time: 14.20m
# [BYOL] 019/100 | Loss: 0.4092 | Epoch Time: 0.77m | Total Time: 14.97m
# [BYOL] 020/100 | Loss: 0.4100 | Epoch Time: 0.77m | Total Time: 15.75m
# [BYOL] 021/100 | Loss: 0.4084 | Epoch Time: 0.77m | Total Time: 16.52m
# [BYOL] 022/100 | Loss: 0.4067 | Epoch Time: 0.77m | Total Time: 17.29m
# [BYOL] 023/100 | Loss: 0.4070 | Epoch Time: 0.77m | Total Time: 18.07m
# [BYOL] 024/100 | Loss: 0.4057 | Epoch Time: 0.77m | Total Time: 18.84m
# [BYOL] 025/100 | Loss: 0.4024 | Epoch Time: 0.79m | Total Time: 19.63m
# [BYOL] 026/100 | Loss: 0.4001 | Epoch Time: 0.78m | Total Time: 20.40m
# [BYOL] 027/100 | Loss: 0.4010 | Epoch Time: 0.77m | Total Time: 21.18m
# [BYOL] 028/100 | Loss: 0.3980 | Epoch Time: 0.77m | Total Time: 21.94m
# [BYOL] 029/100 | Loss: 0.3984 | Epoch Time: 0.77m | Total Time: 22.72m
# [BYOL] 030/100 | Loss: 0.3988 | Epoch Time: 0.78m | Total Time: 23.50m
# [BYOL] 031/100 | Loss: 0.3974 | Epoch Time: 0.77m | Total Time: 24.27m
# [BYOL] 032/100 | Loss: 0.3971 | Epoch Time: 0.77m | Total Time: 25.04m
# [BYOL] 033/100 | Loss: 0.3973 | Epoch Time: 0.77m | Total Time: 25.81m
# [BYOL] 034/100 | Loss: 0.3960 | Epoch Time: 0.77m | Total Time: 26.58m
# [BYOL] 035/100 | Loss: 0.3952 | Epoch Time: 0.78m | Total Time: 27.36m
# [BYOL] 036/100 | Loss: 0.3933 | Epoch Time: 0.77m | Total Time: 28.12m
# [BYOL] 037/100 | Loss: 0.3915 | Epoch Time: 0.78m | Total Time: 28.90m
# [BYOL] 038/100 | Loss: 0.3929 | Epoch Time: 0.77m | Total Time: 29.66m
# [BYOL] 039/100 | Loss: 0.3925 | Epoch Time: 0.76m | Total Time: 30.43m
# [BYOL] 040/100 | Loss: 0.3925 | Epoch Time: 0.76m | Total Time: 31.18m
# [BYOL] 041/100 | Loss: 0.3909 | Epoch Time: 0.77m | Total Time: 31.95m
# [BYOL] 042/100 | Loss: 0.3914 | Epoch Time: 0.77m | Total Time: 32.73m
# [BYOL] 043/100 | Loss: 0.3939 | Epoch Time: 0.77m | Total Time: 33.49m
# [BYOL] 044/100 | Loss: 0.3933 | Epoch Time: 0.76m | Total Time: 34.26m
# [BYOL] 045/100 | Loss: 0.3923 | Epoch Time: 0.77m | Total Time: 35.02m
# [BYOL] 046/100 | Loss: 0.3912 | Epoch Time: 0.76m | Total Time: 35.78m
# [BYOL] 047/100 | Loss: 0.3921 | Epoch Time: 0.76m | Total Time: 36.53m
# [BYOL] 048/100 | Loss: 0.3923 | Epoch Time: 0.76m | Total Time: 37.30m
# [BYOL] 049/100 | Loss: 0.3893 | Epoch Time: 0.77m | Total Time: 38.07m
# [BYOL] 050/100 | Loss: 0.3904 | Epoch Time: 0.76m | Total Time: 38.83m
# [BYOL] 051/100 | Loss: 0.3913 | Epoch Time: 0.77m | Total Time: 39.60m
# [BYOL] 052/100 | Loss: 0.3892 | Epoch Time: 0.77m | Total Time: 40.37m
# [BYOL] 053/100 | Loss: 0.3888 | Epoch Time: 0.77m | Total Time: 41.14m
# [BYOL] 054/100 | Loss: 0.3867 | Epoch Time: 0.77m | Total Time: 41.91m
# [BYOL] 055/100 | Loss: 0.3877 | Epoch Time: 0.77m | Total Time: 42.68m
# [BYOL] 056/100 | Loss: 0.3861 | Epoch Time: 0.76m | Total Time: 43.44m
# [BYOL] 057/100 | Loss: 0.3882 | Epoch Time: 0.77m | Total Time: 44.21m
# [BYOL] 058/100 | Loss: 0.3858 | Epoch Time: 0.76m | Total Time: 44.97m
# [BYOL] 059/100 | Loss: 0.3841 | Epoch Time: 0.76m | Total Time: 45.73m
# [BYOL] 060/100 | Loss: 0.3841 | Epoch Time: 0.76m | Total Time: 46.50m
# [BYOL] 061/100 | Loss: 0.3833 | Epoch Time: 0.76m | Total Time: 47.26m
# [BYOL] 062/100 | Loss: 0.3825 | Epoch Time: 0.76m | Total Time: 48.01m
# [BYOL] 063/100 | Loss: 0.3828 | Epoch Time: 0.78m | Total Time: 48.79m
# [BYOL] 064/100 | Loss: 0.3823 | Epoch Time: 0.78m | Total Time: 49.57m
# [BYOL] 065/100 | Loss: 0.3824 | Epoch Time: 0.76m | Total Time: 50.33m
# [BYOL] 066/100 | Loss: 0.3830 | Epoch Time: 0.77m | Total Time: 51.10m
# [BYOL] 067/100 | Loss: 0.3800 | Epoch Time: 0.77m | Total Time: 51.86m
# [BYOL] 068/100 | Loss: 0.3799 | Epoch Time: 0.78m | Total Time: 52.64m
# [BYOL] 069/100 | Loss: 0.3802 | Epoch Time: 0.77m | Total Time: 53.41m
# [BYOL] 070/100 | Loss: 0.3808 | Epoch Time: 0.77m | Total Time: 54.18m
# [BYOL] 071/100 | Loss: 0.3793 | Epoch Time: 0.77m | Total Time: 54.95m
# [BYOL] 072/100 | Loss: 0.3798 | Epoch Time: 0.76m | Total Time: 55.71m
# [BYOL] 073/100 | Loss: 0.3790 | Epoch Time: 0.77m | Total Time: 56.47m
# [BYOL] 074/100 | Loss: 0.3787 | Epoch Time: 0.76m | Total Time: 57.24m
# [BYOL] 075/100 | Loss: 0.3781 | Epoch Time: 0.76m | Total Time: 57.99m
# [BYOL] 076/100 | Loss: 0.3788 | Epoch Time: 0.77m | Total Time: 58.76m
# [BYOL] 077/100 | Loss: 0.3770 | Epoch Time: 0.76m | Total Time: 59.51m
# [BYOL] 078/100 | Loss: 0.3769 | Epoch Time: 0.76m | Total Time: 60.27m
# [BYOL] 079/100 | Loss: 0.3765 | Epoch Time: 0.77m | Total Time: 61.04m
# [BYOL] 080/100 | Loss: 0.3768 | Epoch Time: 0.76m | Total Time: 61.80m
# [BYOL] 081/100 | Loss: 0.3762 | Epoch Time: 0.76m | Total Time: 62.56m
# [BYOL] 082/100 | Loss: 0.3759 | Epoch Time: 0.76m | Total Time: 63.32m
# [BYOL] 083/100 | Loss: 0.3758 | Epoch Time: 0.77m | Total Time: 64.09m
# [BYOL] 084/100 | Loss: 0.3751 | Epoch Time: 0.76m | Total Time: 64.85m
# [BYOL] 085/100 | Loss: 0.3766 | Epoch Time: 0.76m | Total Time: 65.61m
# [BYOL] 086/100 | Loss: 0.3754 | Epoch Time: 0.76m | Total Time: 66.37m
# [BYOL] 087/100 | Loss: 0.3740 | Epoch Time: 0.76m | Total Time: 67.12m
# [BYOL] 088/100 | Loss: 0.3721 | Epoch Time: 0.76m | Total Time: 67.88m
# [BYOL] 089/100 | Loss: 0.3754 | Epoch Time: 0.76m | Total Time: 68.64m
# [BYOL] 090/100 | Loss: 0.3736 | Epoch Time: 0.76m | Total Time: 69.40m
# [BYOL] 091/100 | Loss: 0.3732 | Epoch Time: 0.76m | Total Time: 70.16m
# [BYOL] 092/100 | Loss: 0.3740 | Epoch Time: 0.76m | Total Time: 70.92m
# [BYOL] 093/100 | Loss: 0.3728 | Epoch Time: 0.76m | Total Time: 71.67m
# [BYOL] 094/100 | Loss: 0.3726 | Epoch Time: 0.76m | Total Time: 72.43m
# [BYOL] 095/100 | Loss: 0.3733 | Epoch Time: 0.76m | Total Time: 73.19m
# [BYOL] 096/100 | Loss: 0.3723 | Epoch Time: 0.77m | Total Time: 73.96m
# [BYOL] 097/100 | Loss: 0.3740 | Epoch Time: 0.76m | Total Time: 74.73m
# [BYOL] 098/100 | Loss: 0.3721 | Epoch Time: 0.76m | Total Time: 75.48m
# [BYOL] 099/100 | Loss: 0.3733 | Epoch Time: 0.75m | Total Time: 76.23m
# [BYOL] 100/100 | Loss: 0.3725 | Epoch Time: 0.75m | Total Time: 76.98m
# [SimCLR] 001/100 | Loss: 4.6718 | Epoch Time: 0.82m | Total Time: 0.82m
# [SimCLR] 002/100 | Loss: 4.4874 | Epoch Time: 0.81m | Total Time: 1.63m
# [SimCLR] 003/100 | Loss: 4.4275 | Epoch Time: 0.83m | Total Time: 2.46m
# [SimCLR] 004/100 | Loss: 4.3851 | Epoch Time: 0.81m | Total Time: 3.27m
# [SimCLR] 005/100 | Loss: 4.3581 | Epoch Time: 0.82m | Total Time: 4.09m
# [SimCLR] 006/100 | Loss: 4.3331 | Epoch Time: 0.82m | Total Time: 4.91m
# [SimCLR] 007/100 | Loss: 4.3180 | Epoch Time: 0.81m | Total Time: 5.72m
# [SimCLR] 008/100 | Loss: 4.2956 | Epoch Time: 0.82m | Total Time: 6.53m
# [SimCLR] 009/100 | Loss: 4.2768 | Epoch Time: 0.82m | Total Time: 7.35m
# [SimCLR] 010/100 | Loss: 4.2640 | Epoch Time: 0.82m | Total Time: 8.17m
# [SimCLR] 011/100 | Loss: 4.2485 | Epoch Time: 0.81m | Total Time: 8.98m
# [SimCLR] 012/100 | Loss: 4.2374 | Epoch Time: 0.82m | Total Time: 9.80m
# [SimCLR] 013/100 | Loss: 4.2287 | Epoch Time: 0.83m | Total Time: 10.63m
# [SimCLR] 014/100 | Loss: 4.2141 | Epoch Time: 0.81m | Total Time: 11.45m
# [SimCLR] 015/100 | Loss: 4.2064 | Epoch Time: 0.83m | Total Time: 12.27m
# [SimCLR] 016/100 | Loss: 4.1957 | Epoch Time: 0.82m | Total Time: 13.09m
# [SimCLR] 017/100 | Loss: 4.1909 | Epoch Time: 0.82m | Total Time: 13.91m
# [SimCLR] 018/100 | Loss: 4.1864 | Epoch Time: 0.82m | Total Time: 14.73m
# [SimCLR] 019/100 | Loss: 4.1757 | Epoch Time: 0.81m | Total Time: 15.55m
# [SimCLR] 020/100 | Loss: 4.1690 | Epoch Time: 0.81m | Total Time: 16.36m
# [SimCLR] 021/100 | Loss: 4.1636 | Epoch Time: 0.82m | Total Time: 17.18m
# [SimCLR] 022/100 | Loss: 4.1582 | Epoch Time: 0.81m | Total Time: 17.99m
# [SimCLR] 023/100 | Loss: 4.1521 | Epoch Time: 0.81m | Total Time: 18.81m
# [SimCLR] 024/100 | Loss: 4.1479 | Epoch Time: 0.83m | Total Time: 19.63m
# [SimCLR] 025/100 | Loss: 4.1469 | Epoch Time: 0.82m | Total Time: 20.45m
# [SimCLR] 026/100 | Loss: 4.1410 | Epoch Time: 0.82m | Total Time: 21.27m
# [SimCLR] 027/100 | Loss: 4.1342 | Epoch Time: 0.82m | Total Time: 22.09m
# [SimCLR] 028/100 | Loss: 4.1306 | Epoch Time: 0.83m | Total Time: 22.92m
# [SimCLR] 029/100 | Loss: 4.1264 | Epoch Time: 0.83m | Total Time: 23.75m
# [SimCLR] 030/100 | Loss: 4.1233 | Epoch Time: 0.83m | Total Time: 24.57m
# [SimCLR] 031/100 | Loss: 4.1225 | Epoch Time: 0.82m | Total Time: 25.40m
# [SimCLR] 032/100 | Loss: 4.1184 | Epoch Time: 0.82m | Total Time: 26.22m
# [SimCLR] 033/100 | Loss: 4.1147 | Epoch Time: 0.83m | Total Time: 27.05m
# [SimCLR] 034/100 | Loss: 4.1086 | Epoch Time: 0.84m | Total Time: 27.89m
# [SimCLR] 035/100 | Loss: 4.1075 | Epoch Time: 0.83m | Total Time: 28.72m
# [SimCLR] 036/100 | Loss: 4.1058 | Epoch Time: 0.83m | Total Time: 29.55m
# [SimCLR] 037/100 | Loss: 4.1029 | Epoch Time: 0.82m | Total Time: 30.37m
# [SimCLR] 038/100 | Loss: 4.0965 | Epoch Time: 0.83m | Total Time: 31.20m
# [SimCLR] 039/100 | Loss: 4.0965 | Epoch Time: 0.82m | Total Time: 32.02m
# [SimCLR] 040/100 | Loss: 4.0918 | Epoch Time: 0.83m | Total Time: 32.85m
# [SimCLR] 041/100 | Loss: 4.0926 | Epoch Time: 0.82m | Total Time: 33.67m
# [SimCLR] 042/100 | Loss: 4.0873 | Epoch Time: 0.82m | Total Time: 34.49m
# [SimCLR] 043/100 | Loss: 4.0836 | Epoch Time: 0.82m | Total Time: 35.30m
# [SimCLR] 044/100 | Loss: 4.0795 | Epoch Time: 0.83m | Total Time: 36.14m
# [SimCLR] 045/100 | Loss: 4.0793 | Epoch Time: 0.83m | Total Time: 36.96m
# [SimCLR] 046/100 | Loss: 4.0772 | Epoch Time: 0.82m | Total Time: 37.78m
# [SimCLR] 047/100 | Loss: 4.0731 | Epoch Time: 0.82m | Total Time: 38.60m
# [SimCLR] 048/100 | Loss: 4.0728 | Epoch Time: 0.82m | Total Time: 39.42m
# [SimCLR] 049/100 | Loss: 4.0694 | Epoch Time: 0.83m | Total Time: 40.25m
# [SimCLR] 050/100 | Loss: 4.0690 | Epoch Time: 0.81m | Total Time: 41.06m
# [SimCLR] 051/100 | Loss: 4.0665 | Epoch Time: 0.82m | Total Time: 41.88m
# [SimCLR] 052/100 | Loss: 4.0640 | Epoch Time: 0.82m | Total Time: 42.70m
# [SimCLR] 053/100 | Loss: 4.0630 | Epoch Time: 0.83m | Total Time: 43.53m
# [SimCLR] 054/100 | Loss: 4.0619 | Epoch Time: 0.83m | Total Time: 44.35m
# [SimCLR] 055/100 | Loss: 4.0581 | Epoch Time: 0.81m | Total Time: 45.16m
# [SimCLR] 056/100 | Loss: 4.0563 | Epoch Time: 0.83m | Total Time: 45.99m
# [SimCLR] 057/100 | Loss: 4.0550 | Epoch Time: 0.83m | Total Time: 46.82m
# [SimCLR] 058/100 | Loss: 4.0515 | Epoch Time: 0.82m | Total Time: 47.64m
# [SimCLR] 059/100 | Loss: 4.0511 | Epoch Time: 0.83m | Total Time: 48.47m
# [SimCLR] 060/100 | Loss: 4.0505 | Epoch Time: 0.82m | Total Time: 49.29m
# [SimCLR] 061/100 | Loss: 4.0466 | Epoch Time: 0.82m | Total Time: 50.11m
# [SimCLR] 062/100 | Loss: 4.0469 | Epoch Time: 0.83m | Total Time: 50.93m
# [SimCLR] 063/100 | Loss: 4.0448 | Epoch Time: 0.83m | Total Time: 51.76m
# [SimCLR] 064/100 | Loss: 4.0434 | Epoch Time: 0.82m | Total Time: 52.59m
# [SimCLR] 065/100 | Loss: 4.0437 | Epoch Time: 0.81m | Total Time: 53.40m
# [SimCLR] 066/100 | Loss: 4.0412 | Epoch Time: 0.82m | Total Time: 54.22m
# [SimCLR] 067/100 | Loss: 4.0404 | Epoch Time: 0.82m | Total Time: 55.04m
# [SimCLR] 068/100 | Loss: 4.0399 | Epoch Time: 0.82m | Total Time: 55.86m
# [SimCLR] 069/100 | Loss: 4.0346 | Epoch Time: 0.83m | Total Time: 56.70m
# [SimCLR] 070/100 | Loss: 4.0351 | Epoch Time: 0.82m | Total Time: 57.52m
# [SimCLR] 071/100 | Loss: 4.0332 | Epoch Time: 0.82m | Total Time: 58.34m
# [SimCLR] 072/100 | Loss: 4.0318 | Epoch Time: 0.82m | Total Time: 59.15m
# [SimCLR] 073/100 | Loss: 4.0353 | Epoch Time: 0.82m | Total Time: 59.97m
# [SimCLR] 074/100 | Loss: 4.0308 | Epoch Time: 0.82m | Total Time: 60.79m
# [SimCLR] 075/100 | Loss: 4.0260 | Epoch Time: 0.81m | Total Time: 61.60m
# [SimCLR] 076/100 | Loss: 4.0241 | Epoch Time: 0.83m | Total Time: 62.43m
# [SimCLR] 077/100 | Loss: 4.0268 | Epoch Time: 0.82m | Total Time: 63.25m
# [SimCLR] 078/100 | Loss: 4.0227 | Epoch Time: 0.83m | Total Time: 64.08m
# [SimCLR] 079/100 | Loss: 4.0234 | Epoch Time: 0.82m | Total Time: 64.89m
# [SimCLR] 080/100 | Loss: 4.0217 | Epoch Time: 0.82m | Total Time: 65.71m
# [SimCLR] 081/100 | Loss: 4.0213 | Epoch Time: 0.81m | Total Time: 66.52m
# [SimCLR] 082/100 | Loss: 4.0202 | Epoch Time: 0.82m | Total Time: 67.34m
# [SimCLR] 083/100 | Loss: 4.0177 | Epoch Time: 0.84m | Total Time: 68.18m
# [SimCLR] 084/100 | Loss: 4.0167 | Epoch Time: 0.82m | Total Time: 69.00m
# [SimCLR] 085/100 | Loss: 4.0173 | Epoch Time: 0.82m | Total Time: 69.82m
# [SimCLR] 086/100 | Loss: 4.0177 | Epoch Time: 0.82m | Total Time: 70.64m
# [SimCLR] 087/100 | Loss: 4.0152 | Epoch Time: 0.81m | Total Time: 71.46m
# [SimCLR] 088/100 | Loss: 4.0139 | Epoch Time: 0.82m | Total Time: 72.28m
# [SimCLR] 089/100 | Loss: 4.0105 | Epoch Time: 0.81m | Total Time: 73.09m
# [SimCLR] 090/100 | Loss: 4.0122 | Epoch Time: 0.83m | Total Time: 73.91m
# [SimCLR] 091/100 | Loss: 4.0096 | Epoch Time: 0.82m | Total Time: 74.74m
# [SimCLR] 092/100 | Loss: 4.0100 | Epoch Time: 0.83m | Total Time: 75.57m
# [SimCLR] 093/100 | Loss: 4.0096 | Epoch Time: 0.82m | Total Time: 76.39m
# [SimCLR] 094/100 | Loss: 4.0066 | Epoch Time: 0.83m | Total Time: 77.22m
# [SimCLR] 095/100 | Loss: 4.0106 | Epoch Time: 0.83m | Total Time: 78.05m
# [SimCLR] 096/100 | Loss: 4.0077 | Epoch Time: 0.82m | Total Time: 78.87m
# [SimCLR] 097/100 | Loss: 4.0051 | Epoch Time: 0.82m | Total Time: 79.70m
# [SimCLR] 098/100 | Loss: 4.0042 | Epoch Time: 0.82m | Total Time: 80.52m
# [SimCLR] 099/100 | Loss: 4.0023 | Epoch Time: 0.82m | Total Time: 81.34m
# [SimCLR] 100/100 | Loss: 4.0024 | Epoch Time: 0.81m | Total Time: 82.15m
# [SimCLR] 001/100 | Loss: 4.7528 | Epoch Time: 1.72m | Total Time: 1.72m
# [SimCLR] 002/100 | Loss: 4.5231 | Epoch Time: 1.72m | Total Time: 3.44m
# [SimCLR] 003/100 | Loss: 4.4486 | Epoch Time: 1.72m | Total Time: 5.16m
# [SimCLR] 004/100 | Loss: 4.4024 | Epoch Time: 1.72m | Total Time: 6.87m
# [SimCLR] 005/100 | Loss: 4.3627 | Epoch Time: 1.72m | Total Time: 8.59m
# [SimCLR] 006/100 | Loss: 4.3402 | Epoch Time: 1.72m | Total Time: 10.31m
# [SimCLR] 007/100 | Loss: 4.3177 | Epoch Time: 1.72m | Total Time: 12.03m
# [SimCLR] 008/100 | Loss: 4.2980 | Epoch Time: 1.72m | Total Time: 13.75m
# [SimCLR] 009/100 | Loss: 4.2862 | Epoch Time: 1.72m | Total Time: 15.47m
# [SimCLR] 010/100 | Loss: 4.2680 | Epoch Time: 1.72m | Total Time: 17.19m
# [SimCLR] 011/100 | Loss: 4.2521 | Epoch Time: 1.71m | Total Time: 18.90m
# [SimCLR] 012/100 | Loss: 4.2451 | Epoch Time: 1.72m | Total Time: 20.62m
# [SimCLR] 013/100 | Loss: 4.2344 | Epoch Time: 1.72m | Total Time: 22.34m
# [SimCLR] 014/100 | Loss: 4.2208 | Epoch Time: 1.72m | Total Time: 24.05m
# [SimCLR] 015/100 | Loss: 4.2152 | Epoch Time: 1.72m | Total Time: 25.77m
# [SimCLR] 016/100 | Loss: 4.2038 | Epoch Time: 1.72m | Total Time: 27.49m
# [SimCLR] 017/100 | Loss: 4.2013 | Epoch Time: 1.72m | Total Time: 29.21m
# [SimCLR] 018/100 | Loss: 4.1937 | Epoch Time: 1.72m | Total Time: 30.93m
# [SimCLR] 019/100 | Loss: 4.1844 | Epoch Time: 1.72m | Total Time: 32.65m
# [SimCLR] 020/100 | Loss: 4.1816 | Epoch Time: 1.72m | Total Time: 34.36m
# [SimCLR] 021/100 | Loss: 4.1762 | Epoch Time: 1.72m | Total Time: 36.08m
# [SimCLR] 022/100 | Loss: 4.1718 | Epoch Time: 1.72m | Total Time: 37.80m
# [SimCLR] 023/100 | Loss: 4.1683 | Epoch Time: 1.72m | Total Time: 39.52m
# [SimCLR] 024/100 | Loss: 4.1619 | Epoch Time: 1.72m | Total Time: 41.24m
# [SimCLR] 025/100 | Loss: 4.1542 | Epoch Time: 1.72m | Total Time: 42.95m
# [SimCLR] 026/100 | Loss: 4.1534 | Epoch Time: 1.72m | Total Time: 44.67m
# [SimCLR] 027/100 | Loss: 4.1471 | Epoch Time: 1.72m | Total Time: 46.39m
# [SimCLR] 028/100 | Loss: 4.1461 | Epoch Time: 1.72m | Total Time: 48.11m
# [SimCLR] 029/100 | Loss: 4.1425 | Epoch Time: 1.72m | Total Time: 49.82m
# [SimCLR] 030/100 | Loss: 4.1372 | Epoch Time: 1.72m | Total Time: 51.54m
# [SimCLR] 031/100 | Loss: 4.1335 | Epoch Time: 1.72m | Total Time: 53.26m
# [SimCLR] 032/100 | Loss: 4.1335 | Epoch Time: 1.72m | Total Time: 54.98m
# [SimCLR] 033/100 | Loss: 4.1278 | Epoch Time: 1.72m | Total Time: 56.70m
# [SimCLR] 034/100 | Loss: 4.1248 | Epoch Time: 1.72m | Total Time: 58.42m
# [SimCLR] 035/100 | Loss: 4.1239 | Epoch Time: 1.72m | Total Time: 60.14m
# [SimCLR] 036/100 | Loss: 4.1205 | Epoch Time: 1.72m | Total Time: 61.86m
# [SimCLR] 037/100 | Loss: 4.1193 | Epoch Time: 1.71m | Total Time: 63.57m
# [SimCLR] 038/100 | Loss: 4.1132 | Epoch Time: 1.72m | Total Time: 65.29m
# [SimCLR] 039/100 | Loss: 4.1125 | Epoch Time: 1.72m | Total Time: 67.01m
# [SimCLR] 040/100 | Loss: 4.1104 | Epoch Time: 1.72m | Total Time: 68.73m
# [SimCLR] 041/100 | Loss: 4.1062 | Epoch Time: 1.72m | Total Time: 70.45m
# [SimCLR] 042/100 | Loss: 4.1045 | Epoch Time: 1.72m | Total Time: 72.16m
# [SimCLR] 043/100 | Loss: 4.1029 | Epoch Time: 1.72m | Total Time: 73.88m
# [SimCLR] 044/100 | Loss: 4.0993 | Epoch Time: 1.71m | Total Time: 75.60m
# [SimCLR] 045/100 | Loss: 4.0962 | Epoch Time: 1.72m | Total Time: 77.32m
# [SimCLR] 046/100 | Loss: 4.0956 | Epoch Time: 1.72m | Total Time: 79.04m
# [SimCLR] 047/100 | Loss: 4.0929 | Epoch Time: 1.72m | Total Time: 80.75m
# [SimCLR] 048/100 | Loss: 4.0912 | Epoch Time: 1.72m | Total Time: 82.47m
# [SimCLR] 049/100 | Loss: 4.0879 | Epoch Time: 1.72m | Total Time: 84.19m
# [SimCLR] 050/100 | Loss: 4.0875 | Epoch Time: 1.72m | Total Time: 85.91m
# [SimCLR] 051/100 | Loss: 4.0866 | Epoch Time: 1.72m | Total Time: 87.62m
# [SimCLR] 052/100 | Loss: 4.0833 | Epoch Time: 1.72m | Total Time: 89.34m
# [SimCLR] 053/100 | Loss: 4.0845 | Epoch Time: 1.72m | Total Time: 91.06m
# [SimCLR] 054/100 | Loss: 4.0793 | Epoch Time: 1.72m | Total Time: 92.78m
# [SimCLR] 055/100 | Loss: 4.0784 | Epoch Time: 1.72m | Total Time: 94.50m
# [SimCLR] 056/100 | Loss: 4.0789 | Epoch Time: 1.72m | Total Time: 96.22m
# [SimCLR] 057/100 | Loss: 4.0768 | Epoch Time: 1.72m | Total Time: 97.93m
# [SimCLR] 058/100 | Loss: 4.0737 | Epoch Time: 1.72m | Total Time: 99.65m
# [SimCLR] 059/100 | Loss: 4.0748 | Epoch Time: 1.72m | Total Time: 101.37m
# [SimCLR] 060/100 | Loss: 4.0723 | Epoch Time: 1.72m | Total Time: 103.09m
# [SimCLR] 061/100 | Loss: 4.0701 | Epoch Time: 1.72m | Total Time: 104.81m
# [SimCLR] 062/100 | Loss: 4.0675 | Epoch Time: 1.72m | Total Time: 106.52m
# [SimCLR] 063/100 | Loss: 4.0684 | Epoch Time: 1.72m | Total Time: 108.24m
# [SimCLR] 064/100 | Loss: 4.0653 | Epoch Time: 1.72m | Total Time: 109.96m
# [SimCLR] 065/100 | Loss: 4.0674 | Epoch Time: 1.72m | Total Time: 111.68m
# [SimCLR] 066/100 | Loss: 4.0639 | Epoch Time: 1.72m | Total Time: 113.40m
# [SimCLR] 067/100 | Loss: 4.0584 | Epoch Time: 1.72m | Total Time: 115.12m
# [SimCLR] 068/100 | Loss: 4.0634 | Epoch Time: 1.72m | Total Time: 116.83m
# [SimCLR] 069/100 | Loss: 4.0622 | Epoch Time: 1.72m | Total Time: 118.55m
# [SimCLR] 070/100 | Loss: 4.0584 | Epoch Time: 1.72m | Total Time: 120.27m
# [SimCLR] 071/100 | Loss: 4.0574 | Epoch Time: 1.72m | Total Time: 121.99m
# [SimCLR] 072/100 | Loss: 4.0565 | Epoch Time: 1.72m | Total Time: 123.71m
# [SimCLR] 073/100 | Loss: 4.0558 | Epoch Time: 1.72m | Total Time: 125.43m
# [SimCLR] 074/100 | Loss: 4.0576 | Epoch Time: 1.72m | Total Time: 127.15m
# [SimCLR] 075/100 | Loss: 4.0534 | Epoch Time: 1.72m | Total Time: 128.86m
# [SimCLR] 076/100 | Loss: 4.0513 | Epoch Time: 1.72m | Total Time: 130.58m
# [SimCLR] 077/100 | Loss: 4.0486 | Epoch Time: 1.72m | Total Time: 132.30m
# [SimCLR] 078/100 | Loss: 4.0504 | Epoch Time: 1.72m | Total Time: 134.02m
# [SimCLR] 079/100 | Loss: 4.0512 | Epoch Time: 1.72m | Total Time: 135.74m
# [SimCLR] 080/100 | Loss: 4.0481 | Epoch Time: 1.72m | Total Time: 137.45m
# [SimCLR] 081/100 | Loss: 4.0489 | Epoch Time: 1.72m | Total Time: 139.17m
# [SimCLR] 082/100 | Loss: 4.0493 | Epoch Time: 1.72m | Total Time: 140.89m
# [SimCLR] 083/100 | Loss: 4.0455 | Epoch Time: 1.72m | Total Time: 142.61m
# [SimCLR] 084/100 | Loss: 4.0474 | Epoch Time: 1.72m | Total Time: 144.33m
# [SimCLR] 085/100 | Loss: 4.0460 | Epoch Time: 1.72m | Total Time: 146.05m
# [SimCLR] 086/100 | Loss: 4.0446 | Epoch Time: 1.72m | Total Time: 147.76m
# [SimCLR] 087/100 | Loss: 4.0440 | Epoch Time: 1.72m | Total Time: 149.48m
# [SimCLR] 088/100 | Loss: 4.0431 | Epoch Time: 1.72m | Total Time: 151.20m
# [SimCLR] 089/100 | Loss: 4.0408 | Epoch Time: 1.72m | Total Time: 152.91m
# [SimCLR] 090/100 | Loss: 4.0415 | Epoch Time: 1.72m | Total Time: 154.63m
# [SimCLR] 091/100 | Loss: 4.0380 | Epoch Time: 1.72m | Total Time: 156.35m
# [SimCLR] 092/100 | Loss: 4.0405 | Epoch Time: 1.72m | Total Time: 158.07m
# [SimCLR] 093/100 | Loss: 4.0367 | Epoch Time: 1.72m | Total Time: 159.79m
# [SimCLR] 094/100 | Loss: 4.0375 | Epoch Time: 1.72m | Total Time: 161.50m
# [SimCLR] 095/100 | Loss: 4.0365 | Epoch Time: 1.72m | Total Time: 163.22m
# [SimCLR] 096/100 | Loss: 4.0373 | Epoch Time: 1.72m | Total Time: 164.94m
# [SimCLR] 097/100 | Loss: 4.0380 | Epoch Time: 1.72m | Total Time: 166.66m
# [SimCLR] 098/100 | Loss: 4.0358 | Epoch Time: 1.72m | Total Time: 168.38m
# [SimCLR] 099/100 | Loss: 4.0349 | Epoch Time: 1.72m | Total Time: 170.10m
# [SimCLR] 100/100 | Loss: 4.0331 | Epoch Time: 1.72m | Total Time: 171.82m
# Saved results to: /kaggle/working/byol_simclr_results.csv
#
# Running Mean Summary:
#             Seed   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# Method
# BYOL         2.0  64.825742        12.813510          13.276976
# SimCLR       2.0  86.643990        15.600620          18.544576
# SimCLR+Jac   2.0  66.116948        15.781106          15.577176
#
#             Linear_Probe_Acc
# Method
# BYOL                  0.6580
# SimCLR                0.7018
# SimCLR+Jac            0.6700
#
# Seed 2 finished in 333.59 minutes
#
# ====================================
# Running Seed: 3
# ====================================
# [BYOL] 001/100 | Loss: 0.7396 | Epoch Time: 0.75m | Total Time: 0.75m
# [BYOL] 002/100 | Loss: 0.5743 | Epoch Time: 0.77m | Total Time: 1.52m
# [BYOL] 003/100 | Loss: 0.5190 | Epoch Time: 0.77m | Total Time: 2.29m
# [BYOL] 004/100 | Loss: 0.4831 | Epoch Time: 0.76m | Total Time: 3.04m
# [BYOL] 005/100 | Loss: 0.4650 | Epoch Time: 0.77m | Total Time: 3.81m
# [BYOL] 006/100 | Loss: 0.4542 | Epoch Time: 0.77m | Total Time: 4.58m
# [BYOL] 007/100 | Loss: 0.4462 | Epoch Time: 0.76m | Total Time: 5.34m
# [BYOL] 008/100 | Loss: 0.4375 | Epoch Time: 0.77m | Total Time: 6.10m
# [BYOL] 009/100 | Loss: 0.4357 | Epoch Time: 0.76m | Total Time: 6.86m
# [BYOL] 010/100 | Loss: 0.4310 | Epoch Time: 0.75m | Total Time: 7.62m
# [BYOL] 011/100 | Loss: 0.4273 | Epoch Time: 0.76m | Total Time: 8.38m
# [BYOL] 012/100 | Loss: 0.4231 | Epoch Time: 0.76m | Total Time: 9.14m
# [BYOL] 013/100 | Loss: 0.4209 | Epoch Time: 0.77m | Total Time: 9.91m
# [BYOL] 014/100 | Loss: 0.4172 | Epoch Time: 0.77m | Total Time: 10.68m
# [BYOL] 015/100 | Loss: 0.4158 | Epoch Time: 0.76m | Total Time: 11.44m
# [BYOL] 016/100 | Loss: 0.4150 | Epoch Time: 0.75m | Total Time: 12.19m
# [BYOL] 017/100 | Loss: 0.4149 | Epoch Time: 0.76m | Total Time: 12.95m
# [BYOL] 018/100 | Loss: 0.4135 | Epoch Time: 0.76m | Total Time: 13.71m
# [BYOL] 019/100 | Loss: 0.4102 | Epoch Time: 0.76m | Total Time: 14.47m
# [BYOL] 020/100 | Loss: 0.4113 | Epoch Time: 0.77m | Total Time: 15.24m
# [BYOL] 021/100 | Loss: 0.4110 | Epoch Time: 0.76m | Total Time: 16.00m
# [BYOL] 022/100 | Loss: 0.4098 | Epoch Time: 0.76m | Total Time: 16.76m
# [BYOL] 023/100 | Loss: 0.4103 | Epoch Time: 0.77m | Total Time: 17.53m
# [BYOL] 024/100 | Loss: 0.4116 | Epoch Time: 0.76m | Total Time: 18.29m
# [BYOL] 025/100 | Loss: 0.4091 | Epoch Time: 0.77m | Total Time: 19.06m
# [BYOL] 026/100 | Loss: 0.4068 | Epoch Time: 0.78m | Total Time: 19.84m
# [BYOL] 027/100 | Loss: 0.4069 | Epoch Time: 0.77m | Total Time: 20.61m
# [BYOL] 028/100 | Loss: 0.4058 | Epoch Time: 0.76m | Total Time: 21.37m
# [BYOL] 029/100 | Loss: 0.4048 | Epoch Time: 0.77m | Total Time: 22.14m
# [BYOL] 030/100 | Loss: 0.4037 | Epoch Time: 0.76m | Total Time: 22.91m
# [BYOL] 031/100 | Loss: 0.4020 | Epoch Time: 0.77m | Total Time: 23.68m
# [BYOL] 032/100 | Loss: 0.4026 | Epoch Time: 0.76m | Total Time: 24.44m
# [BYOL] 033/100 | Loss: 0.4003 | Epoch Time: 0.76m | Total Time: 25.20m
# [BYOL] 034/100 | Loss: 0.4018 | Epoch Time: 0.76m | Total Time: 25.96m
# [BYOL] 035/100 | Loss: 0.4014 | Epoch Time: 0.77m | Total Time: 26.73m
# [BYOL] 036/100 | Loss: 0.4008 | Epoch Time: 0.76m | Total Time: 27.49m
# [BYOL] 037/100 | Loss: 0.3989 | Epoch Time: 0.77m | Total Time: 28.26m
# [BYOL] 038/100 | Loss: 0.3985 | Epoch Time: 0.76m | Total Time: 29.02m
# [BYOL] 039/100 | Loss: 0.3998 | Epoch Time: 0.76m | Total Time: 29.78m
# [BYOL] 040/100 | Loss: 0.3986 | Epoch Time: 0.76m | Total Time: 30.54m
# [BYOL] 041/100 | Loss: 0.3995 | Epoch Time: 0.77m | Total Time: 31.31m
# [BYOL] 042/100 | Loss: 0.4000 | Epoch Time: 0.76m | Total Time: 32.07m
# [BYOL] 043/100 | Loss: 0.3982 | Epoch Time: 0.76m | Total Time: 32.82m
# [BYOL] 044/100 | Loss: 0.3973 | Epoch Time: 0.77m | Total Time: 33.60m
# [BYOL] 045/100 | Loss: 0.3985 | Epoch Time: 0.75m | Total Time: 34.35m
# [BYOL] 046/100 | Loss: 0.3982 | Epoch Time: 0.77m | Total Time: 35.12m
# [BYOL] 047/100 | Loss: 0.3959 | Epoch Time: 0.77m | Total Time: 35.89m
# [BYOL] 048/100 | Loss: 0.3953 | Epoch Time: 0.76m | Total Time: 36.64m
# [BYOL] 049/100 | Loss: 0.3958 | Epoch Time: 0.76m | Total Time: 37.40m
# [BYOL] 050/100 | Loss: 0.3946 | Epoch Time: 0.76m | Total Time: 38.16m
# [BYOL] 051/100 | Loss: 0.3948 | Epoch Time: 0.76m | Total Time: 38.91m
# [BYOL] 052/100 | Loss: 0.3960 | Epoch Time: 0.76m | Total Time: 39.68m
# [BYOL] 053/100 | Loss: 0.3928 | Epoch Time: 0.76m | Total Time: 40.43m
# [BYOL] 054/100 | Loss: 0.3953 | Epoch Time: 0.76m | Total Time: 41.20m
# [BYOL] 055/100 | Loss: 0.3931 | Epoch Time: 0.76m | Total Time: 41.96m
# [BYOL] 056/100 | Loss: 0.3932 | Epoch Time: 0.75m | Total Time: 42.71m
# [BYOL] 057/100 | Loss: 0.3923 | Epoch Time: 0.76m | Total Time: 43.48m
# [BYOL] 058/100 | Loss: 0.3913 | Epoch Time: 0.76m | Total Time: 44.24m
# [BYOL] 059/100 | Loss: 0.3917 | Epoch Time: 0.76m | Total Time: 45.00m
# [BYOL] 060/100 | Loss: 0.3921 | Epoch Time: 0.78m | Total Time: 45.78m
# [BYOL] 061/100 | Loss: 0.3917 | Epoch Time: 0.77m | Total Time: 46.55m
# [BYOL] 062/100 | Loss: 0.3906 | Epoch Time: 0.77m | Total Time: 47.31m
# [BYOL] 063/100 | Loss: 0.3899 | Epoch Time: 0.76m | Total Time: 48.08m
# [BYOL] 064/100 | Loss: 0.3912 | Epoch Time: 0.77m | Total Time: 48.85m
# [BYOL] 065/100 | Loss: 0.3881 | Epoch Time: 0.77m | Total Time: 49.61m
# [BYOL] 066/100 | Loss: 0.3866 | Epoch Time: 0.77m | Total Time: 50.38m
# [BYOL] 067/100 | Loss: 0.3860 | Epoch Time: 0.76m | Total Time: 51.15m
# [BYOL] 068/100 | Loss: 0.3865 | Epoch Time: 0.76m | Total Time: 51.91m
# [BYOL] 069/100 | Loss: 0.3854 | Epoch Time: 0.77m | Total Time: 52.68m
# [BYOL] 070/100 | Loss: 0.3867 | Epoch Time: 0.77m | Total Time: 53.45m
# [BYOL] 071/100 | Loss: 0.3859 | Epoch Time: 0.77m | Total Time: 54.21m
# [BYOL] 072/100 | Loss: 0.3855 | Epoch Time: 0.76m | Total Time: 54.97m
# [BYOL] 073/100 | Loss: 0.3858 | Epoch Time: 0.77m | Total Time: 55.74m
# [BYOL] 074/100 | Loss: 0.3845 | Epoch Time: 0.77m | Total Time: 56.52m
# [BYOL] 075/100 | Loss: 0.3838 | Epoch Time: 0.76m | Total Time: 57.28m
# [BYOL] 076/100 | Loss: 0.3834 | Epoch Time: 0.77m | Total Time: 58.05m
# [BYOL] 077/100 | Loss: 0.3818 | Epoch Time: 0.77m | Total Time: 58.82m
# [BYOL] 078/100 | Loss: 0.3824 | Epoch Time: 0.77m | Total Time: 59.59m
# [BYOL] 079/100 | Loss: 0.3814 | Epoch Time: 0.77m | Total Time: 60.36m
# [BYOL] 080/100 | Loss: 0.3805 | Epoch Time: 0.76m | Total Time: 61.12m
# [BYOL] 081/100 | Loss: 0.3821 | Epoch Time: 0.76m | Total Time: 61.88m
# [BYOL] 082/100 | Loss: 0.3827 | Epoch Time: 0.76m | Total Time: 62.64m
# [BYOL] 083/100 | Loss: 0.3813 | Epoch Time: 0.77m | Total Time: 63.41m
# [BYOL] 084/100 | Loss: 0.3822 | Epoch Time: 0.75m | Total Time: 64.16m
# [BYOL] 085/100 | Loss: 0.3806 | Epoch Time: 0.76m | Total Time: 64.92m
# [BYOL] 086/100 | Loss: 0.3824 | Epoch Time: 0.77m | Total Time: 65.69m
# [BYOL] 087/100 | Loss: 0.3810 | Epoch Time: 0.76m | Total Time: 66.45m
# [BYOL] 088/100 | Loss: 0.3805 | Epoch Time: 0.76m | Total Time: 67.21m
# [BYOL] 089/100 | Loss: 0.3815 | Epoch Time: 0.77m | Total Time: 67.98m
# [BYOL] 090/100 | Loss: 0.3811 | Epoch Time: 0.76m | Total Time: 68.75m
# [BYOL] 091/100 | Loss: 0.3805 | Epoch Time: 0.76m | Total Time: 69.51m
# [BYOL] 092/100 | Loss: 0.3801 | Epoch Time: 0.77m | Total Time: 70.28m
# [BYOL] 093/100 | Loss: 0.3797 | Epoch Time: 0.77m | Total Time: 71.05m
# [BYOL] 094/100 | Loss: 0.3803 | Epoch Time: 0.78m | Total Time: 71.83m
# [BYOL] 095/100 | Loss: 0.3797 | Epoch Time: 0.76m | Total Time: 72.59m
# [BYOL] 096/100 | Loss: 0.3798 | Epoch Time: 0.76m | Total Time: 73.35m
# [BYOL] 097/100 | Loss: 0.3791 | Epoch Time: 0.77m | Total Time: 74.11m
# [BYOL] 098/100 | Loss: 0.3799 | Epoch Time: 0.78m | Total Time: 74.89m
# [BYOL] 099/100 | Loss: 0.3790 | Epoch Time: 0.78m | Total Time: 75.67m
# [BYOL] 100/100 | Loss: 0.3783 | Epoch Time: 0.77m | Total Time: 76.44m
# [SimCLR] 001/100 | Loss: 4.6769 | Epoch Time: 0.83m | Total Time: 0.83m
# [SimCLR] 002/100 | Loss: 4.4955 | Epoch Time: 0.82m | Total Time: 1.65m
# [SimCLR] 003/100 | Loss: 4.4368 | Epoch Time: 0.82m | Total Time: 2.47m
# [SimCLR] 004/100 | Loss: 4.3882 | Epoch Time: 0.82m | Total Time: 3.29m
# [SimCLR] 005/100 | Loss: 4.3571 | Epoch Time: 0.83m | Total Time: 4.12m
# [SimCLR] 006/100 | Loss: 4.3356 | Epoch Time: 0.83m | Total Time: 4.95m
# [SimCLR] 007/100 | Loss: 4.3187 | Epoch Time: 0.83m | Total Time: 5.78m
# [SimCLR] 008/100 | Loss: 4.2993 | Epoch Time: 0.82m | Total Time: 6.60m
# [SimCLR] 009/100 | Loss: 4.2833 | Epoch Time: 0.83m | Total Time: 7.43m
# [SimCLR] 010/100 | Loss: 4.2658 | Epoch Time: 0.82m | Total Time: 8.25m
# [SimCLR] 011/100 | Loss: 4.2524 | Epoch Time: 0.82m | Total Time: 9.07m
# [SimCLR] 012/100 | Loss: 4.2406 | Epoch Time: 0.83m | Total Time: 9.90m
# [SimCLR] 013/100 | Loss: 4.2277 | Epoch Time: 0.84m | Total Time: 10.74m
# [SimCLR] 014/100 | Loss: 4.2158 | Epoch Time: 0.83m | Total Time: 11.57m
# [SimCLR] 015/100 | Loss: 4.2049 | Epoch Time: 0.82m | Total Time: 12.39m
# [SimCLR] 016/100 | Loss: 4.1968 | Epoch Time: 0.82m | Total Time: 13.20m
# [SimCLR] 017/100 | Loss: 4.1895 | Epoch Time: 0.87m | Total Time: 14.07m
# [SimCLR] 018/100 | Loss: 4.1836 | Epoch Time: 0.84m | Total Time: 14.91m
# [SimCLR] 019/100 | Loss: 4.1758 | Epoch Time: 0.83m | Total Time: 15.74m
# [SimCLR] 020/100 | Loss: 4.1724 | Epoch Time: 0.83m | Total Time: 16.58m
# [SimCLR] 021/100 | Loss: 4.1606 | Epoch Time: 0.84m | Total Time: 17.42m
# [SimCLR] 022/100 | Loss: 4.1552 | Epoch Time: 0.83m | Total Time: 18.25m
# [SimCLR] 023/100 | Loss: 4.1503 | Epoch Time: 0.83m | Total Time: 19.08m
# [SimCLR] 024/100 | Loss: 4.1436 | Epoch Time: 0.83m | Total Time: 19.91m
# [SimCLR] 025/100 | Loss: 4.1441 | Epoch Time: 0.84m | Total Time: 20.75m
# [SimCLR] 026/100 | Loss: 4.1342 | Epoch Time: 0.84m | Total Time: 21.59m
# [SimCLR] 027/100 | Loss: 4.1322 | Epoch Time: 0.82m | Total Time: 22.41m
# [SimCLR] 028/100 | Loss: 4.1299 | Epoch Time: 0.83m | Total Time: 23.24m
# [SimCLR] 029/100 | Loss: 4.1261 | Epoch Time: 0.84m | Total Time: 24.08m
# [SimCLR] 030/100 | Loss: 4.1188 | Epoch Time: 0.82m | Total Time: 24.90m
# [SimCLR] 031/100 | Loss: 4.1179 | Epoch Time: 0.83m | Total Time: 25.73m
# [SimCLR] 032/100 | Loss: 4.1171 | Epoch Time: 0.82m | Total Time: 26.55m
# [SimCLR] 033/100 | Loss: 4.1116 | Epoch Time: 0.82m | Total Time: 27.36m
# [SimCLR] 034/100 | Loss: 4.1097 | Epoch Time: 0.81m | Total Time: 28.17m
# [SimCLR] 035/100 | Loss: 4.1040 | Epoch Time: 0.81m | Total Time: 28.99m
# [SimCLR] 036/100 | Loss: 4.1025 | Epoch Time: 0.83m | Total Time: 29.82m
# [SimCLR] 037/100 | Loss: 4.0946 | Epoch Time: 0.84m | Total Time: 30.66m
# [SimCLR] 038/100 | Loss: 4.0924 | Epoch Time: 0.85m | Total Time: 31.51m
# [SimCLR] 039/100 | Loss: 4.0904 | Epoch Time: 0.83m | Total Time: 32.33m
# [SimCLR] 040/100 | Loss: 4.0869 | Epoch Time: 0.84m | Total Time: 33.17m
# [SimCLR] 041/100 | Loss: 4.0883 | Epoch Time: 0.82m | Total Time: 34.00m
# [SimCLR] 042/100 | Loss: 4.0823 | Epoch Time: 0.83m | Total Time: 34.83m
# [SimCLR] 043/100 | Loss: 4.0807 | Epoch Time: 0.83m | Total Time: 35.66m
# [SimCLR] 044/100 | Loss: 4.0805 | Epoch Time: 0.84m | Total Time: 36.50m
# [SimCLR] 045/100 | Loss: 4.0766 | Epoch Time: 0.83m | Total Time: 37.33m
# [SimCLR] 046/100 | Loss: 4.0744 | Epoch Time: 0.84m | Total Time: 38.17m
# [SimCLR] 047/100 | Loss: 4.0712 | Epoch Time: 0.84m | Total Time: 39.01m
# [SimCLR] 048/100 | Loss: 4.0703 | Epoch Time: 0.84m | Total Time: 39.85m
# [SimCLR] 049/100 | Loss: 4.0680 | Epoch Time: 0.86m | Total Time: 40.71m
# [SimCLR] 050/100 | Loss: 4.0664 | Epoch Time: 0.84m | Total Time: 41.55m
# [SimCLR] 051/100 | Loss: 4.0606 | Epoch Time: 0.85m | Total Time: 42.39m
# [SimCLR] 052/100 | Loss: 4.0607 | Epoch Time: 0.83m | Total Time: 43.23m
# [SimCLR] 053/100 | Loss: 4.0611 | Epoch Time: 0.83m | Total Time: 44.05m
# [SimCLR] 054/100 | Loss: 4.0570 | Epoch Time: 0.83m | Total Time: 44.89m
# [SimCLR] 055/100 | Loss: 4.0561 | Epoch Time: 0.85m | Total Time: 45.74m
# [SimCLR] 056/100 | Loss: 4.0516 | Epoch Time: 0.83m | Total Time: 46.57m
# [SimCLR] 057/100 | Loss: 4.0528 | Epoch Time: 0.82m | Total Time: 47.39m
# [SimCLR] 058/100 | Loss: 4.0513 | Epoch Time: 0.82m | Total Time: 48.22m
# [SimCLR] 059/100 | Loss: 4.0476 | Epoch Time: 0.82m | Total Time: 49.04m
# [SimCLR] 060/100 | Loss: 4.0471 | Epoch Time: 0.83m | Total Time: 49.87m
# [SimCLR] 061/100 | Loss: 4.0440 | Epoch Time: 0.83m | Total Time: 50.70m
# [SimCLR] 062/100 | Loss: 4.0479 | Epoch Time: 0.83m | Total Time: 51.53m
# [SimCLR] 063/100 | Loss: 4.0407 | Epoch Time: 0.82m | Total Time: 52.35m
# [SimCLR] 064/100 | Loss: 4.0398 | Epoch Time: 0.82m | Total Time: 53.17m
# [SimCLR] 065/100 | Loss: 4.0393 | Epoch Time: 0.82m | Total Time: 54.00m
# [SimCLR] 066/100 | Loss: 4.0378 | Epoch Time: 0.83m | Total Time: 54.82m
# [SimCLR] 067/100 | Loss: 4.0378 | Epoch Time: 0.82m | Total Time: 55.65m
# [SimCLR] 068/100 | Loss: 4.0364 | Epoch Time: 0.82m | Total Time: 56.47m
# [SimCLR] 069/100 | Loss: 4.0294 | Epoch Time: 0.83m | Total Time: 57.29m
# [SimCLR] 070/100 | Loss: 4.0301 | Epoch Time: 0.82m | Total Time: 58.11m
# [SimCLR] 071/100 | Loss: 4.0325 | Epoch Time: 0.82m | Total Time: 58.93m
# [SimCLR] 072/100 | Loss: 4.0282 | Epoch Time: 0.81m | Total Time: 59.74m
# [SimCLR] 073/100 | Loss: 4.0267 | Epoch Time: 0.83m | Total Time: 60.57m
# [SimCLR] 074/100 | Loss: 4.0258 | Epoch Time: 0.83m | Total Time: 61.40m
# [SimCLR] 075/100 | Loss: 4.0243 | Epoch Time: 0.82m | Total Time: 62.22m
# [SimCLR] 076/100 | Loss: 4.0265 | Epoch Time: 0.83m | Total Time: 63.05m
# [SimCLR] 077/100 | Loss: 4.0234 | Epoch Time: 0.82m | Total Time: 63.87m
# [SimCLR] 078/100 | Loss: 4.0220 | Epoch Time: 0.83m | Total Time: 64.69m
# [SimCLR] 079/100 | Loss: 4.0218 | Epoch Time: 0.82m | Total Time: 65.51m
# [SimCLR] 080/100 | Loss: 4.0213 | Epoch Time: 0.82m | Total Time: 66.33m
# [SimCLR] 081/100 | Loss: 4.0192 | Epoch Time: 0.82m | Total Time: 67.15m
# [SimCLR] 082/100 | Loss: 4.0217 | Epoch Time: 0.84m | Total Time: 67.99m
# [SimCLR] 083/100 | Loss: 4.0166 | Epoch Time: 0.83m | Total Time: 68.83m
# [SimCLR] 084/100 | Loss: 4.0156 | Epoch Time: 0.83m | Total Time: 69.66m
# [SimCLR] 085/100 | Loss: 4.0133 | Epoch Time: 0.82m | Total Time: 70.47m
# [SimCLR] 086/100 | Loss: 4.0116 | Epoch Time: 0.84m | Total Time: 71.31m
# [SimCLR] 087/100 | Loss: 4.0113 | Epoch Time: 0.83m | Total Time: 72.14m
# [SimCLR] 088/100 | Loss: 4.0114 | Epoch Time: 0.82m | Total Time: 72.97m
# [SimCLR] 089/100 | Loss: 4.0098 | Epoch Time: 0.81m | Total Time: 73.77m
# [SimCLR] 090/100 | Loss: 4.0103 | Epoch Time: 0.82m | Total Time: 74.59m
# [SimCLR] 091/100 | Loss: 4.0097 | Epoch Time: 0.83m | Total Time: 75.41m
# [SimCLR] 092/100 | Loss: 4.0114 | Epoch Time: 0.82m | Total Time: 76.24m
# [SimCLR] 093/100 | Loss: 4.0092 | Epoch Time: 0.83m | Total Time: 77.06m
# [SimCLR] 094/100 | Loss: 4.0059 | Epoch Time: 0.82m | Total Time: 77.88m
# [SimCLR] 095/100 | Loss: 4.0051 | Epoch Time: 0.84m | Total Time: 78.72m
# [SimCLR] 096/100 | Loss: 4.0069 | Epoch Time: 0.83m | Total Time: 79.55m
# [SimCLR] 097/100 | Loss: 4.0022 | Epoch Time: 0.82m | Total Time: 80.37m
# [SimCLR] 098/100 | Loss: 4.0042 | Epoch Time: 0.82m | Total Time: 81.19m
# [SimCLR] 099/100 | Loss: 4.0028 | Epoch Time: 0.83m | Total Time: 82.02m
# [SimCLR] 100/100 | Loss: 4.0023 | Epoch Time: 0.82m | Total Time: 82.84m
# [SimCLR] 001/100 | Loss: 4.7392 | Epoch Time: 1.71m | Total Time: 1.71m
# [SimCLR] 002/100 | Loss: 4.5145 | Epoch Time: 1.72m | Total Time: 3.43m
# [SimCLR] 003/100 | Loss: 4.4353 | Epoch Time: 1.72m | Total Time: 5.15m
# [SimCLR] 004/100 | Loss: 4.3889 | Epoch Time: 1.72m | Total Time: 6.87m
# [SimCLR] 005/100 | Loss: 4.3557 | Epoch Time: 1.72m | Total Time: 8.59m
# [SimCLR] 006/100 | Loss: 4.3313 | Epoch Time: 1.72m | Total Time: 10.31m
# [SimCLR] 007/100 | Loss: 4.3039 | Epoch Time: 1.72m | Total Time: 12.03m
# [SimCLR] 008/100 | Loss: 4.2888 | Epoch Time: 1.72m | Total Time: 13.75m
# [SimCLR] 009/100 | Loss: 4.2728 | Epoch Time: 1.72m | Total Time: 15.46m
# [SimCLR] 010/100 | Loss: 4.2612 | Epoch Time: 1.72m | Total Time: 17.18m
# [SimCLR] 011/100 | Loss: 4.2490 | Epoch Time: 1.72m | Total Time: 18.90m
# [SimCLR] 012/100 | Loss: 4.2393 | Epoch Time: 1.72m | Total Time: 20.62m
# [SimCLR] 013/100 | Loss: 4.2276 | Epoch Time: 1.72m | Total Time: 22.34m
# [SimCLR] 014/100 | Loss: 4.2251 | Epoch Time: 1.71m | Total Time: 24.05m
# [SimCLR] 015/100 | Loss: 4.2117 | Epoch Time: 1.71m | Total Time: 25.76m
# [SimCLR] 016/100 | Loss: 4.2057 | Epoch Time: 1.72m | Total Time: 27.48m
# [SimCLR] 017/100 | Loss: 4.1975 | Epoch Time: 1.72m | Total Time: 29.20m
# [SimCLR] 018/100 | Loss: 4.1878 | Epoch Time: 1.72m | Total Time: 30.92m
# [SimCLR] 019/100 | Loss: 4.1845 | Epoch Time: 1.71m | Total Time: 32.63m
# [SimCLR] 020/100 | Loss: 4.1794 | Epoch Time: 1.72m | Total Time: 34.35m
# [SimCLR] 021/100 | Loss: 4.1735 | Epoch Time: 1.72m | Total Time: 36.07m
# [SimCLR] 022/100 | Loss: 4.1668 | Epoch Time: 1.72m | Total Time: 37.79m
# [SimCLR] 023/100 | Loss: 4.1628 | Epoch Time: 1.72m | Total Time: 39.51m
# [SimCLR] 024/100 | Loss: 4.1601 | Epoch Time: 1.72m | Total Time: 41.22m
# [SimCLR] 025/100 | Loss: 4.1542 | Epoch Time: 1.72m | Total Time: 42.94m
# [SimCLR] 026/100 | Loss: 4.1517 | Epoch Time: 1.72m | Total Time: 44.66m
# [SimCLR] 027/100 | Loss: 4.1472 | Epoch Time: 1.72m | Total Time: 46.38m
# [SimCLR] 028/100 | Loss: 4.1429 | Epoch Time: 1.72m | Total Time: 48.10m
# [SimCLR] 029/100 | Loss: 4.1431 | Epoch Time: 1.71m | Total Time: 49.82m
# [SimCLR] 030/100 | Loss: 4.1346 | Epoch Time: 1.72m | Total Time: 51.53m
# [SimCLR] 031/100 | Loss: 4.1332 | Epoch Time: 1.72m | Total Time: 53.25m
# [SimCLR] 032/100 | Loss: 4.1305 | Epoch Time: 1.72m | Total Time: 54.97m
# [SimCLR] 033/100 | Loss: 4.1277 | Epoch Time: 1.72m | Total Time: 56.69m
# [SimCLR] 034/100 | Loss: 4.1264 | Epoch Time: 1.72m | Total Time: 58.41m
# [SimCLR] 035/100 | Loss: 4.1211 | Epoch Time: 1.72m | Total Time: 60.13m
# [SimCLR] 036/100 | Loss: 4.1186 | Epoch Time: 1.72m | Total Time: 61.85m
# [SimCLR] 037/100 | Loss: 4.1150 | Epoch Time: 1.72m | Total Time: 63.57m
# [SimCLR] 038/100 | Loss: 4.1139 | Epoch Time: 1.72m | Total Time: 65.28m
# [SimCLR] 039/100 | Loss: 4.1123 | Epoch Time: 1.72m | Total Time: 67.00m
# [SimCLR] 040/100 | Loss: 4.1102 | Epoch Time: 1.72m | Total Time: 68.72m
# [SimCLR] 041/100 | Loss: 4.1072 | Epoch Time: 1.72m | Total Time: 70.44m
# [SimCLR] 042/100 | Loss: 4.1022 | Epoch Time: 1.72m | Total Time: 72.16m
# [SimCLR] 043/100 | Loss: 4.1020 | Epoch Time: 1.72m | Total Time: 73.87m
# [SimCLR] 044/100 | Loss: 4.0994 | Epoch Time: 1.71m | Total Time: 75.59m
# [SimCLR] 045/100 | Loss: 4.0991 | Epoch Time: 1.72m | Total Time: 77.31m
# [SimCLR] 046/100 | Loss: 4.0952 | Epoch Time: 1.72m | Total Time: 79.03m
# [SimCLR] 047/100 | Loss: 4.0932 | Epoch Time: 1.71m | Total Time: 80.74m
# [SimCLR] 048/100 | Loss: 4.0943 | Epoch Time: 1.72m | Total Time: 82.46m
# [SimCLR] 049/100 | Loss: 4.0913 | Epoch Time: 1.72m | Total Time: 84.18m
# [SimCLR] 050/100 | Loss: 4.0887 | Epoch Time: 1.72m | Total Time: 85.90m
# [SimCLR] 051/100 | Loss: 4.0882 | Epoch Time: 1.72m | Total Time: 87.62m
# [SimCLR] 052/100 | Loss: 4.0846 | Epoch Time: 1.72m | Total Time: 89.33m
# [SimCLR] 053/100 | Loss: 4.0867 | Epoch Time: 1.72m | Total Time: 91.05m
# [SimCLR] 054/100 | Loss: 4.0848 | Epoch Time: 1.72m | Total Time: 92.77m
# [SimCLR] 055/100 | Loss: 4.0804 | Epoch Time: 1.72m | Total Time: 94.49m
# [SimCLR] 056/100 | Loss: 4.0778 | Epoch Time: 1.72m | Total Time: 96.21m
# [SimCLR] 057/100 | Loss: 4.0758 | Epoch Time: 1.71m | Total Time: 97.92m
# [SimCLR] 058/100 | Loss: 4.0739 | Epoch Time: 1.72m | Total Time: 99.64m
# [SimCLR] 059/100 | Loss: 4.0725 | Epoch Time: 1.72m | Total Time: 101.36m
# [SimCLR] 060/100 | Loss: 4.0736 | Epoch Time: 1.72m | Total Time: 103.08m
# [SimCLR] 061/100 | Loss: 4.0697 | Epoch Time: 1.72m | Total Time: 104.80m
# [SimCLR] 062/100 | Loss: 4.0663 | Epoch Time: 1.72m | Total Time: 106.52m
# [SimCLR] 063/100 | Loss: 4.0676 | Epoch Time: 1.72m | Total Time: 108.23m
# [SimCLR] 064/100 | Loss: 4.0655 | Epoch Time: 1.72m | Total Time: 109.95m
# [SimCLR] 065/100 | Loss: 4.0656 | Epoch Time: 1.72m | Total Time: 111.67m
# [SimCLR] 066/100 | Loss: 4.0616 | Epoch Time: 1.72m | Total Time: 113.39m
# [SimCLR] 067/100 | Loss: 4.0633 | Epoch Time: 1.72m | Total Time: 115.11m
# [SimCLR] 068/100 | Loss: 4.0584 | Epoch Time: 1.72m | Total Time: 116.83m
# [SimCLR] 069/100 | Loss: 4.0636 | Epoch Time: 1.72m | Total Time: 118.55m
# [SimCLR] 070/100 | Loss: 4.0618 | Epoch Time: 1.72m | Total Time: 120.27m
# [SimCLR] 071/100 | Loss: 4.0555 | Epoch Time: 1.72m | Total Time: 121.99m
# [SimCLR] 072/100 | Loss: 4.0578 | Epoch Time: 1.72m | Total Time: 123.71m
# [SimCLR] 073/100 | Loss: 4.0573 | Epoch Time: 1.72m | Total Time: 125.43m
# [SimCLR] 074/100 | Loss: 4.0552 | Epoch Time: 1.72m | Total Time: 127.15m
# [SimCLR] 075/100 | Loss: 4.0524 | Epoch Time: 1.72m | Total Time: 128.87m
# [SimCLR] 076/100 | Loss: 4.0511 | Epoch Time: 1.72m | Total Time: 130.58m
# [SimCLR] 077/100 | Loss: 4.0541 | Epoch Time: 1.72m | Total Time: 132.30m
# [SimCLR] 078/100 | Loss: 4.0501 | Epoch Time: 1.72m | Total Time: 134.02m
# [SimCLR] 079/100 | Loss: 4.0494 | Epoch Time: 1.72m | Total Time: 135.74m
# [SimCLR] 080/100 | Loss: 4.0466 | Epoch Time: 1.72m | Total Time: 137.46m
# [SimCLR] 081/100 | Loss: 4.0485 | Epoch Time: 1.72m | Total Time: 139.18m
# [SimCLR] 082/100 | Loss: 4.0468 | Epoch Time: 1.72m | Total Time: 140.90m
# [SimCLR] 083/100 | Loss: 4.0465 | Epoch Time: 1.72m | Total Time: 142.61m
# [SimCLR] 084/100 | Loss: 4.0451 | Epoch Time: 1.72m | Total Time: 144.33m
# [SimCLR] 085/100 | Loss: 4.0431 | Epoch Time: 1.72m | Total Time: 146.05m
# [SimCLR] 086/100 | Loss: 4.0423 | Epoch Time: 1.72m | Total Time: 147.77m
# [SimCLR] 087/100 | Loss: 4.0404 | Epoch Time: 1.72m | Total Time: 149.49m
# [SimCLR] 088/100 | Loss: 4.0410 | Epoch Time: 1.72m | Total Time: 151.21m
# [SimCLR] 089/100 | Loss: 4.0417 | Epoch Time: 1.72m | Total Time: 152.93m
# [SimCLR] 090/100 | Loss: 4.0391 | Epoch Time: 1.72m | Total Time: 154.65m
# [SimCLR] 091/100 | Loss: 4.0423 | Epoch Time: 1.72m | Total Time: 156.37m
# [SimCLR] 092/100 | Loss: 4.0411 | Epoch Time: 1.72m | Total Time: 158.09m
# [SimCLR] 093/100 | Loss: 4.0359 | Epoch Time: 1.72m | Total Time: 159.81m
# [SimCLR] 094/100 | Loss: 4.0356 | Epoch Time: 1.72m | Total Time: 161.53m
# [SimCLR] 095/100 | Loss: 4.0352 | Epoch Time: 1.72m | Total Time: 163.25m
# [SimCLR] 096/100 | Loss: 4.0336 | Epoch Time: 1.72m | Total Time: 164.97m
# [SimCLR] 097/100 | Loss: 4.0344 | Epoch Time: 1.72m | Total Time: 166.68m
# [SimCLR] 098/100 | Loss: 4.0333 | Epoch Time: 1.72m | Total Time: 168.40m
# [SimCLR] 099/100 | Loss: 4.0342 | Epoch Time: 1.72m | Total Time: 170.12m
# [SimCLR] 100/100 | Loss: 4.0302 | Epoch Time: 1.72m | Total Time: 171.84m
# Saved results to: /kaggle/working/byol_simclr_results.csv
#
# Running Mean Summary:
#             Seed   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# Method
# BYOL         2.5  64.812246        13.068891          13.757254
# SimCLR       2.5  85.987499        15.410447          18.165172
# SimCLR+Jac   2.5  65.321019        15.109035          15.539095
#
#             Linear_Probe_Acc
# Method
# BYOL                 0.65640
# SimCLR               0.70025
# SimCLR+Jac           0.67275
#
# Seed 3 finished in 333.77 minutes
#
# ================ FINAL RESULTS ================
#    Seed      Method   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# 0     2        BYOL  64.825742        12.813510          13.276976
# 1     2      SimCLR  86.643990        15.600620          18.544576
# 2     2  SimCLR+Jac  66.116948        15.781106          15.577176
# 3     3        BYOL  64.798750        13.324272          14.237532
# 4     3      SimCLR  85.331009        15.220275          17.785767
# 5     3  SimCLR+Jac  64.525089        14.436964          15.501014
#
#    Linear_Probe_Acc
# 0            0.6580
# 1            0.7018
# 2            0.6700
# 3            0.6548
# 4            0.6987
# 5            0.6755
#
# Total experiment time (this session): 667.36 minutes
