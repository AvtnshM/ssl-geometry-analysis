# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import numpy as np
import random
import pandas as pd
import time
import scipy.stats as stats

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def set_seed(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
# Out:
# Device: cuda

# %%
class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform
    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)

ssl_base_transform = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2,1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=ssl_transform
)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=T.ToTensor()
)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)
# Out:
# 100%|██████████| 170M/170M [00:15<00:00, 11.1MB/s]

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        backbone = resnet18(weights=None)
        backbone.fc = nn.Identity()
        self.backbone = backbone
    def forward(self, x):
        return self.backbone(x)

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, hidden_dim=2048, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )
    def forward(self, x):
        return self.net(x)

class BYOL(nn.Module):
    def __init__(self):
        super().__init__()
        self.online_encoder = Encoder()
        self.online_projector = MLP(512)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder = Encoder()
        self.target_projector = MLP(512)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for o, t in zip(self.online_encoder.parameters(),
                        self.target_encoder.parameters()):
            t.data = tau * t.data + (1 - tau) * o.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(
            self.online_projector(self.online_encoder(x1))
        )

        with torch.no_grad():
            t2 = self.target_projector(
                self.target_encoder(x2)
            )

        loss = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        return loss.mean()

# %%
class SimCLR(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.projector = MLP(512)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)

def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)

    sim = torch.mm(z, z.t()) / temperature
    mask = torch.eye(2*N, device=z.device).bool()
    sim.masked_fill_(mask, -9e15)

    positives = torch.cat([
        torch.arange(N,2*N),
        torch.arange(0,N)
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
def jacobian_penalty(model, x):
    x = x.clone().detach().requires_grad_(True)
    z = model(x)

    v = torch.randn_like(z)

    Jv = torch.autograd.grad(
        outputs=z,
        inputs=x,
        grad_outputs=v,
        create_graph=True
    )[0]

    return Jv.pow(2).sum(dim=[1,2,3]).mean()

# %%
def train_byol(model, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            loss = model(x1,x2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            model.update_target()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[BYOL] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.online_encoder


def train_simclr(model, epochs=100, lambda_jac=0.0):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            z1 = model(x1)
            z2 = model(x2)
            loss = nt_xent_loss(z1,z2)

            if lambda_jac > 0:
                jac = jacobian_penalty(model, x1)
                loss = loss + lambda_jac * jac

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[SimCLR] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.encoder

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(512, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    return correct / total

# %%
# =========================================================
# Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
])


def jacobian_frobenius(model, x):
    model.eval()
    x = x.clone().detach().requires_grad_(True)

    y = model(x)

    v = torch.randn_like(y)

    Jv = torch.autograd.grad(
        outputs=y,
        inputs=x,
        grad_outputs=v,
        create_graph=False,
        retain_graph=False
    )[0]

    # Proper per-sample Frobenius estimate
    per_sample = Jv.pow(2).flatten(1).sum(dim=1)

    return torch.sqrt(per_sample.mean())


def compute_metrics(encoder, loader):
    encoder = encoder.to(device)
    encoder.eval()

    jac_vals = []
    aug_vals = []
    noise_vals = []

    for i, (x, _) in enumerate(loader):
        if i == 5:  # limit batches
            break

        x = x.to(device)

        # ---- Jacobian ----
        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # ---- Augmentation Sensitivity ----
        x_aug = torch.stack([
            tensor_aug(img.cpu()) for img in x
        ]).to(device)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        # ---- Noise Sensitivity ----
        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x + noise)
            noise_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

    return (
        np.mean(jac_vals),
        np.mean(aug_vals),
        np.mean(noise_vals)
    )

# %%
# =========================================================
# Supervised Data (for Linear Probe)
# =========================================================

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=False,
    transform=T.ToTensor()
)

supervised_test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=False,
    transform=T.ToTensor()
)

supervised_train_loader = DataLoader(
    supervised_train_dataset,
    batch_size=128,
    shuffle=True,
    num_workers=2
)

supervised_test_loader = DataLoader(
    supervised_test_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=2
)

print("Supervised loaders ready.")
# Out:
# Supervised loaders ready.

# %%
import os

# =========================================================
# CONFIG
# =========================================================

csv_path = "/kaggle/working/byol_simclr_results.csv"
target_seeds = [9]  

# =========================================================
# RESUME LOGIC
# =========================================================

if os.path.exists(csv_path):
    existing_df = pd.read_csv(csv_path)
    completed_seeds = set(existing_df["Seed"].unique())
    all_results = existing_df.to_dict("records")
    print("Loaded existing results. Completed seeds:", completed_seeds)
else:
    completed_seeds = set()
    all_results = []
    print("No existing CSV found. Starting fresh.")

seeds = [s for s in target_seeds if s not in completed_seeds]

print("Seeds to run now:", seeds)

global_start = time.time()

# =========================================================
# MAIN LOOP
# =========================================================

for seed in seeds:

    print("\n====================================")
    print(f"Running Seed: {seed}")
    print("====================================")

    seed_start = time.time()
    set_seed(seed)

    # ------------------------
    # Train Models
    # ------------------------

    byol_encoder = train_byol(BYOL(), epochs=100)

    simclr_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=0.0
    )

    simclr_jac_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=1e-3
    )

    # ------------------------
    # Compute Metrics
    # ------------------------

    byol_metrics = compute_metrics(byol_encoder, test_loader)
    simclr_metrics = compute_metrics(simclr_encoder, test_loader)
    simclr_jac_metrics = compute_metrics(simclr_jac_encoder, test_loader)

    # ------------------------
    # Linear Probe
    # ------------------------

    byol_acc = train_probe(
        byol_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_acc = train_probe(
        simclr_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_jac_acc = train_probe(
        simclr_jac_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    # ------------------------
    # Store Results
    # ------------------------

    seed_results = [
        {
            "Seed": seed,
            "Method": "BYOL",
            "Jacobian": byol_metrics[0],
            "Aug_Sensitivity": byol_metrics[1],
            "Noise_Sensitivity": byol_metrics[2],
            "Linear_Probe_Acc": byol_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR",
            "Jacobian": simclr_metrics[0],
            "Aug_Sensitivity": simclr_metrics[1],
            "Noise_Sensitivity": simclr_metrics[2],
            "Linear_Probe_Acc": simclr_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR+Jac",
            "Jacobian": simclr_jac_metrics[0],
            "Aug_Sensitivity": simclr_jac_metrics[1],
            "Noise_Sensitivity": simclr_jac_metrics[2],
            "Linear_Probe_Acc": simclr_jac_acc
        }
    ]

    all_results.extend(seed_results)

    # ------------------------
    # SAVE AFTER EACH SEED
    # ------------------------

    results_df = pd.DataFrame(all_results)
    results_df.to_csv(csv_path, index=False)

    print("Saved results to:", csv_path)

    # ------------------------
    # Running Summary
    # ------------------------

    summary = results_df.groupby("Method").mean(numeric_only=True)
    print("\nRunning Mean Summary:")
    print(summary)

    # ------------------------
    # GPU Cleanup
    # ------------------------

    del byol_encoder, simclr_encoder, simclr_jac_encoder
    torch.cuda.empty_cache()

    seed_time = (time.time() - seed_start) / 60
    print(f"\nSeed {seed} finished in {seed_time:.2f} minutes")

# =========================================================
# FINAL SUMMARY
# =========================================================

final_df = pd.read_csv(csv_path)

print("\n================ FINAL RESULTS ================")
print(final_df)

total_time = (time.time() - global_start) / 60
print(f"\nTotal experiment time (this session): {total_time:.2f} minutes")
# Out:
# No existing CSV found. Starting fresh.
# Seeds to run now: [9]
#
# ====================================
# Running Seed: 9
# ====================================
# [BYOL] 001/100 | Loss: 0.8128 | Epoch Time: 0.82m | Total Time: 0.82m
# [BYOL] 002/100 | Loss: 0.6284 | Epoch Time: 0.80m | Total Time: 1.62m
# [BYOL] 003/100 | Loss: 0.5564 | Epoch Time: 0.80m | Total Time: 2.42m
# [BYOL] 004/100 | Loss: 0.5266 | Epoch Time: 0.81m | Total Time: 3.23m
# [BYOL] 005/100 | Loss: 0.5105 | Epoch Time: 0.80m | Total Time: 4.03m
# [BYOL] 006/100 | Loss: 0.4970 | Epoch Time: 0.80m | Total Time: 4.83m
# [BYOL] 007/100 | Loss: 0.4871 | Epoch Time: 0.82m | Total Time: 5.65m
# [BYOL] 008/100 | Loss: 0.4796 | Epoch Time: 0.79m | Total Time: 6.45m
# [BYOL] 009/100 | Loss: 0.4730 | Epoch Time: 0.80m | Total Time: 7.25m
# [BYOL] 010/100 | Loss: 0.4631 | Epoch Time: 0.81m | Total Time: 8.06m
# [BYOL] 011/100 | Loss: 0.4590 | Epoch Time: 0.81m | Total Time: 8.87m
# [BYOL] 012/100 | Loss: 0.4566 | Epoch Time: 0.81m | Total Time: 9.68m
# [BYOL] 013/100 | Loss: 0.4508 | Epoch Time: 0.83m | Total Time: 10.51m
# [BYOL] 014/100 | Loss: 0.4485 | Epoch Time: 0.82m | Total Time: 11.32m
# [BYOL] 015/100 | Loss: 0.4440 | Epoch Time: 0.82m | Total Time: 12.14m
# [BYOL] 016/100 | Loss: 0.4409 | Epoch Time: 0.82m | Total Time: 12.97m
# [BYOL] 017/100 | Loss: 0.4377 | Epoch Time: 0.83m | Total Time: 13.79m
# [BYOL] 018/100 | Loss: 0.4367 | Epoch Time: 0.83m | Total Time: 14.63m
# [BYOL] 019/100 | Loss: 0.4331 | Epoch Time: 0.83m | Total Time: 15.45m
# [BYOL] 020/100 | Loss: 0.4318 | Epoch Time: 0.83m | Total Time: 16.28m
# [BYOL] 021/100 | Loss: 0.4319 | Epoch Time: 0.84m | Total Time: 17.12m
# [BYOL] 022/100 | Loss: 0.4294 | Epoch Time: 0.83m | Total Time: 17.95m
# [BYOL] 023/100 | Loss: 0.4290 | Epoch Time: 0.84m | Total Time: 18.79m
# [BYOL] 024/100 | Loss: 0.4247 | Epoch Time: 0.83m | Total Time: 19.62m
# [BYOL] 025/100 | Loss: 0.4241 | Epoch Time: 0.83m | Total Time: 20.44m
# [BYOL] 026/100 | Loss: 0.4256 | Epoch Time: 0.84m | Total Time: 21.28m
# [BYOL] 027/100 | Loss: 0.4251 | Epoch Time: 0.83m | Total Time: 22.11m
# [BYOL] 028/100 | Loss: 0.4218 | Epoch Time: 0.83m | Total Time: 22.94m
# [BYOL] 029/100 | Loss: 0.4226 | Epoch Time: 0.83m | Total Time: 23.77m
# [BYOL] 030/100 | Loss: 0.4217 | Epoch Time: 0.83m | Total Time: 24.60m
# [BYOL] 031/100 | Loss: 0.4214 | Epoch Time: 0.80m | Total Time: 25.40m
# [BYOL] 032/100 | Loss: 0.4197 | Epoch Time: 0.81m | Total Time: 26.21m
# [BYOL] 033/100 | Loss: 0.4176 | Epoch Time: 0.81m | Total Time: 27.02m
# [BYOL] 034/100 | Loss: 0.4205 | Epoch Time: 0.80m | Total Time: 27.82m
# [BYOL] 035/100 | Loss: 0.4173 | Epoch Time: 0.80m | Total Time: 28.62m
# [BYOL] 036/100 | Loss: 0.4192 | Epoch Time: 0.79m | Total Time: 29.41m
# [BYOL] 037/100 | Loss: 0.4181 | Epoch Time: 0.80m | Total Time: 30.21m
# [BYOL] 038/100 | Loss: 0.4156 | Epoch Time: 0.79m | Total Time: 30.99m
# [BYOL] 039/100 | Loss: 0.4167 | Epoch Time: 0.79m | Total Time: 31.78m
# [BYOL] 040/100 | Loss: 0.4141 | Epoch Time: 0.80m | Total Time: 32.58m
# [BYOL] 041/100 | Loss: 0.4140 | Epoch Time: 0.78m | Total Time: 33.36m
# [BYOL] 042/100 | Loss: 0.4129 | Epoch Time: 0.79m | Total Time: 34.15m
# [BYOL] 043/100 | Loss: 0.4130 | Epoch Time: 0.79m | Total Time: 34.94m
# [BYOL] 044/100 | Loss: 0.4106 | Epoch Time: 0.78m | Total Time: 35.72m
# [BYOL] 045/100 | Loss: 0.4111 | Epoch Time: 0.79m | Total Time: 36.51m
# [BYOL] 046/100 | Loss: 0.4127 | Epoch Time: 0.79m | Total Time: 37.31m
# [BYOL] 047/100 | Loss: 0.4140 | Epoch Time: 0.79m | Total Time: 38.10m
# [BYOL] 048/100 | Loss: 0.4112 | Epoch Time: 0.79m | Total Time: 38.89m
# [BYOL] 049/100 | Loss: 0.4111 | Epoch Time: 0.79m | Total Time: 39.68m
# [BYOL] 050/100 | Loss: 0.4093 | Epoch Time: 0.79m | Total Time: 40.47m
# [BYOL] 051/100 | Loss: 0.4100 | Epoch Time: 0.79m | Total Time: 41.26m
# [BYOL] 052/100 | Loss: 0.4079 | Epoch Time: 0.80m | Total Time: 42.06m
# [BYOL] 053/100 | Loss: 0.4079 | Epoch Time: 0.79m | Total Time: 42.85m
# [BYOL] 054/100 | Loss: 0.4097 | Epoch Time: 0.79m | Total Time: 43.64m
# [BYOL] 055/100 | Loss: 0.4092 | Epoch Time: 0.78m | Total Time: 44.42m
# [BYOL] 056/100 | Loss: 0.4074 | Epoch Time: 0.80m | Total Time: 45.22m
# [BYOL] 057/100 | Loss: 0.4076 | Epoch Time: 0.80m | Total Time: 46.02m
# [BYOL] 058/100 | Loss: 0.4083 | Epoch Time: 0.78m | Total Time: 46.80m
# [BYOL] 059/100 | Loss: 0.4061 | Epoch Time: 0.80m | Total Time: 47.60m
# [BYOL] 060/100 | Loss: 0.4056 | Epoch Time: 0.79m | Total Time: 48.39m
# [BYOL] 061/100 | Loss: 0.4056 | Epoch Time: 0.78m | Total Time: 49.17m
# [BYOL] 062/100 | Loss: 0.4056 | Epoch Time: 0.79m | Total Time: 49.96m
# [BYOL] 063/100 | Loss: 0.4020 | Epoch Time: 0.79m | Total Time: 50.75m
# [BYOL] 064/100 | Loss: 0.4045 | Epoch Time: 0.79m | Total Time: 51.53m
# [BYOL] 065/100 | Loss: 0.4023 | Epoch Time: 0.79m | Total Time: 52.32m
# [BYOL] 066/100 | Loss: 0.4053 | Epoch Time: 0.80m | Total Time: 53.12m
# [BYOL] 067/100 | Loss: 0.4045 | Epoch Time: 0.83m | Total Time: 53.95m
# [BYOL] 068/100 | Loss: 0.4038 | Epoch Time: 0.79m | Total Time: 54.74m
# [BYOL] 069/100 | Loss: 0.4042 | Epoch Time: 0.78m | Total Time: 55.52m
# [BYOL] 070/100 | Loss: 0.4062 | Epoch Time: 0.79m | Total Time: 56.31m
# [BYOL] 071/100 | Loss: 0.4047 | Epoch Time: 0.78m | Total Time: 57.09m
# [BYOL] 072/100 | Loss: 0.4030 | Epoch Time: 0.79m | Total Time: 57.88m
# [BYOL] 073/100 | Loss: 0.4030 | Epoch Time: 0.79m | Total Time: 58.67m
# [BYOL] 074/100 | Loss: 0.4027 | Epoch Time: 0.79m | Total Time: 59.46m
# [BYOL] 075/100 | Loss: 0.4030 | Epoch Time: 0.79m | Total Time: 60.25m
# [BYOL] 076/100 | Loss: 0.4037 | Epoch Time: 0.79m | Total Time: 61.03m
# [BYOL] 077/100 | Loss: 0.4024 | Epoch Time: 0.78m | Total Time: 61.81m
# [BYOL] 078/100 | Loss: 0.4045 | Epoch Time: 0.79m | Total Time: 62.60m
# [BYOL] 079/100 | Loss: 0.4016 | Epoch Time: 0.79m | Total Time: 63.39m
# [BYOL] 080/100 | Loss: 0.4025 | Epoch Time: 0.79m | Total Time: 64.17m
# [BYOL] 081/100 | Loss: 0.4007 | Epoch Time: 0.79m | Total Time: 64.96m
# [BYOL] 082/100 | Loss: 0.4010 | Epoch Time: 0.79m | Total Time: 65.75m
# [BYOL] 083/100 | Loss: 0.4001 | Epoch Time: 0.80m | Total Time: 66.54m
# [BYOL] 084/100 | Loss: 0.4008 | Epoch Time: 0.79m | Total Time: 67.34m
# [BYOL] 085/100 | Loss: 0.4015 | Epoch Time: 0.80m | Total Time: 68.14m
# [BYOL] 086/100 | Loss: 0.4001 | Epoch Time: 0.80m | Total Time: 68.94m
# [BYOL] 087/100 | Loss: 0.3990 | Epoch Time: 0.78m | Total Time: 69.72m
# [BYOL] 088/100 | Loss: 0.3992 | Epoch Time: 0.78m | Total Time: 70.50m
# [BYOL] 089/100 | Loss: 0.4002 | Epoch Time: 0.79m | Total Time: 71.29m
# [BYOL] 090/100 | Loss: 0.3980 | Epoch Time: 0.78m | Total Time: 72.07m
# [BYOL] 091/100 | Loss: 0.3980 | Epoch Time: 0.79m | Total Time: 72.86m
# [BYOL] 092/100 | Loss: 0.3989 | Epoch Time: 0.78m | Total Time: 73.64m
# [BYOL] 093/100 | Loss: 0.3964 | Epoch Time: 0.78m | Total Time: 74.42m
# [BYOL] 094/100 | Loss: 0.3973 | Epoch Time: 0.79m | Total Time: 75.22m
# [BYOL] 095/100 | Loss: 0.3996 | Epoch Time: 0.80m | Total Time: 76.01m
# [BYOL] 096/100 | Loss: 0.3987 | Epoch Time: 0.80m | Total Time: 76.81m
# [BYOL] 097/100 | Loss: 0.3966 | Epoch Time: 0.80m | Total Time: 77.61m
# [BYOL] 098/100 | Loss: 0.3952 | Epoch Time: 0.79m | Total Time: 78.40m
# [BYOL] 099/100 | Loss: 0.3972 | Epoch Time: 0.80m | Total Time: 79.19m
# [BYOL] 100/100 | Loss: 0.3955 | Epoch Time: 0.79m | Total Time: 79.98m
# [SimCLR] 001/100 | Loss: 4.6672 | Epoch Time: 0.86m | Total Time: 0.86m
# [SimCLR] 002/100 | Loss: 4.4884 | Epoch Time: 0.87m | Total Time: 1.72m
# [SimCLR] 003/100 | Loss: 4.4237 | Epoch Time: 0.87m | Total Time: 2.59m
# [SimCLR] 004/100 | Loss: 4.3804 | Epoch Time: 0.87m | Total Time: 3.46m
# [SimCLR] 005/100 | Loss: 4.3519 | Epoch Time: 0.89m | Total Time: 4.35m
# [SimCLR] 006/100 | Loss: 4.3299 | Epoch Time: 0.88m | Total Time: 5.22m
# [SimCLR] 007/100 | Loss: 4.3064 | Epoch Time: 0.85m | Total Time: 6.08m
# [SimCLR] 008/100 | Loss: 4.2873 | Epoch Time: 0.87m | Total Time: 6.94m
# [SimCLR] 009/100 | Loss: 4.2670 | Epoch Time: 0.87m | Total Time: 7.81m
# [SimCLR] 010/100 | Loss: 4.2553 | Epoch Time: 0.85m | Total Time: 8.66m
# [SimCLR] 011/100 | Loss: 4.2436 | Epoch Time: 0.85m | Total Time: 9.52m
# [SimCLR] 012/100 | Loss: 4.2323 | Epoch Time: 0.85m | Total Time: 10.37m
# [SimCLR] 013/100 | Loss: 4.2197 | Epoch Time: 0.86m | Total Time: 11.23m
# [SimCLR] 014/100 | Loss: 4.2103 | Epoch Time: 0.85m | Total Time: 12.09m
# [SimCLR] 015/100 | Loss: 4.2044 | Epoch Time: 0.86m | Total Time: 12.94m
# [SimCLR] 016/100 | Loss: 4.1936 | Epoch Time: 0.87m | Total Time: 13.81m
# [SimCLR] 017/100 | Loss: 4.1838 | Epoch Time: 0.86m | Total Time: 14.67m
# [SimCLR] 018/100 | Loss: 4.1769 | Epoch Time: 0.85m | Total Time: 15.52m
# [SimCLR] 019/100 | Loss: 4.1716 | Epoch Time: 0.85m | Total Time: 16.38m
# [SimCLR] 020/100 | Loss: 4.1628 | Epoch Time: 0.87m | Total Time: 17.24m
# [SimCLR] 021/100 | Loss: 4.1622 | Epoch Time: 0.87m | Total Time: 18.11m
# [SimCLR] 022/100 | Loss: 4.1572 | Epoch Time: 0.86m | Total Time: 18.97m
# [SimCLR] 023/100 | Loss: 4.1520 | Epoch Time: 0.86m | Total Time: 19.83m
# [SimCLR] 024/100 | Loss: 4.1452 | Epoch Time: 0.86m | Total Time: 20.69m
# [SimCLR] 025/100 | Loss: 4.1396 | Epoch Time: 0.87m | Total Time: 21.56m
# [SimCLR] 026/100 | Loss: 4.1329 | Epoch Time: 0.86m | Total Time: 22.42m
# [SimCLR] 027/100 | Loss: 4.1321 | Epoch Time: 0.84m | Total Time: 23.26m
# [SimCLR] 028/100 | Loss: 4.1286 | Epoch Time: 0.85m | Total Time: 24.11m
# [SimCLR] 029/100 | Loss: 4.1218 | Epoch Time: 0.86m | Total Time: 24.97m
# [SimCLR] 030/100 | Loss: 4.1229 | Epoch Time: 0.84m | Total Time: 25.81m
# [SimCLR] 031/100 | Loss: 4.1160 | Epoch Time: 0.84m | Total Time: 26.66m
# [SimCLR] 032/100 | Loss: 4.1129 | Epoch Time: 0.86m | Total Time: 27.51m
# [SimCLR] 033/100 | Loss: 4.1127 | Epoch Time: 0.86m | Total Time: 28.37m
# [SimCLR] 034/100 | Loss: 4.1083 | Epoch Time: 0.84m | Total Time: 29.22m
# [SimCLR] 035/100 | Loss: 4.1055 | Epoch Time: 0.85m | Total Time: 30.06m
# [SimCLR] 036/100 | Loss: 4.1012 | Epoch Time: 0.85m | Total Time: 30.92m
# [SimCLR] 037/100 | Loss: 4.0987 | Epoch Time: 0.86m | Total Time: 31.78m
# [SimCLR] 038/100 | Loss: 4.0949 | Epoch Time: 0.85m | Total Time: 32.63m
# [SimCLR] 039/100 | Loss: 4.0932 | Epoch Time: 0.84m | Total Time: 33.48m
# [SimCLR] 040/100 | Loss: 4.0894 | Epoch Time: 0.87m | Total Time: 34.34m
# [SimCLR] 041/100 | Loss: 4.0861 | Epoch Time: 0.84m | Total Time: 35.18m
# [SimCLR] 042/100 | Loss: 4.0889 | Epoch Time: 0.85m | Total Time: 36.03m
# [SimCLR] 043/100 | Loss: 4.0839 | Epoch Time: 0.85m | Total Time: 36.88m
# [SimCLR] 044/100 | Loss: 4.0790 | Epoch Time: 0.84m | Total Time: 37.72m
# [SimCLR] 045/100 | Loss: 4.0819 | Epoch Time: 0.85m | Total Time: 38.58m
# [SimCLR] 046/100 | Loss: 4.0760 | Epoch Time: 0.85m | Total Time: 39.43m
# [SimCLR] 047/100 | Loss: 4.0725 | Epoch Time: 0.86m | Total Time: 40.29m
# [SimCLR] 048/100 | Loss: 4.0741 | Epoch Time: 0.87m | Total Time: 41.16m
# [SimCLR] 049/100 | Loss: 4.0680 | Epoch Time: 0.86m | Total Time: 42.02m
# [SimCLR] 050/100 | Loss: 4.0674 | Epoch Time: 0.84m | Total Time: 42.86m
# [SimCLR] 051/100 | Loss: 4.0660 | Epoch Time: 0.84m | Total Time: 43.69m
# [SimCLR] 052/100 | Loss: 4.0644 | Epoch Time: 0.85m | Total Time: 44.55m
# [SimCLR] 053/100 | Loss: 4.0603 | Epoch Time: 0.86m | Total Time: 45.40m
# [SimCLR] 054/100 | Loss: 4.0614 | Epoch Time: 0.85m | Total Time: 46.25m
# [SimCLR] 055/100 | Loss: 4.0592 | Epoch Time: 0.85m | Total Time: 47.10m
# [SimCLR] 056/100 | Loss: 4.0552 | Epoch Time: 0.86m | Total Time: 47.95m
# [SimCLR] 057/100 | Loss: 4.0551 | Epoch Time: 0.85m | Total Time: 48.80m
# [SimCLR] 058/100 | Loss: 4.0509 | Epoch Time: 0.84m | Total Time: 49.64m
# [SimCLR] 059/100 | Loss: 4.0526 | Epoch Time: 0.85m | Total Time: 50.49m
# [SimCLR] 060/100 | Loss: 4.0500 | Epoch Time: 0.85m | Total Time: 51.34m
# [SimCLR] 061/100 | Loss: 4.0499 | Epoch Time: 0.84m | Total Time: 52.18m
# [SimCLR] 062/100 | Loss: 4.0484 | Epoch Time: 0.86m | Total Time: 53.04m
# [SimCLR] 063/100 | Loss: 4.0432 | Epoch Time: 0.84m | Total Time: 53.89m
# [SimCLR] 064/100 | Loss: 4.0380 | Epoch Time: 0.84m | Total Time: 54.72m
# [SimCLR] 065/100 | Loss: 4.0400 | Epoch Time: 0.85m | Total Time: 55.57m
# [SimCLR] 066/100 | Loss: 4.0401 | Epoch Time: 0.84m | Total Time: 56.42m
# [SimCLR] 067/100 | Loss: 4.0376 | Epoch Time: 0.84m | Total Time: 57.26m
# [SimCLR] 068/100 | Loss: 4.0362 | Epoch Time: 0.83m | Total Time: 58.09m
# [SimCLR] 069/100 | Loss: 4.0344 | Epoch Time: 0.85m | Total Time: 58.94m
# [SimCLR] 070/100 | Loss: 4.0331 | Epoch Time: 0.85m | Total Time: 59.80m
# [SimCLR] 071/100 | Loss: 4.0309 | Epoch Time: 0.85m | Total Time: 60.65m
# [SimCLR] 072/100 | Loss: 4.0312 | Epoch Time: 0.84m | Total Time: 61.49m
# [SimCLR] 073/100 | Loss: 4.0273 | Epoch Time: 0.86m | Total Time: 62.35m
# [SimCLR] 074/100 | Loss: 4.0283 | Epoch Time: 0.87m | Total Time: 63.22m
# [SimCLR] 075/100 | Loss: 4.0257 | Epoch Time: 0.86m | Total Time: 64.09m
# [SimCLR] 076/100 | Loss: 4.0248 | Epoch Time: 0.85m | Total Time: 64.94m
# [SimCLR] 077/100 | Loss: 4.0228 | Epoch Time: 0.86m | Total Time: 65.80m
# [SimCLR] 078/100 | Loss: 4.0226 | Epoch Time: 0.85m | Total Time: 66.65m
# [SimCLR] 079/100 | Loss: 4.0227 | Epoch Time: 0.85m | Total Time: 67.51m
# [SimCLR] 080/100 | Loss: 4.0196 | Epoch Time: 0.85m | Total Time: 68.36m
# [SimCLR] 081/100 | Loss: 4.0216 | Epoch Time: 0.87m | Total Time: 69.23m
# [SimCLR] 082/100 | Loss: 4.0186 | Epoch Time: 0.87m | Total Time: 70.10m
# [SimCLR] 083/100 | Loss: 4.0213 | Epoch Time: 0.86m | Total Time: 70.96m
# [SimCLR] 084/100 | Loss: 4.0183 | Epoch Time: 0.87m | Total Time: 71.83m
# [SimCLR] 085/100 | Loss: 4.0157 | Epoch Time: 0.85m | Total Time: 72.69m
# [SimCLR] 086/100 | Loss: 4.0175 | Epoch Time: 0.86m | Total Time: 73.55m
# [SimCLR] 087/100 | Loss: 4.0143 | Epoch Time: 0.85m | Total Time: 74.40m
# [SimCLR] 088/100 | Loss: 4.0124 | Epoch Time: 0.85m | Total Time: 75.25m
# [SimCLR] 089/100 | Loss: 4.0126 | Epoch Time: 0.83m | Total Time: 76.08m
# [SimCLR] 090/100 | Loss: 4.0105 | Epoch Time: 0.85m | Total Time: 76.93m
# [SimCLR] 091/100 | Loss: 4.0105 | Epoch Time: 0.86m | Total Time: 77.79m
# [SimCLR] 092/100 | Loss: 4.0094 | Epoch Time: 0.85m | Total Time: 78.64m
# [SimCLR] 093/100 | Loss: 4.0084 | Epoch Time: 0.84m | Total Time: 79.49m
# [SimCLR] 094/100 | Loss: 4.0085 | Epoch Time: 0.85m | Total Time: 80.34m
# [SimCLR] 095/100 | Loss: 4.0057 | Epoch Time: 0.87m | Total Time: 81.20m
# [SimCLR] 096/100 | Loss: 4.0061 | Epoch Time: 0.87m | Total Time: 82.07m
# [SimCLR] 097/100 | Loss: 4.0042 | Epoch Time: 0.85m | Total Time: 82.91m
# [SimCLR] 098/100 | Loss: 4.0036 | Epoch Time: 0.84m | Total Time: 83.76m
# [SimCLR] 099/100 | Loss: 4.0029 | Epoch Time: 0.84m | Total Time: 84.60m
# [SimCLR] 100/100 | Loss: 4.0018 | Epoch Time: 0.87m | Total Time: 85.47m
# [SimCLR] 001/100 | Loss: 4.7624 | Epoch Time: 1.44m | Total Time: 1.44m
# [SimCLR] 002/100 | Loss: 4.5018 | Epoch Time: 1.44m | Total Time: 2.87m
# [SimCLR] 003/100 | Loss: 4.4266 | Epoch Time: 1.44m | Total Time: 4.31m
# [SimCLR] 004/100 | Loss: 4.3864 | Epoch Time: 1.44m | Total Time: 5.75m
# [SimCLR] 005/100 | Loss: 4.3606 | Epoch Time: 1.43m | Total Time: 7.18m
# [SimCLR] 006/100 | Loss: 4.3377 | Epoch Time: 1.44m | Total Time: 8.62m
# [SimCLR] 007/100 | Loss: 4.3174 | Epoch Time: 1.44m | Total Time: 10.05m
# [SimCLR] 008/100 | Loss: 4.3015 | Epoch Time: 1.44m | Total Time: 11.49m
# [SimCLR] 009/100 | Loss: 4.2859 | Epoch Time: 1.43m | Total Time: 12.92m
# [SimCLR] 010/100 | Loss: 4.2706 | Epoch Time: 1.44m | Total Time: 14.36m
# [SimCLR] 011/100 | Loss: 4.2621 | Epoch Time: 1.44m | Total Time: 15.80m
# [SimCLR] 012/100 | Loss: 4.2489 | Epoch Time: 1.44m | Total Time: 17.24m
# [SimCLR] 013/100 | Loss: 4.2399 | Epoch Time: 1.44m | Total Time: 18.68m
# [SimCLR] 014/100 | Loss: 4.2263 | Epoch Time: 1.44m | Total Time: 20.11m
# [SimCLR] 015/100 | Loss: 4.2225 | Epoch Time: 1.43m | Total Time: 21.55m
# [SimCLR] 016/100 | Loss: 4.2087 | Epoch Time: 1.43m | Total Time: 22.98m
# [SimCLR] 017/100 | Loss: 4.2052 | Epoch Time: 1.44m | Total Time: 24.42m
# [SimCLR] 018/100 | Loss: 4.1991 | Epoch Time: 1.44m | Total Time: 25.86m
# [SimCLR] 019/100 | Loss: 4.1906 | Epoch Time: 1.44m | Total Time: 27.29m
# [SimCLR] 020/100 | Loss: 4.1826 | Epoch Time: 1.44m | Total Time: 28.73m
# [SimCLR] 021/100 | Loss: 4.1806 | Epoch Time: 1.44m | Total Time: 30.17m
# [SimCLR] 022/100 | Loss: 4.1725 | Epoch Time: 1.43m | Total Time: 31.60m
# [SimCLR] 023/100 | Loss: 4.1696 | Epoch Time: 1.43m | Total Time: 33.03m
# [SimCLR] 024/100 | Loss: 4.1651 | Epoch Time: 1.44m | Total Time: 34.47m
# [SimCLR] 025/100 | Loss: 4.1626 | Epoch Time: 1.44m | Total Time: 35.92m
# [SimCLR] 026/100 | Loss: 4.1569 | Epoch Time: 1.44m | Total Time: 37.35m
# [SimCLR] 027/100 | Loss: 4.1489 | Epoch Time: 1.44m | Total Time: 38.79m
# [SimCLR] 028/100 | Loss: 4.1484 | Epoch Time: 1.44m | Total Time: 40.23m
# [SimCLR] 029/100 | Loss: 4.1444 | Epoch Time: 1.43m | Total Time: 41.66m
# [SimCLR] 030/100 | Loss: 4.1398 | Epoch Time: 1.43m | Total Time: 43.10m
# [SimCLR] 031/100 | Loss: 4.1337 | Epoch Time: 1.43m | Total Time: 44.53m
# [SimCLR] 032/100 | Loss: 4.1334 | Epoch Time: 1.44m | Total Time: 45.96m
# [SimCLR] 033/100 | Loss: 4.1303 | Epoch Time: 1.44m | Total Time: 47.40m
# [SimCLR] 034/100 | Loss: 4.1293 | Epoch Time: 1.44m | Total Time: 48.84m
# [SimCLR] 035/100 | Loss: 4.1252 | Epoch Time: 1.43m | Total Time: 50.27m
# [SimCLR] 036/100 | Loss: 4.1222 | Epoch Time: 1.43m | Total Time: 51.71m
# [SimCLR] 037/100 | Loss: 4.1209 | Epoch Time: 1.43m | Total Time: 53.14m
# [SimCLR] 038/100 | Loss: 4.1152 | Epoch Time: 1.43m | Total Time: 54.57m
# [SimCLR] 039/100 | Loss: 4.1152 | Epoch Time: 1.43m | Total Time: 56.00m
# [SimCLR] 040/100 | Loss: 4.1152 | Epoch Time: 1.43m | Total Time: 57.44m
# [SimCLR] 041/100 | Loss: 4.1117 | Epoch Time: 1.43m | Total Time: 58.87m
# [SimCLR] 042/100 | Loss: 4.1061 | Epoch Time: 1.44m | Total Time: 60.31m
# [SimCLR] 043/100 | Loss: 4.1030 | Epoch Time: 1.43m | Total Time: 61.74m
# [SimCLR] 044/100 | Loss: 4.1023 | Epoch Time: 1.43m | Total Time: 63.17m
# [SimCLR] 045/100 | Loss: 4.0984 | Epoch Time: 1.43m | Total Time: 64.61m
# [SimCLR] 046/100 | Loss: 4.0976 | Epoch Time: 1.43m | Total Time: 66.04m
# [SimCLR] 047/100 | Loss: 4.0977 | Epoch Time: 1.43m | Total Time: 67.47m
# [SimCLR] 048/100 | Loss: 4.0947 | Epoch Time: 1.43m | Total Time: 68.90m
# [SimCLR] 049/100 | Loss: 4.0920 | Epoch Time: 1.43m | Total Time: 70.33m
# [SimCLR] 050/100 | Loss: 4.0889 | Epoch Time: 1.43m | Total Time: 71.76m
# [SimCLR] 051/100 | Loss: 4.0872 | Epoch Time: 1.43m | Total Time: 73.20m
# [SimCLR] 052/100 | Loss: 4.0841 | Epoch Time: 1.43m | Total Time: 74.63m
# [SimCLR] 053/100 | Loss: 4.0860 | Epoch Time: 1.43m | Total Time: 76.06m
# [SimCLR] 054/100 | Loss: 4.0802 | Epoch Time: 1.43m | Total Time: 77.50m
# [SimCLR] 055/100 | Loss: 4.0810 | Epoch Time: 1.43m | Total Time: 78.93m
# [SimCLR] 056/100 | Loss: 4.0754 | Epoch Time: 1.44m | Total Time: 80.37m
# [SimCLR] 057/100 | Loss: 4.0749 | Epoch Time: 1.43m | Total Time: 81.80m
# [SimCLR] 058/100 | Loss: 4.0737 | Epoch Time: 1.43m | Total Time: 83.24m
# [SimCLR] 059/100 | Loss: 4.0749 | Epoch Time: 1.43m | Total Time: 84.67m
# [SimCLR] 060/100 | Loss: 4.0720 | Epoch Time: 1.43m | Total Time: 86.10m
# [SimCLR] 061/100 | Loss: 4.0658 | Epoch Time: 1.43m | Total Time: 87.54m
# [SimCLR] 062/100 | Loss: 4.0679 | Epoch Time: 1.43m | Total Time: 88.97m
# [SimCLR] 063/100 | Loss: 4.0636 | Epoch Time: 1.43m | Total Time: 90.40m
# [SimCLR] 064/100 | Loss: 4.0687 | Epoch Time: 1.43m | Total Time: 91.83m
# [SimCLR] 065/100 | Loss: 4.0628 | Epoch Time: 1.43m | Total Time: 93.26m
# [SimCLR] 066/100 | Loss: 4.0630 | Epoch Time: 1.43m | Total Time: 94.70m
# [SimCLR] 067/100 | Loss: 4.0610 | Epoch Time: 1.44m | Total Time: 96.13m
# [SimCLR] 068/100 | Loss: 4.0603 | Epoch Time: 1.43m | Total Time: 97.57m
# [SimCLR] 069/100 | Loss: 4.0600 | Epoch Time: 1.43m | Total Time: 99.00m
# [SimCLR] 070/100 | Loss: 4.0601 | Epoch Time: 1.43m | Total Time: 100.43m
# [SimCLR] 071/100 | Loss: 4.0583 | Epoch Time: 1.44m | Total Time: 101.87m
# [SimCLR] 072/100 | Loss: 4.0546 | Epoch Time: 1.44m | Total Time: 103.30m
# [SimCLR] 073/100 | Loss: 4.0563 | Epoch Time: 1.44m | Total Time: 104.74m
# [SimCLR] 074/100 | Loss: 4.0538 | Epoch Time: 1.43m | Total Time: 106.17m
# [SimCLR] 075/100 | Loss: 4.0517 | Epoch Time: 1.44m | Total Time: 107.61m
# [SimCLR] 076/100 | Loss: 4.0500 | Epoch Time: 1.43m | Total Time: 109.04m
# [SimCLR] 077/100 | Loss: 4.0494 | Epoch Time: 1.43m | Total Time: 110.48m
# [SimCLR] 078/100 | Loss: 4.0484 | Epoch Time: 1.43m | Total Time: 111.91m
# [SimCLR] 079/100 | Loss: 4.0497 | Epoch Time: 1.43m | Total Time: 113.34m
# [SimCLR] 080/100 | Loss: 4.0461 | Epoch Time: 1.43m | Total Time: 114.78m
# [SimCLR] 081/100 | Loss: 4.0474 | Epoch Time: 1.43m | Total Time: 116.21m
# [SimCLR] 082/100 | Loss: 4.0459 | Epoch Time: 1.43m | Total Time: 117.65m
# [SimCLR] 083/100 | Loss: 4.0471 | Epoch Time: 1.43m | Total Time: 119.08m
# [SimCLR] 084/100 | Loss: 4.0436 | Epoch Time: 1.43m | Total Time: 120.51m
# [SimCLR] 085/100 | Loss: 4.0431 | Epoch Time: 1.43m | Total Time: 121.94m
# [SimCLR] 086/100 | Loss: 4.0465 | Epoch Time: 1.44m | Total Time: 123.38m
# [SimCLR] 087/100 | Loss: 4.0415 | Epoch Time: 1.43m | Total Time: 124.82m
# [SimCLR] 088/100 | Loss: 4.0403 | Epoch Time: 1.43m | Total Time: 126.25m
# [SimCLR] 089/100 | Loss: 4.0393 | Epoch Time: 1.43m | Total Time: 127.69m
# [SimCLR] 090/100 | Loss: 4.0364 | Epoch Time: 1.44m | Total Time: 129.13m
# [SimCLR] 091/100 | Loss: 4.0367 | Epoch Time: 1.43m | Total Time: 130.56m
# [SimCLR] 092/100 | Loss: 4.0367 | Epoch Time: 1.43m | Total Time: 132.00m
# [SimCLR] 093/100 | Loss: 4.0375 | Epoch Time: 1.43m | Total Time: 133.43m
# [SimCLR] 094/100 | Loss: 4.0374 | Epoch Time: 1.43m | Total Time: 134.86m
# [SimCLR] 095/100 | Loss: 4.0360 | Epoch Time: 1.43m | Total Time: 136.29m
# [SimCLR] 096/100 | Loss: 4.0343 | Epoch Time: 1.43m | Total Time: 137.72m
# [SimCLR] 097/100 | Loss: 4.0339 | Epoch Time: 1.43m | Total Time: 139.16m
# [SimCLR] 098/100 | Loss: 4.0372 | Epoch Time: 1.44m | Total Time: 140.59m
# [SimCLR] 099/100 | Loss: 4.0296 | Epoch Time: 1.43m | Total Time: 142.02m
# [SimCLR] 100/100 | Loss: 4.0319 | Epoch Time: 1.43m | Total Time: 143.45m
# Saved results to: /kaggle/working/byol_simclr_results.csv
#
# Running Mean Summary:
#             Seed   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# Method
# BYOL         9.0  68.018796        13.002658          14.134727
# SimCLR       9.0  90.046928        15.785530          19.482696
# SimCLR+Jac   9.0  64.400887        14.605758          15.853318
#
#             Linear_Probe_Acc
# Method
# BYOL                  0.6622
# SimCLR                0.6939
# SimCLR+Jac            0.6819
#
# Seed 9 finished in 311.57 minutes
#
# ================ FINAL RESULTS ================
#    Seed      Method   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# 0     9        BYOL  68.018796        13.002658          14.134727
# 1     9      SimCLR  90.046928        15.785530          19.482696
# 2     9  SimCLR+Jac  64.400887        14.605758          15.853318
#
#    Linear_Probe_Acc
# 0            0.6622
# 1            0.6939
# 2            0.6819
#
# Total experiment time (this session): 311.57 minutes
