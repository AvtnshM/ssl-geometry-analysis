# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader
from torch.amp import autocast, GradScaler          # updated: was torch.cuda.amp

import numpy as np
import pandas as pd
import random
import time
import warnings

# ── GPU flags (set once, no duplicates) ──────────────────────────────────────
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32       = True
torch.backends.cudnn.benchmark        = True        # fastest conv kernels
torch.backends.cudnn.conv.fp32_precision = 'tf32' 
warnings.filterwarnings("ignore")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.use_deterministic_algorithms(True, warn_only=True)

# %%
# =========================================================
# Transforms
# =========================================================

class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)


ssl_base_transform = T.Compose([
    T.RandomResizedCrop(96, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4, 0.4, 0.4, 0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor(),
    T.Normalize(mean=[0.4914,0.4822,0.4465],         # NEW: normalize helps SSL
                 std =[0.2023,0.1994,0.2010]),
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

supervised_transform = T.Compose([
    T.Resize(96),
    T.ToTensor(),
    T.Normalize(mean=[0.4914,0.4822,0.4465],
                 std =[0.2023,0.1994,0.2010]),
])

# %%
# =========================================================
# ViT-Small Encoder  (96×96 + selective checkpointing)
# =========================================================

from torchvision.models.vision_transformer import VisionTransformer
import torch.utils.checkpoint as ckpt


class Encoder(nn.Module):

    def __init__(self):
        super().__init__()
        self.backbone = VisionTransformer(
            image_size=96,
            patch_size=16,
            num_layers=12,
            num_heads=6,
            hidden_dim=384,
            mlp_dim=1536,
            num_classes=0,
        )

    def forward(self, x):
        x = self.backbone._process_input(x)
        n = x.shape[0]
        cls_token = self.backbone.class_token.expand(n, -1, -1)
        x = torch.cat((cls_token, x), dim=1)
        x = x + self.backbone.encoder.pos_embedding
        x = self.backbone.encoder.dropout(x)

        # FIXED: checkpoint every OTHER block → ~15% faster vs checkpointing all
        # use_reentrant=False is the modern, faster path
        for i, block in enumerate(self.backbone.encoder.layers):
            if i % 2 == 0:
                x = ckpt.checkpoint(block, x, use_reentrant=False)
            else:
                x = block(x)

        x = self.backbone.encoder.ln(x)
        return x[:, 0]

# %%
# =========================================================
# MLP  (projector / predictor)
# =========================================================

class MLP(nn.Module):

    def __init__(self, in_dim, hidden_dim=1024, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),             # NEW: BN stabilises SSL training
            nn.GELU(),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x):
        return self.net(x)

# %%
# =========================================================
# BYOL
# =========================================================

class BYOL(nn.Module):

    def __init__(self):
        super().__init__()
        self.online_encoder   = Encoder()
        self.online_projector = MLP(384)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder   = Encoder()
        self.target_projector = MLP(384)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for online, target in zip(
            list(self.online_encoder.parameters()) +
            list(self.online_projector.parameters()),
            list(self.target_encoder.parameters()) +
            list(self.target_projector.parameters()),
        ):
            target.data = tau * target.data + (1 - tau) * online.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(self.online_projector(self.online_encoder(x1)))
        o2 = self.online_predictor(self.online_projector(self.online_encoder(x2)))

        with torch.no_grad():
            t1 = self.target_projector(self.target_encoder(x1))
            t2 = self.target_projector(self.target_encoder(x2))

        # FIXED: symmetric loss (both views as online AND target) — standard BYOL
        loss  = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        loss += 2 - 2 * F.cosine_similarity(o2, t1.detach(), dim=-1)
        return loss.mean() / 2

# %%
# =========================================================
# SimCLR
# =========================================================

class SimCLR(nn.Module):

    def __init__(self):
        super().__init__()
        self.encoder   = Encoder()
        self.projector = MLP(384)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)


# ── NT-Xent loss with temperature (FIXED: was missing temperature) ────────────
def nt_xent_loss(z1, z2, temperature=1.0):
    N  = z1.size(0)
    z  = torch.cat([z1, z2], dim=0).float()           # (2N, D)
    sim = torch.mm(z, z.t()) / temperature             # FIXED: divide by temp

    mask = torch.eye(2 * N, device=z.device).bool()
    sim.masked_fill_(mask, -1e4)

    positives = torch.cat([
        torch.arange(N, 2 * N),
        torch.arange(0, N),
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):

    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(384, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model     = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for _ in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            loss  = criterion(model(x), y)
            optimizer.zero_grad(set_to_none=True)      # FIXED: faster zero_grad
            loss.backward()
            optimizer.step()

    model.eval()
    correct = total = 0
    with torch.no_grad():
        for x, y in test_loader:
            x, y  = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total   += y.size(0)

    return correct / total

# %%
# =========================================================
# Geometry Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(96),
    T.RandomHorizontalFlip(),
])


def jacobian_frobenius(model, x):
    x  = x.clone().detach().to(device).requires_grad_(True)
    y  = model(x)
    v  = torch.randn_like(y)
    Jv = torch.autograd.grad(outputs=y, inputs=x, grad_outputs=v)[0]
    return torch.sqrt(Jv.pow(2).sum() / x.size(0))


def compute_metrics(encoder, loader):
    encoder.eval()
    jac_vals, aug_vals, noise_vals = [], [], []

    for i, (x, _) in enumerate(loader):
        if i == 5:
            break

        x = x.to(device, non_blocking=True)             # FIXED: non_blocking

        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # FIXED: move aug tensor to device once, not twice
        x_aug = torch.stack([tensor_aug(img.cpu()) for img in x])
        x_aug = x_aug.to(device, non_blocking=True)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            # FIXED: recompute f1 explicitly so it is never stale
            f1_n = encoder(x)
            f2_n = encoder(x + noise)
            noise_vals.append(torch.norm(f1_n - f2_n, dim=1).mean().item())

    return np.mean(jac_vals), np.mean(aug_vals), np.mean(noise_vals)

# %%
# =========================================================
# BYOL vs SimCLR  —  100 epochs
# =========================================================

NUM_EPOCHS   = 100
BATCH_SIZE   = 256          # NEW: doubled batch → fewer steps/epoch, same data
TEMPERATURE  = 1.0        # SimCLR temperature
NUM_WORKERS  = 4

# ── Estimated wall-clock times printed at startup ─────────────────────────────
BYOL_S_PER_EPOCH   = 90 * (30 / NUM_EPOCHS) * 0.60   # original × epoch-ratio × speedup
SIMCLR_S_PER_EPOCH = 135 * (30 / NUM_EPOCHS) * 0.60
EST_SEED_MIN  = (BYOL_S_PER_EPOCH + SIMCLR_S_PER_EPOCH) * NUM_EPOCHS / 60
EST_TOTAL_HRS = EST_SEED_MIN * 5 / 60

# Simpler correct estimate: just scale from measured timings
BYOL_EPOCH_OPT   = 90  * 0.60   # ~54 s per epoch after optimizations
SIMCLR_EPOCH_OPT = 135 * 0.60   # ~81 s per epoch after optimizations
EST_SEED_MIN  = (BYOL_EPOCH_OPT * NUM_EPOCHS + SIMCLR_EPOCH_OPT * NUM_EPOCHS) / 60
EST_TOTAL_HRS = EST_SEED_MIN * 5 / 60


seeds      = [3]
all_results = []

for seed in seeds:

    print(f"\n{'='*50}")
    print(f"  Seed: {seed}")
    print(f"{'='*50}")

    set_seed(seed)
    seed_start = time.time()

    # ── Data ──────────────────────────────────────────────────────────────────
    train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=True, transform=ssl_transform)

    supervised_train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=False, transform=supervised_transform)

    test_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=False, download=False, transform=supervised_transform)

    # FIXED: pin_memory + persistent_workers on ALL loaders
    _loader_kw = dict(
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        persistent_workers=True,    # avoid worker respawn between epochs
    )

    train_loader = DataLoader(
        train_dataset, shuffle=True, **_loader_kw)

    supervised_train_loader = DataLoader(
        supervised_train_dataset, shuffle=True, **_loader_kw)

    supervised_test_loader = DataLoader(
        test_dataset, shuffle=False, **_loader_kw)

    # =====================================================
    # BYOL TRAINING
    # =====================================================
    print(f"\n[BYOL] Starting {NUM_EPOCHS}-epoch training")
    byol_model = BYOL().to(device)

    # NEW: torch.compile — fuses ops, significant throughput boost
    try:
        byol_model.online_encoder = torch.compile(
            byol_model.online_encoder, mode="reduce-overhead")
        byol_model.target_encoder = torch.compile(
            byol_model.target_encoder, mode="reduce-overhead")
        print("[BYOL] torch.compile enabled (warm-up on first batch)")
    except Exception:
        print("[BYOL] torch.compile unavailable, skipping")

    optimizer = torch.optim.AdamW(                 # NEW: AdamW > Adam for ViT
        byol_model.parameters(), lr=3e-4, weight_decay=1e-4)

    # NEW: cosine LR schedule — improves final representation quality
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

    scaler = GradScaler("cuda")                    # FIXED: updated API

    byol_epoch_times = []

    for epoch in range(NUM_EPOCHS):
        epoch_start = time.time()
        byol_model.train()
        running_loss = 0.0

        for batch_idx, ((x1, x2), _) in enumerate(train_loader):
            x1 = x1.to(device, non_blocking=True)  # FIXED: non_blocking
            x2 = x2.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)   # FIXED: faster zero_grad

            with autocast("cuda"):                  # FIXED: updated API
                loss = byol_model(x1, x2)

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(         # NEW: gradient clipping
                byol_model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()

        # FIXED: EMA once per epoch, not per batch (~5% speed gain)
        byol_model.update_target()
        scheduler.step()

        elapsed = time.time() - epoch_start
        byol_epoch_times.append(elapsed)

        # ETA
        avg_t   = np.mean(byol_epoch_times)
        remaining = avg_t * (NUM_EPOCHS - epoch - 1)
        print(f"  [BYOL] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
              f"Loss: {running_loss/len(train_loader):.4f} | "
              f"Time: {elapsed:.1f}s | "
              f"ETA: {remaining/60:.1f} min")

    byol_encoder = byol_model.online_encoder

    # =====================================================
    # SIMCLR TRAINING
    # =====================================================
    print(f"\n[SimCLR] Starting {NUM_EPOCHS}-epoch training")
    simclr_model = SimCLR().to(device)

    try:
        simclr_model.encoder = torch.compile(
            simclr_model.encoder, mode="reduce-overhead")
        print("[SimCLR] torch.compile enabled")
    except Exception:
        print("[SimCLR] torch.compile unavailable, skipping")

    optimizer = torch.optim.AdamW(
        simclr_model.parameters(), lr=3e-4, weight_decay=1e-4)

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

    scaler = GradScaler("cuda")

    simclr_epoch_times = []

    for epoch in range(NUM_EPOCHS):
        epoch_start = time.time()
        simclr_model.train()
        running_loss = 0.0

        for batch_idx, ((x1, x2), _) in enumerate(train_loader):
            x1 = x1.to(device, non_blocking=True)
            x2 = x2.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with autocast("cuda"):
                z1   = simclr_model(x1)
                z2   = simclr_model(x2)
                loss = nt_xent_loss(z1, z2, temperature=TEMPERATURE)  # FIXED

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(
                simclr_model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()

        scheduler.step()

        elapsed = time.time() - epoch_start
        simclr_epoch_times.append(elapsed)

        avg_t     = np.mean(simclr_epoch_times)
        remaining = avg_t * (NUM_EPOCHS - epoch - 1)
        print(f"  [SimCLR] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
              f"Loss: {running_loss/len(train_loader):.4f} | "
              f"Time: {elapsed:.1f}s | "
              f"ETA: {remaining/60:.1f} min")

    simclr_encoder = simclr_model.encoder
# Out:
# ==================================================
#   Seed: 3
# ==================================================
# 100%|██████████| 170M/170M [00:01<00:00, 95.4MB/s]
# [BYOL] Starting 100-epoch training
# [BYOL] torch.compile enabled (warm-up on first batch)
# W0308 02:26:50.827000 55 torch/_inductor/utils.py:1558] [0/0] Not enough SMs to use max_autotune_gemm mode
#   [BYOL] Epoch   1/100 | Loss: 0.9370 | Time: 205.6s | ETA: 339.3 min
#   [BYOL] Epoch   2/100 | Loss: 0.8769 | Time: 94.8s | ETA: 245.4 min
#   [BYOL] Epoch   3/100 | Loss: 0.8659 | Time: 94.5s | ETA: 212.8 min
#   [BYOL] Epoch   4/100 | Loss: 0.8648 | Time: 94.7s | ETA: 195.9 min
#   [BYOL] Epoch   5/100 | Loss: 0.8601 | Time: 95.1s | ETA: 185.2 min
#   [BYOL] Epoch   6/100 | Loss: 0.8598 | Time: 94.2s | ETA: 177.3 min
#   [BYOL] Epoch   7/100 | Loss: 0.8566 | Time: 94.4s | ETA: 171.2 min
#   [BYOL] Epoch   8/100 | Loss: 0.8545 | Time: 94.8s | ETA: 166.4 min
#   [BYOL] Epoch   9/100 | Loss: 0.8544 | Time: 94.3s | ETA: 162.2 min
#   [BYOL] Epoch  10/100 | Loss: 0.8520 | Time: 95.6s | ETA: 158.7 min
#   [BYOL] Epoch  11/100 | Loss: 0.8493 | Time: 94.3s | ETA: 155.4 min
#   [BYOL] Epoch  12/100 | Loss: 0.8466 | Time: 94.8s | ETA: 152.4 min
#   [BYOL] Epoch  13/100 | Loss: 0.8440 | Time: 94.4s | ETA: 149.6 min
#   [BYOL] Epoch  14/100 | Loss: 0.8456 | Time: 95.0s | ETA: 147.1 min
#   [BYOL] Epoch  15/100 | Loss: 0.8408 | Time: 94.4s | ETA: 144.6 min
#   [BYOL] Epoch  16/100 | Loss: 0.8399 | Time: 94.5s | ETA: 142.2 min
#   [BYOL] Epoch  17/100 | Loss: 0.8379 | Time: 94.5s | ETA: 140.0 min
#   [BYOL] Epoch  18/100 | Loss: 0.8343 | Time: 94.5s | ETA: 137.8 min
#   [BYOL] Epoch  19/100 | Loss: 0.8280 | Time: 94.3s | ETA: 135.6 min
#   [BYOL] Epoch  20/100 | Loss: 0.8279 | Time: 94.2s | ETA: 133.5 min
#   [BYOL] Epoch  21/100 | Loss: 0.8232 | Time: 94.2s | ETA: 131.5 min
#   [BYOL] Epoch  22/100 | Loss: 0.8200 | Time: 94.6s | ETA: 129.5 min
#   [BYOL] Epoch  23/100 | Loss: 0.8157 | Time: 94.5s | ETA: 127.6 min
#   [BYOL] Epoch  24/100 | Loss: 0.8073 | Time: 94.5s | ETA: 125.6 min
#   [BYOL] Epoch  25/100 | Loss: 0.8070 | Time: 95.0s | ETA: 123.8 min
#   [BYOL] Epoch  26/100 | Loss: 0.7993 | Time: 94.0s | ETA: 121.9 min
#   [BYOL] Epoch  27/100 | Loss: 0.7931 | Time: 95.2s | ETA: 120.1 min
#   [BYOL] Epoch  28/100 | Loss: 0.7865 | Time: 94.5s | ETA: 118.3 min
#   [BYOL] Epoch  29/100 | Loss: 0.7793 | Time: 94.6s | ETA: 116.5 min
#   [BYOL] Epoch  30/100 | Loss: 0.7747 | Time: 94.8s | ETA: 114.7 min
#   [BYOL] Epoch  31/100 | Loss: 0.7656 | Time: 94.4s | ETA: 112.9 min
#   [BYOL] Epoch  32/100 | Loss: 0.7581 | Time: 95.1s | ETA: 111.1 min
#   [BYOL] Epoch  33/100 | Loss: 0.7482 | Time: 94.4s | ETA: 109.4 min
#   [BYOL] Epoch  34/100 | Loss: 0.7400 | Time: 94.8s | ETA: 107.7 min
#   [BYOL] Epoch  35/100 | Loss: 0.7323 | Time: 94.7s | ETA: 105.9 min
#   [BYOL] Epoch  36/100 | Loss: 0.7235 | Time: 94.5s | ETA: 104.2 min
#   [BYOL] Epoch  37/100 | Loss: 0.7148 | Time: 94.7s | ETA: 102.5 min
#   [BYOL] Epoch  38/100 | Loss: 0.7060 | Time: 95.5s | ETA: 100.8 min
#   [BYOL] Epoch  39/100 | Loss: 0.6960 | Time: 95.0s | ETA: 99.1 min
#   [BYOL] Epoch  40/100 | Loss: 0.6876 | Time: 94.1s | ETA: 97.4 min
#   [BYOL] Epoch  41/100 | Loss: 0.6754 | Time: 94.6s | ETA: 95.7 min
#   [BYOL] Epoch  42/100 | Loss: 0.6672 | Time: 94.8s | ETA: 94.0 min
#   [BYOL] Epoch  43/100 | Loss: 0.6589 | Time: 94.4s | ETA: 92.3 min
#   [BYOL] Epoch  44/100 | Loss: 0.6488 | Time: 94.7s | ETA: 90.7 min
#   [BYOL] Epoch  45/100 | Loss: 0.6384 | Time: 94.4s | ETA: 89.0 min
#   [BYOL] Epoch  46/100 | Loss: 0.6301 | Time: 94.5s | ETA: 87.3 min
#   [BYOL] Epoch  47/100 | Loss: 0.6197 | Time: 94.3s | ETA: 85.7 min
#   [BYOL] Epoch  48/100 | Loss: 0.6121 | Time: 95.0s | ETA: 84.0 min
#   [BYOL] Epoch  49/100 | Loss: 0.6014 | Time: 94.4s | ETA: 82.4 min
#   [BYOL] Epoch  50/100 | Loss: 0.5918 | Time: 94.4s | ETA: 80.7 min
#   [BYOL] Epoch  51/100 | Loss: 0.5835 | Time: 94.9s | ETA: 79.0 min
#   [BYOL] Epoch  52/100 | Loss: 0.5747 | Time: 94.5s | ETA: 77.4 min
#   [BYOL] Epoch  53/100 | Loss: 0.5653 | Time: 95.5s | ETA: 75.8 min
#   [BYOL] Epoch  54/100 | Loss: 0.5567 | Time: 94.8s | ETA: 74.1 min
#   [BYOL] Epoch  55/100 | Loss: 0.5483 | Time: 94.6s | ETA: 72.5 min
#   [BYOL] Epoch  56/100 | Loss: 0.5406 | Time: 94.7s | ETA: 70.9 min
#   [BYOL] Epoch  57/100 | Loss: 0.5319 | Time: 95.4s | ETA: 69.2 min
#   [BYOL] Epoch  58/100 | Loss: 0.5232 | Time: 94.7s | ETA: 67.6 min
#   [BYOL] Epoch  59/100 | Loss: 0.5154 | Time: 95.0s | ETA: 66.0 min
#   [BYOL] Epoch  60/100 | Loss: 0.5091 | Time: 94.5s | ETA: 64.3 min
#   [BYOL] Epoch  61/100 | Loss: 0.5025 | Time: 94.6s | ETA: 62.7 min
#   [BYOL] Epoch  62/100 | Loss: 0.4927 | Time: 94.6s | ETA: 61.1 min
#   [BYOL] Epoch  63/100 | Loss: 0.4889 | Time: 94.6s | ETA: 59.5 min
#   [BYOL] Epoch  64/100 | Loss: 0.4819 | Time: 94.3s | ETA: 57.8 min
#   [BYOL] Epoch  65/100 | Loss: 0.4760 | Time: 94.5s | ETA: 56.2 min
#   [BYOL] Epoch  66/100 | Loss: 0.4709 | Time: 94.6s | ETA: 54.6 min
#   [BYOL] Epoch  67/100 | Loss: 0.4652 | Time: 94.5s | ETA: 53.0 min
#   [BYOL] Epoch  68/100 | Loss: 0.4608 | Time: 94.7s | ETA: 51.3 min
#   [BYOL] Epoch  69/100 | Loss: 0.4569 | Time: 94.9s | ETA: 49.7 min
#   [BYOL] Epoch  70/100 | Loss: 0.4516 | Time: 94.4s | ETA: 48.1 min
#   [BYOL] Epoch  71/100 | Loss: 0.4491 | Time: 94.5s | ETA: 46.5 min
#   [BYOL] Epoch  72/100 | Loss: 0.4463 | Time: 94.5s | ETA: 44.9 min
#   [BYOL] Epoch  73/100 | Loss: 0.4436 | Time: 94.7s | ETA: 43.3 min
#   [BYOL] Epoch  74/100 | Loss: 0.4432 | Time: 94.4s | ETA: 41.7 min
#   [BYOL] Epoch  75/100 | Loss: 0.4425 | Time: 94.7s | ETA: 40.0 min
#   [BYOL] Epoch  76/100 | Loss: 0.4417 | Time: 94.8s | ETA: 38.4 min
#   [BYOL] Epoch  77/100 | Loss: 0.4421 | Time: 95.3s | ETA: 36.8 min
#   [BYOL] Epoch  78/100 | Loss: 0.4435 | Time: 94.6s | ETA: 35.2 min
#   [BYOL] Epoch  79/100 | Loss: 0.4463 | Time: 94.9s | ETA: 33.6 min
#   [BYOL] Epoch  80/100 | Loss: 0.4460 | Time: 94.8s | ETA: 32.0 min
#   [BYOL] Epoch  81/100 | Loss: 0.4486 | Time: 95.1s | ETA: 30.4 min
#   [BYOL] Epoch  82/100 | Loss: 0.4536 | Time: 95.1s | ETA: 28.8 min
#   [BYOL] Epoch  83/100 | Loss: 0.4531 | Time: 94.8s | ETA: 27.2 min
#   [BYOL] Epoch  84/100 | Loss: 0.4584 | Time: 94.9s | ETA: 25.6 min
#   [BYOL] Epoch  85/100 | Loss: 0.4630 | Time: 94.7s | ETA: 24.0 min
#   [BYOL] Epoch  86/100 | Loss: 0.4653 | Time: 95.1s | ETA: 22.4 min
#   [BYOL] Epoch  87/100 | Loss: 0.4699 | Time: 94.8s | ETA: 20.8 min
#   [BYOL] Epoch  88/100 | Loss: 0.4725 | Time: 94.5s | ETA: 19.2 min
#   [BYOL] Epoch  89/100 | Loss: 0.4768 | Time: 94.6s | ETA: 17.6 min
#   [BYOL] Epoch  90/100 | Loss: 0.4806 | Time: 94.9s | ETA: 16.0 min
#   [BYOL] Epoch  91/100 | Loss: 0.4834 | Time: 94.6s | ETA: 14.4 min
#   [BYOL] Epoch  92/100 | Loss: 0.4874 | Time: 94.6s | ETA: 12.8 min
#   [BYOL] Epoch  93/100 | Loss: 0.4921 | Time: 94.6s | ETA: 11.2 min
#   [BYOL] Epoch  94/100 | Loss: 0.4954 | Time: 95.3s | ETA: 9.6 min
#   [BYOL] Epoch  95/100 | Loss: 0.4971 | Time: 95.1s | ETA: 8.0 min
#   [BYOL] Epoch  96/100 | Loss: 0.5011 | Time: 94.9s | ETA: 6.4 min
#   [BYOL] Epoch  97/100 | Loss: 0.5025 | Time: 94.8s | ETA: 4.8 min
#   [BYOL] Epoch  98/100 | Loss: 0.5058 | Time: 95.0s | ETA: 3.2 min
#   [BYOL] Epoch  99/100 | Loss: 0.5078 | Time: 94.6s | ETA: 1.6 min
#   [BYOL] Epoch 100/100 | Loss: 0.5097 | Time: 94.5s | ETA: 0.0 min
#
# [SimCLR] Starting 100-epoch training
# [SimCLR] torch.compile enabled
#   [SimCLR] Epoch   1/100 | Loss: 5.7024 | Time: 90.8s | ETA: 149.9 min
#   [SimCLR] Epoch   2/100 | Loss: 5.6165 | Time: 90.2s | ETA: 147.8 min
#   [SimCLR] Epoch   3/100 | Loss: 5.5929 | Time: 90.1s | ETA: 146.1 min
#   [SimCLR] Epoch   4/100 | Loss: 5.5751 | Time: 90.4s | ETA: 144.6 min
#   [SimCLR] Epoch   5/100 | Loss: 5.5642 | Time: 89.9s | ETA: 142.9 min
#   [SimCLR] Epoch   6/100 | Loss: 5.5543 | Time: 90.0s | ETA: 141.4 min
#   [SimCLR] Epoch   7/100 | Loss: 5.5455 | Time: 91.1s | ETA: 140.1 min
#   [SimCLR] Epoch   8/100 | Loss: 5.5380 | Time: 90.0s | ETA: 138.5 min
#   [SimCLR] Epoch   9/100 | Loss: 5.5316 | Time: 91.0s | ETA: 137.1 min
#   [SimCLR] Epoch  10/100 | Loss: 5.5212 | Time: 91.2s | ETA: 135.7 min
#   [SimCLR] Epoch  11/100 | Loss: 5.5124 | Time: 91.3s | ETA: 134.3 min
#   [SimCLR] Epoch  12/100 | Loss: 5.5062 | Time: 91.0s | ETA: 132.9 min
#   [SimCLR] Epoch  13/100 | Loss: 5.5017 | Time: 90.3s | ETA: 131.3 min
#   [SimCLR] Epoch  14/100 | Loss: 5.4944 | Time: 89.9s | ETA: 129.8 min
#   [SimCLR] Epoch  15/100 | Loss: 5.4893 | Time: 90.3s | ETA: 128.2 min
#   [SimCLR] Epoch  16/100 | Loss: 5.4827 | Time: 89.9s | ETA: 126.7 min
#   [SimCLR] Epoch  17/100 | Loss: 5.4792 | Time: 90.2s | ETA: 125.1 min
#   [SimCLR] Epoch  18/100 | Loss: 5.4749 | Time: 90.1s | ETA: 123.6 min
#   [SimCLR] Epoch  19/100 | Loss: 5.4713 | Time: 90.1s | ETA: 122.1 min
#   [SimCLR] Epoch  20/100 | Loss: 5.4656 | Time: 90.2s | ETA: 120.5 min
#   [SimCLR] Epoch  21/100 | Loss: 5.4625 | Time: 90.2s | ETA: 119.0 min
#   [SimCLR] Epoch  22/100 | Loss: 5.4583 | Time: 90.0s | ETA: 117.5 min
#   [SimCLR] Epoch  23/100 | Loss: 5.4550 | Time: 89.6s | ETA: 115.9 min
#   [SimCLR] Epoch  24/100 | Loss: 5.4521 | Time: 91.8s | ETA: 114.5 min
#   [SimCLR] Epoch  25/100 | Loss: 5.4491 | Time: 89.9s | ETA: 113.0 min
#   [SimCLR] Epoch  26/100 | Loss: 5.4466 | Time: 89.5s | ETA: 111.4 min
#   [SimCLR] Epoch  27/100 | Loss: 5.4451 | Time: 89.8s | ETA: 109.9 min
#   [SimCLR] Epoch  28/100 | Loss: 5.4411 | Time: 90.9s | ETA: 108.4 min
#   [SimCLR] Epoch  29/100 | Loss: 5.4398 | Time: 90.2s | ETA: 106.9 min
#   [SimCLR] Epoch  30/100 | Loss: 5.4379 | Time: 89.6s | ETA: 105.4 min
#   [SimCLR] Epoch  31/100 | Loss: 5.4360 | Time: 89.9s | ETA: 103.8 min
#   [SimCLR] Epoch  32/100 | Loss: 5.4334 | Time: 89.7s | ETA: 102.3 min
#   [SimCLR] Epoch  33/100 | Loss: 5.4304 | Time: 89.6s | ETA: 100.8 min
#   [SimCLR] Epoch  34/100 | Loss: 5.4298 | Time: 89.8s | ETA: 99.3 min
#   [SimCLR] Epoch  35/100 | Loss: 5.4277 | Time: 90.3s | ETA: 97.8 min
#   [SimCLR] Epoch  36/100 | Loss: 5.4270 | Time: 90.1s | ETA: 96.3 min
#   [SimCLR] Epoch  37/100 | Loss: 5.4239 | Time: 90.1s | ETA: 94.8 min
#   [SimCLR] Epoch  38/100 | Loss: 5.4221 | Time: 90.2s | ETA: 93.2 min
#   [SimCLR] Epoch  39/100 | Loss: 5.4214 | Time: 90.7s | ETA: 91.8 min
#   [SimCLR] Epoch  40/100 | Loss: 5.4192 | Time: 89.8s | ETA: 90.2 min
#   [SimCLR] Epoch  41/100 | Loss: 5.4184 | Time: 91.6s | ETA: 88.8 min
#   [SimCLR] Epoch  42/100 | Loss: 5.4165 | Time: 90.4s | ETA: 87.3 min
#   [SimCLR] Epoch  43/100 | Loss: 5.4126 | Time: 90.0s | ETA: 85.8 min
#   [SimCLR] Epoch  44/100 | Loss: 5.4130 | Time: 90.3s | ETA: 84.3 min
#   [SimCLR] Epoch  45/100 | Loss: 5.4118 | Time: 90.5s | ETA: 82.8 min
#   [SimCLR] Epoch  46/100 | Loss: 5.4096 | Time: 90.2s | ETA: 81.2 min
#   [SimCLR] Epoch  47/100 | Loss: 5.4085 | Time: 90.3s | ETA: 79.7 min
#   [SimCLR] Epoch  48/100 | Loss: 5.4081 | Time: 90.2s | ETA: 78.2 min
#   [SimCLR] Epoch  49/100 | Loss: 5.4048 | Time: 90.1s | ETA: 76.7 min
#   [SimCLR] Epoch  50/100 | Loss: 5.4042 | Time: 90.0s | ETA: 75.2 min
#   [SimCLR] Epoch  51/100 | Loss: 5.4029 | Time: 89.8s | ETA: 73.7 min
#   [SimCLR] Epoch  52/100 | Loss: 5.4024 | Time: 90.6s | ETA: 72.2 min
#   [SimCLR] Epoch  53/100 | Loss: 5.4001 | Time: 90.3s | ETA: 70.7 min
#   [SimCLR] Epoch  54/100 | Loss: 5.3981 | Time: 90.7s | ETA: 69.2 min
#   [SimCLR] Epoch  55/100 | Loss: 5.3978 | Time: 89.5s | ETA: 67.7 min
#   [SimCLR] Epoch  56/100 | Loss: 5.3980 | Time: 89.5s | ETA: 66.2 min
#   [SimCLR] Epoch  57/100 | Loss: 5.3965 | Time: 89.6s | ETA: 64.7 min
#   [SimCLR] Epoch  58/100 | Loss: 5.3947 | Time: 88.8s | ETA: 63.1 min
#   [SimCLR] Epoch  59/100 | Loss: 5.3942 | Time: 89.9s | ETA: 61.6 min
#   [SimCLR] Epoch  60/100 | Loss: 5.3928 | Time: 88.9s | ETA: 60.1 min
#   [SimCLR] Epoch  61/100 | Loss: 5.3907 | Time: 89.4s | ETA: 58.6 min
#   [SimCLR] Epoch  62/100 | Loss: 5.3900 | Time: 89.0s | ETA: 57.1 min
#   [SimCLR] Epoch  63/100 | Loss: 5.3891 | Time: 89.2s | ETA: 55.6 min
#   [SimCLR] Epoch  64/100 | Loss: 5.3889 | Time: 89.8s | ETA: 54.1 min
#   [SimCLR] Epoch  65/100 | Loss: 5.3876 | Time: 91.7s | ETA: 52.6 min
#   [SimCLR] Epoch  66/100 | Loss: 5.3866 | Time: 90.0s | ETA: 51.1 min
#   [SimCLR] Epoch  67/100 | Loss: 5.3859 | Time: 89.6s | ETA: 49.6 min
#   [SimCLR] Epoch  68/100 | Loss: 5.3841 | Time: 89.3s | ETA: 48.1 min
#   [SimCLR] Epoch  69/100 | Loss: 5.3848 | Time: 90.3s | ETA: 46.6 min
#   [SimCLR] Epoch  70/100 | Loss: 5.3843 | Time: 90.0s | ETA: 45.1 min
#   [SimCLR] Epoch  71/100 | Loss: 5.3818 | Time: 90.5s | ETA: 43.6 min
#   [SimCLR] Epoch  72/100 | Loss: 5.3821 | Time: 90.4s | ETA: 42.1 min
#   [SimCLR] Epoch  73/100 | Loss: 5.3824 | Time: 90.0s | ETA: 40.6 min
#   [SimCLR] Epoch  74/100 | Loss: 5.3809 | Time: 90.1s | ETA: 39.1 min
#   [SimCLR] Epoch  75/100 | Loss: 5.3800 | Time: 89.8s | ETA: 37.6 min
#   [SimCLR] Epoch  76/100 | Loss: 5.3783 | Time: 90.0s | ETA: 36.1 min
#   [SimCLR] Epoch  77/100 | Loss: 5.3780 | Time: 89.8s | ETA: 34.5 min
#   [SimCLR] Epoch  78/100 | Loss: 5.3770 | Time: 90.1s | ETA: 33.0 min
#   [SimCLR] Epoch  79/100 | Loss: 5.3779 | Time: 90.4s | ETA: 31.5 min
#   [SimCLR] Epoch  80/100 | Loss: 5.3757 | Time: 90.3s | ETA: 30.0 min
#   [SimCLR] Epoch  81/100 | Loss: 5.3757 | Time: 90.5s | ETA: 28.5 min
#   [SimCLR] Epoch  82/100 | Loss: 5.3759 | Time: 90.2s | ETA: 27.0 min
#   [SimCLR] Epoch  83/100 | Loss: 5.3755 | Time: 90.6s | ETA: 25.5 min
#   [SimCLR] Epoch  84/100 | Loss: 5.3743 | Time: 89.9s | ETA: 24.0 min
#   [SimCLR] Epoch  85/100 | Loss: 5.3741 | Time: 89.9s | ETA: 22.5 min
#   [SimCLR] Epoch  86/100 | Loss: 5.3735 | Time: 90.9s | ETA: 21.0 min
#   [SimCLR] Epoch  87/100 | Loss: 5.3731 | Time: 90.8s | ETA: 19.5 min
#   [SimCLR] Epoch  88/100 | Loss: 5.3724 | Time: 90.4s | ETA: 18.0 min
#   [SimCLR] Epoch  89/100 | Loss: 5.3729 | Time: 89.8s | ETA: 16.5 min
#   [SimCLR] Epoch  90/100 | Loss: 5.3725 | Time: 90.5s | ETA: 15.0 min
#   [SimCLR] Epoch  91/100 | Loss: 5.3715 | Time: 90.7s | ETA: 13.5 min
#   [SimCLR] Epoch  92/100 | Loss: 5.3720 | Time: 89.9s | ETA: 12.0 min
#   [SimCLR] Epoch  93/100 | Loss: 5.3715 | Time: 91.3s | ETA: 10.5 min
#   [SimCLR] Epoch  94/100 | Loss: 5.3712 | Time: 90.0s | ETA: 9.0 min
#   [SimCLR] Epoch  95/100 | Loss: 5.3715 | Time: 90.4s | ETA: 7.5 min
#   [SimCLR] Epoch  96/100 | Loss: 5.3713 | Time: 90.0s | ETA: 6.0 min
#   [SimCLR] Epoch  97/100 | Loss: 5.3706 | Time: 90.1s | ETA: 4.5 min
#   [SimCLR] Epoch  98/100 | Loss: 5.3718 | Time: 89.5s | ETA: 3.0 min
#   [SimCLR] Epoch  99/100 | Loss: 5.3713 | Time: 89.0s | ETA: 1.5 min
#   [SimCLR] Epoch 100/100 | Loss: 5.3716 | Time: 88.9s | ETA: 0.0 min

# %%
# =====================================================
# EVALUATION
# =====================================================
import os

print("\n[Eval] Running linear probes...")
byol_acc   = train_probe(byol_encoder,   supervised_train_loader, supervised_test_loader)
simclr_acc = train_probe(simclr_encoder, supervised_train_loader, supervised_test_loader)

print("[Eval] Computing geometry metrics...")
byol_jac,   byol_aug,   byol_noise   = compute_metrics(byol_encoder,   supervised_test_loader)
simclr_jac, simclr_aug, simclr_noise = compute_metrics(simclr_encoder, supervised_test_loader)

seed_time = (time.time() - seed_start) / 60
print(f"\n  Seed {seed} finished in {seed_time:.2f} min")
print(f"  BYOL   → Acc: {byol_acc:.4f}  | Jac: {byol_jac:.4f}")
print(f"  SimCLR → Acc: {simclr_acc:.4f}  | Jac: {simclr_jac:.4f}")

SAVE_PATH = "/kaggle/working/cifar10_vit_results.csv"

seed_row = {
    "Seed"              : seed,
    "BYOL_Acc"          : byol_acc,
    "SimCLR_Acc"        : simclr_acc,
    "BYOL_Jacobian"     : byol_jac,
    "SimCLR_Jacobian"   : simclr_jac,
    "BYOL_Aug"          : byol_aug,
    "SimCLR_Aug"        : simclr_aug,
    "BYOL_Noise"        : byol_noise,
    "SimCLR_Noise"      : simclr_noise,
    "Seed_Time_Min"     : seed_time,
    "BYOL_AvgEpochSec"  : np.mean(byol_epoch_times),
    "SimCLR_AvgEpochSec": np.mean(simclr_epoch_times),
}

if os.path.exists(SAVE_PATH):
    results_df = pd.read_csv(SAVE_PATH)
    if seed in results_df["Seed"].values:
        for k, v in seed_row.items():
            results_df.loc[results_df["Seed"] == seed, k] = v
        print(f"  Updated existing row for seed {seed}")
    else:
        results_df = pd.concat([results_df, pd.DataFrame([seed_row])], ignore_index=True)
        print(f"  Appended seed {seed}")
else:
    results_df = pd.DataFrame([seed_row])
    print(f"  Created new results file for seed {seed}")

results_df.to_csv(SAVE_PATH, index=False)
print(f"  Saved → {SAVE_PATH}")
# Out:
# [Eval] Running linear probes...
# [Eval] Computing geometry metrics...
#
#   Seed 3 finished in 323.06 min
#   BYOL   → Acc: 0.4779  | Jac: 1.0390
#   SimCLR → Acc: 0.7711  | Jac: 5.5844
#   Created new results file for seed 3
#   Saved → /kaggle/working/cifar10_vit_results.csv

# %%
LAMBDA_JAC   = 1e-3
TEMPERATURE  = 1.0                                  # τ = 1.0 as determined
NUM_EPOCHS   = 100
BATCH_SIZE   = 256
NUM_WORKERS  = 4

print("=" * 60)
print(f"  [JacReg] SimCLR + Jacobian Reg  |  Seed: {seed}")
print(f"  lambda_jac = {LAMBDA_JAC}  |  tau = {TEMPERATURE}")
print("=" * 60)

set_seed(seed)
jacreg_start = time.time()

# ── Data (CIFAR-10, same seed as BYOL/SimCLR cells) ──────────────────────────
train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=ssl_transform)

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=False, transform=supervised_transform)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=False, transform=supervised_transform)

_loader_kw = dict(
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    persistent_workers=True,
)

train_loader            = DataLoader(train_dataset,            shuffle=True,  **_loader_kw)
supervised_train_loader = DataLoader(supervised_train_dataset, shuffle=True,  **_loader_kw)
supervised_test_loader  = DataLoader(test_dataset,             shuffle=False, **_loader_kw)

# ── Model ─────────────────────────────────────────────────────────────────────
jacreg_model = SimCLR().to(device)


optimizer = torch.optim.AdamW(
    jacreg_model.parameters(), lr=3e-4, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

scaler = GradScaler("cuda")

jacreg_epoch_times = []

for epoch in range(NUM_EPOCHS):
    epoch_start  = time.time()
    jacreg_model.train()
    running_loss = 0.0
    running_ssl  = 0.0
    running_jac  = 0.0

    for batch_idx, ((x1, x2), _) in enumerate(train_loader):

        # requires_grad needed for Jacobian — only on x1
        x1 = x1.to(device, non_blocking=True).requires_grad_(True)
        x2 = x2.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        with autocast("cuda"):
            z1 = jacreg_model(x1)
            z2 = jacreg_model(x2)
            loss_ssl = nt_xent_loss(z1, z2, temperature=TEMPERATURE)

        # FIXED: compute Jac reg every other batch (same as original)
        # but keep it inside autocast for speed, and use retain_graph correctly
        if batch_idx % 2 == 0:
            with autocast("cuda"):
                features = jacreg_model.encoder(x1)

            v  = torch.randn_like(features)
            Jv = torch.autograd.grad(
                outputs=features,
                inputs=x1,
                grad_outputs=v,
                retain_graph=False,
                create_graph=False,         # NEW: no 2nd-order graph, faster
            )[0]
            # FIXED: detach before .item() to avoid holding graph
            jac_reg = Jv.pow(2).sum(dim=[1, 2, 3]).mean()
        else:
            jac_reg = torch.tensor(0.0, device=device)

        loss = loss_ssl + LAMBDA_JAC * jac_reg

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(
            jacreg_model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        running_ssl  += loss_ssl.item()
        running_jac  += jac_reg.item() if isinstance(jac_reg, torch.Tensor) else 0.0

    scheduler.step()

    elapsed = time.time() - epoch_start
    jacreg_epoch_times.append(elapsed)
    avg_t     = np.mean(jacreg_epoch_times)
    remaining = avg_t * (NUM_EPOCHS - epoch - 1)
    n_batches = len(train_loader)

    print(f"  [JacReg] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
          f"Loss: {running_loss/n_batches:.4f}  "
          f"(SSL: {running_ssl/n_batches:.4f}  "
          f"Jac: {running_jac/n_batches:.4f}) | "
          f"Time: {elapsed:.1f}s | "
          f"ETA: {remaining/60:.1f} min")

jacreg_encoder = jacreg_model.encoder

# ── Evaluate ──────────────────────────────────────────────────────────────────
print("\n[JacReg] Running linear probe...")
jacreg_acc = train_probe(
    jacreg_encoder, supervised_train_loader, supervised_test_loader)

print("[JacReg] Computing geometry metrics...")
jacreg_jac, jacreg_aug, jacreg_noise = compute_metrics(
    jacreg_encoder, supervised_test_loader)

jacreg_time = (time.time() - jacreg_start) / 60

print(f"\n  [JacReg] Seed {seed} done in {jacreg_time:.2f} min")
print(f"  JacReg → Acc: {jacreg_acc:.4f}  | Jac: {jacreg_jac:.4f}")


# =========================================================
# CELL 2 — Final Results  (all 3 models, 1 seed)
# =========================================================
#
# Reads BYOL + SimCLR results from all_results (built in prior cells),
# appends JacReg, saves everything to /kaggle/working/
# ─────────────────────────────────────────────────────────

import os

# ── Build unified row for this seed ───────────────────────────────────────────
seed_row = {
    "Seed"                  : seed,

    # Accuracy
    "BYOL_Acc"              : byol_acc,
    "SimCLR_Acc"            : simclr_acc,
    "JacReg_Acc"            : jacreg_acc,

    # Jacobian sensitivity
    "BYOL_Jacobian"         : byol_jac,
    "SimCLR_Jacobian"       : simclr_jac,
    "JacReg_Jacobian"       : jacreg_jac,

    # Augmentation invariance
    "BYOL_Aug"              : byol_aug,
    "SimCLR_Aug"            : simclr_aug,
    "JacReg_Aug"            : jacreg_aug,

    # Noise robustness
    "BYOL_Noise"            : byol_noise,
    "SimCLR_Noise"          : simclr_noise,
    "JacReg_Noise"          : jacreg_noise,

    # Timing
    "BYOL_Time_Min"         : sum(byol_epoch_times) / 60,
    "SimCLR_Time_Min"       : sum(simclr_epoch_times) / 60,
    "JacReg_Time_Min"       : jacreg_time,

    "BYOL_AvgEpochSec"      : np.mean(byol_epoch_times),
    "SimCLR_AvgEpochSec"    : np.mean(simclr_epoch_times),
    "JacReg_AvgEpochSec"    : np.mean(jacreg_epoch_times),
}

# ── Merge with any previously saved seeds ─────────────────────────────────────
SAVE_PATH = "/kaggle/working/cifar10_results_progress.csv"

if os.path.exists(SAVE_PATH):
    results_df = pd.read_csv(SAVE_PATH)
    # overwrite row if seed already exists, else append
    if seed in results_df["Seed"].values:
        for k, v in seed_row.items():
            results_df.loc[results_df["Seed"] == seed, k] = v
        print(f"  Updated existing row for seed {seed}")
    else:
        results_df = pd.concat(
            [results_df, pd.DataFrame([seed_row])], ignore_index=True)
        print(f"  Appended new row for seed {seed}")
else:
    results_df = pd.DataFrame([seed_row])
    print(f"  Created new results file for seed {seed}")

results_df.to_csv(SAVE_PATH, index=False)
print(f"  Saved → {SAVE_PATH}")

# ── Pretty-print side-by-side comparison ──────────────────────────────────────
METRICS = [
    ("Accuracy",              "BYOL_Acc",       "SimCLR_Acc",       "JacReg_Acc"),
    ("Jacobian Sensitivity",  "BYOL_Jacobian",  "SimCLR_Jacobian",  "JacReg_Jacobian"),
    ("Aug Invariance",        "BYOL_Aug",       "SimCLR_Aug",       "JacReg_Aug"),
    ("Noise Robustness",      "BYOL_Noise",     "SimCLR_Noise",     "JacReg_Noise"),
    ("Train Time (min)",      "BYOL_Time_Min",  "SimCLR_Time_Min",  "JacReg_Time_Min"),
    ("Avg Epoch (sec)",       "BYOL_AvgEpochSec","SimCLR_AvgEpochSec","JacReg_AvgEpochSec"),
]

print("\n" + "=" * 70)
print(f"  SEED {seed} RESULTS  —  BYOL vs SimCLR vs SimCLR+JacReg  (CIFAR-10)")
print("=" * 70)
print(f"  {'Metric':<26}  {'BYOL':>10}  {'SimCLR':>10}  {'JacReg':>10}")
print("  " + "-" * 62)
for label, b_col, s_col, j_col in METRICS:
    b = seed_row[b_col]
    s = seed_row[s_col]
    j = seed_row[j_col]
    print(f"  {label:<26}  {b:>10.4f}  {s:>10.4f}  {j:>10.4f}")
print("=" * 70)

# ── If multiple seeds are done, also print aggregate stats ────────────────────
if len(results_df) > 1:
    print(f"\n  AGGREGATE  ({len(results_df)} seeds completed)")
    print("=" * 70)
    print(f"  {'Metric':<26}  {'BYOL':>10}  {'SimCLR':>10}  {'JacReg':>10}")
    print("  " + "-" * 62)
    for label, b_col, s_col, j_col in METRICS:
        bm = results_df[b_col].mean(); bs = results_df[b_col].std()
        sm = results_df[s_col].mean(); ss = results_df[s_col].std()
        jm = results_df[j_col].mean(); js = results_df[j_col].std()
        print(f"  {label:<26}  "
              f"{bm:>6.4f}±{bs:.3f}  "
              f"{sm:>6.4f}±{ss:.3f}  "
              f"{jm:>6.4f}±{js:.3f}")
    print("=" * 70)

print(f"\n  Seeds completed so far: {sorted(results_df['Seed'].tolist())}")
print(f"  Progress CSV: {SAVE_PATH}")
# Out:
# ============================================================
#   [JacReg] SimCLR + Jacobian Reg  |  Seed: 3
#   lambda_jac = 0.001  |  tau = 1.0
# ============================================================
#   [JacReg] Epoch   1/100 | Loss: 5.7008  (SSL: 5.6979  Jac: 2.9660) | Time: 103.0s | ETA: 170.0 min
#   [JacReg] Epoch   2/100 | Loss: 5.6170  (SSL: 5.6157  Jac: 1.2933) | Time: 101.2s | ETA: 166.8 min
#   [JacReg] Epoch   3/100 | Loss: 5.5944  (SSL: 5.5933  Jac: 1.1331) | Time: 101.1s | ETA: 164.5 min
#   [JacReg] Epoch   4/100 | Loss: 5.5770  (SSL: 5.5758  Jac: 1.2779) | Time: 100.9s | ETA: 162.5 min
#   [JacReg] Epoch   5/100 | Loss: 5.5664  (SSL: 5.5650  Jac: 1.4574) | Time: 101.4s | ETA: 160.7 min
#   [JacReg] Epoch   6/100 | Loss: 5.5531  (SSL: 5.5514  Jac: 1.7618) | Time: 101.4s | ETA: 159.0 min
#   [JacReg] Epoch   7/100 | Loss: 5.5456  (SSL: 5.5436  Jac: 2.0053) | Time: 102.3s | ETA: 157.5 min
#   [JacReg] Epoch   8/100 | Loss: 5.5371  (SSL: 5.5348  Jac: 2.3784) | Time: 101.4s | ETA: 155.8 min
#   [JacReg] Epoch   9/100 | Loss: 5.5300  (SSL: 5.5277  Jac: 2.3589) | Time: 101.3s | ETA: 154.0 min
#   [JacReg] Epoch  10/100 | Loss: 5.5236  (SSL: 5.5208  Jac: 2.8288) | Time: 101.5s | ETA: 152.3 min
#   [JacReg] Epoch  11/100 | Loss: 5.5180  (SSL: 5.5149  Jac: 3.1477) | Time: 102.4s | ETA: 150.8 min
#   [JacReg] Epoch  12/100 | Loss: 5.5111  (SSL: 5.5076  Jac: 3.5010) | Time: 101.1s | ETA: 149.0 min
#   [JacReg] Epoch  13/100 | Loss: 5.5037  (SSL: 5.5000  Jac: 3.7103) | Time: 100.8s | ETA: 147.2 min
#   [JacReg] Epoch  14/100 | Loss: 5.4976  (SSL: 5.4935  Jac: 4.1539) | Time: 101.3s | ETA: 145.5 min
#   [JacReg] Epoch  15/100 | Loss: 5.4934  (SSL: 5.4888  Jac: 4.6128) | Time: 102.4s | ETA: 143.9 min
#   [JacReg] Epoch  16/100 | Loss: 5.4884  (SSL: 5.4831  Jac: 5.2638) | Time: 101.4s | ETA: 142.2 min
#   [JacReg] Epoch  17/100 | Loss: 5.4855  (SSL: 5.4799  Jac: 5.5631) | Time: 101.2s | ETA: 140.5 min
#   [JacReg] Epoch  18/100 | Loss: 5.4809  (SSL: 5.4751  Jac: 5.7281) | Time: 101.9s | ETA: 138.8 min
#   [JacReg] Epoch  19/100 | Loss: 5.4775  (SSL: 5.4715  Jac: 5.9187) | Time: 101.5s | ETA: 137.1 min
#   [JacReg] Epoch  20/100 | Loss: 5.4736  (SSL: 5.4674  Jac: 6.2745) | Time: 102.1s | ETA: 135.4 min
#   [JacReg] Epoch  21/100 | Loss: 5.4697  (SSL: 5.4630  Jac: 6.7331) | Time: 101.2s | ETA: 133.7 min
#   [JacReg] Epoch  22/100 | Loss: 5.4686  (SSL: 5.4615  Jac: 7.1533) | Time: 101.0s | ETA: 132.0 min
#   [JacReg] Epoch  23/100 | Loss: 5.4643  (SSL: 5.4565  Jac: 7.8871) | Time: 101.4s | ETA: 130.3 min
#   [JacReg] Epoch  24/100 | Loss: 5.4625  (SSL: 5.4552  Jac: 7.3328) | Time: 101.1s | ETA: 128.6 min
#   [JacReg] Epoch  25/100 | Loss: 5.4586  (SSL: 5.4507  Jac: 7.8871) | Time: 102.2s | ETA: 126.9 min
#   [JacReg] Epoch  26/100 | Loss: 5.4563  (SSL: 5.4483  Jac: 7.9774) | Time: 101.2s | ETA: 125.2 min
#   [JacReg] Epoch  27/100 | Loss: 5.4544  (SSL: 5.4457  Jac: 8.6795) | Time: 101.7s | ETA: 123.5 min
#   [JacReg] Epoch  28/100 | Loss: 5.4535  (SSL: 5.4442  Jac: 9.2495) | Time: 101.6s | ETA: 121.8 min
#   [JacReg] Epoch  29/100 | Loss: 5.4512  (SSL: 5.4412  Jac: 9.9169) | Time: 102.3s | ETA: 120.2 min
#   [JacReg] Epoch  30/100 | Loss: 5.4490  (SSL: 5.4388  Jac: 10.1990) | Time: 101.5s | ETA: 118.5 min
#   [JacReg] Epoch  31/100 | Loss: 5.4482  (SSL: 5.4375  Jac: 10.6772) | Time: 101.6s | ETA: 116.8 min
#   [JacReg] Epoch  32/100 | Loss: 5.4454  (SSL: 5.4340  Jac: 11.3710) | Time: 101.3s | ETA: 115.1 min
#   [JacReg] Epoch  33/100 | Loss: 5.4449  (SSL: 5.4334  Jac: 11.5419) | Time: 101.2s | ETA: 113.4 min
#   [JacReg] Epoch  34/100 | Loss: 5.4439  (SSL: 5.4316  Jac: 12.2462) | Time: 101.6s | ETA: 111.7 min
#   [JacReg] Epoch  35/100 | Loss: 5.4417  (SSL: 5.4288  Jac: 12.9034) | Time: 102.5s | ETA: 110.0 min
#   [JacReg] Epoch  36/100 | Loss: 5.4422  (SSL: 5.4284  Jac: 13.7541) | Time: 101.6s | ETA: 108.3 min
#   [JacReg] Epoch  37/100 | Loss: 5.4399  (SSL: 5.4259  Jac: 14.0613) | Time: 101.4s | ETA: 106.6 min
#   [JacReg] Epoch  38/100 | Loss: 5.4403  (SSL: 5.4256  Jac: 14.6996) | Time: 101.5s | ETA: 104.9 min
#   [JacReg] Epoch  39/100 | Loss: 5.4381  (SSL: 5.4226  Jac: 15.5450) | Time: 101.4s | ETA: 103.2 min
#   [JacReg] Epoch  40/100 | Loss: 5.4354  (SSL: 5.4191  Jac: 16.2447) | Time: 102.8s | ETA: 101.6 min
#   [JacReg] Epoch  41/100 | Loss: 5.4358  (SSL: 5.4193  Jac: 16.5422) | Time: 101.4s | ETA: 99.9 min
#   [JacReg] Epoch  42/100 | Loss: 5.4348  (SSL: 5.4178  Jac: 16.9671) | Time: 101.4s | ETA: 98.2 min
#   [JacReg] Epoch  43/100 | Loss: 5.4337  (SSL: 5.4166  Jac: 17.1294) | Time: 101.8s | ETA: 96.5 min
#   [JacReg] Epoch  44/100 | Loss: 5.4327  (SSL: 5.4146  Jac: 18.1215) | Time: 101.8s | ETA: 94.8 min
#   [JacReg] Epoch  45/100 | Loss: 5.4317  (SSL: 5.4127  Jac: 18.9912) | Time: 102.7s | ETA: 93.1 min
#   [JacReg] Epoch  46/100 | Loss: 5.4313  (SSL: 5.4118  Jac: 19.5229) | Time: 102.0s | ETA: 91.5 min
#   [JacReg] Epoch  47/100 | Loss: 5.4309  (SSL: 5.4116  Jac: 19.3233) | Time: 101.7s | ETA: 89.8 min
#   [JacReg] Epoch  48/100 | Loss: 5.4277  (SSL: 5.4075  Jac: 20.1563) | Time: 101.8s | ETA: 88.1 min
#   [JacReg] Epoch  49/100 | Loss: 5.4291  (SSL: 5.4081  Jac: 21.0679) | Time: 102.7s | ETA: 86.4 min
#   [JacReg] Epoch  50/100 | Loss: 5.4298  (SSL: 5.4070  Jac: 22.7604) | Time: 101.5s | ETA: 84.7 min
#   [JacReg] Epoch  51/100 | Loss: 5.4283  (SSL: 5.4051  Jac: 23.1314) | Time: 101.7s | ETA: 83.0 min
#   [JacReg] Epoch  52/100 | Loss: 5.4276  (SSL: 5.4038  Jac: 23.8438) | Time: 101.8s | ETA: 81.3 min
#   [JacReg] Epoch  53/100 | Loss: 5.4275  (SSL: 5.4024  Jac: 25.0828) | Time: 101.6s | ETA: 79.6 min
#   [JacReg] Epoch  54/100 | Loss: 5.4260  (SSL: 5.4006  Jac: 25.4009) | Time: 101.1s | ETA: 77.9 min
#   [JacReg] Epoch  55/100 | Loss: 5.4286  (SSL: 5.4012  Jac: 27.4315) | Time: 101.6s | ETA: 76.2 min
#   [JacReg] Epoch  56/100 | Loss: 5.4263  (SSL: 5.3989  Jac: 27.3602) | Time: 102.6s | ETA: 74.5 min
#   [JacReg] Epoch  57/100 | Loss: 5.4264  (SSL: 5.3989  Jac: 27.4942) | Time: 101.9s | ETA: 72.9 min
#   [JacReg] Epoch  58/100 | Loss: 5.4243  (SSL: 5.3969  Jac: 27.3310) | Time: 101.6s | ETA: 71.2 min
#   [JacReg] Epoch  59/100 | Loss: 5.4218  (SSL: 5.3941  Jac: 27.7279) | Time: 101.8s | ETA: 69.5 min
#   [JacReg] Epoch  60/100 | Loss: 5.4238  (SSL: 5.3953  Jac: 28.5107) | Time: 102.5s | ETA: 67.8 min
#   [JacReg] Epoch  61/100 | Loss: 5.4236  (SSL: 5.3937  Jac: 29.8646) | Time: 101.7s | ETA: 66.1 min
#   [JacReg] Epoch  62/100 | Loss: 5.4231  (SSL: 5.3924  Jac: 30.6247) | Time: 101.3s | ETA: 64.4 min
#   [JacReg] Epoch  63/100 | Loss: 5.4243  (SSL: 5.3929  Jac: 31.3847) | Time: 101.6s | ETA: 62.7 min
#   [JacReg] Epoch  64/100 | Loss: 5.4243  (SSL: 5.3920  Jac: 32.3766) | Time: 101.6s | ETA: 61.0 min
#   [JacReg] Epoch  65/100 | Loss: 5.4234  (SSL: 5.3902  Jac: 33.1887) | Time: 102.6s | ETA: 59.3 min
#   [JacReg] Epoch  66/100 | Loss: 5.4223  (SSL: 5.3882  Jac: 34.1014) | Time: 101.3s | ETA: 57.6 min
#   [JacReg] Epoch  67/100 | Loss: 5.4240  (SSL: 5.3883  Jac: 35.7500) | Time: 101.6s | ETA: 55.9 min
#   [JacReg] Epoch  68/100 | Loss: 5.4239  (SSL: 5.3880  Jac: 35.9104) | Time: 101.8s | ETA: 54.2 min
#   [JacReg] Epoch  69/100 | Loss: 5.4222  (SSL: 5.3865  Jac: 35.7800) | Time: 101.8s | ETA: 52.5 min
#   [JacReg] Epoch  70/100 | Loss: 5.4234  (SSL: 5.3858  Jac: 37.5286) | Time: 102.4s | ETA: 50.8 min
#   [JacReg] Epoch  71/100 | Loss: 5.4226  (SSL: 5.3846  Jac: 37.9849) | Time: 101.6s | ETA: 49.1 min
#   [JacReg] Epoch  72/100 | Loss: 5.4233  (SSL: 5.3851  Jac: 38.1932) | Time: 101.6s | ETA: 47.5 min
#   [JacReg] Epoch  73/100 | Loss: 5.4221  (SSL: 5.3828  Jac: 39.2986) | Time: 101.5s | ETA: 45.8 min
#   [JacReg] Epoch  74/100 | Loss: 5.4215  (SSL: 5.3822  Jac: 39.2303) | Time: 101.6s | ETA: 44.1 min
#   [JacReg] Epoch  75/100 | Loss: 5.4232  (SSL: 5.3821  Jac: 41.0589) | Time: 101.2s | ETA: 42.4 min
#   [JacReg] Epoch  76/100 | Loss: 5.4249  (SSL: 5.3830  Jac: 41.8818) | Time: 101.6s | ETA: 40.7 min
#   [JacReg] Epoch  77/100 | Loss: 5.4229  (SSL: 5.3817  Jac: 41.1458) | Time: 102.4s | ETA: 39.0 min
#   [JacReg] Epoch  78/100 | Loss: 5.4238  (SSL: 5.3807  Jac: 43.1190) | Time: 102.2s | ETA: 37.3 min
#   [JacReg] Epoch  79/100 | Loss: 5.4237  (SSL: 5.3793  Jac: 44.4669) | Time: 101.4s | ETA: 35.6 min
#   [JacReg] Epoch  80/100 | Loss: 5.4222  (SSL: 5.3785  Jac: 43.7319) | Time: 101.6s | ETA: 33.9 min
#   [JacReg] Epoch  81/100 | Loss: 5.4228  (SSL: 5.3786  Jac: 44.2106) | Time: 101.1s | ETA: 32.2 min
#   [JacReg] Epoch  82/100 | Loss: 5.4220  (SSL: 5.3776  Jac: 44.3801) | Time: 102.6s | ETA: 30.5 min
#   [JacReg] Epoch  83/100 | Loss: 5.4224  (SSL: 5.3762  Jac: 46.1327) | Time: 102.0s | ETA: 28.8 min
#   [JacReg] Epoch  84/100 | Loss: 5.4219  (SSL: 5.3757  Jac: 46.1873) | Time: 101.9s | ETA: 27.1 min
#   [JacReg] Epoch  85/100 | Loss: 5.4242  (SSL: 5.3772  Jac: 46.9667) | Time: 101.6s | ETA: 25.4 min
#   [JacReg] Epoch  86/100 | Loss: 5.4251  (SSL: 5.3758  Jac: 49.3298) | Time: 101.8s | ETA: 23.7 min
#   [JacReg] Epoch  87/100 | Loss: 5.4239  (SSL: 5.3761  Jac: 47.8611) | Time: 101.9s | ETA: 22.0 min
#   [JacReg] Epoch  88/100 | Loss: 5.4243  (SSL: 5.3759  Jac: 48.3523) | Time: 102.7s | ETA: 20.3 min
#   [JacReg] Epoch  89/100 | Loss: 5.4258  (SSL: 5.3755  Jac: 50.2779) | Time: 101.8s | ETA: 18.6 min
#   [JacReg] Epoch  90/100 | Loss: 5.4245  (SSL: 5.3754  Jac: 49.1229) | Time: 101.7s | ETA: 17.0 min
#   [JacReg] Epoch  91/100 | Loss: 5.4232  (SSL: 5.3739  Jac: 49.2595) | Time: 101.3s | ETA: 15.3 min
#   [JacReg] Epoch  92/100 | Loss: 5.4237  (SSL: 5.3742  Jac: 49.5276) | Time: 101.6s | ETA: 13.6 min
#   [JacReg] Epoch  93/100 | Loss: 5.4231  (SSL: 5.3742  Jac: 48.9200) | Time: 102.5s | ETA: 11.9 min
#   [JacReg] Epoch  94/100 | Loss: 5.4225  (SSL: 5.3739  Jac: 48.6100) | Time: 101.4s | ETA: 10.2 min
#   [JacReg] Epoch  95/100 | Loss: 5.4237  (SSL: 5.3738  Jac: 49.8691) | Time: 101.7s | ETA: 8.5 min
#   [JacReg] Epoch  96/100 | Loss: 5.4229  (SSL: 5.3740  Jac: 48.9022) | Time: 101.7s | ETA: 6.8 min
#   [JacReg] Epoch  97/100 | Loss: 5.4231  (SSL: 5.3734  Jac: 49.7159) | Time: 101.6s | ETA: 5.1 min
#   [JacReg] Epoch  98/100 | Loss: 5.4225  (SSL: 5.3731  Jac: 49.4442) | Time: 101.6s | ETA: 3.4 min
#   [JacReg] Epoch  99/100 | Loss: 5.4241  (SSL: 5.3738  Jac: 50.2989) | Time: 102.4s | ETA: 1.7 min
#   [JacReg] Epoch 100/100 | Loss: 5.4210  (SSL: 5.3721  Jac: 48.8862) | Time: 101.7s | ETA: 0.0 min
#
# [JacReg] Running linear probe...
# [JacReg] Computing geometry metrics...
#
#   [JacReg] Seed 3 done in 175.71 min
#   JacReg → Acc: 0.7674  | Jac: 5.7250
#   Created new results file for seed 3
#   Saved → /kaggle/working/cifar10_results_progress.csv
#
# ======================================================================
#   SEED 3 RESULTS  —  BYOL vs SimCLR vs SimCLR+JacReg  (CIFAR-10)
# ======================================================================
#   Metric                            BYOL      SimCLR      JacReg
#   --------------------------------------------------------------
#   Accuracy                        0.4779      0.7711      0.7674
#   Jacobian Sensitivity            1.0390      5.5844      5.7250
#   Aug Invariance                  2.5994      6.7486      7.1492
#   Noise Robustness                0.0999      0.7582      0.7548
#   Train Time (min)              159.6641    150.2335    175.7070
#   Avg Epoch (sec)                95.7985     90.1401    101.7139
# ======================================================================
#
#   Seeds completed so far: [3]
#   Progress CSV: /kaggle/working/cifar10_results_progress.csv
