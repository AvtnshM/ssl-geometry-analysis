# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import numpy as np
import random
import pandas as pd
import time
import scipy.stats as stats

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def set_seed(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
# Out:
# Device: cuda

# %%
class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform
    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)

ssl_base_transform = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2,1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=ssl_transform
)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=T.ToTensor()
)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)
# Out:
# 100%|██████████| 170M/170M [00:13<00:00, 12.7MB/s]

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        backbone = resnet18(weights=None)
        backbone.fc = nn.Identity()
        self.backbone = backbone
    def forward(self, x):
        return self.backbone(x)

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, hidden_dim=2048, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )
    def forward(self, x):
        return self.net(x)

class BYOL(nn.Module):
    def __init__(self):
        super().__init__()
        self.online_encoder = Encoder()
        self.online_projector = MLP(512)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder = Encoder()
        self.target_projector = MLP(512)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for o, t in zip(self.online_encoder.parameters(),
                        self.target_encoder.parameters()):
            t.data = tau * t.data + (1 - tau) * o.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(
            self.online_projector(self.online_encoder(x1))
        )

        with torch.no_grad():
            t2 = self.target_projector(
                self.target_encoder(x2)
            )

        loss = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        return loss.mean()

# %%
class SimCLR(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.projector = MLP(512)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)

def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)

    sim = torch.mm(z, z.t()) / temperature
    mask = torch.eye(2*N, device=z.device).bool()
    sim.masked_fill_(mask, -9e15)

    positives = torch.cat([
        torch.arange(N,2*N),
        torch.arange(0,N)
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
def jacobian_penalty(model, x):
    x = x.clone().detach().requires_grad_(True)
    z = model(x)

    v = torch.randn_like(z)

    Jv = torch.autograd.grad(
        outputs=z,
        inputs=x,
        grad_outputs=v,
        create_graph=True
    )[0]

    return Jv.pow(2).sum(dim=[1,2,3]).mean()

# %%
def train_byol(model, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            loss = model(x1,x2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            model.update_target()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[BYOL] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.online_encoder


def train_simclr(model, epochs=100, lambda_jac=0.0):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            z1 = model(x1)
            z2 = model(x2)
            loss = nt_xent_loss(z1,z2)

            if lambda_jac > 0:
                jac = jacobian_penalty(model, x1)
                loss = loss + lambda_jac * jac

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[SimCLR] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.encoder

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(512, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    return correct / total

# %%
# =========================================================
# Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
])


def jacobian_frobenius(model, x):
    model.eval()
    x = x.clone().detach().requires_grad_(True)

    y = model(x)

    v = torch.randn_like(y)

    Jv = torch.autograd.grad(
        outputs=y,
        inputs=x,
        grad_outputs=v,
        create_graph=False,
        retain_graph=False
    )[0]

    # Proper per-sample Frobenius estimate
    per_sample = Jv.pow(2).flatten(1).sum(dim=1)

    return torch.sqrt(per_sample.mean())


def compute_metrics(encoder, loader):
    encoder = encoder.to(device)
    encoder.eval()

    jac_vals = []
    aug_vals = []
    noise_vals = []

    for i, (x, _) in enumerate(loader):
        if i == 5:  # limit batches
            break

        x = x.to(device)

        # ---- Jacobian ----
        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # ---- Augmentation Sensitivity ----
        x_aug = torch.stack([
            tensor_aug(img.cpu()) for img in x
        ]).to(device)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        # ---- Noise Sensitivity ----
        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x + noise)
            noise_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

    return (
        np.mean(jac_vals),
        np.mean(aug_vals),
        np.mean(noise_vals)
    )

# %%
# =========================================================
# Supervised Data (for Linear Probe)
# =========================================================

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=False,
    transform=T.ToTensor()
)

supervised_test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=False,
    transform=T.ToTensor()
)

supervised_train_loader = DataLoader(
    supervised_train_dataset,
    batch_size=128,
    shuffle=True,
    num_workers=2
)

supervised_test_loader = DataLoader(
    supervised_test_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=2
)

print("Supervised loaders ready.")
# Out:
# Supervised loaders ready.

# %%
import os

# =========================================================
# CONFIG
# =========================================================

csv_path = "/kaggle/working/byol_simclr_results.csv"
target_seeds = [6, 7]  

# =========================================================
# RESUME LOGIC
# =========================================================

if os.path.exists(csv_path):
    existing_df = pd.read_csv(csv_path)
    completed_seeds = set(existing_df["Seed"].unique())
    all_results = existing_df.to_dict("records")
    print("Loaded existing results. Completed seeds:", completed_seeds)
else:
    completed_seeds = set()
    all_results = []
    print("No existing CSV found. Starting fresh.")

seeds = [s for s in target_seeds if s not in completed_seeds]

print("Seeds to run now:", seeds)

global_start = time.time()

# =========================================================
# MAIN LOOP
# =========================================================

for seed in seeds:

    print("\n====================================")
    print(f"Running Seed: {seed}")
    print("====================================")

    seed_start = time.time()
    set_seed(seed)

    # ------------------------
    # Train Models
    # ------------------------

    byol_encoder = train_byol(BYOL(), epochs=100)

    simclr_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=0.0
    )

    simclr_jac_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=1e-3
    )

    # ------------------------
    # Compute Metrics
    # ------------------------

    byol_metrics = compute_metrics(byol_encoder, test_loader)
    simclr_metrics = compute_metrics(simclr_encoder, test_loader)
    simclr_jac_metrics = compute_metrics(simclr_jac_encoder, test_loader)

    # ------------------------
    # Linear Probe
    # ------------------------

    byol_acc = train_probe(
        byol_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_acc = train_probe(
        simclr_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_jac_acc = train_probe(
        simclr_jac_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    # ------------------------
    # Store Results
    # ------------------------

    seed_results = [
        {
            "Seed": seed,
            "Method": "BYOL",
            "Jacobian": byol_metrics[0],
            "Aug_Sensitivity": byol_metrics[1],
            "Noise_Sensitivity": byol_metrics[2],
            "Linear_Probe_Acc": byol_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR",
            "Jacobian": simclr_metrics[0],
            "Aug_Sensitivity": simclr_metrics[1],
            "Noise_Sensitivity": simclr_metrics[2],
            "Linear_Probe_Acc": simclr_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR+Jac",
            "Jacobian": simclr_jac_metrics[0],
            "Aug_Sensitivity": simclr_jac_metrics[1],
            "Noise_Sensitivity": simclr_jac_metrics[2],
            "Linear_Probe_Acc": simclr_jac_acc
        }
    ]

    all_results.extend(seed_results)

    # ------------------------
    # SAVE AFTER EACH SEED
    # ------------------------

    results_df = pd.DataFrame(all_results)
    results_df.to_csv(csv_path, index=False)

    print("Saved results to:", csv_path)

    # ------------------------
    # Running Summary
    # ------------------------

    summary = results_df.groupby("Method").mean(numeric_only=True)
    print("\nRunning Mean Summary:")
    print(summary)

    # ------------------------
    # GPU Cleanup
    # ------------------------

    del byol_encoder, simclr_encoder, simclr_jac_encoder
    torch.cuda.empty_cache()

    seed_time = (time.time() - seed_start) / 60
    print(f"\nSeed {seed} finished in {seed_time:.2f} minutes")

# =========================================================
# FINAL SUMMARY
# =========================================================

final_df = pd.read_csv(csv_path)

print("\n================ FINAL RESULTS ================")
print(final_df)

total_time = (time.time() - global_start) / 60
print(f"\nTotal experiment time (this session): {total_time:.2f} minutes")
# Out:
# No existing CSV found. Starting fresh.
# Seeds to run now: [6, 7]
#
# ====================================
# Running Seed: 6
# ====================================
# [BYOL] 001/100 | Loss: 0.7467 | Epoch Time: 0.82m | Total Time: 0.82m
# [BYOL] 002/100 | Loss: 0.6010 | Epoch Time: 0.78m | Total Time: 1.60m
# [BYOL] 003/100 | Loss: 0.5215 | Epoch Time: 0.79m | Total Time: 2.39m
# [BYOL] 004/100 | Loss: 0.4836 | Epoch Time: 0.78m | Total Time: 3.16m
# [BYOL] 005/100 | Loss: 0.4631 | Epoch Time: 0.78m | Total Time: 3.94m
# [BYOL] 006/100 | Loss: 0.4542 | Epoch Time: 0.79m | Total Time: 4.73m
# [BYOL] 007/100 | Loss: 0.4446 | Epoch Time: 0.79m | Total Time: 5.52m
# [BYOL] 008/100 | Loss: 0.4370 | Epoch Time: 0.78m | Total Time: 6.29m
# [BYOL] 009/100 | Loss: 0.4350 | Epoch Time: 0.78m | Total Time: 7.08m
# [BYOL] 010/100 | Loss: 0.4318 | Epoch Time: 0.78m | Total Time: 7.86m
# [BYOL] 011/100 | Loss: 0.4295 | Epoch Time: 0.78m | Total Time: 8.64m
# [BYOL] 012/100 | Loss: 0.4295 | Epoch Time: 0.77m | Total Time: 9.41m
# [BYOL] 013/100 | Loss: 0.4240 | Epoch Time: 0.77m | Total Time: 10.18m
# [BYOL] 014/100 | Loss: 0.4224 | Epoch Time: 0.78m | Total Time: 10.96m
# [BYOL] 015/100 | Loss: 0.4228 | Epoch Time: 0.78m | Total Time: 11.74m
# [BYOL] 016/100 | Loss: 0.4202 | Epoch Time: 0.79m | Total Time: 12.53m
# [BYOL] 017/100 | Loss: 0.4167 | Epoch Time: 0.79m | Total Time: 13.32m
# [BYOL] 018/100 | Loss: 0.4153 | Epoch Time: 0.78m | Total Time: 14.09m
# [BYOL] 019/100 | Loss: 0.4128 | Epoch Time: 0.78m | Total Time: 14.87m
# [BYOL] 020/100 | Loss: 0.4138 | Epoch Time: 0.78m | Total Time: 15.65m
# [BYOL] 021/100 | Loss: 0.4111 | Epoch Time: 0.79m | Total Time: 16.44m
# [BYOL] 022/100 | Loss: 0.4114 | Epoch Time: 0.78m | Total Time: 17.22m
# [BYOL] 023/100 | Loss: 0.4098 | Epoch Time: 0.78m | Total Time: 18.00m
# [BYOL] 024/100 | Loss: 0.4077 | Epoch Time: 0.76m | Total Time: 18.76m
# [BYOL] 025/100 | Loss: 0.4074 | Epoch Time: 0.77m | Total Time: 19.53m
# [BYOL] 026/100 | Loss: 0.4081 | Epoch Time: 0.77m | Total Time: 20.30m
# [BYOL] 027/100 | Loss: 0.4084 | Epoch Time: 0.78m | Total Time: 21.08m
# [BYOL] 028/100 | Loss: 0.4062 | Epoch Time: 0.80m | Total Time: 21.87m
# [BYOL] 029/100 | Loss: 0.4054 | Epoch Time: 0.79m | Total Time: 22.66m
# [BYOL] 030/100 | Loss: 0.4069 | Epoch Time: 0.79m | Total Time: 23.45m
# [BYOL] 031/100 | Loss: 0.4062 | Epoch Time: 0.81m | Total Time: 24.27m
# [BYOL] 032/100 | Loss: 0.4038 | Epoch Time: 0.80m | Total Time: 25.07m
# [BYOL] 033/100 | Loss: 0.4050 | Epoch Time: 0.81m | Total Time: 25.88m
# [BYOL] 034/100 | Loss: 0.4027 | Epoch Time: 0.81m | Total Time: 26.69m
# [BYOL] 035/100 | Loss: 0.4019 | Epoch Time: 0.80m | Total Time: 27.49m
# [BYOL] 036/100 | Loss: 0.4017 | Epoch Time: 0.82m | Total Time: 28.31m
# [BYOL] 037/100 | Loss: 0.4010 | Epoch Time: 0.82m | Total Time: 29.13m
# [BYOL] 038/100 | Loss: 0.4001 | Epoch Time: 0.81m | Total Time: 29.94m
# [BYOL] 039/100 | Loss: 0.3987 | Epoch Time: 0.81m | Total Time: 30.75m
# [BYOL] 040/100 | Loss: 0.3964 | Epoch Time: 0.81m | Total Time: 31.56m
# [BYOL] 041/100 | Loss: 0.3962 | Epoch Time: 0.80m | Total Time: 32.37m
# [BYOL] 042/100 | Loss: 0.3954 | Epoch Time: 0.81m | Total Time: 33.18m
# [BYOL] 043/100 | Loss: 0.3935 | Epoch Time: 0.80m | Total Time: 33.98m
# [BYOL] 044/100 | Loss: 0.3935 | Epoch Time: 0.80m | Total Time: 34.78m
# [BYOL] 045/100 | Loss: 0.3924 | Epoch Time: 0.81m | Total Time: 35.58m
# [BYOL] 046/100 | Loss: 0.3903 | Epoch Time: 0.81m | Total Time: 36.40m
# [BYOL] 047/100 | Loss: 0.3918 | Epoch Time: 0.80m | Total Time: 37.20m
# [BYOL] 048/100 | Loss: 0.3904 | Epoch Time: 0.80m | Total Time: 38.00m
# [BYOL] 049/100 | Loss: 0.3888 | Epoch Time: 0.80m | Total Time: 38.81m
# [BYOL] 050/100 | Loss: 0.3865 | Epoch Time: 0.81m | Total Time: 39.61m
# [BYOL] 051/100 | Loss: 0.3844 | Epoch Time: 0.80m | Total Time: 40.42m
# [BYOL] 052/100 | Loss: 0.3856 | Epoch Time: 0.81m | Total Time: 41.23m
# [BYOL] 053/100 | Loss: 0.3858 | Epoch Time: 0.81m | Total Time: 42.04m
# [BYOL] 054/100 | Loss: 0.3847 | Epoch Time: 0.79m | Total Time: 42.83m
# [BYOL] 055/100 | Loss: 0.3833 | Epoch Time: 0.80m | Total Time: 43.63m
# [BYOL] 056/100 | Loss: 0.3840 | Epoch Time: 0.78m | Total Time: 44.41m
# [BYOL] 057/100 | Loss: 0.3827 | Epoch Time: 0.79m | Total Time: 45.19m
# [BYOL] 058/100 | Loss: 0.3823 | Epoch Time: 0.78m | Total Time: 45.98m
# [BYOL] 059/100 | Loss: 0.3839 | Epoch Time: 0.79m | Total Time: 46.77m
# [BYOL] 060/100 | Loss: 0.3811 | Epoch Time: 0.79m | Total Time: 47.56m
# [BYOL] 061/100 | Loss: 0.3832 | Epoch Time: 0.78m | Total Time: 48.34m
# [BYOL] 062/100 | Loss: 0.3824 | Epoch Time: 0.80m | Total Time: 49.14m
# [BYOL] 063/100 | Loss: 0.3808 | Epoch Time: 0.78m | Total Time: 49.92m
# [BYOL] 064/100 | Loss: 0.3817 | Epoch Time: 0.79m | Total Time: 50.71m
# [BYOL] 065/100 | Loss: 0.3815 | Epoch Time: 0.79m | Total Time: 51.50m
# [BYOL] 066/100 | Loss: 0.3799 | Epoch Time: 0.78m | Total Time: 52.28m
# [BYOL] 067/100 | Loss: 0.3801 | Epoch Time: 0.78m | Total Time: 53.06m
# [BYOL] 068/100 | Loss: 0.3788 | Epoch Time: 0.78m | Total Time: 53.84m
# [BYOL] 069/100 | Loss: 0.3796 | Epoch Time: 0.78m | Total Time: 54.62m
# [BYOL] 070/100 | Loss: 0.3785 | Epoch Time: 0.78m | Total Time: 55.40m
# [BYOL] 071/100 | Loss: 0.3782 | Epoch Time: 0.79m | Total Time: 56.20m
# [BYOL] 072/100 | Loss: 0.3775 | Epoch Time: 0.82m | Total Time: 57.01m
# [BYOL] 073/100 | Loss: 0.3761 | Epoch Time: 0.82m | Total Time: 57.83m
# [BYOL] 074/100 | Loss: 0.3755 | Epoch Time: 0.82m | Total Time: 58.65m
# [BYOL] 075/100 | Loss: 0.3763 | Epoch Time: 0.82m | Total Time: 59.47m
# [BYOL] 076/100 | Loss: 0.3741 | Epoch Time: 0.82m | Total Time: 60.28m
# [BYOL] 077/100 | Loss: 0.3761 | Epoch Time: 0.82m | Total Time: 61.10m
# [BYOL] 078/100 | Loss: 0.3742 | Epoch Time: 0.81m | Total Time: 61.91m
# [BYOL] 079/100 | Loss: 0.3762 | Epoch Time: 0.81m | Total Time: 62.71m
# [BYOL] 080/100 | Loss: 0.3754 | Epoch Time: 0.81m | Total Time: 63.52m
# [BYOL] 081/100 | Loss: 0.3741 | Epoch Time: 0.81m | Total Time: 64.33m
# [BYOL] 082/100 | Loss: 0.3759 | Epoch Time: 0.81m | Total Time: 65.14m
# [BYOL] 083/100 | Loss: 0.3742 | Epoch Time: 0.81m | Total Time: 65.95m
# [BYOL] 084/100 | Loss: 0.3737 | Epoch Time: 0.81m | Total Time: 66.76m
# [BYOL] 085/100 | Loss: 0.3736 | Epoch Time: 0.81m | Total Time: 67.57m
# [BYOL] 086/100 | Loss: 0.3726 | Epoch Time: 0.82m | Total Time: 68.39m
# [BYOL] 087/100 | Loss: 0.3706 | Epoch Time: 0.81m | Total Time: 69.19m
# [BYOL] 088/100 | Loss: 0.3720 | Epoch Time: 0.81m | Total Time: 70.01m
# [BYOL] 089/100 | Loss: 0.3717 | Epoch Time: 0.83m | Total Time: 70.83m
# [BYOL] 090/100 | Loss: 0.3735 | Epoch Time: 0.80m | Total Time: 71.64m
# [BYOL] 091/100 | Loss: 0.3719 | Epoch Time: 0.81m | Total Time: 72.45m
# [BYOL] 092/100 | Loss: 0.3722 | Epoch Time: 0.81m | Total Time: 73.26m
# [BYOL] 093/100 | Loss: 0.3733 | Epoch Time: 0.81m | Total Time: 74.07m
# [BYOL] 094/100 | Loss: 0.3710 | Epoch Time: 0.81m | Total Time: 74.88m
# [BYOL] 095/100 | Loss: 0.3719 | Epoch Time: 0.80m | Total Time: 75.68m
# [BYOL] 096/100 | Loss: 0.3725 | Epoch Time: 0.83m | Total Time: 76.51m
# [BYOL] 097/100 | Loss: 0.3725 | Epoch Time: 0.80m | Total Time: 77.31m
# [BYOL] 098/100 | Loss: 0.3717 | Epoch Time: 0.80m | Total Time: 78.11m
# [BYOL] 099/100 | Loss: 0.3730 | Epoch Time: 0.79m | Total Time: 78.90m
# [BYOL] 100/100 | Loss: 0.3743 | Epoch Time: 0.80m | Total Time: 79.70m
# [SimCLR] 001/100 | Loss: 4.6586 | Epoch Time: 0.86m | Total Time: 0.86m
# [SimCLR] 002/100 | Loss: 4.4933 | Epoch Time: 0.86m | Total Time: 1.72m
# [SimCLR] 003/100 | Loss: 4.4225 | Epoch Time: 0.88m | Total Time: 2.60m
# [SimCLR] 004/100 | Loss: 4.3840 | Epoch Time: 0.87m | Total Time: 3.48m
# [SimCLR] 005/100 | Loss: 4.3569 | Epoch Time: 0.86m | Total Time: 4.33m
# [SimCLR] 006/100 | Loss: 4.3310 | Epoch Time: 0.86m | Total Time: 5.20m
# [SimCLR] 007/100 | Loss: 4.3113 | Epoch Time: 0.88m | Total Time: 6.07m
# [SimCLR] 008/100 | Loss: 4.2949 | Epoch Time: 0.86m | Total Time: 6.93m
# [SimCLR] 009/100 | Loss: 4.2816 | Epoch Time: 0.87m | Total Time: 7.81m
# [SimCLR] 010/100 | Loss: 4.2603 | Epoch Time: 0.87m | Total Time: 8.67m
# [SimCLR] 011/100 | Loss: 4.2438 | Epoch Time: 0.85m | Total Time: 9.52m
# [SimCLR] 012/100 | Loss: 4.2346 | Epoch Time: 0.88m | Total Time: 10.41m
# [SimCLR] 013/100 | Loss: 4.2213 | Epoch Time: 0.86m | Total Time: 11.27m
# [SimCLR] 014/100 | Loss: 4.2111 | Epoch Time: 0.86m | Total Time: 12.13m
# [SimCLR] 015/100 | Loss: 4.2033 | Epoch Time: 0.86m | Total Time: 12.99m
# [SimCLR] 016/100 | Loss: 4.1949 | Epoch Time: 0.88m | Total Time: 13.87m
# [SimCLR] 017/100 | Loss: 4.1840 | Epoch Time: 0.86m | Total Time: 14.73m
# [SimCLR] 018/100 | Loss: 4.1819 | Epoch Time: 0.86m | Total Time: 15.58m
# [SimCLR] 019/100 | Loss: 4.1753 | Epoch Time: 0.86m | Total Time: 16.45m
# [SimCLR] 020/100 | Loss: 4.1670 | Epoch Time: 0.85m | Total Time: 17.30m
# [SimCLR] 021/100 | Loss: 4.1669 | Epoch Time: 0.87m | Total Time: 18.17m
# [SimCLR] 022/100 | Loss: 4.1565 | Epoch Time: 0.87m | Total Time: 19.03m
# [SimCLR] 023/100 | Loss: 4.1525 | Epoch Time: 0.85m | Total Time: 19.89m
# [SimCLR] 024/100 | Loss: 4.1472 | Epoch Time: 0.85m | Total Time: 20.74m
# [SimCLR] 025/100 | Loss: 4.1458 | Epoch Time: 0.86m | Total Time: 21.60m
# [SimCLR] 026/100 | Loss: 4.1379 | Epoch Time: 0.86m | Total Time: 22.45m
# [SimCLR] 027/100 | Loss: 4.1374 | Epoch Time: 0.87m | Total Time: 23.33m
# [SimCLR] 028/100 | Loss: 4.1309 | Epoch Time: 0.85m | Total Time: 24.18m
# [SimCLR] 029/100 | Loss: 4.1279 | Epoch Time: 0.87m | Total Time: 25.05m
# [SimCLR] 030/100 | Loss: 4.1229 | Epoch Time: 0.86m | Total Time: 25.90m
# [SimCLR] 031/100 | Loss: 4.1177 | Epoch Time: 0.86m | Total Time: 26.76m
# [SimCLR] 032/100 | Loss: 4.1167 | Epoch Time: 0.87m | Total Time: 27.63m
# [SimCLR] 033/100 | Loss: 4.1117 | Epoch Time: 0.87m | Total Time: 28.50m
# [SimCLR] 034/100 | Loss: 4.1088 | Epoch Time: 0.86m | Total Time: 29.36m
# [SimCLR] 035/100 | Loss: 4.1045 | Epoch Time: 0.86m | Total Time: 30.22m
# [SimCLR] 036/100 | Loss: 4.1059 | Epoch Time: 0.86m | Total Time: 31.08m
# [SimCLR] 037/100 | Loss: 4.1001 | Epoch Time: 0.86m | Total Time: 31.93m
# [SimCLR] 038/100 | Loss: 4.0989 | Epoch Time: 0.87m | Total Time: 32.80m
# [SimCLR] 039/100 | Loss: 4.0953 | Epoch Time: 0.87m | Total Time: 33.67m
# [SimCLR] 040/100 | Loss: 4.0929 | Epoch Time: 0.87m | Total Time: 34.54m
# [SimCLR] 041/100 | Loss: 4.0878 | Epoch Time: 0.88m | Total Time: 35.42m
# [SimCLR] 042/100 | Loss: 4.0864 | Epoch Time: 0.85m | Total Time: 36.27m
# [SimCLR] 043/100 | Loss: 4.0856 | Epoch Time: 0.86m | Total Time: 37.13m
# [SimCLR] 044/100 | Loss: 4.0820 | Epoch Time: 0.87m | Total Time: 38.00m
# [SimCLR] 045/100 | Loss: 4.0837 | Epoch Time: 0.85m | Total Time: 38.85m
# [SimCLR] 046/100 | Loss: 4.0810 | Epoch Time: 0.86m | Total Time: 39.71m
# [SimCLR] 047/100 | Loss: 4.0752 | Epoch Time: 0.86m | Total Time: 40.57m
# [SimCLR] 048/100 | Loss: 4.0742 | Epoch Time: 0.86m | Total Time: 41.43m
# [SimCLR] 049/100 | Loss: 4.0714 | Epoch Time: 0.86m | Total Time: 42.29m
# [SimCLR] 050/100 | Loss: 4.0702 | Epoch Time: 0.86m | Total Time: 43.14m
# [SimCLR] 051/100 | Loss: 4.0685 | Epoch Time: 0.87m | Total Time: 44.01m
# [SimCLR] 052/100 | Loss: 4.0674 | Epoch Time: 0.87m | Total Time: 44.89m
# [SimCLR] 053/100 | Loss: 4.0664 | Epoch Time: 0.85m | Total Time: 45.74m
# [SimCLR] 054/100 | Loss: 4.0646 | Epoch Time: 0.85m | Total Time: 46.59m
# [SimCLR] 055/100 | Loss: 4.0587 | Epoch Time: 0.85m | Total Time: 47.44m
# [SimCLR] 056/100 | Loss: 4.0592 | Epoch Time: 0.86m | Total Time: 48.31m
# [SimCLR] 057/100 | Loss: 4.0588 | Epoch Time: 0.86m | Total Time: 49.16m
# [SimCLR] 058/100 | Loss: 4.0571 | Epoch Time: 0.85m | Total Time: 50.02m
# [SimCLR] 059/100 | Loss: 4.0534 | Epoch Time: 0.86m | Total Time: 50.87m
# [SimCLR] 060/100 | Loss: 4.0509 | Epoch Time: 0.86m | Total Time: 51.73m
# [SimCLR] 061/100 | Loss: 4.0513 | Epoch Time: 0.86m | Total Time: 52.59m
# [SimCLR] 062/100 | Loss: 4.0483 | Epoch Time: 0.86m | Total Time: 53.45m
# [SimCLR] 063/100 | Loss: 4.0476 | Epoch Time: 0.86m | Total Time: 54.32m
# [SimCLR] 064/100 | Loss: 4.0430 | Epoch Time: 0.86m | Total Time: 55.17m
# [SimCLR] 065/100 | Loss: 4.0428 | Epoch Time: 0.85m | Total Time: 56.02m
# [SimCLR] 066/100 | Loss: 4.0403 | Epoch Time: 0.86m | Total Time: 56.88m
# [SimCLR] 067/100 | Loss: 4.0401 | Epoch Time: 0.85m | Total Time: 57.73m
# [SimCLR] 068/100 | Loss: 4.0404 | Epoch Time: 0.87m | Total Time: 58.60m
# [SimCLR] 069/100 | Loss: 4.0384 | Epoch Time: 0.85m | Total Time: 59.45m
# [SimCLR] 070/100 | Loss: 4.0345 | Epoch Time: 0.87m | Total Time: 60.32m
# [SimCLR] 071/100 | Loss: 4.0363 | Epoch Time: 0.86m | Total Time: 61.17m
# [SimCLR] 072/100 | Loss: 4.0355 | Epoch Time: 0.86m | Total Time: 62.03m
# [SimCLR] 073/100 | Loss: 4.0321 | Epoch Time: 0.86m | Total Time: 62.90m
# [SimCLR] 074/100 | Loss: 4.0291 | Epoch Time: 0.86m | Total Time: 63.76m
# [SimCLR] 075/100 | Loss: 4.0314 | Epoch Time: 0.86m | Total Time: 64.62m
# [SimCLR] 076/100 | Loss: 4.0290 | Epoch Time: 0.85m | Total Time: 65.47m
# [SimCLR] 077/100 | Loss: 4.0280 | Epoch Time: 0.87m | Total Time: 66.33m
# [SimCLR] 078/100 | Loss: 4.0247 | Epoch Time: 0.85m | Total Time: 67.19m
# [SimCLR] 079/100 | Loss: 4.0251 | Epoch Time: 0.86m | Total Time: 68.05m
# [SimCLR] 080/100 | Loss: 4.0248 | Epoch Time: 0.86m | Total Time: 68.91m
# [SimCLR] 081/100 | Loss: 4.0243 | Epoch Time: 0.85m | Total Time: 69.77m
# [SimCLR] 082/100 | Loss: 4.0218 | Epoch Time: 0.85m | Total Time: 70.62m
# [SimCLR] 083/100 | Loss: 4.0203 | Epoch Time: 0.86m | Total Time: 71.48m
# [SimCLR] 084/100 | Loss: 4.0191 | Epoch Time: 0.86m | Total Time: 72.34m
# [SimCLR] 085/100 | Loss: 4.0201 | Epoch Time: 0.87m | Total Time: 73.22m
# [SimCLR] 086/100 | Loss: 4.0154 | Epoch Time: 0.86m | Total Time: 74.08m
# [SimCLR] 087/100 | Loss: 4.0165 | Epoch Time: 0.86m | Total Time: 74.94m
# [SimCLR] 088/100 | Loss: 4.0155 | Epoch Time: 0.86m | Total Time: 75.80m
# [SimCLR] 089/100 | Loss: 4.0152 | Epoch Time: 0.86m | Total Time: 76.66m
# [SimCLR] 090/100 | Loss: 4.0135 | Epoch Time: 0.87m | Total Time: 77.53m
# [SimCLR] 091/100 | Loss: 4.0106 | Epoch Time: 0.87m | Total Time: 78.40m
# [SimCLR] 092/100 | Loss: 4.0114 | Epoch Time: 0.86m | Total Time: 79.26m
# [SimCLR] 093/100 | Loss: 4.0107 | Epoch Time: 0.86m | Total Time: 80.13m
# [SimCLR] 094/100 | Loss: 4.0089 | Epoch Time: 0.86m | Total Time: 80.99m
# [SimCLR] 095/100 | Loss: 4.0081 | Epoch Time: 0.87m | Total Time: 81.85m
# [SimCLR] 096/100 | Loss: 4.0096 | Epoch Time: 0.86m | Total Time: 82.71m
# [SimCLR] 097/100 | Loss: 4.0081 | Epoch Time: 0.85m | Total Time: 83.56m
# [SimCLR] 098/100 | Loss: 4.0043 | Epoch Time: 0.85m | Total Time: 84.41m
# [SimCLR] 099/100 | Loss: 4.0092 | Epoch Time: 0.86m | Total Time: 85.27m
# [SimCLR] 100/100 | Loss: 4.0034 | Epoch Time: 0.85m | Total Time: 86.12m
# [SimCLR] 001/100 | Loss: 4.7586 | Epoch Time: 1.44m | Total Time: 1.44m
# [SimCLR] 002/100 | Loss: 4.5187 | Epoch Time: 1.44m | Total Time: 2.88m
# [SimCLR] 003/100 | Loss: 4.4306 | Epoch Time: 1.44m | Total Time: 4.32m
# [SimCLR] 004/100 | Loss: 4.3915 | Epoch Time: 1.44m | Total Time: 5.75m
# [SimCLR] 005/100 | Loss: 4.3669 | Epoch Time: 1.44m | Total Time: 7.19m
# [SimCLR] 006/100 | Loss: 4.3367 | Epoch Time: 1.44m | Total Time: 8.63m
# [SimCLR] 007/100 | Loss: 4.3202 | Epoch Time: 1.44m | Total Time: 10.06m
# [SimCLR] 008/100 | Loss: 4.3013 | Epoch Time: 1.44m | Total Time: 11.50m
# [SimCLR] 009/100 | Loss: 4.2851 | Epoch Time: 1.44m | Total Time: 12.94m
# [SimCLR] 010/100 | Loss: 4.2702 | Epoch Time: 1.44m | Total Time: 14.38m
# [SimCLR] 011/100 | Loss: 4.2612 | Epoch Time: 1.44m | Total Time: 15.82m
# [SimCLR] 012/100 | Loss: 4.2510 | Epoch Time: 1.44m | Total Time: 17.26m
# [SimCLR] 013/100 | Loss: 4.2346 | Epoch Time: 1.44m | Total Time: 18.69m
# [SimCLR] 014/100 | Loss: 4.2254 | Epoch Time: 1.44m | Total Time: 20.13m
# [SimCLR] 015/100 | Loss: 4.2160 | Epoch Time: 1.44m | Total Time: 21.57m
# [SimCLR] 016/100 | Loss: 4.2102 | Epoch Time: 1.44m | Total Time: 23.01m
# [SimCLR] 017/100 | Loss: 4.2030 | Epoch Time: 1.44m | Total Time: 24.46m
# [SimCLR] 018/100 | Loss: 4.1933 | Epoch Time: 1.44m | Total Time: 25.90m
# [SimCLR] 019/100 | Loss: 4.1906 | Epoch Time: 1.45m | Total Time: 27.35m
# [SimCLR] 020/100 | Loss: 4.1835 | Epoch Time: 1.45m | Total Time: 28.80m
# [SimCLR] 021/100 | Loss: 4.1784 | Epoch Time: 1.44m | Total Time: 30.24m
# [SimCLR] 022/100 | Loss: 4.1695 | Epoch Time: 1.43m | Total Time: 31.67m
# [SimCLR] 023/100 | Loss: 4.1598 | Epoch Time: 1.44m | Total Time: 33.11m
# [SimCLR] 024/100 | Loss: 4.1633 | Epoch Time: 1.44m | Total Time: 34.54m
# [SimCLR] 025/100 | Loss: 4.1604 | Epoch Time: 1.44m | Total Time: 35.98m
# [SimCLR] 026/100 | Loss: 4.1528 | Epoch Time: 1.44m | Total Time: 37.42m
# [SimCLR] 027/100 | Loss: 4.1468 | Epoch Time: 1.44m | Total Time: 38.85m
# [SimCLR] 028/100 | Loss: 4.1440 | Epoch Time: 1.44m | Total Time: 40.29m
# [SimCLR] 029/100 | Loss: 4.1373 | Epoch Time: 1.44m | Total Time: 41.73m
# [SimCLR] 030/100 | Loss: 4.1400 | Epoch Time: 1.44m | Total Time: 43.17m
# [SimCLR] 031/100 | Loss: 4.1390 | Epoch Time: 1.44m | Total Time: 44.60m
# [SimCLR] 032/100 | Loss: 4.1319 | Epoch Time: 1.44m | Total Time: 46.04m
# [SimCLR] 033/100 | Loss: 4.1303 | Epoch Time: 1.44m | Total Time: 47.48m
# [SimCLR] 034/100 | Loss: 4.1277 | Epoch Time: 1.44m | Total Time: 48.92m
# [SimCLR] 035/100 | Loss: 4.1206 | Epoch Time: 1.44m | Total Time: 50.36m
# [SimCLR] 036/100 | Loss: 4.1187 | Epoch Time: 1.44m | Total Time: 51.79m
# [SimCLR] 037/100 | Loss: 4.1161 | Epoch Time: 1.44m | Total Time: 53.23m
# [SimCLR] 038/100 | Loss: 4.1168 | Epoch Time: 1.44m | Total Time: 54.67m
# [SimCLR] 039/100 | Loss: 4.1124 | Epoch Time: 1.44m | Total Time: 56.11m
# [SimCLR] 040/100 | Loss: 4.1101 | Epoch Time: 1.44m | Total Time: 57.55m
# [SimCLR] 041/100 | Loss: 4.1066 | Epoch Time: 1.44m | Total Time: 59.00m
# [SimCLR] 042/100 | Loss: 4.1001 | Epoch Time: 1.44m | Total Time: 60.44m
# [SimCLR] 043/100 | Loss: 4.1000 | Epoch Time: 1.44m | Total Time: 61.88m
# [SimCLR] 044/100 | Loss: 4.0989 | Epoch Time: 1.44m | Total Time: 63.32m
# [SimCLR] 045/100 | Loss: 4.0960 | Epoch Time: 1.44m | Total Time: 64.76m
# [SimCLR] 046/100 | Loss: 4.0954 | Epoch Time: 1.45m | Total Time: 66.21m
# [SimCLR] 047/100 | Loss: 4.0908 | Epoch Time: 1.44m | Total Time: 67.66m
# [SimCLR] 048/100 | Loss: 4.0900 | Epoch Time: 1.44m | Total Time: 69.10m
# [SimCLR] 049/100 | Loss: 4.0852 | Epoch Time: 1.44m | Total Time: 70.54m
# [SimCLR] 050/100 | Loss: 4.0872 | Epoch Time: 1.44m | Total Time: 71.98m
# [SimCLR] 051/100 | Loss: 4.0859 | Epoch Time: 1.44m | Total Time: 73.42m
# [SimCLR] 052/100 | Loss: 4.0865 | Epoch Time: 1.44m | Total Time: 74.86m
# [SimCLR] 053/100 | Loss: 4.0792 | Epoch Time: 1.44m | Total Time: 76.29m
# [SimCLR] 054/100 | Loss: 4.0790 | Epoch Time: 1.44m | Total Time: 77.73m
# [SimCLR] 055/100 | Loss: 4.0776 | Epoch Time: 1.44m | Total Time: 79.17m
# [SimCLR] 056/100 | Loss: 4.0760 | Epoch Time: 1.44m | Total Time: 80.62m
# [SimCLR] 057/100 | Loss: 4.0752 | Epoch Time: 1.44m | Total Time: 82.06m
# [SimCLR] 058/100 | Loss: 4.0715 | Epoch Time: 1.44m | Total Time: 83.51m
# [SimCLR] 059/100 | Loss: 4.0722 | Epoch Time: 1.44m | Total Time: 84.95m
# [SimCLR] 060/100 | Loss: 4.0706 | Epoch Time: 1.44m | Total Time: 86.40m
# [SimCLR] 061/100 | Loss: 4.0677 | Epoch Time: 1.44m | Total Time: 87.84m
# [SimCLR] 062/100 | Loss: 4.0677 | Epoch Time: 1.44m | Total Time: 89.28m
# [SimCLR] 063/100 | Loss: 4.0663 | Epoch Time: 1.44m | Total Time: 90.72m
# [SimCLR] 064/100 | Loss: 4.0623 | Epoch Time: 1.44m | Total Time: 92.16m
# [SimCLR] 065/100 | Loss: 4.0633 | Epoch Time: 1.44m | Total Time: 93.60m
# [SimCLR] 066/100 | Loss: 4.0631 | Epoch Time: 1.44m | Total Time: 95.04m
# [SimCLR] 067/100 | Loss: 4.0599 | Epoch Time: 1.44m | Total Time: 96.49m
# [SimCLR] 068/100 | Loss: 4.0598 | Epoch Time: 1.44m | Total Time: 97.93m
# [SimCLR] 069/100 | Loss: 4.0597 | Epoch Time: 1.44m | Total Time: 99.37m
# [SimCLR] 070/100 | Loss: 4.0570 | Epoch Time: 1.44m | Total Time: 100.81m
# [SimCLR] 071/100 | Loss: 4.0526 | Epoch Time: 1.44m | Total Time: 102.25m
# [SimCLR] 072/100 | Loss: 4.0554 | Epoch Time: 1.44m | Total Time: 103.69m
# [SimCLR] 073/100 | Loss: 4.0551 | Epoch Time: 1.44m | Total Time: 105.14m
# [SimCLR] 074/100 | Loss: 4.0531 | Epoch Time: 1.44m | Total Time: 106.58m
# [SimCLR] 075/100 | Loss: 4.0515 | Epoch Time: 1.44m | Total Time: 108.02m
# [SimCLR] 076/100 | Loss: 4.0530 | Epoch Time: 1.44m | Total Time: 109.47m
# [SimCLR] 077/100 | Loss: 4.0490 | Epoch Time: 1.44m | Total Time: 110.91m
# [SimCLR] 078/100 | Loss: 4.0493 | Epoch Time: 1.44m | Total Time: 112.35m
# [SimCLR] 079/100 | Loss: 4.0452 | Epoch Time: 1.44m | Total Time: 113.80m
# [SimCLR] 080/100 | Loss: 4.0464 | Epoch Time: 1.44m | Total Time: 115.24m
# [SimCLR] 081/100 | Loss: 4.0468 | Epoch Time: 1.45m | Total Time: 116.68m
# [SimCLR] 082/100 | Loss: 4.0470 | Epoch Time: 1.44m | Total Time: 118.13m
# [SimCLR] 083/100 | Loss: 4.0435 | Epoch Time: 1.44m | Total Time: 119.57m
# [SimCLR] 084/100 | Loss: 4.0429 | Epoch Time: 1.44m | Total Time: 121.02m
# [SimCLR] 085/100 | Loss: 4.0407 | Epoch Time: 1.44m | Total Time: 122.46m
# [SimCLR] 086/100 | Loss: 4.0436 | Epoch Time: 1.44m | Total Time: 123.90m
# [SimCLR] 087/100 | Loss: 4.0384 | Epoch Time: 1.44m | Total Time: 125.34m
# [SimCLR] 088/100 | Loss: 4.0417 | Epoch Time: 1.44m | Total Time: 126.79m
# [SimCLR] 089/100 | Loss: 4.0381 | Epoch Time: 1.44m | Total Time: 128.23m
# [SimCLR] 090/100 | Loss: 4.0383 | Epoch Time: 1.44m | Total Time: 129.67m
# [SimCLR] 091/100 | Loss: 4.0384 | Epoch Time: 1.44m | Total Time: 131.11m
# [SimCLR] 092/100 | Loss: 4.0367 | Epoch Time: 1.44m | Total Time: 132.55m
# [SimCLR] 093/100 | Loss: 4.0341 | Epoch Time: 1.44m | Total Time: 133.99m
# [SimCLR] 094/100 | Loss: 4.0348 | Epoch Time: 1.44m | Total Time: 135.44m
# [SimCLR] 095/100 | Loss: 4.0362 | Epoch Time: 1.44m | Total Time: 136.88m
# [SimCLR] 096/100 | Loss: 4.0336 | Epoch Time: 1.44m | Total Time: 138.32m
# [SimCLR] 097/100 | Loss: 4.0323 | Epoch Time: 1.44m | Total Time: 139.76m
# [SimCLR] 098/100 | Loss: 4.0340 | Epoch Time: 1.44m | Total Time: 141.20m
# [SimCLR] 099/100 | Loss: 4.0311 | Epoch Time: 1.44m | Total Time: 142.64m
# [SimCLR] 100/100 | Loss: 4.0293 | Epoch Time: 1.44m | Total Time: 144.07m
# Saved results to: /kaggle/working/byol_simclr_results.csv
#
# Running Mean Summary:
#             Seed   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# Method
# BYOL         6.0  61.887311        13.626039          14.518287
# SimCLR       6.0  89.363847        15.015509          18.349785
# SimCLR+Jac   6.0  65.949622        15.731129          16.418068
#
#             Linear_Probe_Acc
# Method
# BYOL                  0.6571
# SimCLR                0.6832
# SimCLR+Jac            0.6712
#
# Seed 6 finished in 312.55 minutes
#
# ====================================
# Running Seed: 7
# ====================================
# [BYOL] 001/100 | Loss: 0.7446 | Epoch Time: 0.75m | Total Time: 0.75m
# [BYOL] 002/100 | Loss: 0.5989 | Epoch Time: 0.76m | Total Time: 1.51m
# [BYOL] 003/100 | Loss: 0.5290 | Epoch Time: 0.77m | Total Time: 2.27m
# [BYOL] 004/100 | Loss: 0.4976 | Epoch Time: 0.77m | Total Time: 3.05m
# [BYOL] 005/100 | Loss: 0.4780 | Epoch Time: 0.81m | Total Time: 3.85m
# [BYOL] 006/100 | Loss: 0.4623 | Epoch Time: 0.79m | Total Time: 4.65m
# [BYOL] 007/100 | Loss: 0.4529 | Epoch Time: 0.78m | Total Time: 5.42m
# [BYOL] 008/100 | Loss: 0.4432 | Epoch Time: 0.78m | Total Time: 6.20m
# [BYOL] 009/100 | Loss: 0.4366 | Epoch Time: 0.76m | Total Time: 6.96m
# [BYOL] 010/100 | Loss: 0.4332 | Epoch Time: 0.76m | Total Time: 7.73m
# [BYOL] 011/100 | Loss: 0.4309 | Epoch Time: 0.77m | Total Time: 8.50m
# [BYOL] 012/100 | Loss: 0.4238 | Epoch Time: 0.77m | Total Time: 9.27m
# [BYOL] 013/100 | Loss: 0.4212 | Epoch Time: 0.77m | Total Time: 10.03m
# [BYOL] 014/100 | Loss: 0.4164 | Epoch Time: 0.78m | Total Time: 10.81m
# [BYOL] 015/100 | Loss: 0.4149 | Epoch Time: 0.78m | Total Time: 11.59m
# [BYOL] 016/100 | Loss: 0.4138 | Epoch Time: 0.77m | Total Time: 12.36m
# [BYOL] 017/100 | Loss: 0.4109 | Epoch Time: 0.77m | Total Time: 13.13m
# [BYOL] 018/100 | Loss: 0.4099 | Epoch Time: 0.78m | Total Time: 13.91m
# [BYOL] 019/100 | Loss: 0.4078 | Epoch Time: 0.76m | Total Time: 14.67m
# [BYOL] 020/100 | Loss: 0.4060 | Epoch Time: 0.79m | Total Time: 15.46m
# [BYOL] 021/100 | Loss: 0.4019 | Epoch Time: 0.78m | Total Time: 16.24m
# [BYOL] 022/100 | Loss: 0.4019 | Epoch Time: 0.76m | Total Time: 17.01m
# [BYOL] 023/100 | Loss: 0.4040 | Epoch Time: 0.77m | Total Time: 17.77m
# [BYOL] 024/100 | Loss: 0.4055 | Epoch Time: 0.76m | Total Time: 18.54m
# [BYOL] 025/100 | Loss: 0.4016 | Epoch Time: 0.77m | Total Time: 19.30m
# [BYOL] 026/100 | Loss: 0.3999 | Epoch Time: 0.77m | Total Time: 20.07m
# [BYOL] 027/100 | Loss: 0.4015 | Epoch Time: 0.76m | Total Time: 20.84m
# [BYOL] 028/100 | Loss: 0.4009 | Epoch Time: 0.76m | Total Time: 21.60m
# [BYOL] 029/100 | Loss: 0.4011 | Epoch Time: 0.77m | Total Time: 22.36m
# [BYOL] 030/100 | Loss: 0.3989 | Epoch Time: 0.77m | Total Time: 23.14m
# [BYOL] 031/100 | Loss: 0.3989 | Epoch Time: 0.77m | Total Time: 23.90m
# [BYOL] 032/100 | Loss: 0.3986 | Epoch Time: 0.77m | Total Time: 24.67m
# [BYOL] 033/100 | Loss: 0.3986 | Epoch Time: 0.78m | Total Time: 25.44m
# [BYOL] 034/100 | Loss: 0.3982 | Epoch Time: 0.78m | Total Time: 26.23m
# [BYOL] 035/100 | Loss: 0.3960 | Epoch Time: 0.79m | Total Time: 27.01m
# [BYOL] 036/100 | Loss: 0.3953 | Epoch Time: 0.78m | Total Time: 27.79m
# [BYOL] 037/100 | Loss: 0.3952 | Epoch Time: 0.78m | Total Time: 28.58m
# [BYOL] 038/100 | Loss: 0.3945 | Epoch Time: 0.78m | Total Time: 29.36m
# [BYOL] 039/100 | Loss: 0.3933 | Epoch Time: 0.80m | Total Time: 30.16m
# [BYOL] 040/100 | Loss: 0.3963 | Epoch Time: 0.80m | Total Time: 30.95m
# [BYOL] 041/100 | Loss: 0.3938 | Epoch Time: 0.79m | Total Time: 31.75m
# [BYOL] 042/100 | Loss: 0.3942 | Epoch Time: 0.79m | Total Time: 32.54m
# [BYOL] 043/100 | Loss: 0.3938 | Epoch Time: 0.80m | Total Time: 33.34m
# [BYOL] 044/100 | Loss: 0.3945 | Epoch Time: 0.80m | Total Time: 34.14m
# [BYOL] 045/100 | Loss: 0.3920 | Epoch Time: 0.81m | Total Time: 34.94m
# [BYOL] 046/100 | Loss: 0.3925 | Epoch Time: 0.80m | Total Time: 35.74m
# [BYOL] 047/100 | Loss: 0.3916 | Epoch Time: 0.81m | Total Time: 36.55m
# [BYOL] 048/100 | Loss: 0.3929 | Epoch Time: 0.79m | Total Time: 37.34m
# [BYOL] 049/100 | Loss: 0.3926 | Epoch Time: 0.80m | Total Time: 38.14m
# [BYOL] 050/100 | Loss: 0.3913 | Epoch Time: 0.81m | Total Time: 38.96m
# [BYOL] 051/100 | Loss: 0.3926 | Epoch Time: 0.80m | Total Time: 39.75m
# [BYOL] 052/100 | Loss: 0.3910 | Epoch Time: 0.80m | Total Time: 40.55m
# [BYOL] 053/100 | Loss: 0.3900 | Epoch Time: 0.79m | Total Time: 41.34m
# [BYOL] 054/100 | Loss: 0.3888 | Epoch Time: 0.80m | Total Time: 42.15m
# [BYOL] 055/100 | Loss: 0.3874 | Epoch Time: 0.79m | Total Time: 42.94m
# [BYOL] 056/100 | Loss: 0.3880 | Epoch Time: 0.80m | Total Time: 43.73m
# [BYOL] 057/100 | Loss: 0.3875 | Epoch Time: 0.80m | Total Time: 44.53m
# [BYOL] 058/100 | Loss: 0.3878 | Epoch Time: 0.80m | Total Time: 45.33m
# [BYOL] 059/100 | Loss: 0.3890 | Epoch Time: 0.79m | Total Time: 46.12m
# [BYOL] 060/100 | Loss: 0.3872 | Epoch Time: 0.78m | Total Time: 46.90m
# [BYOL] 061/100 | Loss: 0.3877 | Epoch Time: 0.80m | Total Time: 47.71m
# [BYOL] 062/100 | Loss: 0.3872 | Epoch Time: 0.80m | Total Time: 48.51m
# [BYOL] 063/100 | Loss: 0.3880 | Epoch Time: 0.80m | Total Time: 49.30m
# [BYOL] 064/100 | Loss: 0.3889 | Epoch Time: 0.79m | Total Time: 50.09m
# [BYOL] 065/100 | Loss: 0.3866 | Epoch Time: 0.81m | Total Time: 50.90m
# [BYOL] 066/100 | Loss: 0.3850 | Epoch Time: 0.79m | Total Time: 51.69m
# [BYOL] 067/100 | Loss: 0.3847 | Epoch Time: 0.81m | Total Time: 52.50m
# [BYOL] 068/100 | Loss: 0.3848 | Epoch Time: 0.80m | Total Time: 53.30m
# [BYOL] 069/100 | Loss: 0.3852 | Epoch Time: 0.80m | Total Time: 54.10m
# [BYOL] 070/100 | Loss: 0.3833 | Epoch Time: 0.80m | Total Time: 54.90m
# [BYOL] 071/100 | Loss: 0.3836 | Epoch Time: 0.80m | Total Time: 55.71m
# [BYOL] 072/100 | Loss: 0.3835 | Epoch Time: 0.80m | Total Time: 56.50m
# [BYOL] 073/100 | Loss: 0.3836 | Epoch Time: 0.79m | Total Time: 57.30m
# [BYOL] 074/100 | Loss: 0.3834 | Epoch Time: 0.79m | Total Time: 58.09m
# [BYOL] 075/100 | Loss: 0.3851 | Epoch Time: 0.80m | Total Time: 58.88m
# [BYOL] 076/100 | Loss: 0.3832 | Epoch Time: 0.77m | Total Time: 59.66m
# [BYOL] 077/100 | Loss: 0.3848 | Epoch Time: 0.81m | Total Time: 60.46m
# [BYOL] 078/100 | Loss: 0.3832 | Epoch Time: 0.80m | Total Time: 61.27m
# [BYOL] 079/100 | Loss: 0.3841 | Epoch Time: 0.78m | Total Time: 62.05m
# [BYOL] 080/100 | Loss: 0.3826 | Epoch Time: 0.78m | Total Time: 62.84m
# [BYOL] 081/100 | Loss: 0.3823 | Epoch Time: 0.78m | Total Time: 63.61m
# [BYOL] 082/100 | Loss: 0.3831 | Epoch Time: 0.78m | Total Time: 64.40m
# [BYOL] 083/100 | Loss: 0.3833 | Epoch Time: 0.79m | Total Time: 65.19m
# [BYOL] 084/100 | Loss: 0.3807 | Epoch Time: 0.79m | Total Time: 65.98m
# [BYOL] 085/100 | Loss: 0.3815 | Epoch Time: 0.78m | Total Time: 66.76m
# [BYOL] 086/100 | Loss: 0.3802 | Epoch Time: 0.79m | Total Time: 67.55m
# [BYOL] 087/100 | Loss: 0.3826 | Epoch Time: 0.80m | Total Time: 68.35m
# [BYOL] 088/100 | Loss: 0.3832 | Epoch Time: 0.79m | Total Time: 69.14m
# [BYOL] 089/100 | Loss: 0.3820 | Epoch Time: 0.80m | Total Time: 69.94m
# [BYOL] 090/100 | Loss: 0.3812 | Epoch Time: 0.79m | Total Time: 70.72m
# [BYOL] 091/100 | Loss: 0.3811 | Epoch Time: 0.79m | Total Time: 71.52m
# [BYOL] 092/100 | Loss: 0.3809 | Epoch Time: 0.79m | Total Time: 72.30m
# [BYOL] 093/100 | Loss: 0.3803 | Epoch Time: 0.79m | Total Time: 73.09m
# [BYOL] 094/100 | Loss: 0.3806 | Epoch Time: 0.79m | Total Time: 73.88m
# [BYOL] 095/100 | Loss: 0.3798 | Epoch Time: 0.78m | Total Time: 74.66m
# [BYOL] 096/100 | Loss: 0.3796 | Epoch Time: 0.79m | Total Time: 75.45m
# [BYOL] 097/100 | Loss: 0.3786 | Epoch Time: 0.78m | Total Time: 76.23m
# [BYOL] 098/100 | Loss: 0.3803 | Epoch Time: 0.79m | Total Time: 77.02m
# [BYOL] 099/100 | Loss: 0.3793 | Epoch Time: 0.79m | Total Time: 77.80m
# [BYOL] 100/100 | Loss: 0.3785 | Epoch Time: 0.79m | Total Time: 78.59m
# [SimCLR] 001/100 | Loss: 4.6742 | Epoch Time: 0.85m | Total Time: 0.85m
# [SimCLR] 002/100 | Loss: 4.4958 | Epoch Time: 0.86m | Total Time: 1.71m
# [SimCLR] 003/100 | Loss: 4.4373 | Epoch Time: 0.86m | Total Time: 2.57m
# [SimCLR] 004/100 | Loss: 4.3890 | Epoch Time: 0.86m | Total Time: 3.43m
# [SimCLR] 005/100 | Loss: 4.3538 | Epoch Time: 0.85m | Total Time: 4.28m
# [SimCLR] 006/100 | Loss: 4.3325 | Epoch Time: 0.85m | Total Time: 5.13m
# [SimCLR] 007/100 | Loss: 4.3085 | Epoch Time: 0.85m | Total Time: 5.98m
# [SimCLR] 008/100 | Loss: 4.2909 | Epoch Time: 0.84m | Total Time: 6.83m
# [SimCLR] 009/100 | Loss: 4.2782 | Epoch Time: 0.87m | Total Time: 7.69m
# [SimCLR] 010/100 | Loss: 4.2605 | Epoch Time: 0.85m | Total Time: 8.55m
# [SimCLR] 011/100 | Loss: 4.2428 | Epoch Time: 0.87m | Total Time: 9.41m
# [SimCLR] 012/100 | Loss: 4.2362 | Epoch Time: 0.85m | Total Time: 10.27m
# [SimCLR] 013/100 | Loss: 4.2217 | Epoch Time: 0.85m | Total Time: 11.12m
# [SimCLR] 014/100 | Loss: 4.2133 | Epoch Time: 0.84m | Total Time: 11.96m
# [SimCLR] 015/100 | Loss: 4.2026 | Epoch Time: 0.85m | Total Time: 12.81m
# [SimCLR] 016/100 | Loss: 4.2010 | Epoch Time: 0.86m | Total Time: 13.67m
# [SimCLR] 017/100 | Loss: 4.1882 | Epoch Time: 0.86m | Total Time: 14.53m
# [SimCLR] 018/100 | Loss: 4.1799 | Epoch Time: 0.85m | Total Time: 15.38m
# [SimCLR] 019/100 | Loss: 4.1737 | Epoch Time: 0.85m | Total Time: 16.23m
# [SimCLR] 020/100 | Loss: 4.1647 | Epoch Time: 0.85m | Total Time: 17.07m
# [SimCLR] 021/100 | Loss: 4.1612 | Epoch Time: 0.85m | Total Time: 17.93m
# [SimCLR] 022/100 | Loss: 4.1584 | Epoch Time: 0.86m | Total Time: 18.79m
# [SimCLR] 023/100 | Loss: 4.1510 | Epoch Time: 0.86m | Total Time: 19.65m
# [SimCLR] 024/100 | Loss: 4.1481 | Epoch Time: 0.86m | Total Time: 20.51m
# [SimCLR] 025/100 | Loss: 4.1458 | Epoch Time: 0.85m | Total Time: 21.35m
# [SimCLR] 026/100 | Loss: 4.1386 | Epoch Time: 0.85m | Total Time: 22.21m
# [SimCLR] 027/100 | Loss: 4.1354 | Epoch Time: 0.86m | Total Time: 23.07m
# [SimCLR] 028/100 | Loss: 4.1298 | Epoch Time: 0.85m | Total Time: 23.92m
# [SimCLR] 029/100 | Loss: 4.1251 | Epoch Time: 0.84m | Total Time: 24.76m
# [SimCLR] 030/100 | Loss: 4.1212 | Epoch Time: 0.86m | Total Time: 25.62m
# [SimCLR] 031/100 | Loss: 4.1164 | Epoch Time: 0.85m | Total Time: 26.47m
# [SimCLR] 032/100 | Loss: 4.1159 | Epoch Time: 0.89m | Total Time: 27.36m
# [SimCLR] 033/100 | Loss: 4.1118 | Epoch Time: 0.87m | Total Time: 28.23m
# [SimCLR] 034/100 | Loss: 4.1121 | Epoch Time: 0.86m | Total Time: 29.09m
# [SimCLR] 035/100 | Loss: 4.1070 | Epoch Time: 0.86m | Total Time: 29.95m
# [SimCLR] 036/100 | Loss: 4.1034 | Epoch Time: 0.86m | Total Time: 30.80m
# [SimCLR] 037/100 | Loss: 4.0999 | Epoch Time: 0.86m | Total Time: 31.67m
# [SimCLR] 038/100 | Loss: 4.1005 | Epoch Time: 0.86m | Total Time: 32.52m
# [SimCLR] 039/100 | Loss: 4.0945 | Epoch Time: 0.86m | Total Time: 33.38m
# [SimCLR] 040/100 | Loss: 4.0936 | Epoch Time: 0.86m | Total Time: 34.25m
# [SimCLR] 041/100 | Loss: 4.0905 | Epoch Time: 0.87m | Total Time: 35.11m
# [SimCLR] 042/100 | Loss: 4.0877 | Epoch Time: 0.86m | Total Time: 35.97m
# [SimCLR] 043/100 | Loss: 4.0837 | Epoch Time: 0.85m | Total Time: 36.82m
# [SimCLR] 044/100 | Loss: 4.0846 | Epoch Time: 0.86m | Total Time: 37.68m
# [SimCLR] 045/100 | Loss: 4.0757 | Epoch Time: 0.86m | Total Time: 38.54m
# [SimCLR] 046/100 | Loss: 4.0760 | Epoch Time: 0.87m | Total Time: 39.41m
# [SimCLR] 047/100 | Loss: 4.0730 | Epoch Time: 0.86m | Total Time: 40.27m
# [SimCLR] 048/100 | Loss: 4.0719 | Epoch Time: 0.86m | Total Time: 41.14m
# [SimCLR] 049/100 | Loss: 4.0720 | Epoch Time: 0.86m | Total Time: 42.00m
# [SimCLR] 050/100 | Loss: 4.0657 | Epoch Time: 0.85m | Total Time: 42.85m
# [SimCLR] 051/100 | Loss: 4.0670 | Epoch Time: 0.84m | Total Time: 43.69m
# [SimCLR] 052/100 | Loss: 4.0639 | Epoch Time: 0.84m | Total Time: 44.53m
# [SimCLR] 053/100 | Loss: 4.0613 | Epoch Time: 0.84m | Total Time: 45.37m
# [SimCLR] 054/100 | Loss: 4.0610 | Epoch Time: 0.84m | Total Time: 46.21m
# [SimCLR] 055/100 | Loss: 4.0569 | Epoch Time: 0.85m | Total Time: 47.06m
# [SimCLR] 056/100 | Loss: 4.0559 | Epoch Time: 0.86m | Total Time: 47.92m
# [SimCLR] 057/100 | Loss: 4.0553 | Epoch Time: 0.86m | Total Time: 48.78m
# [SimCLR] 058/100 | Loss: 4.0556 | Epoch Time: 0.86m | Total Time: 49.64m
# [SimCLR] 059/100 | Loss: 4.0508 | Epoch Time: 0.85m | Total Time: 50.49m
# [SimCLR] 060/100 | Loss: 4.0487 | Epoch Time: 0.85m | Total Time: 51.35m
# [SimCLR] 061/100 | Loss: 4.0461 | Epoch Time: 0.85m | Total Time: 52.20m
# [SimCLR] 062/100 | Loss: 4.0448 | Epoch Time: 0.86m | Total Time: 53.06m
# [SimCLR] 063/100 | Loss: 4.0420 | Epoch Time: 0.85m | Total Time: 53.91m
# [SimCLR] 064/100 | Loss: 4.0404 | Epoch Time: 0.86m | Total Time: 54.77m
# [SimCLR] 065/100 | Loss: 4.0428 | Epoch Time: 0.86m | Total Time: 55.63m
# [SimCLR] 066/100 | Loss: 4.0429 | Epoch Time: 0.85m | Total Time: 56.48m
# [SimCLR] 067/100 | Loss: 4.0381 | Epoch Time: 0.87m | Total Time: 57.35m
# [SimCLR] 068/100 | Loss: 4.0349 | Epoch Time: 0.86m | Total Time: 58.21m
# [SimCLR] 069/100 | Loss: 4.0389 | Epoch Time: 0.86m | Total Time: 59.07m
# [SimCLR] 070/100 | Loss: 4.0328 | Epoch Time: 0.85m | Total Time: 59.92m
# [SimCLR] 071/100 | Loss: 4.0341 | Epoch Time: 0.87m | Total Time: 60.79m
# [SimCLR] 072/100 | Loss: 4.0317 | Epoch Time: 0.85m | Total Time: 61.64m
# [SimCLR] 073/100 | Loss: 4.0300 | Epoch Time: 0.85m | Total Time: 62.50m
# [SimCLR] 074/100 | Loss: 4.0308 | Epoch Time: 0.85m | Total Time: 63.35m
# [SimCLR] 075/100 | Loss: 4.0283 | Epoch Time: 0.85m | Total Time: 64.20m
# [SimCLR] 076/100 | Loss: 4.0268 | Epoch Time: 0.84m | Total Time: 65.04m
# [SimCLR] 077/100 | Loss: 4.0237 | Epoch Time: 0.85m | Total Time: 65.90m
# [SimCLR] 078/100 | Loss: 4.0277 | Epoch Time: 0.85m | Total Time: 66.75m
# [SimCLR] 079/100 | Loss: 4.0243 | Epoch Time: 0.84m | Total Time: 67.59m
# [SimCLR] 080/100 | Loss: 4.0218 | Epoch Time: 0.84m | Total Time: 68.43m
# [SimCLR] 081/100 | Loss: 4.0210 | Epoch Time: 0.84m | Total Time: 69.27m
# [SimCLR] 082/100 | Loss: 4.0190 | Epoch Time: 0.84m | Total Time: 70.11m
# [SimCLR] 083/100 | Loss: 4.0196 | Epoch Time: 0.84m | Total Time: 70.95m
# [SimCLR] 084/100 | Loss: 4.0194 | Epoch Time: 0.84m | Total Time: 71.78m
# [SimCLR] 085/100 | Loss: 4.0171 | Epoch Time: 0.84m | Total Time: 72.62m
# [SimCLR] 086/100 | Loss: 4.0192 | Epoch Time: 0.86m | Total Time: 73.48m
# [SimCLR] 087/100 | Loss: 4.0143 | Epoch Time: 0.85m | Total Time: 74.33m
# [SimCLR] 088/100 | Loss: 4.0136 | Epoch Time: 0.86m | Total Time: 75.19m
# [SimCLR] 089/100 | Loss: 4.0154 | Epoch Time: 0.86m | Total Time: 76.05m
# [SimCLR] 090/100 | Loss: 4.0131 | Epoch Time: 0.87m | Total Time: 76.92m
# [SimCLR] 091/100 | Loss: 4.0093 | Epoch Time: 0.86m | Total Time: 77.78m
# [SimCLR] 092/100 | Loss: 4.0119 | Epoch Time: 0.85m | Total Time: 78.63m
# [SimCLR] 093/100 | Loss: 4.0099 | Epoch Time: 0.86m | Total Time: 79.48m
# [SimCLR] 094/100 | Loss: 4.0080 | Epoch Time: 0.85m | Total Time: 80.33m
# [SimCLR] 095/100 | Loss: 4.0082 | Epoch Time: 0.85m | Total Time: 81.18m
# [SimCLR] 096/100 | Loss: 4.0049 | Epoch Time: 0.85m | Total Time: 82.03m
# [SimCLR] 097/100 | Loss: 4.0074 | Epoch Time: 0.85m | Total Time: 82.89m
# [SimCLR] 098/100 | Loss: 4.0073 | Epoch Time: 0.85m | Total Time: 83.74m
# [SimCLR] 099/100 | Loss: 4.0040 | Epoch Time: 0.85m | Total Time: 84.58m
# [SimCLR] 100/100 | Loss: 4.0057 | Epoch Time: 0.86m | Total Time: 85.44m
# [SimCLR] 001/100 | Loss: 4.7418 | Epoch Time: 1.44m | Total Time: 1.44m
# [SimCLR] 002/100 | Loss: 4.5018 | Epoch Time: 1.44m | Total Time: 2.88m
# [SimCLR] 003/100 | Loss: 4.4369 | Epoch Time: 1.44m | Total Time: 4.32m
# [SimCLR] 004/100 | Loss: 4.3935 | Epoch Time: 1.44m | Total Time: 5.76m
# [SimCLR] 005/100 | Loss: 4.3636 | Epoch Time: 1.44m | Total Time: 7.20m
# [SimCLR] 006/100 | Loss: 4.3393 | Epoch Time: 1.44m | Total Time: 8.63m
# [SimCLR] 007/100 | Loss: 4.3201 | Epoch Time: 1.44m | Total Time: 10.07m
# [SimCLR] 008/100 | Loss: 4.2999 | Epoch Time: 1.44m | Total Time: 11.51m
# [SimCLR] 009/100 | Loss: 4.2829 | Epoch Time: 1.44m | Total Time: 12.95m
# [SimCLR] 010/100 | Loss: 4.2709 | Epoch Time: 1.45m | Total Time: 14.40m
# [SimCLR] 011/100 | Loss: 4.2576 | Epoch Time: 1.44m | Total Time: 15.84m
# [SimCLR] 012/100 | Loss: 4.2413 | Epoch Time: 1.44m | Total Time: 17.28m
# [SimCLR] 013/100 | Loss: 4.2328 | Epoch Time: 1.44m | Total Time: 18.72m
# [SimCLR] 014/100 | Loss: 4.2282 | Epoch Time: 1.44m | Total Time: 20.16m
# [SimCLR] 015/100 | Loss: 4.2145 | Epoch Time: 1.44m | Total Time: 21.60m
# [SimCLR] 016/100 | Loss: 4.2114 | Epoch Time: 1.44m | Total Time: 23.03m
# [SimCLR] 017/100 | Loss: 4.2019 | Epoch Time: 1.44m | Total Time: 24.47m
# [SimCLR] 018/100 | Loss: 4.1958 | Epoch Time: 1.44m | Total Time: 25.91m
# [SimCLR] 019/100 | Loss: 4.1893 | Epoch Time: 1.44m | Total Time: 27.35m
# [SimCLR] 020/100 | Loss: 4.1808 | Epoch Time: 1.44m | Total Time: 28.79m
# [SimCLR] 021/100 | Loss: 4.1756 | Epoch Time: 1.45m | Total Time: 30.23m
# [SimCLR] 022/100 | Loss: 4.1739 | Epoch Time: 1.44m | Total Time: 31.68m
# [SimCLR] 023/100 | Loss: 4.1672 | Epoch Time: 1.44m | Total Time: 33.12m
# [SimCLR] 024/100 | Loss: 4.1602 | Epoch Time: 1.44m | Total Time: 34.55m
# [SimCLR] 025/100 | Loss: 4.1565 | Epoch Time: 1.44m | Total Time: 35.99m
# [SimCLR] 026/100 | Loss: 4.1516 | Epoch Time: 1.44m | Total Time: 37.43m
# [SimCLR] 027/100 | Loss: 4.1508 | Epoch Time: 1.44m | Total Time: 38.87m
# [SimCLR] 028/100 | Loss: 4.1444 | Epoch Time: 1.44m | Total Time: 40.31m
# [SimCLR] 029/100 | Loss: 4.1411 | Epoch Time: 1.44m | Total Time: 41.75m
# [SimCLR] 030/100 | Loss: 4.1415 | Epoch Time: 1.44m | Total Time: 43.20m
# [SimCLR] 031/100 | Loss: 4.1384 | Epoch Time: 1.45m | Total Time: 44.65m
# [SimCLR] 032/100 | Loss: 4.1326 | Epoch Time: 1.45m | Total Time: 46.09m
# [SimCLR] 033/100 | Loss: 4.1262 | Epoch Time: 1.45m | Total Time: 47.54m
# [SimCLR] 034/100 | Loss: 4.1254 | Epoch Time: 1.45m | Total Time: 48.99m
# [SimCLR] 035/100 | Loss: 4.1186 | Epoch Time: 1.45m | Total Time: 50.44m
# [SimCLR] 036/100 | Loss: 4.1194 | Epoch Time: 1.45m | Total Time: 51.89m
# [SimCLR] 037/100 | Loss: 4.1163 | Epoch Time: 1.45m | Total Time: 53.34m
# [SimCLR] 038/100 | Loss: 4.1125 | Epoch Time: 1.45m | Total Time: 54.79m
# [SimCLR] 039/100 | Loss: 4.1106 | Epoch Time: 1.45m | Total Time: 56.24m
# [SimCLR] 040/100 | Loss: 4.1093 | Epoch Time: 1.45m | Total Time: 57.69m
# [SimCLR] 041/100 | Loss: 4.1056 | Epoch Time: 1.45m | Total Time: 59.14m
# [SimCLR] 042/100 | Loss: 4.1024 | Epoch Time: 1.45m | Total Time: 60.59m
# [SimCLR] 043/100 | Loss: 4.0991 | Epoch Time: 1.44m | Total Time: 62.03m
# [SimCLR] 044/100 | Loss: 4.1011 | Epoch Time: 1.45m | Total Time: 63.48m
# [SimCLR] 045/100 | Loss: 4.0953 | Epoch Time: 1.44m | Total Time: 64.92m
# [SimCLR] 046/100 | Loss: 4.0970 | Epoch Time: 1.44m | Total Time: 66.36m
# [SimCLR] 047/100 | Loss: 4.0907 | Epoch Time: 1.45m | Total Time: 67.81m
# [SimCLR] 048/100 | Loss: 4.0896 | Epoch Time: 1.45m | Total Time: 69.25m
# [SimCLR] 049/100 | Loss: 4.0892 | Epoch Time: 1.45m | Total Time: 70.70m
# [SimCLR] 050/100 | Loss: 4.0866 | Epoch Time: 1.45m | Total Time: 72.15m
# [SimCLR] 051/100 | Loss: 4.0858 | Epoch Time: 1.45m | Total Time: 73.60m
# [SimCLR] 052/100 | Loss: 4.0856 | Epoch Time: 1.45m | Total Time: 75.05m
# [SimCLR] 053/100 | Loss: 4.0785 | Epoch Time: 1.45m | Total Time: 76.50m
# [SimCLR] 054/100 | Loss: 4.0813 | Epoch Time: 1.45m | Total Time: 77.94m
# [SimCLR] 055/100 | Loss: 4.0795 | Epoch Time: 1.45m | Total Time: 79.39m
# [SimCLR] 056/100 | Loss: 4.0759 | Epoch Time: 1.45m | Total Time: 80.84m
# [SimCLR] 057/100 | Loss: 4.0735 | Epoch Time: 1.45m | Total Time: 82.28m
# [SimCLR] 058/100 | Loss: 4.0739 | Epoch Time: 1.44m | Total Time: 83.73m
# [SimCLR] 059/100 | Loss: 4.0707 | Epoch Time: 1.44m | Total Time: 85.17m
# [SimCLR] 060/100 | Loss: 4.0717 | Epoch Time: 1.45m | Total Time: 86.62m
# [SimCLR] 061/100 | Loss: 4.0668 | Epoch Time: 1.44m | Total Time: 88.06m
# [SimCLR] 062/100 | Loss: 4.0678 | Epoch Time: 1.44m | Total Time: 89.50m
# [SimCLR] 063/100 | Loss: 4.0681 | Epoch Time: 1.45m | Total Time: 90.95m
# [SimCLR] 064/100 | Loss: 4.0646 | Epoch Time: 1.44m | Total Time: 92.39m
# [SimCLR] 065/100 | Loss: 4.0625 | Epoch Time: 1.45m | Total Time: 93.84m
# [SimCLR] 066/100 | Loss: 4.0645 | Epoch Time: 1.44m | Total Time: 95.28m
# [SimCLR] 067/100 | Loss: 4.0616 | Epoch Time: 1.44m | Total Time: 96.73m
# [SimCLR] 068/100 | Loss: 4.0610 | Epoch Time: 1.44m | Total Time: 98.17m
# [SimCLR] 069/100 | Loss: 4.0590 | Epoch Time: 1.45m | Total Time: 99.62m
# [SimCLR] 070/100 | Loss: 4.0566 | Epoch Time: 1.45m | Total Time: 101.08m
# [SimCLR] 071/100 | Loss: 4.0547 | Epoch Time: 1.45m | Total Time: 102.53m
# [SimCLR] 072/100 | Loss: 4.0548 | Epoch Time: 1.45m | Total Time: 103.98m
# [SimCLR] 073/100 | Loss: 4.0549 | Epoch Time: 1.45m | Total Time: 105.43m
# [SimCLR] 074/100 | Loss: 4.0529 | Epoch Time: 1.45m | Total Time: 106.88m
# [SimCLR] 075/100 | Loss: 4.0525 | Epoch Time: 1.45m | Total Time: 108.32m
# [SimCLR] 076/100 | Loss: 4.0511 | Epoch Time: 1.45m | Total Time: 109.77m
# [SimCLR] 077/100 | Loss: 4.0509 | Epoch Time: 1.45m | Total Time: 111.22m
# [SimCLR] 078/100 | Loss: 4.0478 | Epoch Time: 1.45m | Total Time: 112.66m
# [SimCLR] 079/100 | Loss: 4.0498 | Epoch Time: 1.45m | Total Time: 114.11m
# [SimCLR] 080/100 | Loss: 4.0472 | Epoch Time: 1.45m | Total Time: 115.56m
# [SimCLR] 081/100 | Loss: 4.0487 | Epoch Time: 1.45m | Total Time: 117.00m
# [SimCLR] 082/100 | Loss: 4.0464 | Epoch Time: 1.45m | Total Time: 118.45m
# [SimCLR] 083/100 | Loss: 4.0488 | Epoch Time: 1.44m | Total Time: 119.90m
# [SimCLR] 084/100 | Loss: 4.0470 | Epoch Time: 1.44m | Total Time: 121.34m
# [SimCLR] 085/100 | Loss: 4.0435 | Epoch Time: 1.45m | Total Time: 122.79m
# [SimCLR] 086/100 | Loss: 4.0448 | Epoch Time: 1.45m | Total Time: 124.23m
# [SimCLR] 087/100 | Loss: 4.0441 | Epoch Time: 1.45m | Total Time: 125.68m
# [SimCLR] 088/100 | Loss: 4.0402 | Epoch Time: 1.44m | Total Time: 127.12m
# [SimCLR] 089/100 | Loss: 4.0406 | Epoch Time: 1.44m | Total Time: 128.57m
# [SimCLR] 090/100 | Loss: 4.0434 | Epoch Time: 1.45m | Total Time: 130.01m
# [SimCLR] 091/100 | Loss: 4.0400 | Epoch Time: 1.45m | Total Time: 131.46m
# [SimCLR] 092/100 | Loss: 4.0396 | Epoch Time: 1.44m | Total Time: 132.90m
# [SimCLR] 093/100 | Loss: 4.0366 | Epoch Time: 1.44m | Total Time: 134.34m
# [SimCLR] 094/100 | Loss: 4.0372 | Epoch Time: 1.45m | Total Time: 135.79m
# [SimCLR] 095/100 | Loss: 4.0353 | Epoch Time: 1.44m | Total Time: 137.23m
# [SimCLR] 096/100 | Loss: 4.0334 | Epoch Time: 1.44m | Total Time: 138.67m
# [SimCLR] 097/100 | Loss: 4.0349 | Epoch Time: 1.44m | Total Time: 140.11m
# [SimCLR] 098/100 | Loss: 4.0363 | Epoch Time: 1.44m | Total Time: 141.56m
# [SimCLR] 099/100 | Loss: 4.0331 | Epoch Time: 1.44m | Total Time: 143.00m
# [SimCLR] 100/100 | Loss: 4.0329 | Epoch Time: 1.45m | Total Time: 144.45m
# Saved results to: /kaggle/working/byol_simclr_results.csv
#
# Running Mean Summary:
#             Seed   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# Method
# BYOL         6.5  58.614551        13.026648          13.030577
# SimCLR       6.5  87.195892        15.396568          18.410448
# SimCLR+Jac   6.5  65.618567        15.471270          16.419826
#
#             Linear_Probe_Acc
# Method
# BYOL                 0.65115
# SimCLR               0.68755
# SimCLR+Jac           0.67420
#
# Seed 7 finished in 311.26 minutes
#
# ================ FINAL RESULTS ================
#    Seed      Method   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# 0     6        BYOL  61.887311        13.626039          14.518287
# 1     6      SimCLR  89.363847        15.015509          18.349785
# 2     6  SimCLR+Jac  65.949622        15.731129          16.418068
# 3     7        BYOL  55.341792        12.427256          11.542867
# 4     7      SimCLR  85.027936        15.777627          18.471111
# 5     7  SimCLR+Jac  65.287511        15.211410          16.421584
#
#    Linear_Probe_Acc
# 0            0.6571
# 1            0.6832
# 2            0.6712
# 3            0.6452
# 4            0.6919
# 5            0.6772
#
# Total experiment time (this session): 623.81 minutes
