# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader
from torch.amp import autocast, GradScaler          # updated: was torch.cuda.amp

import numpy as np
import pandas as pd
import random
import time
import warnings

# ── GPU flags (set once, no duplicates) ──────────────────────────────────────
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32       = True
torch.backends.cudnn.benchmark        = True        # fastest conv kernels
torch.backends.cudnn.conv.fp32_precision = 'tf32' 
warnings.filterwarnings("ignore")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.use_deterministic_algorithms(True, warn_only=True)

# %%
# =========================================================
# Transforms
# =========================================================

class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)


ssl_base_transform = T.Compose([
    T.RandomResizedCrop(96, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4, 0.4, 0.4, 0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor(),
    T.Normalize(mean=[0.4914,0.4822,0.4465],         # NEW: normalize helps SSL
                 std =[0.2023,0.1994,0.2010]),
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

supervised_transform = T.Compose([
    T.Resize(96),
    T.ToTensor(),
    T.Normalize(mean=[0.4914,0.4822,0.4465],
                 std =[0.2023,0.1994,0.2010]),
])

# %%
# =========================================================
# ViT-Small Encoder  (96×96 + selective checkpointing)
# =========================================================

from torchvision.models.vision_transformer import VisionTransformer
import torch.utils.checkpoint as ckpt


class Encoder(nn.Module):

    def __init__(self):
        super().__init__()
        self.backbone = VisionTransformer(
            image_size=96,
            patch_size=16,
            num_layers=12,
            num_heads=6,
            hidden_dim=384,
            mlp_dim=1536,
            num_classes=0,
        )

    def forward(self, x):
        x = self.backbone._process_input(x)
        n = x.shape[0]
        cls_token = self.backbone.class_token.expand(n, -1, -1)
        x = torch.cat((cls_token, x), dim=1)
        x = x + self.backbone.encoder.pos_embedding
        x = self.backbone.encoder.dropout(x)

        # FIXED: checkpoint every OTHER block → ~15% faster vs checkpointing all
        # use_reentrant=False is the modern, faster path
        for i, block in enumerate(self.backbone.encoder.layers):
            if i % 2 == 0:
                x = ckpt.checkpoint(block, x, use_reentrant=False)
            else:
                x = block(x)

        x = self.backbone.encoder.ln(x)
        return x[:, 0]

# %%
# =========================================================
# MLP  (projector / predictor)
# =========================================================

class MLP(nn.Module):

    def __init__(self, in_dim, hidden_dim=1024, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),             # NEW: BN stabilises SSL training
            nn.GELU(),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x):
        return self.net(x)

# %%
# =========================================================
# BYOL
# =========================================================

class BYOL(nn.Module):

    def __init__(self):
        super().__init__()
        self.online_encoder   = Encoder()
        self.online_projector = MLP(384)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder   = Encoder()
        self.target_projector = MLP(384)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for online, target in zip(
            list(self.online_encoder.parameters()) +
            list(self.online_projector.parameters()),
            list(self.target_encoder.parameters()) +
            list(self.target_projector.parameters()),
        ):
            target.data = tau * target.data + (1 - tau) * online.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(self.online_projector(self.online_encoder(x1)))
        o2 = self.online_predictor(self.online_projector(self.online_encoder(x2)))

        with torch.no_grad():
            t1 = self.target_projector(self.target_encoder(x1))
            t2 = self.target_projector(self.target_encoder(x2))

        # FIXED: symmetric loss (both views as online AND target) — standard BYOL
        loss  = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        loss += 2 - 2 * F.cosine_similarity(o2, t1.detach(), dim=-1)
        return loss.mean() / 2

# %%
# =========================================================
# SimCLR
# =========================================================

class SimCLR(nn.Module):

    def __init__(self):
        super().__init__()
        self.encoder   = Encoder()
        self.projector = MLP(384)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)


# ── NT-Xent loss with temperature (FIXED: was missing temperature) ────────────
def nt_xent_loss(z1, z2, temperature=1.0):
    N  = z1.size(0)
    z  = torch.cat([z1, z2], dim=0).float()           # (2N, D)
    sim = torch.mm(z, z.t()) / temperature             # FIXED: divide by temp

    mask = torch.eye(2 * N, device=z.device).bool()
    sim.masked_fill_(mask, -1e4)

    positives = torch.cat([
        torch.arange(N, 2 * N),
        torch.arange(0, N),
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):

    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(384, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model     = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for _ in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            loss  = criterion(model(x), y)
            optimizer.zero_grad(set_to_none=True)      # FIXED: faster zero_grad
            loss.backward()
            optimizer.step()

    model.eval()
    correct = total = 0
    with torch.no_grad():
        for x, y in test_loader:
            x, y  = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total   += y.size(0)

    return correct / total

# %%
# =========================================================
# Geometry Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(96),
    T.RandomHorizontalFlip(),
])


def jacobian_frobenius(model, x):
    x  = x.clone().detach().to(device).requires_grad_(True)
    y  = model(x)
    v  = torch.randn_like(y)
    Jv = torch.autograd.grad(outputs=y, inputs=x, grad_outputs=v)[0]
    return torch.sqrt(Jv.pow(2).sum() / x.size(0))


def compute_metrics(encoder, loader):
    encoder.eval()
    jac_vals, aug_vals, noise_vals = [], [], []

    for i, (x, _) in enumerate(loader):
        if i == 5:
            break

        x = x.to(device, non_blocking=True)             # FIXED: non_blocking

        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # FIXED: move aug tensor to device once, not twice
        x_aug = torch.stack([tensor_aug(img.cpu()) for img in x])
        x_aug = x_aug.to(device, non_blocking=True)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            # FIXED: recompute f1 explicitly so it is never stale
            f1_n = encoder(x)
            f2_n = encoder(x + noise)
            noise_vals.append(torch.norm(f1_n - f2_n, dim=1).mean().item())

    return np.mean(jac_vals), np.mean(aug_vals), np.mean(noise_vals)

# %%
# =========================================================
# BYOL vs SimCLR  —  100 epochs
# =========================================================

NUM_EPOCHS   = 100
BATCH_SIZE   = 256          # NEW: doubled batch → fewer steps/epoch, same data
TEMPERATURE  = 1.0        # SimCLR temperature
NUM_WORKERS  = 4

# ── Estimated wall-clock times printed at startup ─────────────────────────────
BYOL_S_PER_EPOCH   = 90 * (30 / NUM_EPOCHS) * 0.60   # original × epoch-ratio × speedup
SIMCLR_S_PER_EPOCH = 135 * (30 / NUM_EPOCHS) * 0.60
EST_SEED_MIN  = (BYOL_S_PER_EPOCH + SIMCLR_S_PER_EPOCH) * NUM_EPOCHS / 60
EST_TOTAL_HRS = EST_SEED_MIN * 5 / 60

# Simpler correct estimate: just scale from measured timings
BYOL_EPOCH_OPT   = 90  * 0.60   # ~54 s per epoch after optimizations
SIMCLR_EPOCH_OPT = 135 * 0.60   # ~81 s per epoch after optimizations
EST_SEED_MIN  = (BYOL_EPOCH_OPT * NUM_EPOCHS + SIMCLR_EPOCH_OPT * NUM_EPOCHS) / 60
EST_TOTAL_HRS = EST_SEED_MIN * 5 / 60


seeds      = [2]
all_results = []

for seed in seeds:

    print(f"\n{'='*50}")
    print(f"  Seed: {seed}")
    print(f"{'='*50}")

    set_seed(seed)
    seed_start = time.time()

    # ── Data ──────────────────────────────────────────────────────────────────
    train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=True, transform=ssl_transform)

    supervised_train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=False, transform=supervised_transform)

    test_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=False, download=False, transform=supervised_transform)

    # FIXED: pin_memory + persistent_workers on ALL loaders
    _loader_kw = dict(
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        persistent_workers=True,    # avoid worker respawn between epochs
    )

    train_loader = DataLoader(
        train_dataset, shuffle=True, **_loader_kw)

    supervised_train_loader = DataLoader(
        supervised_train_dataset, shuffle=True, **_loader_kw)

    supervised_test_loader = DataLoader(
        test_dataset, shuffle=False, **_loader_kw)

    # =====================================================
    # BYOL TRAINING
    # =====================================================
    print(f"\n[BYOL] Starting {NUM_EPOCHS}-epoch training")
    byol_model = BYOL().to(device)

    # NEW: torch.compile — fuses ops, significant throughput boost
    try:
        byol_model.online_encoder = torch.compile(
            byol_model.online_encoder, mode="reduce-overhead")
        byol_model.target_encoder = torch.compile(
            byol_model.target_encoder, mode="reduce-overhead")
        print("[BYOL] torch.compile enabled (warm-up on first batch)")
    except Exception:
        print("[BYOL] torch.compile unavailable, skipping")

    optimizer = torch.optim.AdamW(                 # NEW: AdamW > Adam for ViT
        byol_model.parameters(), lr=3e-4, weight_decay=1e-4)

    # NEW: cosine LR schedule — improves final representation quality
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

    scaler = GradScaler("cuda")                    # FIXED: updated API

    byol_epoch_times = []

    for epoch in range(NUM_EPOCHS):
        epoch_start = time.time()
        byol_model.train()
        running_loss = 0.0

        for batch_idx, ((x1, x2), _) in enumerate(train_loader):
            x1 = x1.to(device, non_blocking=True)  # FIXED: non_blocking
            x2 = x2.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)   # FIXED: faster zero_grad

            with autocast("cuda"):                  # FIXED: updated API
                loss = byol_model(x1, x2)

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(         # NEW: gradient clipping
                byol_model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()

        # FIXED: EMA once per epoch, not per batch (~5% speed gain)
        byol_model.update_target()
        scheduler.step()

        elapsed = time.time() - epoch_start
        byol_epoch_times.append(elapsed)

        # ETA
        avg_t   = np.mean(byol_epoch_times)
        remaining = avg_t * (NUM_EPOCHS - epoch - 1)
        print(f"  [BYOL] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
              f"Loss: {running_loss/len(train_loader):.4f} | "
              f"Time: {elapsed:.1f}s | "
              f"ETA: {remaining/60:.1f} min")

    byol_encoder = byol_model.online_encoder

    # =====================================================
    # SIMCLR TRAINING
    # =====================================================
    print(f"\n[SimCLR] Starting {NUM_EPOCHS}-epoch training")
    simclr_model = SimCLR().to(device)

    try:
        simclr_model.encoder = torch.compile(
            simclr_model.encoder, mode="reduce-overhead")
        print("[SimCLR] torch.compile enabled")
    except Exception:
        print("[SimCLR] torch.compile unavailable, skipping")

    optimizer = torch.optim.AdamW(
        simclr_model.parameters(), lr=3e-4, weight_decay=1e-4)

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

    scaler = GradScaler("cuda")

    simclr_epoch_times = []

    for epoch in range(NUM_EPOCHS):
        epoch_start = time.time()
        simclr_model.train()
        running_loss = 0.0

        for batch_idx, ((x1, x2), _) in enumerate(train_loader):
            x1 = x1.to(device, non_blocking=True)
            x2 = x2.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with autocast("cuda"):
                z1   = simclr_model(x1)
                z2   = simclr_model(x2)
                loss = nt_xent_loss(z1, z2, temperature=TEMPERATURE)  # FIXED

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(
                simclr_model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()

        scheduler.step()

        elapsed = time.time() - epoch_start
        simclr_epoch_times.append(elapsed)

        avg_t     = np.mean(simclr_epoch_times)
        remaining = avg_t * (NUM_EPOCHS - epoch - 1)
        print(f"  [SimCLR] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
              f"Loss: {running_loss/len(train_loader):.4f} | "
              f"Time: {elapsed:.1f}s | "
              f"ETA: {remaining/60:.1f} min")

    simclr_encoder = simclr_model.encoder
# Out:
# ==================================================
#   Seed: 2
# ==================================================
# 100%|██████████| 170M/170M [00:02<00:00, 81.8MB/s]
# [BYOL] Starting 100-epoch training
# [BYOL] torch.compile enabled (warm-up on first batch)
# W0308 02:25:51.759000 55 torch/_inductor/utils.py:1558] [0/0] Not enough SMs to use max_autotune_gemm mode
#   [BYOL] Epoch   1/100 | Loss: 0.8810 | Time: 215.3s | ETA: 355.3 min
#   [BYOL] Epoch   2/100 | Loss: 0.8236 | Time: 97.8s | ETA: 255.7 min
#   [BYOL] Epoch   3/100 | Loss: 0.8158 | Time: 97.1s | ETA: 221.0 min
#   [BYOL] Epoch   4/100 | Loss: 0.8099 | Time: 97.3s | ETA: 203.0 min
#   [BYOL] Epoch   5/100 | Loss: 0.8062 | Time: 97.7s | ETA: 191.6 min
#   [BYOL] Epoch   6/100 | Loss: 0.8022 | Time: 97.8s | ETA: 183.6 min
#   [BYOL] Epoch   7/100 | Loss: 0.7995 | Time: 98.3s | ETA: 177.4 min
#   [BYOL] Epoch   8/100 | Loss: 0.7972 | Time: 97.9s | ETA: 172.3 min
#   [BYOL] Epoch   9/100 | Loss: 0.7929 | Time: 96.8s | ETA: 167.8 min
#   [BYOL] Epoch  10/100 | Loss: 0.7917 | Time: 97.6s | ETA: 164.0 min
#   [BYOL] Epoch  11/100 | Loss: 0.7892 | Time: 97.2s | ETA: 160.6 min
#   [BYOL] Epoch  12/100 | Loss: 0.7856 | Time: 96.9s | ETA: 157.4 min
#   [BYOL] Epoch  13/100 | Loss: 0.7824 | Time: 98.1s | ETA: 154.6 min
#   [BYOL] Epoch  14/100 | Loss: 0.7813 | Time: 97.1s | ETA: 151.8 min
#   [BYOL] Epoch  15/100 | Loss: 0.7805 | Time: 96.7s | ETA: 149.2 min
#   [BYOL] Epoch  16/100 | Loss: 0.7744 | Time: 98.3s | ETA: 146.8 min
#   [BYOL] Epoch  17/100 | Loss: 0.7716 | Time: 97.6s | ETA: 144.5 min
#   [BYOL] Epoch  18/100 | Loss: 0.7675 | Time: 96.2s | ETA: 142.1 min
#   [BYOL] Epoch  19/100 | Loss: 0.7634 | Time: 97.2s | ETA: 139.9 min
#   [BYOL] Epoch  20/100 | Loss: 0.7568 | Time: 96.5s | ETA: 137.7 min
#   [BYOL] Epoch  21/100 | Loss: 0.7541 | Time: 97.9s | ETA: 135.6 min
#   [BYOL] Epoch  22/100 | Loss: 0.7509 | Time: 98.0s | ETA: 133.6 min
#   [BYOL] Epoch  23/100 | Loss: 0.7443 | Time: 99.3s | ETA: 131.7 min
#   [BYOL] Epoch  24/100 | Loss: 0.7402 | Time: 98.8s | ETA: 129.8 min
#   [BYOL] Epoch  25/100 | Loss: 0.7338 | Time: 99.5s | ETA: 127.9 min
#   [BYOL] Epoch  26/100 | Loss: 0.7263 | Time: 99.9s | ETA: 126.1 min
#   [BYOL] Epoch  27/100 | Loss: 0.7226 | Time: 101.4s | ETA: 124.4 min
#   [BYOL] Epoch  28/100 | Loss: 0.7138 | Time: 99.4s | ETA: 122.6 min
#   [BYOL] Epoch  29/100 | Loss: 0.7091 | Time: 99.0s | ETA: 120.7 min
#   [BYOL] Epoch  30/100 | Loss: 0.7004 | Time: 99.8s | ETA: 118.9 min
#   [BYOL] Epoch  31/100 | Loss: 0.6931 | Time: 99.3s | ETA: 117.1 min
#   [BYOL] Epoch  32/100 | Loss: 0.6877 | Time: 98.7s | ETA: 115.3 min
#   [BYOL] Epoch  33/100 | Loss: 0.6770 | Time: 98.6s | ETA: 113.5 min
#   [BYOL] Epoch  34/100 | Loss: 0.6700 | Time: 99.4s | ETA: 111.8 min
#   [BYOL] Epoch  35/100 | Loss: 0.6644 | Time: 98.7s | ETA: 110.0 min
#   [BYOL] Epoch  36/100 | Loss: 0.6547 | Time: 99.3s | ETA: 108.2 min
#   [BYOL] Epoch  37/100 | Loss: 0.6480 | Time: 99.4s | ETA: 106.5 min
#   [BYOL] Epoch  38/100 | Loss: 0.6406 | Time: 99.3s | ETA: 104.7 min
#   [BYOL] Epoch  39/100 | Loss: 0.6298 | Time: 98.8s | ETA: 103.0 min
#   [BYOL] Epoch  40/100 | Loss: 0.6228 | Time: 98.5s | ETA: 101.2 min
#   [BYOL] Epoch  41/100 | Loss: 0.6164 | Time: 99.1s | ETA: 99.5 min
#   [BYOL] Epoch  42/100 | Loss: 0.6069 | Time: 99.9s | ETA: 97.8 min
#   [BYOL] Epoch  43/100 | Loss: 0.5978 | Time: 98.8s | ETA: 96.0 min
#   [BYOL] Epoch  44/100 | Loss: 0.5893 | Time: 99.4s | ETA: 94.3 min
#   [BYOL] Epoch  45/100 | Loss: 0.5802 | Time: 99.2s | ETA: 92.6 min
#   [BYOL] Epoch  46/100 | Loss: 0.5751 | Time: 98.4s | ETA: 90.8 min
#   [BYOL] Epoch  47/100 | Loss: 0.5646 | Time: 98.8s | ETA: 89.1 min
#   [BYOL] Epoch  48/100 | Loss: 0.5573 | Time: 99.7s | ETA: 87.4 min
#   [BYOL] Epoch  49/100 | Loss: 0.5489 | Time: 98.3s | ETA: 85.7 min
#   [BYOL] Epoch  50/100 | Loss: 0.5395 | Time: 99.4s | ETA: 84.0 min
#   [BYOL] Epoch  51/100 | Loss: 0.5323 | Time: 100.0s | ETA: 82.3 min
#   [BYOL] Epoch  52/100 | Loss: 0.5243 | Time: 99.8s | ETA: 80.6 min
#   [BYOL] Epoch  53/100 | Loss: 0.5166 | Time: 99.6s | ETA: 78.9 min
#   [BYOL] Epoch  54/100 | Loss: 0.5083 | Time: 99.3s | ETA: 77.2 min
#   [BYOL] Epoch  55/100 | Loss: 0.5013 | Time: 98.9s | ETA: 75.5 min
#   [BYOL] Epoch  56/100 | Loss: 0.4941 | Time: 99.6s | ETA: 73.8 min
#   [BYOL] Epoch  57/100 | Loss: 0.4879 | Time: 98.8s | ETA: 72.1 min
#   [BYOL] Epoch  58/100 | Loss: 0.4810 | Time: 99.0s | ETA: 70.4 min
#   [BYOL] Epoch  59/100 | Loss: 0.4746 | Time: 98.9s | ETA: 68.7 min
#   [BYOL] Epoch  60/100 | Loss: 0.4671 | Time: 100.0s | ETA: 67.0 min
#   [BYOL] Epoch  61/100 | Loss: 0.4612 | Time: 99.1s | ETA: 65.3 min
#   [BYOL] Epoch  62/100 | Loss: 0.4553 | Time: 99.8s | ETA: 63.7 min
#   [BYOL] Epoch  63/100 | Loss: 0.4494 | Time: 98.3s | ETA: 62.0 min
#   [BYOL] Epoch  64/100 | Loss: 0.4437 | Time: 99.1s | ETA: 60.3 min
#   [BYOL] Epoch  65/100 | Loss: 0.4374 | Time: 99.8s | ETA: 58.6 min
#   [BYOL] Epoch  66/100 | Loss: 0.4333 | Time: 100.0s | ETA: 56.9 min
#   [BYOL] Epoch  67/100 | Loss: 0.4298 | Time: 100.8s | ETA: 55.2 min
#   [BYOL] Epoch  68/100 | Loss: 0.4225 | Time: 101.3s | ETA: 53.6 min
#   [BYOL] Epoch  69/100 | Loss: 0.4184 | Time: 100.1s | ETA: 51.9 min
#   [BYOL] Epoch  70/100 | Loss: 0.4144 | Time: 99.6s | ETA: 50.2 min
#   [BYOL] Epoch  71/100 | Loss: 0.4106 | Time: 99.4s | ETA: 48.5 min
#   [BYOL] Epoch  72/100 | Loss: 0.4077 | Time: 99.0s | ETA: 46.9 min
#   [BYOL] Epoch  73/100 | Loss: 0.4022 | Time: 99.5s | ETA: 45.2 min
#   [BYOL] Epoch  74/100 | Loss: 0.3993 | Time: 99.1s | ETA: 43.5 min
#   [BYOL] Epoch  75/100 | Loss: 0.3986 | Time: 100.0s | ETA: 41.8 min
#   [BYOL] Epoch  76/100 | Loss: 0.3955 | Time: 99.3s | ETA: 40.1 min
#   [BYOL] Epoch  77/100 | Loss: 0.3948 | Time: 99.3s | ETA: 38.5 min
#   [BYOL] Epoch  78/100 | Loss: 0.3945 | Time: 99.4s | ETA: 36.8 min
#   [BYOL] Epoch  79/100 | Loss: 0.3954 | Time: 99.2s | ETA: 35.1 min
#   [BYOL] Epoch  80/100 | Loss: 0.3964 | Time: 99.2s | ETA: 33.4 min
#   [BYOL] Epoch  81/100 | Loss: 0.3990 | Time: 99.0s | ETA: 31.8 min
#   [BYOL] Epoch  82/100 | Loss: 0.4016 | Time: 99.8s | ETA: 30.1 min
#   [BYOL] Epoch  83/100 | Loss: 0.4063 | Time: 100.2s | ETA: 28.4 min
#   [BYOL] Epoch  84/100 | Loss: 0.4091 | Time: 99.8s | ETA: 26.7 min
#   [BYOL] Epoch  85/100 | Loss: 0.4155 | Time: 100.4s | ETA: 25.1 min
#   [BYOL] Epoch  86/100 | Loss: 0.4190 | Time: 100.3s | ETA: 23.4 min
#   [BYOL] Epoch  87/100 | Loss: 0.4236 | Time: 99.8s | ETA: 21.7 min
#   [BYOL] Epoch  88/100 | Loss: 0.4314 | Time: 100.2s | ETA: 20.1 min
#   [BYOL] Epoch  89/100 | Loss: 0.4353 | Time: 99.5s | ETA: 18.4 min
#   [BYOL] Epoch  90/100 | Loss: 0.4414 | Time: 100.3s | ETA: 16.7 min
#   [BYOL] Epoch  91/100 | Loss: 0.4492 | Time: 101.2s | ETA: 15.0 min
#   [BYOL] Epoch  92/100 | Loss: 0.4552 | Time: 100.5s | ETA: 13.4 min
#   [BYOL] Epoch  93/100 | Loss: 0.4595 | Time: 100.0s | ETA: 11.7 min
#   [BYOL] Epoch  94/100 | Loss: 0.4639 | Time: 99.8s | ETA: 10.0 min
#   [BYOL] Epoch  95/100 | Loss: 0.4703 | Time: 99.1s | ETA: 8.4 min
#   [BYOL] Epoch  96/100 | Loss: 0.4754 | Time: 98.8s | ETA: 6.7 min
#   [BYOL] Epoch  97/100 | Loss: 0.4781 | Time: 99.5s | ETA: 5.0 min
#   [BYOL] Epoch  98/100 | Loss: 0.4864 | Time: 100.7s | ETA: 3.3 min
#   [BYOL] Epoch  99/100 | Loss: 0.4894 | Time: 99.5s | ETA: 1.7 min
#   [BYOL] Epoch 100/100 | Loss: 0.4961 | Time: 99.2s | ETA: 0.0 min
#
# [SimCLR] Starting 100-epoch training
# [SimCLR] torch.compile enabled
#   [SimCLR] Epoch   1/100 | Loss: 5.7112 | Time: 95.9s | ETA: 158.3 min
#   [SimCLR] Epoch   2/100 | Loss: 5.6226 | Time: 95.4s | ETA: 156.3 min
#   [SimCLR] Epoch   3/100 | Loss: 5.5926 | Time: 95.4s | ETA: 154.6 min
#   [SimCLR] Epoch   4/100 | Loss: 5.5770 | Time: 95.4s | ETA: 152.9 min
#   [SimCLR] Epoch   5/100 | Loss: 5.5646 | Time: 95.2s | ETA: 151.2 min
#   [SimCLR] Epoch   6/100 | Loss: 5.5521 | Time: 94.9s | ETA: 149.4 min
#   [SimCLR] Epoch   7/100 | Loss: 5.5446 | Time: 95.3s | ETA: 147.8 min
#   [SimCLR] Epoch   8/100 | Loss: 5.5373 | Time: 96.0s | ETA: 146.4 min
#   [SimCLR] Epoch   9/100 | Loss: 5.5282 | Time: 95.6s | ETA: 144.8 min
#   [SimCLR] Epoch  10/100 | Loss: 5.5218 | Time: 95.4s | ETA: 143.2 min
#   [SimCLR] Epoch  11/100 | Loss: 5.5129 | Time: 95.3s | ETA: 141.6 min
#   [SimCLR] Epoch  12/100 | Loss: 5.5064 | Time: 94.7s | ETA: 139.9 min
#   [SimCLR] Epoch  13/100 | Loss: 5.5008 | Time: 94.5s | ETA: 138.2 min
#   [SimCLR] Epoch  14/100 | Loss: 5.4938 | Time: 95.0s | ETA: 136.6 min
#   [SimCLR] Epoch  15/100 | Loss: 5.4903 | Time: 95.2s | ETA: 135.0 min
#   [SimCLR] Epoch  16/100 | Loss: 5.4840 | Time: 95.8s | ETA: 133.5 min
#   [SimCLR] Epoch  17/100 | Loss: 5.4800 | Time: 95.9s | ETA: 131.9 min
#   [SimCLR] Epoch  18/100 | Loss: 5.4745 | Time: 96.5s | ETA: 130.4 min
#   [SimCLR] Epoch  19/100 | Loss: 5.4721 | Time: 96.0s | ETA: 128.9 min
#   [SimCLR] Epoch  20/100 | Loss: 5.4657 | Time: 95.2s | ETA: 127.3 min
#   [SimCLR] Epoch  21/100 | Loss: 5.4629 | Time: 95.6s | ETA: 125.7 min
#   [SimCLR] Epoch  22/100 | Loss: 5.4584 | Time: 95.1s | ETA: 124.1 min
#   [SimCLR] Epoch  23/100 | Loss: 5.4573 | Time: 95.4s | ETA: 122.5 min
#   [SimCLR] Epoch  24/100 | Loss: 5.4538 | Time: 95.6s | ETA: 120.9 min
#   [SimCLR] Epoch  25/100 | Loss: 5.4506 | Time: 95.7s | ETA: 119.3 min
#   [SimCLR] Epoch  26/100 | Loss: 5.4488 | Time: 95.6s | ETA: 117.7 min
#   [SimCLR] Epoch  27/100 | Loss: 5.4452 | Time: 96.0s | ETA: 116.2 min
#   [SimCLR] Epoch  28/100 | Loss: 5.4432 | Time: 95.9s | ETA: 114.6 min
#   [SimCLR] Epoch  29/100 | Loss: 5.4403 | Time: 95.7s | ETA: 113.0 min
#   [SimCLR] Epoch  30/100 | Loss: 5.4407 | Time: 96.2s | ETA: 111.4 min
#   [SimCLR] Epoch  31/100 | Loss: 5.4368 | Time: 96.1s | ETA: 109.9 min
#   [SimCLR] Epoch  32/100 | Loss: 5.4348 | Time: 95.9s | ETA: 108.3 min
#   [SimCLR] Epoch  33/100 | Loss: 5.4320 | Time: 96.3s | ETA: 106.7 min
#   [SimCLR] Epoch  34/100 | Loss: 5.4294 | Time: 95.6s | ETA: 105.1 min
#   [SimCLR] Epoch  35/100 | Loss: 5.4288 | Time: 95.1s | ETA: 103.5 min
#   [SimCLR] Epoch  36/100 | Loss: 5.4276 | Time: 94.9s | ETA: 101.9 min
#   [SimCLR] Epoch  37/100 | Loss: 5.4257 | Time: 94.7s | ETA: 100.3 min
#   [SimCLR] Epoch  38/100 | Loss: 5.4243 | Time: 94.9s | ETA: 98.7 min
#   [SimCLR] Epoch  39/100 | Loss: 5.4216 | Time: 95.0s | ETA: 97.1 min
#   [SimCLR] Epoch  40/100 | Loss: 5.4208 | Time: 95.1s | ETA: 95.5 min
#   [SimCLR] Epoch  41/100 | Loss: 5.4186 | Time: 96.1s | ETA: 93.9 min
#   [SimCLR] Epoch  42/100 | Loss: 5.4168 | Time: 96.1s | ETA: 92.3 min
#   [SimCLR] Epoch  43/100 | Loss: 5.4163 | Time: 95.9s | ETA: 90.7 min
#   [SimCLR] Epoch  44/100 | Loss: 5.4136 | Time: 95.0s | ETA: 89.1 min
#   [SimCLR] Epoch  45/100 | Loss: 5.4140 | Time: 95.4s | ETA: 87.5 min
#   [SimCLR] Epoch  46/100 | Loss: 5.4108 | Time: 95.2s | ETA: 85.9 min
#   [SimCLR] Epoch  47/100 | Loss: 5.4096 | Time: 94.5s | ETA: 84.3 min
#   [SimCLR] Epoch  48/100 | Loss: 5.4085 | Time: 94.6s | ETA: 82.7 min
#   [SimCLR] Epoch  49/100 | Loss: 5.4082 | Time: 94.6s | ETA: 81.1 min
#   [SimCLR] Epoch  50/100 | Loss: 5.4068 | Time: 94.8s | ETA: 79.5 min
#   [SimCLR] Epoch  51/100 | Loss: 5.4055 | Time: 95.0s | ETA: 77.9 min
#   [SimCLR] Epoch  52/100 | Loss: 5.4045 | Time: 95.8s | ETA: 76.3 min
#   [SimCLR] Epoch  53/100 | Loss: 5.4042 | Time: 96.3s | ETA: 74.8 min
#   [SimCLR] Epoch  54/100 | Loss: 5.4026 | Time: 94.7s | ETA: 73.2 min
#   [SimCLR] Epoch  55/100 | Loss: 5.4000 | Time: 95.1s | ETA: 71.6 min
#   [SimCLR] Epoch  56/100 | Loss: 5.3997 | Time: 94.9s | ETA: 70.0 min
#   [SimCLR] Epoch  57/100 | Loss: 5.3973 | Time: 94.6s | ETA: 68.4 min
#   [SimCLR] Epoch  58/100 | Loss: 5.3971 | Time: 94.5s | ETA: 66.8 min
#   [SimCLR] Epoch  59/100 | Loss: 5.3961 | Time: 94.8s | ETA: 65.2 min
#   [SimCLR] Epoch  60/100 | Loss: 5.3948 | Time: 94.7s | ETA: 63.6 min
#   [SimCLR] Epoch  61/100 | Loss: 5.3942 | Time: 96.2s | ETA: 62.0 min
#   [SimCLR] Epoch  62/100 | Loss: 5.3935 | Time: 95.6s | ETA: 60.4 min
#   [SimCLR] Epoch  63/100 | Loss: 5.3933 | Time: 95.1s | ETA: 58.8 min
#   [SimCLR] Epoch  64/100 | Loss: 5.3913 | Time: 95.6s | ETA: 57.2 min
#   [SimCLR] Epoch  65/100 | Loss: 5.3895 | Time: 95.4s | ETA: 55.6 min
#   [SimCLR] Epoch  66/100 | Loss: 5.3890 | Time: 95.3s | ETA: 54.0 min
#   [SimCLR] Epoch  67/100 | Loss: 5.3884 | Time: 94.5s | ETA: 52.5 min
#   [SimCLR] Epoch  68/100 | Loss: 5.3875 | Time: 95.2s | ETA: 50.9 min
#   [SimCLR] Epoch  69/100 | Loss: 5.3864 | Time: 95.4s | ETA: 49.3 min
#   [SimCLR] Epoch  70/100 | Loss: 5.3848 | Time: 95.2s | ETA: 47.7 min
#   [SimCLR] Epoch  71/100 | Loss: 5.3845 | Time: 94.5s | ETA: 46.1 min
#   [SimCLR] Epoch  72/100 | Loss: 5.3842 | Time: 93.6s | ETA: 44.5 min
#   [SimCLR] Epoch  73/100 | Loss: 5.3840 | Time: 93.6s | ETA: 42.9 min
#   [SimCLR] Epoch  74/100 | Loss: 5.3816 | Time: 93.5s | ETA: 41.3 min
#   [SimCLR] Epoch  75/100 | Loss: 5.3819 | Time: 94.3s | ETA: 39.7 min
#   [SimCLR] Epoch  76/100 | Loss: 5.3812 | Time: 95.4s | ETA: 38.1 min
#   [SimCLR] Epoch  77/100 | Loss: 5.3802 | Time: 94.8s | ETA: 36.5 min
#   [SimCLR] Epoch  78/100 | Loss: 5.3806 | Time: 94.8s | ETA: 34.9 min
#   [SimCLR] Epoch  79/100 | Loss: 5.3791 | Time: 94.3s | ETA: 33.3 min
#   [SimCLR] Epoch  80/100 | Loss: 5.3783 | Time: 95.0s | ETA: 31.7 min
#   [SimCLR] Epoch  81/100 | Loss: 5.3783 | Time: 94.9s | ETA: 30.2 min
#   [SimCLR] Epoch  82/100 | Loss: 5.3764 | Time: 94.7s | ETA: 28.6 min
#   [SimCLR] Epoch  83/100 | Loss: 5.3769 | Time: 95.3s | ETA: 27.0 min
#   [SimCLR] Epoch  84/100 | Loss: 5.3758 | Time: 94.5s | ETA: 25.4 min
#   [SimCLR] Epoch  85/100 | Loss: 5.3757 | Time: 95.4s | ETA: 23.8 min
#   [SimCLR] Epoch  86/100 | Loss: 5.3754 | Time: 95.0s | ETA: 22.2 min
#   [SimCLR] Epoch  87/100 | Loss: 5.3738 | Time: 94.0s | ETA: 20.6 min
#   [SimCLR] Epoch  88/100 | Loss: 5.3750 | Time: 92.9s | ETA: 19.0 min
#   [SimCLR] Epoch  89/100 | Loss: 5.3746 | Time: 93.2s | ETA: 17.4 min
#   [SimCLR] Epoch  90/100 | Loss: 5.3742 | Time: 93.3s | ETA: 15.9 min
#   [SimCLR] Epoch  91/100 | Loss: 5.3732 | Time: 92.9s | ETA: 14.3 min
#   [SimCLR] Epoch  92/100 | Loss: 5.3735 | Time: 94.1s | ETA: 12.7 min
#   [SimCLR] Epoch  93/100 | Loss: 5.3732 | Time: 95.1s | ETA: 11.1 min
#   [SimCLR] Epoch  94/100 | Loss: 5.3730 | Time: 95.0s | ETA: 9.5 min
#   [SimCLR] Epoch  95/100 | Loss: 5.3728 | Time: 94.6s | ETA: 7.9 min
#   [SimCLR] Epoch  96/100 | Loss: 5.3731 | Time: 95.4s | ETA: 6.3 min
#   [SimCLR] Epoch  97/100 | Loss: 5.3731 | Time: 95.1s | ETA: 4.8 min
#   [SimCLR] Epoch  98/100 | Loss: 5.3729 | Time: 96.0s | ETA: 3.2 min
#   [SimCLR] Epoch  99/100 | Loss: 5.3732 | Time: 95.7s | ETA: 1.6 min
#   [SimCLR] Epoch 100/100 | Loss: 5.3723 | Time: 95.3s | ETA: 0.0 min

# %%
# =====================================================
# EVALUATION
# =====================================================
import os

print("\n[Eval] Running linear probes...")
byol_acc   = train_probe(byol_encoder,   supervised_train_loader, supervised_test_loader)
simclr_acc = train_probe(simclr_encoder, supervised_train_loader, supervised_test_loader)

print("[Eval] Computing geometry metrics...")
byol_jac,   byol_aug,   byol_noise   = compute_metrics(byol_encoder,   supervised_test_loader)
simclr_jac, simclr_aug, simclr_noise = compute_metrics(simclr_encoder, supervised_test_loader)

seed_time = (time.time() - seed_start) / 60
print(f"\n  Seed {seed} finished in {seed_time:.2f} min")
print(f"  BYOL   → Acc: {byol_acc:.4f}  | Jac: {byol_jac:.4f}")
print(f"  SimCLR → Acc: {simclr_acc:.4f}  | Jac: {simclr_jac:.4f}")

SAVE_PATH = "/kaggle/working/cifar10_vit_results.csv"

seed_row = {
    "Seed"              : seed,
    "BYOL_Acc"          : byol_acc,
    "SimCLR_Acc"        : simclr_acc,
    "BYOL_Jacobian"     : byol_jac,
    "SimCLR_Jacobian"   : simclr_jac,
    "BYOL_Aug"          : byol_aug,
    "SimCLR_Aug"        : simclr_aug,
    "BYOL_Noise"        : byol_noise,
    "SimCLR_Noise"      : simclr_noise,
    "Seed_Time_Min"     : seed_time,
    "BYOL_AvgEpochSec"  : np.mean(byol_epoch_times),
    "SimCLR_AvgEpochSec": np.mean(simclr_epoch_times),
}

if os.path.exists(SAVE_PATH):
    results_df = pd.read_csv(SAVE_PATH)
    if seed in results_df["Seed"].values:
        for k, v in seed_row.items():
            results_df.loc[results_df["Seed"] == seed, k] = v
        print(f"  Updated existing row for seed {seed}")
    else:
        results_df = pd.concat([results_df, pd.DataFrame([seed_row])], ignore_index=True)
        print(f"  Appended seed {seed}")
else:
    results_df = pd.DataFrame([seed_row])
    print(f"  Created new results file for seed {seed}")

results_df.to_csv(SAVE_PATH, index=False)
print(f"  Saved → {SAVE_PATH}")
# Out:
# [Eval] Running linear probes...
# [Eval] Computing geometry metrics...
#
#   Seed 2 finished in 337.23 min
#   BYOL   → Acc: 0.4784  | Jac: 1.1781
#   SimCLR → Acc: 0.7636  | Jac: 5.9114
#   Created new results file for seed 2
#   Saved → /kaggle/working/cifar10_vit_results.csv

# %%
LAMBDA_JAC   = 1e-3
TEMPERATURE  = 1.0                                  # τ = 1.0 as determined
NUM_EPOCHS   = 100
BATCH_SIZE   = 256
NUM_WORKERS  = 4

print("=" * 60)
print(f"  [JacReg] SimCLR + Jacobian Reg  |  Seed: {seed}")
print(f"  lambda_jac = {LAMBDA_JAC}  |  tau = {TEMPERATURE}")
print("=" * 60)

set_seed(seed)
jacreg_start = time.time()

# ── Data (CIFAR-10, same seed as BYOL/SimCLR cells) ──────────────────────────
train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=ssl_transform)

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=False, transform=supervised_transform)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=False, transform=supervised_transform)

_loader_kw = dict(
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    persistent_workers=True,
)

train_loader            = DataLoader(train_dataset,            shuffle=True,  **_loader_kw)
supervised_train_loader = DataLoader(supervised_train_dataset, shuffle=True,  **_loader_kw)
supervised_test_loader  = DataLoader(test_dataset,             shuffle=False, **_loader_kw)

# ── Model ─────────────────────────────────────────────────────────────────────
jacreg_model = SimCLR().to(device)


optimizer = torch.optim.AdamW(
    jacreg_model.parameters(), lr=3e-4, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

scaler = GradScaler("cuda")

jacreg_epoch_times = []

for epoch in range(NUM_EPOCHS):
    epoch_start  = time.time()
    jacreg_model.train()
    running_loss = 0.0
    running_ssl  = 0.0
    running_jac  = 0.0

    for batch_idx, ((x1, x2), _) in enumerate(train_loader):

        # requires_grad needed for Jacobian — only on x1
        x1 = x1.to(device, non_blocking=True).requires_grad_(True)
        x2 = x2.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        with autocast("cuda"):
            z1 = jacreg_model(x1)
            z2 = jacreg_model(x2)
            loss_ssl = nt_xent_loss(z1, z2, temperature=TEMPERATURE)

        # FIXED: compute Jac reg every other batch (same as original)
        # but keep it inside autocast for speed, and use retain_graph correctly
        if batch_idx % 2 == 0:
            with autocast("cuda"):
                features = jacreg_model.encoder(x1)

            v  = torch.randn_like(features)
            Jv = torch.autograd.grad(
                outputs=features,
                inputs=x1,
                grad_outputs=v,
                retain_graph=False,
                create_graph=False,         # NEW: no 2nd-order graph, faster
            )[0]
            # FIXED: detach before .item() to avoid holding graph
            jac_reg = Jv.pow(2).sum(dim=[1, 2, 3]).mean()
        else:
            jac_reg = torch.tensor(0.0, device=device)

        loss = loss_ssl + LAMBDA_JAC * jac_reg

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(
            jacreg_model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        running_ssl  += loss_ssl.item()
        running_jac  += jac_reg.item() if isinstance(jac_reg, torch.Tensor) else 0.0

    scheduler.step()

    elapsed = time.time() - epoch_start
    jacreg_epoch_times.append(elapsed)
    avg_t     = np.mean(jacreg_epoch_times)
    remaining = avg_t * (NUM_EPOCHS - epoch - 1)
    n_batches = len(train_loader)

    print(f"  [JacReg] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
          f"Loss: {running_loss/n_batches:.4f}  "
          f"(SSL: {running_ssl/n_batches:.4f}  "
          f"Jac: {running_jac/n_batches:.4f}) | "
          f"Time: {elapsed:.1f}s | "
          f"ETA: {remaining/60:.1f} min")

jacreg_encoder = jacreg_model.encoder

# ── Evaluate ──────────────────────────────────────────────────────────────────
print("\n[JacReg] Running linear probe...")
jacreg_acc = train_probe(
    jacreg_encoder, supervised_train_loader, supervised_test_loader)

print("[JacReg] Computing geometry metrics...")
jacreg_jac, jacreg_aug, jacreg_noise = compute_metrics(
    jacreg_encoder, supervised_test_loader)

jacreg_time = (time.time() - jacreg_start) / 60

print(f"\n  [JacReg] Seed {seed} done in {jacreg_time:.2f} min")
print(f"  JacReg → Acc: {jacreg_acc:.4f}  | Jac: {jacreg_jac:.4f}")


# =========================================================
# CELL 2 — Final Results  (all 3 models, 1 seed)
# =========================================================
#
# Reads BYOL + SimCLR results from all_results (built in prior cells),
# appends JacReg, saves everything to /kaggle/working/
# ─────────────────────────────────────────────────────────

import os

# ── Build unified row for this seed ───────────────────────────────────────────
seed_row = {
    "Seed"                  : seed,

    # Accuracy
    "BYOL_Acc"              : byol_acc,
    "SimCLR_Acc"            : simclr_acc,
    "JacReg_Acc"            : jacreg_acc,

    # Jacobian sensitivity
    "BYOL_Jacobian"         : byol_jac,
    "SimCLR_Jacobian"       : simclr_jac,
    "JacReg_Jacobian"       : jacreg_jac,

    # Augmentation invariance
    "BYOL_Aug"              : byol_aug,
    "SimCLR_Aug"            : simclr_aug,
    "JacReg_Aug"            : jacreg_aug,

    # Noise robustness
    "BYOL_Noise"            : byol_noise,
    "SimCLR_Noise"          : simclr_noise,
    "JacReg_Noise"          : jacreg_noise,

    # Timing
    "BYOL_Time_Min"         : sum(byol_epoch_times) / 60,
    "SimCLR_Time_Min"       : sum(simclr_epoch_times) / 60,
    "JacReg_Time_Min"       : jacreg_time,

    "BYOL_AvgEpochSec"      : np.mean(byol_epoch_times),
    "SimCLR_AvgEpochSec"    : np.mean(simclr_epoch_times),
    "JacReg_AvgEpochSec"    : np.mean(jacreg_epoch_times),
}

# ── Merge with any previously saved seeds ─────────────────────────────────────
SAVE_PATH = "/kaggle/working/cifar10_results_progress.csv"

if os.path.exists(SAVE_PATH):
    results_df = pd.read_csv(SAVE_PATH)
    # overwrite row if seed already exists, else append
    if seed in results_df["Seed"].values:
        for k, v in seed_row.items():
            results_df.loc[results_df["Seed"] == seed, k] = v
        print(f"  Updated existing row for seed {seed}")
    else:
        results_df = pd.concat(
            [results_df, pd.DataFrame([seed_row])], ignore_index=True)
        print(f"  Appended new row for seed {seed}")
else:
    results_df = pd.DataFrame([seed_row])
    print(f"  Created new results file for seed {seed}")

results_df.to_csv(SAVE_PATH, index=False)
print(f"  Saved → {SAVE_PATH}")

# ── Pretty-print side-by-side comparison ──────────────────────────────────────
METRICS = [
    ("Accuracy",              "BYOL_Acc",       "SimCLR_Acc",       "JacReg_Acc"),
    ("Jacobian Sensitivity",  "BYOL_Jacobian",  "SimCLR_Jacobian",  "JacReg_Jacobian"),
    ("Aug Invariance",        "BYOL_Aug",       "SimCLR_Aug",       "JacReg_Aug"),
    ("Noise Robustness",      "BYOL_Noise",     "SimCLR_Noise",     "JacReg_Noise"),
    ("Train Time (min)",      "BYOL_Time_Min",  "SimCLR_Time_Min",  "JacReg_Time_Min"),
    ("Avg Epoch (sec)",       "BYOL_AvgEpochSec","SimCLR_AvgEpochSec","JacReg_AvgEpochSec"),
]

print("\n" + "=" * 70)
print(f"  SEED {seed} RESULTS  —  BYOL vs SimCLR vs SimCLR+JacReg  (CIFAR-10)")
print("=" * 70)
print(f"  {'Metric':<26}  {'BYOL':>10}  {'SimCLR':>10}  {'JacReg':>10}")
print("  " + "-" * 62)
for label, b_col, s_col, j_col in METRICS:
    b = seed_row[b_col]
    s = seed_row[s_col]
    j = seed_row[j_col]
    print(f"  {label:<26}  {b:>10.4f}  {s:>10.4f}  {j:>10.4f}")
print("=" * 70)

# ── If multiple seeds are done, also print aggregate stats ────────────────────
if len(results_df) > 1:
    print(f"\n  AGGREGATE  ({len(results_df)} seeds completed)")
    print("=" * 70)
    print(f"  {'Metric':<26}  {'BYOL':>10}  {'SimCLR':>10}  {'JacReg':>10}")
    print("  " + "-" * 62)
    for label, b_col, s_col, j_col in METRICS:
        bm = results_df[b_col].mean(); bs = results_df[b_col].std()
        sm = results_df[s_col].mean(); ss = results_df[s_col].std()
        jm = results_df[j_col].mean(); js = results_df[j_col].std()
        print(f"  {label:<26}  "
              f"{bm:>6.4f}±{bs:.3f}  "
              f"{sm:>6.4f}±{ss:.3f}  "
              f"{jm:>6.4f}±{js:.3f}")
    print("=" * 70)

print(f"\n  Seeds completed so far: {sorted(results_df['Seed'].tolist())}")
print(f"  Progress CSV: {SAVE_PATH}")
# Out:
# ============================================================
#   [JacReg] SimCLR + Jacobian Reg  |  Seed: 2
#   lambda_jac = 0.001  |  tau = 1.0
# ============================================================
#   [JacReg] Epoch   1/100 | Loss: 5.7042  (SSL: 5.7011  Jac: 3.0849) | Time: 106.5s | ETA: 175.7 min
#   [JacReg] Epoch   2/100 | Loss: 5.6188  (SSL: 5.6177  Jac: 1.1312) | Time: 103.0s | ETA: 171.1 min
#   [JacReg] Epoch   3/100 | Loss: 5.5954  (SSL: 5.5943  Jac: 1.0871) | Time: 105.3s | ETA: 169.6 min
#   [JacReg] Epoch   4/100 | Loss: 5.5773  (SSL: 5.5762  Jac: 1.1283) | Time: 104.2s | ETA: 167.6 min
#   [JacReg] Epoch   5/100 | Loss: 5.5652  (SSL: 5.5639  Jac: 1.2568) | Time: 102.3s | ETA: 165.1 min
#   [JacReg] Epoch   6/100 | Loss: 5.5561  (SSL: 5.5547  Jac: 1.4205) | Time: 101.9s | ETA: 162.7 min
#   [JacReg] Epoch   7/100 | Loss: 5.5478  (SSL: 5.5462  Jac: 1.6393) | Time: 101.3s | ETA: 160.4 min
#   [JacReg] Epoch   8/100 | Loss: 5.5387  (SSL: 5.5369  Jac: 1.7768) | Time: 101.3s | ETA: 158.3 min
#   [JacReg] Epoch   9/100 | Loss: 5.5323  (SSL: 5.5302  Jac: 2.0924) | Time: 102.1s | ETA: 156.3 min
#   [JacReg] Epoch  10/100 | Loss: 5.5248  (SSL: 5.5223  Jac: 2.4564) | Time: 102.6s | ETA: 154.6 min
#   [JacReg] Epoch  11/100 | Loss: 5.5167  (SSL: 5.5140  Jac: 2.7077) | Time: 104.2s | ETA: 153.0 min
#   [JacReg] Epoch  12/100 | Loss: 5.5100  (SSL: 5.5069  Jac: 3.0701) | Time: 100.8s | ETA: 151.0 min
#   [JacReg] Epoch  13/100 | Loss: 5.5025  (SSL: 5.4990  Jac: 3.5059) | Time: 101.2s | ETA: 149.1 min
#   [JacReg] Epoch  14/100 | Loss: 5.4977  (SSL: 5.4942  Jac: 3.5078) | Time: 101.5s | ETA: 147.2 min
#   [JacReg] Epoch  15/100 | Loss: 5.4918  (SSL: 5.4878  Jac: 4.0098) | Time: 102.1s | ETA: 145.5 min
#   [JacReg] Epoch  16/100 | Loss: 5.4880  (SSL: 5.4836  Jac: 4.3860) | Time: 103.4s | ETA: 143.8 min
#   [JacReg] Epoch  17/100 | Loss: 5.4833  (SSL: 5.4786  Jac: 4.7251) | Time: 104.4s | ETA: 142.2 min
#   [JacReg] Epoch  18/100 | Loss: 5.4777  (SSL: 5.4728  Jac: 4.9110) | Time: 105.3s | ETA: 140.7 min
#   [JacReg] Epoch  19/100 | Loss: 5.4740  (SSL: 5.4687  Jac: 5.3574) | Time: 104.2s | ETA: 139.1 min
#   [JacReg] Epoch  20/100 | Loss: 5.4712  (SSL: 5.4657  Jac: 5.4301) | Time: 102.7s | ETA: 137.4 min
#   [JacReg] Epoch  21/100 | Loss: 5.4690  (SSL: 5.4634  Jac: 5.6660) | Time: 102.4s | ETA: 135.6 min
#   [JacReg] Epoch  22/100 | Loss: 5.4641  (SSL: 5.4580  Jac: 6.0956) | Time: 104.4s | ETA: 134.0 min
#   [JacReg] Epoch  23/100 | Loss: 5.4619  (SSL: 5.4556  Jac: 6.3386) | Time: 105.1s | ETA: 132.4 min
#   [JacReg] Epoch  24/100 | Loss: 5.4595  (SSL: 5.4526  Jac: 6.9092) | Time: 104.0s | ETA: 130.7 min
#   [JacReg] Epoch  25/100 | Loss: 5.4577  (SSL: 5.4506  Jac: 7.1167) | Time: 102.6s | ETA: 128.9 min
#   [JacReg] Epoch  26/100 | Loss: 5.4558  (SSL: 5.4481  Jac: 7.6954) | Time: 102.4s | ETA: 127.2 min
#   [JacReg] Epoch  27/100 | Loss: 5.4533  (SSL: 5.4454  Jac: 7.9388) | Time: 103.4s | ETA: 125.5 min
#   [JacReg] Epoch  28/100 | Loss: 5.4515  (SSL: 5.4433  Jac: 8.1304) | Time: 103.4s | ETA: 123.8 min
#   [JacReg] Epoch  29/100 | Loss: 5.4479  (SSL: 5.4395  Jac: 8.3653) | Time: 103.1s | ETA: 122.0 min
#   [JacReg] Epoch  30/100 | Loss: 5.4467  (SSL: 5.4374  Jac: 9.3514) | Time: 102.6s | ETA: 120.3 min
#   [JacReg] Epoch  31/100 | Loss: 5.4460  (SSL: 5.4370  Jac: 9.0864) | Time: 102.8s | ETA: 118.6 min
#   [JacReg] Epoch  32/100 | Loss: 5.4456  (SSL: 5.4353  Jac: 10.2471) | Time: 102.3s | ETA: 116.8 min
#   [JacReg] Epoch  33/100 | Loss: 5.4425  (SSL: 5.4318  Jac: 10.6390) | Time: 102.8s | ETA: 115.1 min
#   [JacReg] Epoch  34/100 | Loss: 5.4414  (SSL: 5.4301  Jac: 11.2620) | Time: 103.8s | ETA: 113.4 min
#   [JacReg] Epoch  35/100 | Loss: 5.4391  (SSL: 5.4275  Jac: 11.6083) | Time: 102.8s | ETA: 111.7 min
#   [JacReg] Epoch  36/100 | Loss: 5.4381  (SSL: 5.4262  Jac: 11.8409) | Time: 103.7s | ETA: 110.0 min
#   [JacReg] Epoch  37/100 | Loss: 5.4371  (SSL: 5.4250  Jac: 12.0947) | Time: 103.9s | ETA: 108.3 min
#   [JacReg] Epoch  38/100 | Loss: 5.4362  (SSL: 5.4232  Jac: 13.0006) | Time: 102.5s | ETA: 106.5 min
#   [JacReg] Epoch  39/100 | Loss: 5.4347  (SSL: 5.4216  Jac: 13.0828) | Time: 105.0s | ETA: 104.9 min
#   [JacReg] Epoch  40/100 | Loss: 5.4345  (SSL: 5.4206  Jac: 13.9145) | Time: 102.9s | ETA: 103.2 min
#   [JacReg] Epoch  41/100 | Loss: 5.4317  (SSL: 5.4178  Jac: 13.8518) | Time: 102.5s | ETA: 101.4 min
#   [JacReg] Epoch  42/100 | Loss: 5.4306  (SSL: 5.4162  Jac: 14.4698) | Time: 102.0s | ETA: 99.7 min
#   [JacReg] Epoch  43/100 | Loss: 5.4303  (SSL: 5.4153  Jac: 15.0580) | Time: 103.4s | ETA: 98.0 min
#   [JacReg] Epoch  44/100 | Loss: 5.4302  (SSL: 5.4144  Jac: 15.7739) | Time: 102.5s | ETA: 96.2 min
#   [JacReg] Epoch  45/100 | Loss: 5.4301  (SSL: 5.4136  Jac: 16.5026) | Time: 103.1s | ETA: 94.5 min
#   [JacReg] Epoch  46/100 | Loss: 5.4295  (SSL: 5.4127  Jac: 16.8151) | Time: 103.2s | ETA: 92.8 min
#   [JacReg] Epoch  47/100 | Loss: 5.4274  (SSL: 5.4100  Jac: 17.3775) | Time: 102.6s | ETA: 91.1 min
#   [JacReg] Epoch  48/100 | Loss: 5.4294  (SSL: 5.4106  Jac: 18.7566) | Time: 103.5s | ETA: 89.4 min
#   [JacReg] Epoch  49/100 | Loss: 5.4252  (SSL: 5.4066  Jac: 18.6133) | Time: 104.1s | ETA: 87.7 min
#   [JacReg] Epoch  50/100 | Loss: 5.4247  (SSL: 5.4050  Jac: 19.7188) | Time: 103.5s | ETA: 85.9 min
#   [JacReg] Epoch  51/100 | Loss: 5.4243  (SSL: 5.4048  Jac: 19.4973) | Time: 103.4s | ETA: 84.2 min
#   [JacReg] Epoch  52/100 | Loss: 5.4236  (SSL: 5.4034  Jac: 20.2001) | Time: 104.3s | ETA: 82.5 min
#   [JacReg] Epoch  53/100 | Loss: 5.4223  (SSL: 5.4017  Jac: 20.6133) | Time: 103.7s | ETA: 80.8 min
#   [JacReg] Epoch  54/100 | Loss: 5.4223  (SSL: 5.4011  Jac: 21.1668) | Time: 102.5s | ETA: 79.1 min
#   [JacReg] Epoch  55/100 | Loss: 5.4212  (SSL: 5.3991  Jac: 22.0631) | Time: 102.1s | ETA: 77.4 min
#   [JacReg] Epoch  56/100 | Loss: 5.4219  (SSL: 5.3993  Jac: 22.6375) | Time: 102.7s | ETA: 75.6 min
#   [JacReg] Epoch  57/100 | Loss: 5.4224  (SSL: 5.3980  Jac: 24.4555) | Time: 104.4s | ETA: 73.9 min
#   [JacReg] Epoch  58/100 | Loss: 5.4206  (SSL: 5.3964  Jac: 24.2321) | Time: 102.9s | ETA: 72.2 min
#   [JacReg] Epoch  59/100 | Loss: 5.4218  (SSL: 5.3959  Jac: 25.8887) | Time: 103.6s | ETA: 70.5 min
#   [JacReg] Epoch  60/100 | Loss: 5.4205  (SSL: 5.3950  Jac: 25.4948) | Time: 102.9s | ETA: 68.8 min
#   [JacReg] Epoch  61/100 | Loss: 5.4188  (SSL: 5.3930  Jac: 25.8347) | Time: 103.3s | ETA: 67.0 min
#   [JacReg] Epoch  62/100 | Loss: 5.4200  (SSL: 5.3933  Jac: 26.6953) | Time: 103.7s | ETA: 65.3 min
#   [JacReg] Epoch  63/100 | Loss: 5.4179  (SSL: 5.3908  Jac: 27.1286) | Time: 103.0s | ETA: 63.6 min
#   [JacReg] Epoch  64/100 | Loss: 5.4195  (SSL: 5.3909  Jac: 28.6042) | Time: 103.3s | ETA: 61.9 min
#   [JacReg] Epoch  65/100 | Loss: 5.4185  (SSL: 5.3890  Jac: 29.4758) | Time: 103.2s | ETA: 60.2 min
#   [JacReg] Epoch  66/100 | Loss: 5.4197  (SSL: 5.3893  Jac: 30.4084) | Time: 103.0s | ETA: 58.5 min
#   [JacReg] Epoch  67/100 | Loss: 5.4193  (SSL: 5.3882  Jac: 31.0944) | Time: 104.2s | ETA: 56.7 min
#   [JacReg] Epoch  68/100 | Loss: 5.4176  (SSL: 5.3864  Jac: 31.1986) | Time: 103.6s | ETA: 55.0 min
#   [JacReg] Epoch  69/100 | Loss: 5.4182  (SSL: 5.3860  Jac: 32.2499) | Time: 102.5s | ETA: 53.3 min
#   [JacReg] Epoch  70/100 | Loss: 5.4184  (SSL: 5.3851  Jac: 33.2721) | Time: 102.7s | ETA: 51.6 min
#   [JacReg] Epoch  71/100 | Loss: 5.4206  (SSL: 5.3863  Jac: 34.2888) | Time: 103.9s | ETA: 49.9 min
#   [JacReg] Epoch  72/100 | Loss: 5.4195  (SSL: 5.3841  Jac: 35.3801) | Time: 103.5s | ETA: 48.2 min
#   [JacReg] Epoch  73/100 | Loss: 5.4179  (SSL: 5.3828  Jac: 35.0726) | Time: 103.5s | ETA: 46.4 min
#   [JacReg] Epoch  74/100 | Loss: 5.4208  (SSL: 5.3832  Jac: 37.5313) | Time: 103.7s | ETA: 44.7 min
#   [JacReg] Epoch  75/100 | Loss: 5.4185  (SSL: 5.3814  Jac: 37.1409) | Time: 104.5s | ETA: 43.0 min
#   [JacReg] Epoch  76/100 | Loss: 5.4199  (SSL: 5.3813  Jac: 38.6789) | Time: 103.1s | ETA: 41.3 min
#   [JacReg] Epoch  77/100 | Loss: 5.4188  (SSL: 5.3803  Jac: 38.5001) | Time: 103.7s | ETA: 39.6 min
#   [JacReg] Epoch  78/100 | Loss: 5.4181  (SSL: 5.3786  Jac: 39.5413) | Time: 103.0s | ETA: 37.8 min
#   [JacReg] Epoch  79/100 | Loss: 5.4162  (SSL: 5.3784  Jac: 37.8504) | Time: 101.4s | ETA: 36.1 min
#   [JacReg] Epoch  80/100 | Loss: 5.4174  (SSL: 5.3778  Jac: 39.6277) | Time: 102.1s | ETA: 34.4 min
#   [JacReg] Epoch  81/100 | Loss: 5.4185  (SSL: 5.3771  Jac: 41.3989) | Time: 102.3s | ETA: 32.7 min
#   [JacReg] Epoch  82/100 | Loss: 5.4201  (SSL: 5.3780  Jac: 42.1018) | Time: 103.5s | ETA: 31.0 min
#   [JacReg] Epoch  83/100 | Loss: 5.4194  (SSL: 5.3765  Jac: 42.9244) | Time: 102.5s | ETA: 29.2 min
#   [JacReg] Epoch  84/100 | Loss: 5.4190  (SSL: 5.3768  Jac: 42.2317) | Time: 102.1s | ETA: 27.5 min
#   [JacReg] Epoch  85/100 | Loss: 5.4159  (SSL: 5.3759  Jac: 40.0718) | Time: 102.3s | ETA: 25.8 min
#   [JacReg] Epoch  86/100 | Loss: 5.4179  (SSL: 5.3752  Jac: 42.7775) | Time: 102.6s | ETA: 24.1 min
#   [JacReg] Epoch  87/100 | Loss: 5.4188  (SSL: 5.3759  Jac: 42.9360) | Time: 102.8s | ETA: 22.3 min
#   [JacReg] Epoch  88/100 | Loss: 5.4190  (SSL: 5.3753  Jac: 43.7002) | Time: 102.8s | ETA: 20.6 min
#   [JacReg] Epoch  89/100 | Loss: 5.4188  (SSL: 5.3746  Jac: 44.2197) | Time: 102.1s | ETA: 18.9 min
#   [JacReg] Epoch  90/100 | Loss: 5.4189  (SSL: 5.3738  Jac: 45.1164) | Time: 103.0s | ETA: 17.2 min
#   [JacReg] Epoch  91/100 | Loss: 5.4180  (SSL: 5.3735  Jac: 44.4640) | Time: 102.9s | ETA: 15.5 min
#   [JacReg] Epoch  92/100 | Loss: 5.4180  (SSL: 5.3740  Jac: 44.0226) | Time: 102.8s | ETA: 13.7 min
#   [JacReg] Epoch  93/100 | Loss: 5.4187  (SSL: 5.3737  Jac: 45.0597) | Time: 102.6s | ETA: 12.0 min
#   [JacReg] Epoch  94/100 | Loss: 5.4170  (SSL: 5.3727  Jac: 44.2887) | Time: 102.4s | ETA: 10.3 min
#   [JacReg] Epoch  95/100 | Loss: 5.4175  (SSL: 5.3717  Jac: 45.7499) | Time: 103.2s | ETA: 8.6 min
#   [JacReg] Epoch  96/100 | Loss: 5.4181  (SSL: 5.3728  Jac: 45.3459) | Time: 102.8s | ETA: 6.9 min
#   [JacReg] Epoch  97/100 | Loss: 5.4180  (SSL: 5.3726  Jac: 45.4387) | Time: 102.9s | ETA: 5.2 min
#   [JacReg] Epoch  98/100 | Loss: 5.4196  (SSL: 5.3731  Jac: 46.4637) | Time: 101.3s | ETA: 3.4 min
#   [JacReg] Epoch  99/100 | Loss: 5.4189  (SSL: 5.3730  Jac: 45.8409) | Time: 101.9s | ETA: 1.7 min
#   [JacReg] Epoch 100/100 | Loss: 5.4179  (SSL: 5.3727  Jac: 45.2218) | Time: 102.4s | ETA: 0.0 min
#
# [JacReg] Running linear probe...
# [JacReg] Computing geometry metrics...
#
#   [JacReg] Seed 2 done in 177.10 min
#   JacReg → Acc: 0.7644  | Jac: 5.5409
#   Created new results file for seed 2
#   Saved → /kaggle/working/cifar10_results_progress.csv
#
# ======================================================================
#   SEED 2 RESULTS  —  BYOL vs SimCLR vs SimCLR+JacReg  (CIFAR-10)
# ======================================================================
#   Metric                            BYOL      SimCLR      JacReg
#   --------------------------------------------------------------
#   Accuracy                        0.4784      0.7636      0.7644
#   Jacobian Sensitivity            1.1781      5.9114      5.5409
#   Aug Invariance                  2.5847      7.0848      6.5294
#   Noise Robustness                0.1190      0.7717      0.7411
#   Train Time (min)              167.0294    158.5305    177.1030
#   Avg Epoch (sec)               100.2177     95.1183    103.0504
# ======================================================================
#
#   Seeds completed so far: [2]
#   Progress CSV: /kaggle/working/cifar10_results_progress.csv
