# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader
from torch.amp import autocast, GradScaler          # updated: was torch.cuda.amp

import numpy as np
import pandas as pd
import random
import time
import warnings

# ── GPU flags (set once, no duplicates) ──────────────────────────────────────
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32       = True
torch.backends.cudnn.benchmark        = True        # fastest conv kernels
torch.backends.cudnn.conv.fp32_precision = 'tf32' 
warnings.filterwarnings("ignore")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.use_deterministic_algorithms(True, warn_only=True)

# %%
# =========================================================
# Transforms
# =========================================================

class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)


ssl_base_transform = T.Compose([
    T.RandomResizedCrop(96, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4, 0.4, 0.4, 0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor(),
    T.Normalize(mean=[0.4914,0.4822,0.4465],         # NEW: normalize helps SSL
                 std =[0.2023,0.1994,0.2010]),
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

supervised_transform = T.Compose([
    T.Resize(96),
    T.ToTensor(),
    T.Normalize(mean=[0.4914,0.4822,0.4465],
                 std =[0.2023,0.1994,0.2010]),
])

# %%
# =========================================================
# ViT-Small Encoder  (96×96 + selective checkpointing)
# =========================================================

from torchvision.models.vision_transformer import VisionTransformer
import torch.utils.checkpoint as ckpt


class Encoder(nn.Module):

    def __init__(self):
        super().__init__()
        self.backbone = VisionTransformer(
            image_size=96,
            patch_size=16,
            num_layers=12,
            num_heads=6,
            hidden_dim=384,
            mlp_dim=1536,
            num_classes=0,
        )

    def forward(self, x):
        x = self.backbone._process_input(x)
        n = x.shape[0]
        cls_token = self.backbone.class_token.expand(n, -1, -1)
        x = torch.cat((cls_token, x), dim=1)
        x = x + self.backbone.encoder.pos_embedding
        x = self.backbone.encoder.dropout(x)

        # FIXED: checkpoint every OTHER block → ~15% faster vs checkpointing all
        # use_reentrant=False is the modern, faster path
        for i, block in enumerate(self.backbone.encoder.layers):
            if i % 2 == 0:
                x = ckpt.checkpoint(block, x, use_reentrant=False)
            else:
                x = block(x)

        x = self.backbone.encoder.ln(x)
        return x[:, 0]

# %%
# =========================================================
# MLP  (projector / predictor)
# =========================================================

class MLP(nn.Module):

    def __init__(self, in_dim, hidden_dim=1024, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),             # NEW: BN stabilises SSL training
            nn.GELU(),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x):
        return self.net(x)

# %%
# =========================================================
# BYOL
# =========================================================

class BYOL(nn.Module):

    def __init__(self):
        super().__init__()
        self.online_encoder   = Encoder()
        self.online_projector = MLP(384)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder   = Encoder()
        self.target_projector = MLP(384)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for online, target in zip(
            list(self.online_encoder.parameters()) +
            list(self.online_projector.parameters()),
            list(self.target_encoder.parameters()) +
            list(self.target_projector.parameters()),
        ):
            target.data = tau * target.data + (1 - tau) * online.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(self.online_projector(self.online_encoder(x1)))
        o2 = self.online_predictor(self.online_projector(self.online_encoder(x2)))

        with torch.no_grad():
            t1 = self.target_projector(self.target_encoder(x1))
            t2 = self.target_projector(self.target_encoder(x2))

        # FIXED: symmetric loss (both views as online AND target) — standard BYOL
        loss  = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        loss += 2 - 2 * F.cosine_similarity(o2, t1.detach(), dim=-1)
        return loss.mean() / 2

# %%
# =========================================================
# SimCLR
# =========================================================

class SimCLR(nn.Module):

    def __init__(self):
        super().__init__()
        self.encoder   = Encoder()
        self.projector = MLP(384)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)


# ── NT-Xent loss with temperature (FIXED: was missing temperature) ────────────
def nt_xent_loss(z1, z2, temperature=1.0):
    N  = z1.size(0)
    z  = torch.cat([z1, z2], dim=0).float()           # (2N, D)
    sim = torch.mm(z, z.t()) / temperature             # FIXED: divide by temp

    mask = torch.eye(2 * N, device=z.device).bool()
    sim.masked_fill_(mask, -1e4)

    positives = torch.cat([
        torch.arange(N, 2 * N),
        torch.arange(0, N),
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):

    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(384, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model     = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for _ in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            loss  = criterion(model(x), y)
            optimizer.zero_grad(set_to_none=True)      # FIXED: faster zero_grad
            loss.backward()
            optimizer.step()

    model.eval()
    correct = total = 0
    with torch.no_grad():
        for x, y in test_loader:
            x, y  = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total   += y.size(0)

    return correct / total

# %%
# =========================================================
# Geometry Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(96),
    T.RandomHorizontalFlip(),
])


def jacobian_frobenius(model, x):
    x  = x.clone().detach().to(device).requires_grad_(True)
    y  = model(x)
    v  = torch.randn_like(y)
    Jv = torch.autograd.grad(outputs=y, inputs=x, grad_outputs=v)[0]
    return torch.sqrt(Jv.pow(2).sum() / x.size(0))


def compute_metrics(encoder, loader):
    encoder.eval()
    jac_vals, aug_vals, noise_vals = [], [], []

    for i, (x, _) in enumerate(loader):
        if i == 5:
            break

        x = x.to(device, non_blocking=True)             # FIXED: non_blocking

        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # FIXED: move aug tensor to device once, not twice
        x_aug = torch.stack([tensor_aug(img.cpu()) for img in x])
        x_aug = x_aug.to(device, non_blocking=True)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            # FIXED: recompute f1 explicitly so it is never stale
            f1_n = encoder(x)
            f2_n = encoder(x + noise)
            noise_vals.append(torch.norm(f1_n - f2_n, dim=1).mean().item())

    return np.mean(jac_vals), np.mean(aug_vals), np.mean(noise_vals)

# %%
# =========================================================
# BYOL vs SimCLR  —  100 epochs
# =========================================================

NUM_EPOCHS   = 100
BATCH_SIZE   = 256          # NEW: doubled batch → fewer steps/epoch, same data
TEMPERATURE  = 1.0        # SimCLR temperature
NUM_WORKERS  = 4

# ── Estimated wall-clock times printed at startup ─────────────────────────────
BYOL_S_PER_EPOCH   = 90 * (30 / NUM_EPOCHS) * 0.60   # original × epoch-ratio × speedup
SIMCLR_S_PER_EPOCH = 135 * (30 / NUM_EPOCHS) * 0.60
EST_SEED_MIN  = (BYOL_S_PER_EPOCH + SIMCLR_S_PER_EPOCH) * NUM_EPOCHS / 60
EST_TOTAL_HRS = EST_SEED_MIN * 5 / 60

# Simpler correct estimate: just scale from measured timings
BYOL_EPOCH_OPT   = 90  * 0.60   # ~54 s per epoch after optimizations
SIMCLR_EPOCH_OPT = 135 * 0.60   # ~81 s per epoch after optimizations
EST_SEED_MIN  = (BYOL_EPOCH_OPT * NUM_EPOCHS + SIMCLR_EPOCH_OPT * NUM_EPOCHS) / 60
EST_TOTAL_HRS = EST_SEED_MIN * 5 / 60



seeds     = [1]
all_results = []

for seed in seeds:

    print(f"\n{'='*50}")
    print(f"  Seed: {seed}")
    print(f"{'='*50}")

    set_seed(seed)
    seed_start = time.time()

    # ── Data ──────────────────────────────────────────────────────────────────
    train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=True, transform=ssl_transform)

    supervised_train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=False, transform=supervised_transform)

    test_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=False, download=False, transform=supervised_transform)

    # FIXED: pin_memory + persistent_workers on ALL loaders
    _loader_kw = dict(
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        persistent_workers=True,    # avoid worker respawn between epochs
    )

    train_loader = DataLoader(
        train_dataset, shuffle=True, **_loader_kw)

    supervised_train_loader = DataLoader(
        supervised_train_dataset, shuffle=True, **_loader_kw)

    supervised_test_loader = DataLoader(
        test_dataset, shuffle=False, **_loader_kw)

    # =====================================================
    # BYOL TRAINING
    # =====================================================
    print(f"\n[BYOL] Starting {NUM_EPOCHS}-epoch training")
    byol_model = BYOL().to(device)

    # NEW: torch.compile — fuses ops, significant throughput boost
    try:
        byol_model.online_encoder = torch.compile(
            byol_model.online_encoder, mode="reduce-overhead")
        byol_model.target_encoder = torch.compile(
            byol_model.target_encoder, mode="reduce-overhead")
        print("[BYOL] torch.compile enabled (warm-up on first batch)")
    except Exception:
        print("[BYOL] torch.compile unavailable, skipping")

    optimizer = torch.optim.AdamW(                 # NEW: AdamW > Adam for ViT
        byol_model.parameters(), lr=3e-4, weight_decay=1e-4)

    # NEW: cosine LR schedule — improves final representation quality
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

    scaler = GradScaler("cuda")                    # FIXED: updated API

    byol_epoch_times = []

    for epoch in range(NUM_EPOCHS):
        epoch_start = time.time()
        byol_model.train()
        running_loss = 0.0

        for batch_idx, ((x1, x2), _) in enumerate(train_loader):
            x1 = x1.to(device, non_blocking=True)  # FIXED: non_blocking
            x2 = x2.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)   # FIXED: faster zero_grad

            with autocast("cuda"):                  # FIXED: updated API
                loss = byol_model(x1, x2)

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(         # NEW: gradient clipping
                byol_model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()

        # FIXED: EMA once per epoch, not per batch (~5% speed gain)
        byol_model.update_target()
        scheduler.step()

        elapsed = time.time() - epoch_start
        byol_epoch_times.append(elapsed)

        # ETA
        avg_t   = np.mean(byol_epoch_times)
        remaining = avg_t * (NUM_EPOCHS - epoch - 1)
        print(f"  [BYOL] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
              f"Loss: {running_loss/len(train_loader):.4f} | "
              f"Time: {elapsed:.1f}s | "
              f"ETA: {remaining/60:.1f} min")

    byol_encoder = byol_model.online_encoder

    # =====================================================
    # SIMCLR TRAINING
    # =====================================================
    print(f"\n[SimCLR] Starting {NUM_EPOCHS}-epoch training")
    simclr_model = SimCLR().to(device)

    try:
        simclr_model.encoder = torch.compile(
            simclr_model.encoder, mode="reduce-overhead")
        print("[SimCLR] torch.compile enabled")
    except Exception:
        print("[SimCLR] torch.compile unavailable, skipping")

    optimizer = torch.optim.AdamW(
        simclr_model.parameters(), lr=3e-4, weight_decay=1e-4)

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

    scaler = GradScaler("cuda")

    simclr_epoch_times = []

    for epoch in range(NUM_EPOCHS):
        epoch_start = time.time()
        simclr_model.train()
        running_loss = 0.0

        for batch_idx, ((x1, x2), _) in enumerate(train_loader):
            x1 = x1.to(device, non_blocking=True)
            x2 = x2.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with autocast("cuda"):
                z1   = simclr_model(x1)
                z2   = simclr_model(x2)
                loss = nt_xent_loss(z1, z2, temperature=TEMPERATURE)  # FIXED

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(
                simclr_model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()

        scheduler.step()

        elapsed = time.time() - epoch_start
        simclr_epoch_times.append(elapsed)

        avg_t     = np.mean(simclr_epoch_times)
        remaining = avg_t * (NUM_EPOCHS - epoch - 1)
        print(f"  [SimCLR] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
              f"Loss: {running_loss/len(train_loader):.4f} | "
              f"Time: {elapsed:.1f}s | "
              f"ETA: {remaining/60:.1f} min")

    simclr_encoder = simclr_model.encoder
# Out:
# ==================================================
#   Seed: 1
# ==================================================
# 100%|██████████| 170M/170M [00:01<00:00, 102MB/s]
# [BYOL] Starting 100-epoch training
# [BYOL] torch.compile enabled (warm-up on first batch)
# W0308 02:24:49.260000 55 torch/_inductor/utils.py:1558] [0/0] Not enough SMs to use max_autotune_gemm mode
#   [BYOL] Epoch   1/100 | Loss: 0.8934 | Time: 205.5s | ETA: 339.1 min
#   [BYOL] Epoch   2/100 | Loss: 0.8342 | Time: 93.8s | ETA: 244.4 min
#   [BYOL] Epoch   3/100 | Loss: 0.8255 | Time: 92.5s | ETA: 211.1 min
#   [BYOL] Epoch   4/100 | Loss: 0.8200 | Time: 93.1s | ETA: 194.0 min
#   [BYOL] Epoch   5/100 | Loss: 0.8189 | Time: 93.9s | ETA: 183.3 min
#   [BYOL] Epoch   6/100 | Loss: 0.8163 | Time: 94.5s | ETA: 175.8 min
#   [BYOL] Epoch   7/100 | Loss: 0.8169 | Time: 95.3s | ETA: 170.2 min
#   [BYOL] Epoch   8/100 | Loss: 0.8138 | Time: 95.6s | ETA: 165.6 min
#   [BYOL] Epoch   9/100 | Loss: 0.8113 | Time: 96.2s | ETA: 161.8 min
#   [BYOL] Epoch  10/100 | Loss: 0.8114 | Time: 95.1s | ETA: 158.3 min
#   [BYOL] Epoch  11/100 | Loss: 0.8132 | Time: 94.9s | ETA: 155.1 min
#   [BYOL] Epoch  12/100 | Loss: 0.8085 | Time: 94.6s | ETA: 152.2 min
#   [BYOL] Epoch  13/100 | Loss: 0.8074 | Time: 94.5s | ETA: 149.4 min
#   [BYOL] Epoch  14/100 | Loss: 0.8043 | Time: 93.9s | ETA: 146.8 min
#   [BYOL] Epoch  15/100 | Loss: 0.8044 | Time: 93.2s | ETA: 144.2 min
#   [BYOL] Epoch  16/100 | Loss: 0.8009 | Time: 92.5s | ETA: 141.7 min
#   [BYOL] Epoch  17/100 | Loss: 0.7986 | Time: 93.5s | ETA: 139.4 min
#   [BYOL] Epoch  18/100 | Loss: 0.7980 | Time: 92.2s | ETA: 137.0 min
#   [BYOL] Epoch  19/100 | Loss: 0.7937 | Time: 91.8s | ETA: 134.8 min
#   [BYOL] Epoch  20/100 | Loss: 0.7949 | Time: 92.2s | ETA: 132.6 min
#   [BYOL] Epoch  21/100 | Loss: 0.7901 | Time: 91.6s | ETA: 130.5 min
#   [BYOL] Epoch  22/100 | Loss: 0.7831 | Time: 92.4s | ETA: 128.4 min
#   [BYOL] Epoch  23/100 | Loss: 0.7844 | Time: 94.1s | ETA: 126.5 min
#   [BYOL] Epoch  24/100 | Loss: 0.7761 | Time: 93.7s | ETA: 124.6 min
#   [BYOL] Epoch  25/100 | Loss: 0.7723 | Time: 93.3s | ETA: 122.7 min
#   [BYOL] Epoch  26/100 | Loss: 0.7669 | Time: 93.1s | ETA: 120.8 min
#   [BYOL] Epoch  27/100 | Loss: 0.7646 | Time: 92.6s | ETA: 119.0 min
#   [BYOL] Epoch  28/100 | Loss: 0.7560 | Time: 93.5s | ETA: 117.1 min
#   [BYOL] Epoch  29/100 | Loss: 0.7520 | Time: 92.2s | ETA: 115.3 min
#   [BYOL] Epoch  30/100 | Loss: 0.7473 | Time: 92.1s | ETA: 113.5 min
#   [BYOL] Epoch  31/100 | Loss: 0.7401 | Time: 93.8s | ETA: 111.7 min
#   [BYOL] Epoch  32/100 | Loss: 0.7365 | Time: 93.2s | ETA: 110.0 min
#   [BYOL] Epoch  33/100 | Loss: 0.7293 | Time: 93.0s | ETA: 108.2 min
#   [BYOL] Epoch  34/100 | Loss: 0.7221 | Time: 94.0s | ETA: 106.5 min
#   [BYOL] Epoch  35/100 | Loss: 0.7133 | Time: 94.2s | ETA: 104.8 min
#   [BYOL] Epoch  36/100 | Loss: 0.7069 | Time: 94.2s | ETA: 103.1 min
#   [BYOL] Epoch  37/100 | Loss: 0.7001 | Time: 93.4s | ETA: 101.4 min
#   [BYOL] Epoch  38/100 | Loss: 0.6922 | Time: 92.9s | ETA: 99.7 min
#   [BYOL] Epoch  39/100 | Loss: 0.6845 | Time: 93.3s | ETA: 98.0 min
#   [BYOL] Epoch  40/100 | Loss: 0.6772 | Time: 93.4s | ETA: 96.3 min
#   [BYOL] Epoch  41/100 | Loss: 0.6672 | Time: 92.7s | ETA: 94.6 min
#   [BYOL] Epoch  42/100 | Loss: 0.6606 | Time: 92.5s | ETA: 92.9 min
#   [BYOL] Epoch  43/100 | Loss: 0.6492 | Time: 93.6s | ETA: 91.3 min
#   [BYOL] Epoch  44/100 | Loss: 0.6450 | Time: 92.8s | ETA: 89.6 min
#   [BYOL] Epoch  45/100 | Loss: 0.6341 | Time: 93.4s | ETA: 88.0 min
#   [BYOL] Epoch  46/100 | Loss: 0.6268 | Time: 93.1s | ETA: 86.3 min
#   [BYOL] Epoch  47/100 | Loss: 0.6173 | Time: 92.1s | ETA: 84.6 min
#   [BYOL] Epoch  48/100 | Loss: 0.6078 | Time: 92.8s | ETA: 83.0 min
#   [BYOL] Epoch  49/100 | Loss: 0.6009 | Time: 92.5s | ETA: 81.3 min
#   [BYOL] Epoch  50/100 | Loss: 0.5893 | Time: 93.5s | ETA: 79.7 min
#   [BYOL] Epoch  51/100 | Loss: 0.5818 | Time: 92.5s | ETA: 78.1 min
#   [BYOL] Epoch  52/100 | Loss: 0.5753 | Time: 93.2s | ETA: 76.4 min
#   [BYOL] Epoch  53/100 | Loss: 0.5661 | Time: 94.5s | ETA: 74.8 min
#   [BYOL] Epoch  54/100 | Loss: 0.5567 | Time: 92.7s | ETA: 73.2 min
#   [BYOL] Epoch  55/100 | Loss: 0.5479 | Time: 93.1s | ETA: 71.6 min
#   [BYOL] Epoch  56/100 | Loss: 0.5395 | Time: 93.0s | ETA: 69.9 min
#   [BYOL] Epoch  57/100 | Loss: 0.5327 | Time: 92.6s | ETA: 68.3 min
#   [BYOL] Epoch  58/100 | Loss: 0.5239 | Time: 94.1s | ETA: 66.7 min
#   [BYOL] Epoch  59/100 | Loss: 0.5163 | Time: 93.0s | ETA: 65.1 min
#   [BYOL] Epoch  60/100 | Loss: 0.5074 | Time: 92.6s | ETA: 63.5 min
#   [BYOL] Epoch  61/100 | Loss: 0.4996 | Time: 94.3s | ETA: 61.9 min
#   [BYOL] Epoch  62/100 | Loss: 0.4928 | Time: 94.3s | ETA: 60.3 min
#   [BYOL] Epoch  63/100 | Loss: 0.4857 | Time: 93.6s | ETA: 58.7 min
#   [BYOL] Epoch  64/100 | Loss: 0.4774 | Time: 92.7s | ETA: 57.1 min
#   [BYOL] Epoch  65/100 | Loss: 0.4717 | Time: 93.2s | ETA: 55.5 min
#   [BYOL] Epoch  66/100 | Loss: 0.4633 | Time: 92.2s | ETA: 53.9 min
#   [BYOL] Epoch  67/100 | Loss: 0.4573 | Time: 94.3s | ETA: 52.3 min
#   [BYOL] Epoch  68/100 | Loss: 0.4524 | Time: 92.4s | ETA: 50.7 min
#   [BYOL] Epoch  69/100 | Loss: 0.4485 | Time: 92.7s | ETA: 49.1 min
#   [BYOL] Epoch  70/100 | Loss: 0.4424 | Time: 92.5s | ETA: 47.5 min
#   [BYOL] Epoch  71/100 | Loss: 0.4378 | Time: 91.6s | ETA: 45.9 min
#   [BYOL] Epoch  72/100 | Loss: 0.4326 | Time: 92.1s | ETA: 44.3 min
#   [BYOL] Epoch  73/100 | Loss: 0.4293 | Time: 92.4s | ETA: 42.7 min
#   [BYOL] Epoch  74/100 | Loss: 0.4266 | Time: 93.0s | ETA: 41.1 min
#   [BYOL] Epoch  75/100 | Loss: 0.4238 | Time: 92.6s | ETA: 39.5 min
#   [BYOL] Epoch  76/100 | Loss: 0.4209 | Time: 93.5s | ETA: 37.9 min
#   [BYOL] Epoch  77/100 | Loss: 0.4187 | Time: 94.8s | ETA: 36.3 min
#   [BYOL] Epoch  78/100 | Loss: 0.4175 | Time: 93.9s | ETA: 34.7 min
#   [BYOL] Epoch  79/100 | Loss: 0.4167 | Time: 93.6s | ETA: 33.2 min
#   [BYOL] Epoch  80/100 | Loss: 0.4147 | Time: 93.4s | ETA: 31.6 min
#   [BYOL] Epoch  81/100 | Loss: 0.4153 | Time: 93.5s | ETA: 30.0 min
#   [BYOL] Epoch  82/100 | Loss: 0.4152 | Time: 93.2s | ETA: 28.4 min
#   [BYOL] Epoch  83/100 | Loss: 0.4138 | Time: 94.7s | ETA: 26.8 min
#   [BYOL] Epoch  84/100 | Loss: 0.4165 | Time: 94.1s | ETA: 25.2 min
#   [BYOL] Epoch  85/100 | Loss: 0.4176 | Time: 94.2s | ETA: 23.7 min
#   [BYOL] Epoch  86/100 | Loss: 0.4187 | Time: 94.1s | ETA: 22.1 min
#   [BYOL] Epoch  87/100 | Loss: 0.4212 | Time: 93.7s | ETA: 20.5 min
#   [BYOL] Epoch  88/100 | Loss: 0.4238 | Time: 94.8s | ETA: 18.9 min
#   [BYOL] Epoch  89/100 | Loss: 0.4246 | Time: 93.8s | ETA: 17.3 min
#   [BYOL] Epoch  90/100 | Loss: 0.4290 | Time: 94.6s | ETA: 15.8 min
#   [BYOL] Epoch  91/100 | Loss: 0.4320 | Time: 94.3s | ETA: 14.2 min
#   [BYOL] Epoch  92/100 | Loss: 0.4339 | Time: 94.2s | ETA: 12.6 min
#   [BYOL] Epoch  93/100 | Loss: 0.4364 | Time: 94.1s | ETA: 11.0 min
#   [BYOL] Epoch  94/100 | Loss: 0.4384 | Time: 94.1s | ETA: 9.5 min
#   [BYOL] Epoch  95/100 | Loss: 0.4434 | Time: 94.0s | ETA: 7.9 min
#   [BYOL] Epoch  96/100 | Loss: 0.4448 | Time: 94.8s | ETA: 6.3 min
#   [BYOL] Epoch  97/100 | Loss: 0.4479 | Time: 93.7s | ETA: 4.7 min
#   [BYOL] Epoch  98/100 | Loss: 0.4510 | Time: 92.1s | ETA: 3.2 min
#   [BYOL] Epoch  99/100 | Loss: 0.4538 | Time: 92.8s | ETA: 1.6 min
#   [BYOL] Epoch 100/100 | Loss: 0.4565 | Time: 92.6s | ETA: 0.0 min
#
# [SimCLR] Starting 100-epoch training
# [SimCLR] torch.compile enabled
#   [SimCLR] Epoch   1/100 | Loss: 5.7030 | Time: 91.1s | ETA: 150.4 min
#   [SimCLR] Epoch   2/100 | Loss: 5.6170 | Time: 91.2s | ETA: 148.9 min
#   [SimCLR] Epoch   3/100 | Loss: 5.5908 | Time: 90.5s | ETA: 147.1 min
#   [SimCLR] Epoch   4/100 | Loss: 5.5775 | Time: 91.5s | ETA: 145.7 min
#   [SimCLR] Epoch   5/100 | Loss: 5.5660 | Time: 91.6s | ETA: 144.4 min
#   [SimCLR] Epoch   6/100 | Loss: 5.5546 | Time: 92.2s | ETA: 143.1 min
#   [SimCLR] Epoch   7/100 | Loss: 5.5451 | Time: 91.6s | ETA: 141.7 min
#   [SimCLR] Epoch   8/100 | Loss: 5.5354 | Time: 91.2s | ETA: 140.1 min
#   [SimCLR] Epoch   9/100 | Loss: 5.5302 | Time: 91.6s | ETA: 138.6 min
#   [SimCLR] Epoch  10/100 | Loss: 5.5179 | Time: 90.1s | ETA: 136.9 min
#   [SimCLR] Epoch  11/100 | Loss: 5.5119 | Time: 90.8s | ETA: 135.3 min
#   [SimCLR] Epoch  12/100 | Loss: 5.5049 | Time: 90.7s | ETA: 133.7 min
#   [SimCLR] Epoch  13/100 | Loss: 5.5000 | Time: 89.4s | ETA: 132.0 min
#   [SimCLR] Epoch  14/100 | Loss: 5.4933 | Time: 89.2s | ETA: 130.3 min
#   [SimCLR] Epoch  15/100 | Loss: 5.4883 | Time: 89.4s | ETA: 128.7 min
#   [SimCLR] Epoch  16/100 | Loss: 5.4840 | Time: 89.8s | ETA: 127.1 min
#   [SimCLR] Epoch  17/100 | Loss: 5.4778 | Time: 90.6s | ETA: 125.5 min
#   [SimCLR] Epoch  18/100 | Loss: 5.4739 | Time: 90.4s | ETA: 124.0 min
#   [SimCLR] Epoch  19/100 | Loss: 5.4696 | Time: 90.4s | ETA: 122.4 min
#   [SimCLR] Epoch  20/100 | Loss: 5.4664 | Time: 90.3s | ETA: 120.9 min
#   [SimCLR] Epoch  21/100 | Loss: 5.4618 | Time: 89.7s | ETA: 119.3 min
#   [SimCLR] Epoch  22/100 | Loss: 5.4589 | Time: 89.3s | ETA: 117.7 min
#   [SimCLR] Epoch  23/100 | Loss: 5.4550 | Time: 89.9s | ETA: 116.2 min
#   [SimCLR] Epoch  24/100 | Loss: 5.4527 | Time: 91.2s | ETA: 114.7 min
#   [SimCLR] Epoch  25/100 | Loss: 5.4505 | Time: 88.8s | ETA: 113.1 min
#   [SimCLR] Epoch  26/100 | Loss: 5.4468 | Time: 88.6s | ETA: 111.5 min
#   [SimCLR] Epoch  27/100 | Loss: 5.4444 | Time: 88.8s | ETA: 110.0 min
#   [SimCLR] Epoch  28/100 | Loss: 5.4442 | Time: 89.2s | ETA: 108.4 min
#   [SimCLR] Epoch  29/100 | Loss: 5.4401 | Time: 89.7s | ETA: 106.9 min
#   [SimCLR] Epoch  30/100 | Loss: 5.4388 | Time: 90.0s | ETA: 105.3 min
#   [SimCLR] Epoch  31/100 | Loss: 5.4361 | Time: 90.9s | ETA: 103.9 min
#   [SimCLR] Epoch  32/100 | Loss: 5.4332 | Time: 89.8s | ETA: 102.3 min
#   [SimCLR] Epoch  33/100 | Loss: 5.4306 | Time: 89.2s | ETA: 100.8 min
#   [SimCLR] Epoch  34/100 | Loss: 5.4283 | Time: 89.0s | ETA: 99.2 min
#   [SimCLR] Epoch  35/100 | Loss: 5.4291 | Time: 89.0s | ETA: 97.7 min
#   [SimCLR] Epoch  36/100 | Loss: 5.4264 | Time: 88.4s | ETA: 96.2 min
#   [SimCLR] Epoch  37/100 | Loss: 5.4236 | Time: 89.4s | ETA: 94.6 min
#   [SimCLR] Epoch  38/100 | Loss: 5.4225 | Time: 89.6s | ETA: 93.1 min
#   [SimCLR] Epoch  39/100 | Loss: 5.4216 | Time: 89.6s | ETA: 91.6 min
#   [SimCLR] Epoch  40/100 | Loss: 5.4205 | Time: 90.1s | ETA: 90.1 min
#   [SimCLR] Epoch  41/100 | Loss: 5.4187 | Time: 90.8s | ETA: 88.6 min
#   [SimCLR] Epoch  42/100 | Loss: 5.4169 | Time: 91.0s | ETA: 87.1 min
#   [SimCLR] Epoch  43/100 | Loss: 5.4160 | Time: 90.3s | ETA: 85.6 min
#   [SimCLR] Epoch  44/100 | Loss: 5.4142 | Time: 90.2s | ETA: 84.1 min
#   [SimCLR] Epoch  45/100 | Loss: 5.4122 | Time: 90.7s | ETA: 82.6 min
#   [SimCLR] Epoch  46/100 | Loss: 5.4105 | Time: 89.3s | ETA: 81.1 min
#   [SimCLR] Epoch  47/100 | Loss: 5.4104 | Time: 89.1s | ETA: 79.6 min
#   [SimCLR] Epoch  48/100 | Loss: 5.4084 | Time: 88.7s | ETA: 78.1 min
#   [SimCLR] Epoch  49/100 | Loss: 5.4060 | Time: 89.4s | ETA: 76.6 min
#   [SimCLR] Epoch  50/100 | Loss: 5.4047 | Time: 87.9s | ETA: 75.0 min
#   [SimCLR] Epoch  51/100 | Loss: 5.4044 | Time: 89.0s | ETA: 73.5 min
#   [SimCLR] Epoch  52/100 | Loss: 5.4033 | Time: 89.7s | ETA: 72.0 min
#   [SimCLR] Epoch  53/100 | Loss: 5.4019 | Time: 89.1s | ETA: 70.5 min
#   [SimCLR] Epoch  54/100 | Loss: 5.4015 | Time: 89.8s | ETA: 69.0 min
#   [SimCLR] Epoch  55/100 | Loss: 5.3986 | Time: 90.7s | ETA: 67.5 min
#   [SimCLR] Epoch  56/100 | Loss: 5.3977 | Time: 90.2s | ETA: 66.0 min
#   [SimCLR] Epoch  57/100 | Loss: 5.3977 | Time: 89.4s | ETA: 64.5 min
#   [SimCLR] Epoch  58/100 | Loss: 5.3959 | Time: 89.2s | ETA: 63.0 min
#   [SimCLR] Epoch  59/100 | Loss: 5.3953 | Time: 88.4s | ETA: 61.5 min
#   [SimCLR] Epoch  60/100 | Loss: 5.3938 | Time: 87.6s | ETA: 59.9 min
#   [SimCLR] Epoch  61/100 | Loss: 5.3923 | Time: 87.6s | ETA: 58.4 min
#   [SimCLR] Epoch  62/100 | Loss: 5.3917 | Time: 87.7s | ETA: 56.9 min
#   [SimCLR] Epoch  63/100 | Loss: 5.3900 | Time: 87.7s | ETA: 55.4 min
#   [SimCLR] Epoch  64/100 | Loss: 5.3901 | Time: 88.5s | ETA: 53.9 min
#   [SimCLR] Epoch  65/100 | Loss: 5.3886 | Time: 90.2s | ETA: 52.4 min
#   [SimCLR] Epoch  66/100 | Loss: 5.3873 | Time: 89.2s | ETA: 50.9 min
#   [SimCLR] Epoch  67/100 | Loss: 5.3872 | Time: 89.1s | ETA: 49.4 min
#   [SimCLR] Epoch  68/100 | Loss: 5.3876 | Time: 90.3s | ETA: 47.9 min
#   [SimCLR] Epoch  69/100 | Loss: 5.3852 | Time: 90.8s | ETA: 46.4 min
#   [SimCLR] Epoch  70/100 | Loss: 5.3851 | Time: 89.4s | ETA: 44.9 min
#   [SimCLR] Epoch  71/100 | Loss: 5.3835 | Time: 89.9s | ETA: 43.4 min
#   [SimCLR] Epoch  72/100 | Loss: 5.3835 | Time: 89.4s | ETA: 41.9 min
#   [SimCLR] Epoch  73/100 | Loss: 5.3822 | Time: 90.3s | ETA: 40.4 min
#   [SimCLR] Epoch  74/100 | Loss: 5.3810 | Time: 90.4s | ETA: 38.9 min
#   [SimCLR] Epoch  75/100 | Loss: 5.3814 | Time: 90.8s | ETA: 37.4 min
#   [SimCLR] Epoch  76/100 | Loss: 5.3811 | Time: 89.9s | ETA: 35.9 min
#   [SimCLR] Epoch  77/100 | Loss: 5.3788 | Time: 90.9s | ETA: 34.4 min
#   [SimCLR] Epoch  78/100 | Loss: 5.3778 | Time: 90.4s | ETA: 32.9 min
#   [SimCLR] Epoch  79/100 | Loss: 5.3783 | Time: 90.6s | ETA: 31.4 min
#   [SimCLR] Epoch  80/100 | Loss: 5.3776 | Time: 90.9s | ETA: 30.0 min
#   [SimCLR] Epoch  81/100 | Loss: 5.3771 | Time: 90.9s | ETA: 28.5 min
#   [SimCLR] Epoch  82/100 | Loss: 5.3768 | Time: 90.8s | ETA: 27.0 min
#   [SimCLR] Epoch  83/100 | Loss: 5.3764 | Time: 91.2s | ETA: 25.5 min
#   [SimCLR] Epoch  84/100 | Loss: 5.3749 | Time: 90.5s | ETA: 24.0 min
#   [SimCLR] Epoch  85/100 | Loss: 5.3756 | Time: 90.8s | ETA: 22.5 min
#   [SimCLR] Epoch  86/100 | Loss: 5.3739 | Time: 89.8s | ETA: 21.0 min
#   [SimCLR] Epoch  87/100 | Loss: 5.3748 | Time: 90.0s | ETA: 19.5 min
#   [SimCLR] Epoch  88/100 | Loss: 5.3728 | Time: 89.2s | ETA: 18.0 min
#   [SimCLR] Epoch  89/100 | Loss: 5.3720 | Time: 89.8s | ETA: 16.5 min
#   [SimCLR] Epoch  90/100 | Loss: 5.3728 | Time: 90.2s | ETA: 15.0 min
#   [SimCLR] Epoch  91/100 | Loss: 5.3734 | Time: 90.1s | ETA: 13.5 min
#   [SimCLR] Epoch  92/100 | Loss: 5.3728 | Time: 89.3s | ETA: 12.0 min
#   [SimCLR] Epoch  93/100 | Loss: 5.3721 | Time: 88.7s | ETA: 10.5 min
#   [SimCLR] Epoch  94/100 | Loss: 5.3725 | Time: 88.6s | ETA: 9.0 min
#   [SimCLR] Epoch  95/100 | Loss: 5.3726 | Time: 88.3s | ETA: 7.5 min
#   [SimCLR] Epoch  96/100 | Loss: 5.3713 | Time: 87.8s | ETA: 6.0 min
#   [SimCLR] Epoch  97/100 | Loss: 5.3720 | Time: 87.6s | ETA: 4.5 min
#   [SimCLR] Epoch  98/100 | Loss: 5.3716 | Time: 88.2s | ETA: 3.0 min
#   [SimCLR] Epoch  99/100 | Loss: 5.3728 | Time: 88.1s | ETA: 1.5 min
#   [SimCLR] Epoch 100/100 | Loss: 5.3711 | Time: 89.1s | ETA: 0.0 min

# %%
# =====================================================
# EVALUATION
# =====================================================
import os

print("\n[Eval] Running linear probes...")
byol_acc   = train_probe(byol_encoder,   supervised_train_loader, supervised_test_loader)
simclr_acc = train_probe(simclr_encoder, supervised_train_loader, supervised_test_loader)

print("[Eval] Computing geometry metrics...")
byol_jac,   byol_aug,   byol_noise   = compute_metrics(byol_encoder,   supervised_test_loader)
simclr_jac, simclr_aug, simclr_noise = compute_metrics(simclr_encoder, supervised_test_loader)

seed_time = (time.time() - seed_start) / 60
print(f"\n  Seed {seed} finished in {seed_time:.2f} min")
print(f"  BYOL   → Acc: {byol_acc:.4f}  | Jac: {byol_jac:.4f}")
print(f"  SimCLR → Acc: {simclr_acc:.4f}  | Jac: {simclr_jac:.4f}")

SAVE_PATH = "/kaggle/working/cifar10_vit_results.csv"

seed_row = {
    "Seed"              : seed,
    "BYOL_Acc"          : byol_acc,
    "SimCLR_Acc"        : simclr_acc,
    "BYOL_Jacobian"     : byol_jac,
    "SimCLR_Jacobian"   : simclr_jac,
    "BYOL_Aug"          : byol_aug,
    "SimCLR_Aug"        : simclr_aug,
    "BYOL_Noise"        : byol_noise,
    "SimCLR_Noise"      : simclr_noise,
    "Seed_Time_Min"     : seed_time,
    "BYOL_AvgEpochSec"  : np.mean(byol_epoch_times),
    "SimCLR_AvgEpochSec": np.mean(simclr_epoch_times),
}

if os.path.exists(SAVE_PATH):
    results_df = pd.read_csv(SAVE_PATH)
    if seed in results_df["Seed"].values:
        for k, v in seed_row.items():
            results_df.loc[results_df["Seed"] == seed, k] = v
        print(f"  Updated existing row for seed {seed}")
    else:
        results_df = pd.concat([results_df, pd.DataFrame([seed_row])], ignore_index=True)
        print(f"  Appended seed {seed}")
else:
    results_df = pd.DataFrame([seed_row])
    print(f"  Created new results file for seed {seed}")

results_df.to_csv(SAVE_PATH, index=False)
print(f"  Saved → {SAVE_PATH}")
# Out:
# [Eval] Running linear probes...
# [Eval] Computing geometry metrics...
#
#   Seed 1 finished in 319.61 min
#   BYOL   → Acc: 0.4879  | Jac: 1.3424
#   SimCLR → Acc: 0.7696  | Jac: 5.5748
#   Created new results file for seed 1
#   Saved → /kaggle/working/cifar10_vit_results.csv

# %%
LAMBDA_JAC   = 1e-3
TEMPERATURE  = 1.0                                  # τ = 1.0 as determined
NUM_EPOCHS   = 100
BATCH_SIZE   = 256
NUM_WORKERS  = 4

print("=" * 60)
print(f"  [JacReg] SimCLR + Jacobian Reg  |  Seed: {seed}")
print(f"  lambda_jac = {LAMBDA_JAC}  |  tau = {TEMPERATURE}")
print("=" * 60)

set_seed(seed)
jacreg_start = time.time()

# ── Data (CIFAR-10, same seed as BYOL/SimCLR cells) ──────────────────────────
train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=ssl_transform)

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=False, transform=supervised_transform)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=False, transform=supervised_transform)

_loader_kw = dict(
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    persistent_workers=True,
)

train_loader            = DataLoader(train_dataset,            shuffle=True,  **_loader_kw)
supervised_train_loader = DataLoader(supervised_train_dataset, shuffle=True,  **_loader_kw)
supervised_test_loader  = DataLoader(test_dataset,             shuffle=False, **_loader_kw)

# ── Model ─────────────────────────────────────────────────────────────────────
jacreg_model = SimCLR().to(device)


optimizer = torch.optim.AdamW(
    jacreg_model.parameters(), lr=3e-4, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

scaler = GradScaler("cuda")

jacreg_epoch_times = []

for epoch in range(NUM_EPOCHS):
    epoch_start  = time.time()
    jacreg_model.train()
    running_loss = 0.0
    running_ssl  = 0.0
    running_jac  = 0.0

    for batch_idx, ((x1, x2), _) in enumerate(train_loader):

        # requires_grad needed for Jacobian — only on x1
        x1 = x1.to(device, non_blocking=True).requires_grad_(True)
        x2 = x2.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        with autocast("cuda"):
            z1 = jacreg_model(x1)
            z2 = jacreg_model(x2)
            loss_ssl = nt_xent_loss(z1, z2, temperature=TEMPERATURE)

        # FIXED: compute Jac reg every other batch (same as original)
        # but keep it inside autocast for speed, and use retain_graph correctly
        if batch_idx % 2 == 0:
            with autocast("cuda"):
                features = jacreg_model.encoder(x1)

            v  = torch.randn_like(features)
            Jv = torch.autograd.grad(
                outputs=features,
                inputs=x1,
                grad_outputs=v,
                retain_graph=False,
                create_graph=False,         # NEW: no 2nd-order graph, faster
            )[0]
            # FIXED: detach before .item() to avoid holding graph
            jac_reg = Jv.pow(2).sum(dim=[1, 2, 3]).mean()
        else:
            jac_reg = torch.tensor(0.0, device=device)

        loss = loss_ssl + LAMBDA_JAC * jac_reg

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(
            jacreg_model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        running_ssl  += loss_ssl.item()
        running_jac  += jac_reg.item() if isinstance(jac_reg, torch.Tensor) else 0.0

    scheduler.step()

    elapsed = time.time() - epoch_start
    jacreg_epoch_times.append(elapsed)
    avg_t     = np.mean(jacreg_epoch_times)
    remaining = avg_t * (NUM_EPOCHS - epoch - 1)
    n_batches = len(train_loader)

    print(f"  [JacReg] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
          f"Loss: {running_loss/n_batches:.4f}  "
          f"(SSL: {running_ssl/n_batches:.4f}  "
          f"Jac: {running_jac/n_batches:.4f}) | "
          f"Time: {elapsed:.1f}s | "
          f"ETA: {remaining/60:.1f} min")

jacreg_encoder = jacreg_model.encoder

# ── Evaluate ──────────────────────────────────────────────────────────────────
print("\n[JacReg] Running linear probe...")
jacreg_acc = train_probe(
    jacreg_encoder, supervised_train_loader, supervised_test_loader)

print("[JacReg] Computing geometry metrics...")
jacreg_jac, jacreg_aug, jacreg_noise = compute_metrics(
    jacreg_encoder, supervised_test_loader)

jacreg_time = (time.time() - jacreg_start) / 60

print(f"\n  [JacReg] Seed {seed} done in {jacreg_time:.2f} min")
print(f"  JacReg → Acc: {jacreg_acc:.4f}  | Jac: {jacreg_jac:.4f}")


# =========================================================
# CELL 2 — Final Results  (all 3 models, 1 seed)
# =========================================================
#
# Reads BYOL + SimCLR results from all_results (built in prior cells),
# appends JacReg, saves everything to /kaggle/working/
# ─────────────────────────────────────────────────────────

import os

# ── Build unified row for this seed ───────────────────────────────────────────
seed_row = {
    "Seed"                  : seed,

    # Accuracy
    "BYOL_Acc"              : byol_acc,
    "SimCLR_Acc"            : simclr_acc,
    "JacReg_Acc"            : jacreg_acc,

    # Jacobian sensitivity
    "BYOL_Jacobian"         : byol_jac,
    "SimCLR_Jacobian"       : simclr_jac,
    "JacReg_Jacobian"       : jacreg_jac,

    # Augmentation invariance
    "BYOL_Aug"              : byol_aug,
    "SimCLR_Aug"            : simclr_aug,
    "JacReg_Aug"            : jacreg_aug,

    # Noise robustness
    "BYOL_Noise"            : byol_noise,
    "SimCLR_Noise"          : simclr_noise,
    "JacReg_Noise"          : jacreg_noise,

    # Timing
    "BYOL_Time_Min"         : sum(byol_epoch_times) / 60,
    "SimCLR_Time_Min"       : sum(simclr_epoch_times) / 60,
    "JacReg_Time_Min"       : jacreg_time,

    "BYOL_AvgEpochSec"      : np.mean(byol_epoch_times),
    "SimCLR_AvgEpochSec"    : np.mean(simclr_epoch_times),
    "JacReg_AvgEpochSec"    : np.mean(jacreg_epoch_times),
}

# ── Merge with any previously saved seeds ─────────────────────────────────────
SAVE_PATH = "/kaggle/working/cifar10_results_progress.csv"

if os.path.exists(SAVE_PATH):
    results_df = pd.read_csv(SAVE_PATH)
    # overwrite row if seed already exists, else append
    if seed in results_df["Seed"].values:
        for k, v in seed_row.items():
            results_df.loc[results_df["Seed"] == seed, k] = v
        print(f"  Updated existing row for seed {seed}")
    else:
        results_df = pd.concat(
            [results_df, pd.DataFrame([seed_row])], ignore_index=True)
        print(f"  Appended new row for seed {seed}")
else:
    results_df = pd.DataFrame([seed_row])
    print(f"  Created new results file for seed {seed}")

results_df.to_csv(SAVE_PATH, index=False)
print(f"  Saved → {SAVE_PATH}")

# ── Pretty-print side-by-side comparison ──────────────────────────────────────
METRICS = [
    ("Accuracy",              "BYOL_Acc",       "SimCLR_Acc",       "JacReg_Acc"),
    ("Jacobian Sensitivity",  "BYOL_Jacobian",  "SimCLR_Jacobian",  "JacReg_Jacobian"),
    ("Aug Invariance",        "BYOL_Aug",       "SimCLR_Aug",       "JacReg_Aug"),
    ("Noise Robustness",      "BYOL_Noise",     "SimCLR_Noise",     "JacReg_Noise"),
    ("Train Time (min)",      "BYOL_Time_Min",  "SimCLR_Time_Min",  "JacReg_Time_Min"),
    ("Avg Epoch (sec)",       "BYOL_AvgEpochSec","SimCLR_AvgEpochSec","JacReg_AvgEpochSec"),
]

print("\n" + "=" * 70)
print(f"  SEED {seed} RESULTS  —  BYOL vs SimCLR vs SimCLR+JacReg  (CIFAR-10)")
print("=" * 70)
print(f"  {'Metric':<26}  {'BYOL':>10}  {'SimCLR':>10}  {'JacReg':>10}")
print("  " + "-" * 62)
for label, b_col, s_col, j_col in METRICS:
    b = seed_row[b_col]
    s = seed_row[s_col]
    j = seed_row[j_col]
    print(f"  {label:<26}  {b:>10.4f}  {s:>10.4f}  {j:>10.4f}")
print("=" * 70)

# ── If multiple seeds are done, also print aggregate stats ────────────────────
if len(results_df) > 1:
    print(f"\n  AGGREGATE  ({len(results_df)} seeds completed)")
    print("=" * 70)
    print(f"  {'Metric':<26}  {'BYOL':>10}  {'SimCLR':>10}  {'JacReg':>10}")
    print("  " + "-" * 62)
    for label, b_col, s_col, j_col in METRICS:
        bm = results_df[b_col].mean(); bs = results_df[b_col].std()
        sm = results_df[s_col].mean(); ss = results_df[s_col].std()
        jm = results_df[j_col].mean(); js = results_df[j_col].std()
        print(f"  {label:<26}  "
              f"{bm:>6.4f}±{bs:.3f}  "
              f"{sm:>6.4f}±{ss:.3f}  "
              f"{jm:>6.4f}±{js:.3f}")
    print("=" * 70)

print(f"\n  Seeds completed so far: {sorted(results_df['Seed'].tolist())}")
print(f"  Progress CSV: {SAVE_PATH}")
# Out:
# ============================================================
#   [JacReg] SimCLR + Jacobian Reg  |  Seed: 1
#   lambda_jac = 0.001  |  tau = 1.0
# ============================================================
#   [JacReg] Epoch   1/100 | Loss: 5.7012  (SSL: 5.6987  Jac: 2.4575) | Time: 99.1s | ETA: 163.5 min
#   [JacReg] Epoch   2/100 | Loss: 5.6195  (SSL: 5.6186  Jac: 0.9850) | Time: 100.2s | ETA: 162.7 min
#   [JacReg] Epoch   3/100 | Loss: 5.5928  (SSL: 5.5917  Jac: 1.0650) | Time: 98.4s | ETA: 160.4 min
#   [JacReg] Epoch   4/100 | Loss: 5.5800  (SSL: 5.5789  Jac: 1.0922) | Time: 98.4s | ETA: 158.4 min
#   [JacReg] Epoch   5/100 | Loss: 5.5668  (SSL: 5.5655  Jac: 1.3043) | Time: 98.4s | ETA: 156.6 min
#   [JacReg] Epoch   6/100 | Loss: 5.5599  (SSL: 5.5585  Jac: 1.4047) | Time: 98.4s | ETA: 154.8 min
#   [JacReg] Epoch   7/100 | Loss: 5.5503  (SSL: 5.5487  Jac: 1.5844) | Time: 98.1s | ETA: 153.0 min
#   [JacReg] Epoch   8/100 | Loss: 5.5428  (SSL: 5.5408  Jac: 1.9772) | Time: 99.1s | ETA: 151.4 min
#   [JacReg] Epoch   9/100 | Loss: 5.5367  (SSL: 5.5347  Jac: 1.9759) | Time: 98.2s | ETA: 149.7 min
#   [JacReg] Epoch  10/100 | Loss: 5.5282  (SSL: 5.5260  Jac: 2.2420) | Time: 98.6s | ETA: 148.0 min
#   [JacReg] Epoch  11/100 | Loss: 5.5179  (SSL: 5.5153  Jac: 2.5770) | Time: 98.3s | ETA: 146.3 min
#   [JacReg] Epoch  12/100 | Loss: 5.5111  (SSL: 5.5082  Jac: 2.8495) | Time: 98.1s | ETA: 144.6 min
#   [JacReg] Epoch  13/100 | Loss: 5.5065  (SSL: 5.5032  Jac: 3.3347) | Time: 98.3s | ETA: 142.9 min
#   [JacReg] Epoch  14/100 | Loss: 5.5011  (SSL: 5.4975  Jac: 3.6347) | Time: 99.6s | ETA: 141.4 min
#   [JacReg] Epoch  15/100 | Loss: 5.4961  (SSL: 5.4922  Jac: 3.9344) | Time: 98.7s | ETA: 139.8 min
#   [JacReg] Epoch  16/100 | Loss: 5.4901  (SSL: 5.4857  Jac: 4.4155) | Time: 98.7s | ETA: 138.1 min
#   [JacReg] Epoch  17/100 | Loss: 5.4855  (SSL: 5.4809  Jac: 4.6028) | Time: 99.0s | ETA: 136.5 min
#   [JacReg] Epoch  18/100 | Loss: 5.4819  (SSL: 5.4767  Jac: 5.1106) | Time: 98.4s | ETA: 134.8 min
#   [JacReg] Epoch  19/100 | Loss: 5.4765  (SSL: 5.4710  Jac: 5.5088) | Time: 99.3s | ETA: 133.2 min
#   [JacReg] Epoch  20/100 | Loss: 5.4746  (SSL: 5.4686  Jac: 5.9382) | Time: 98.4s | ETA: 131.6 min
#   [JacReg] Epoch  21/100 | Loss: 5.4692  (SSL: 5.4634  Jac: 5.8196) | Time: 98.4s | ETA: 129.9 min
#   [JacReg] Epoch  22/100 | Loss: 5.4682  (SSL: 5.4616  Jac: 6.5978) | Time: 99.1s | ETA: 128.3 min
#   [JacReg] Epoch  23/100 | Loss: 5.4641  (SSL: 5.4572  Jac: 6.8732) | Time: 98.4s | ETA: 126.6 min
#   [JacReg] Epoch  24/100 | Loss: 5.4608  (SSL: 5.4538  Jac: 6.9847) | Time: 99.3s | ETA: 125.0 min
#   [JacReg] Epoch  25/100 | Loss: 5.4598  (SSL: 5.4522  Jac: 7.6044) | Time: 98.4s | ETA: 123.4 min
#   [JacReg] Epoch  26/100 | Loss: 5.4559  (SSL: 5.4480  Jac: 7.9148) | Time: 98.3s | ETA: 121.7 min
#   [JacReg] Epoch  27/100 | Loss: 5.4536  (SSL: 5.4454  Jac: 8.2736) | Time: 98.3s | ETA: 120.0 min
#   [JacReg] Epoch  28/100 | Loss: 5.4517  (SSL: 5.4428  Jac: 8.8980) | Time: 98.5s | ETA: 118.4 min
#   [JacReg] Epoch  29/100 | Loss: 5.4495  (SSL: 5.4405  Jac: 9.0287) | Time: 97.9s | ETA: 116.7 min
#   [JacReg] Epoch  30/100 | Loss: 5.4492  (SSL: 5.4391  Jac: 10.0360) | Time: 99.2s | ETA: 115.1 min
#   [JacReg] Epoch  31/100 | Loss: 5.4469  (SSL: 5.4369  Jac: 10.0495) | Time: 98.3s | ETA: 113.4 min
#   [JacReg] Epoch  32/100 | Loss: 5.4452  (SSL: 5.4348  Jac: 10.4267) | Time: 98.1s | ETA: 111.8 min
#   [JacReg] Epoch  33/100 | Loss: 5.4433  (SSL: 5.4326  Jac: 10.6758) | Time: 98.2s | ETA: 110.1 min
#   [JacReg] Epoch  34/100 | Loss: 5.4422  (SSL: 5.4309  Jac: 11.3531) | Time: 98.4s | ETA: 108.5 min
#   [JacReg] Epoch  35/100 | Loss: 5.4421  (SSL: 5.4296  Jac: 12.4578) | Time: 99.3s | ETA: 106.8 min
#   [JacReg] Epoch  36/100 | Loss: 5.4391  (SSL: 5.4265  Jac: 12.6515) | Time: 98.8s | ETA: 105.2 min
#   [JacReg] Epoch  37/100 | Loss: 5.4396  (SSL: 5.4267  Jac: 12.9500) | Time: 98.8s | ETA: 103.6 min
#   [JacReg] Epoch  38/100 | Loss: 5.4364  (SSL: 5.4231  Jac: 13.3125) | Time: 98.4s | ETA: 101.9 min
#   [JacReg] Epoch  39/100 | Loss: 5.4357  (SSL: 5.4218  Jac: 13.9472) | Time: 99.0s | ETA: 100.3 min
#   [JacReg] Epoch  40/100 | Loss: 5.4356  (SSL: 5.4209  Jac: 14.6341) | Time: 100.1s | ETA: 98.7 min
#   [JacReg] Epoch  41/100 | Loss: 5.4342  (SSL: 5.4191  Jac: 15.0811) | Time: 99.8s | ETA: 97.1 min
#   [JacReg] Epoch  42/100 | Loss: 5.4327  (SSL: 5.4175  Jac: 15.2060) | Time: 98.7s | ETA: 95.4 min
#   [JacReg] Epoch  43/100 | Loss: 5.4308  (SSL: 5.4150  Jac: 15.8228) | Time: 98.8s | ETA: 93.8 min
#   [JacReg] Epoch  44/100 | Loss: 5.4313  (SSL: 5.4145  Jac: 16.7683) | Time: 98.4s | ETA: 92.1 min
#   [JacReg] Epoch  45/100 | Loss: 5.4307  (SSL: 5.4134  Jac: 17.3062) | Time: 98.7s | ETA: 90.5 min
#   [JacReg] Epoch  46/100 | Loss: 5.4297  (SSL: 5.4108  Jac: 18.9069) | Time: 99.7s | ETA: 88.8 min
#   [JacReg] Epoch  47/100 | Loss: 5.4299  (SSL: 5.4112  Jac: 18.6705) | Time: 98.5s | ETA: 87.2 min
#   [JacReg] Epoch  48/100 | Loss: 5.4279  (SSL: 5.4086  Jac: 19.2447) | Time: 98.6s | ETA: 85.5 min
#   [JacReg] Epoch  49/100 | Loss: 5.4269  (SSL: 5.4070  Jac: 19.8756) | Time: 98.4s | ETA: 83.9 min
#   [JacReg] Epoch  50/100 | Loss: 5.4267  (SSL: 5.4061  Jac: 20.6326) | Time: 98.7s | ETA: 82.3 min
#   [JacReg] Epoch  51/100 | Loss: 5.4257  (SSL: 5.4041  Jac: 21.6770) | Time: 99.5s | ETA: 80.6 min
#   [JacReg] Epoch  52/100 | Loss: 5.4270  (SSL: 5.4050  Jac: 22.0496) | Time: 98.8s | ETA: 79.0 min
#   [JacReg] Epoch  53/100 | Loss: 5.4256  (SSL: 5.4022  Jac: 23.4101) | Time: 99.0s | ETA: 77.3 min
#   [JacReg] Epoch  54/100 | Loss: 5.4243  (SSL: 5.3997  Jac: 24.5824) | Time: 98.8s | ETA: 75.7 min
#   [JacReg] Epoch  55/100 | Loss: 5.4249  (SSL: 5.4002  Jac: 24.6885) | Time: 99.1s | ETA: 74.0 min
#   [JacReg] Epoch  56/100 | Loss: 5.4245  (SSL: 5.3990  Jac: 25.4292) | Time: 99.6s | ETA: 72.4 min
#   [JacReg] Epoch  57/100 | Loss: 5.4250  (SSL: 5.3981  Jac: 26.9090) | Time: 98.8s | ETA: 70.8 min
#   [JacReg] Epoch  58/100 | Loss: 5.4239  (SSL: 5.3968  Jac: 27.0472) | Time: 100.1s | ETA: 69.1 min
#   [JacReg] Epoch  59/100 | Loss: 5.4241  (SSL: 5.3961  Jac: 27.9245) | Time: 99.7s | ETA: 67.5 min
#   [JacReg] Epoch  60/100 | Loss: 5.4239  (SSL: 5.3948  Jac: 29.1507) | Time: 98.9s | ETA: 65.9 min
#   [JacReg] Epoch  61/100 | Loss: 5.4234  (SSL: 5.3946  Jac: 28.7475) | Time: 98.7s | ETA: 64.2 min
#   [JacReg] Epoch  62/100 | Loss: 5.4221  (SSL: 5.3930  Jac: 29.1026) | Time: 98.6s | ETA: 62.6 min
#   [JacReg] Epoch  63/100 | Loss: 5.4223  (SSL: 5.3907  Jac: 31.5869) | Time: 98.7s | ETA: 60.9 min
#   [JacReg] Epoch  64/100 | Loss: 5.4236  (SSL: 5.3911  Jac: 32.4365) | Time: 99.9s | ETA: 59.3 min
#   [JacReg] Epoch  65/100 | Loss: 5.4223  (SSL: 5.3896  Jac: 32.6383) | Time: 99.2s | ETA: 57.6 min
#   [JacReg] Epoch  66/100 | Loss: 5.4214  (SSL: 5.3885  Jac: 32.8560) | Time: 98.2s | ETA: 56.0 min
#   [JacReg] Epoch  67/100 | Loss: 5.4233  (SSL: 5.3896  Jac: 33.7383) | Time: 98.3s | ETA: 54.3 min
#   [JacReg] Epoch  68/100 | Loss: 5.4209  (SSL: 5.3868  Jac: 34.1498) | Time: 98.5s | ETA: 52.7 min
#   [JacReg] Epoch  69/100 | Loss: 5.4218  (SSL: 5.3862  Jac: 35.6071) | Time: 98.2s | ETA: 51.0 min
#   [JacReg] Epoch  70/100 | Loss: 5.4228  (SSL: 5.3854  Jac: 37.4216) | Time: 99.4s | ETA: 49.4 min
#   [JacReg] Epoch  71/100 | Loss: 5.4205  (SSL: 5.3846  Jac: 35.9731) | Time: 98.6s | ETA: 47.7 min
#   [JacReg] Epoch  72/100 | Loss: 5.4203  (SSL: 5.3829  Jac: 37.3660) | Time: 98.2s | ETA: 46.1 min
#   [JacReg] Epoch  73/100 | Loss: 5.4222  (SSL: 5.3830  Jac: 39.2054) | Time: 98.3s | ETA: 44.4 min
#   [JacReg] Epoch  74/100 | Loss: 5.4217  (SSL: 5.3818  Jac: 39.8899) | Time: 98.2s | ETA: 42.8 min
#   [JacReg] Epoch  75/100 | Loss: 5.4227  (SSL: 5.3818  Jac: 40.8486) | Time: 98.5s | ETA: 41.1 min
#   [JacReg] Epoch  76/100 | Loss: 5.4237  (SSL: 5.3812  Jac: 42.5186) | Time: 99.6s | ETA: 39.5 min
#   [JacReg] Epoch  77/100 | Loss: 5.4240  (SSL: 5.3807  Jac: 43.2248) | Time: 98.4s | ETA: 37.9 min
#   [JacReg] Epoch  78/100 | Loss: 5.4211  (SSL: 5.3794  Jac: 41.6336) | Time: 98.7s | ETA: 36.2 min
#   [JacReg] Epoch  79/100 | Loss: 5.4216  (SSL: 5.3787  Jac: 42.9689) | Time: 98.7s | ETA: 34.6 min
#   [JacReg] Epoch  80/100 | Loss: 5.4209  (SSL: 5.3782  Jac: 42.6803) | Time: 98.4s | ETA: 32.9 min
#   [JacReg] Epoch  81/100 | Loss: 5.4232  (SSL: 5.3783  Jac: 44.9058) | Time: 99.4s | ETA: 31.3 min
#   [JacReg] Epoch  82/100 | Loss: 5.4228  (SSL: 5.3770  Jac: 45.7662) | Time: 98.5s | ETA: 29.6 min
#   [JacReg] Epoch  83/100 | Loss: 5.4238  (SSL: 5.3775  Jac: 46.2717) | Time: 98.5s | ETA: 28.0 min
#   [JacReg] Epoch  84/100 | Loss: 5.4223  (SSL: 5.3762  Jac: 46.0966) | Time: 98.8s | ETA: 26.3 min
#   [JacReg] Epoch  85/100 | Loss: 5.4228  (SSL: 5.3765  Jac: 46.3002) | Time: 98.6s | ETA: 24.7 min
#   [JacReg] Epoch  86/100 | Loss: 5.4229  (SSL: 5.3757  Jac: 47.1838) | Time: 99.3s | ETA: 23.0 min
#   [JacReg] Epoch  87/100 | Loss: 5.4227  (SSL: 5.3755  Jac: 47.1654) | Time: 98.3s | ETA: 21.4 min
#   [JacReg] Epoch  88/100 | Loss: 5.4238  (SSL: 5.3750  Jac: 48.7114) | Time: 98.3s | ETA: 19.8 min
#   [JacReg] Epoch  89/100 | Loss: 5.4223  (SSL: 5.3746  Jac: 47.7504) | Time: 98.4s | ETA: 18.1 min
#   [JacReg] Epoch  90/100 | Loss: 5.4223  (SSL: 5.3739  Jac: 48.4036) | Time: 98.3s | ETA: 16.5 min
#   [JacReg] Epoch  91/100 | Loss: 5.4220  (SSL: 5.3741  Jac: 47.9664) | Time: 99.3s | ETA: 14.8 min
#   [JacReg] Epoch  92/100 | Loss: 5.4224  (SSL: 5.3739  Jac: 48.5221) | Time: 98.2s | ETA: 13.2 min
#   [JacReg] Epoch  93/100 | Loss: 5.4223  (SSL: 5.3736  Jac: 48.6868) | Time: 98.8s | ETA: 11.5 min
#   [JacReg] Epoch  94/100 | Loss: 5.4223  (SSL: 5.3728  Jac: 49.5042) | Time: 98.4s | ETA: 9.9 min
#   [JacReg] Epoch  95/100 | Loss: 5.4221  (SSL: 5.3737  Jac: 48.3655) | Time: 98.1s | ETA: 8.2 min
#   [JacReg] Epoch  96/100 | Loss: 5.4229  (SSL: 5.3721  Jac: 50.7349) | Time: 98.5s | ETA: 6.6 min
#   [JacReg] Epoch  97/100 | Loss: 5.4230  (SSL: 5.3735  Jac: 49.5043) | Time: 99.3s | ETA: 4.9 min
#   [JacReg] Epoch  98/100 | Loss: 5.4219  (SSL: 5.3722  Jac: 49.7128) | Time: 98.4s | ETA: 3.3 min
#   [JacReg] Epoch  99/100 | Loss: 5.4219  (SSL: 5.3720  Jac: 49.8396) | Time: 98.5s | ETA: 1.6 min
#   [JacReg] Epoch 100/100 | Loss: 5.4241  (SSL: 5.3738  Jac: 50.2723) | Time: 98.3s | ETA: 0.0 min
#
# [JacReg] Running linear probe...
# [JacReg] Computing geometry metrics...
#
#   [JacReg] Seed 1 done in 170.33 min
#   JacReg → Acc: 0.7709  | Jac: 5.7697
#   Created new results file for seed 1
#   Saved → /kaggle/working/cifar10_results_progress.csv
#
# ======================================================================
#   SEED 1 RESULTS  —  BYOL vs SimCLR vs SimCLR+JacReg  (CIFAR-10)
# ======================================================================
#   Metric                            BYOL      SimCLR      JacReg
#   --------------------------------------------------------------
#   Accuracy                        0.4879      0.7696      0.7709
#   Jacobian Sensitivity            1.3424      5.5748      5.7697
#   Aug Invariance                  3.1024      6.8314      6.6681
#   Noise Robustness                0.1309      0.7413      0.7858
#   Train Time (min)              157.5622    149.6229    170.3260
#   Avg Epoch (sec)                94.5373     89.7737     98.7284
# ======================================================================
#
#   Seeds completed so far: [1]
#   Progress CSV: /kaggle/working/cifar10_results_progress.csv
