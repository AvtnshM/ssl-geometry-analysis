# %%
# =========================================================
# Setup
# =========================================================

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import numpy as np
import random
import pandas as pd
import scipy.stats as stats
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =========================================================
# Reproducibility
# =========================================================

def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

print("Device:", device)
print("Seed function ready.")
# Out:
# Device: cuda
# Seed function ready.

# %%
# =========================================================
# Data Transforms
# =========================================================

class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)


ssl_base_transform = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

supervised_transform = T.ToTensor()

# %%
# =========================================================
# Encoder
# =========================================================

class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        backbone = resnet18(weights=None)
        backbone.fc = nn.Identity()
        self.backbone = backbone

    def forward(self, x):
        return self.backbone(x)

# %%
# =========================================================
# BYOL
# =========================================================

class MLP(nn.Module):
    def __init__(self, in_dim, hidden_dim=2048, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )

    def forward(self, x):
        return self.net(x)


class BYOL(nn.Module):
    def __init__(self):
        super().__init__()
        self.online_encoder = Encoder()
        self.online_projector = MLP(512)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder = Encoder()
        self.target_projector = MLP(512)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for online, target in zip(self.online_encoder.parameters(),
                                  self.target_encoder.parameters()):
            target.data = tau * target.data + (1 - tau) * online.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(
            self.online_projector(self.online_encoder(x1))
        )

        with torch.no_grad():
            t2 = self.target_projector(
                self.target_encoder(x2)
            )

        loss = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        return loss.mean()

# %%
# =========================================================
# SimCLR
# =========================================================

class SimCLR(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.projector = MLP(512)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        z = F.normalize(z, dim=1)
        return z


def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)

    sim = torch.mm(z, z.t()) / temperature
    mask = torch.eye(2*N, device=z.device).bool()
    sim.masked_fill_(mask, -9e15)

    positives = torch.cat([torch.arange(N, 2*N),
                           torch.arange(0, N)]).to(z.device)

    loss = F.cross_entropy(sim, positives)
    return loss

# %%
# =========================================================
# Training
# =========================================================

def train_byol(model, train_loader, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for (x1, x2), _ in train_loader:
            x1 = x1.to(device)
            x2 = x2.to(device)

            loss = model(x1, x2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            model.update_target()

            total_loss += loss.item()

        print(f"[BYOL] Epoch {epoch+1:03d}/{epochs} | Loss: {total_loss/len(train_loader):.4f}")

    return model.online_encoder


def train_simclr(model, train_loader, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for (x1, x2), _ in train_loader:
            x1 = x1.to(device)
            x2 = x2.to(device)

            z1 = model(x1)
            z2 = model(x2)

            loss = nt_xent_loss(z1, z2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"[SimCLR] Epoch {epoch+1:03d}/{epochs} | Loss: {total_loss/len(train_loader):.4f}")

    return model.encoder

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(512, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    return correct / total

# %%
# =========================================================
# Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
])

def jacobian_frobenius(model, x):
    x = x.clone().detach().to(device).requires_grad_(True)
    y = model(x)
    v = torch.randn_like(y)

    Jv = torch.autograd.grad(
        outputs=y,
        inputs=x,
        grad_outputs=v,
        retain_graph=False
    )[0]

    return torch.sqrt(Jv.pow(2).sum() / x.size(0))


def compute_metrics(encoder, loader):
    encoder = encoder.to(device)
    encoder.eval()

    jac_vals = []
    aug_vals = []
    noise_vals = []

    for i, (x, _) in enumerate(loader):
        if i == 5:
            break

        x = x.to(device)

        jac_vals.append(jacobian_frobenius(encoder, x).item())

        x_aug = torch.stack([tensor_aug(img.cpu()) for img in x]).to(device)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        noise = torch.randn_like(x) * 0.1
        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x + noise)
            noise_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

    return np.mean(jac_vals), np.mean(aug_vals), np.mean(noise_vals)

# %%
# =========================================================
# V2 Multi-Seed Experiment (With Timing)
# =========================================================

seeds = [7,8,9]
all_results = []

overall_start = time.time()

for seed in seeds:

    seed_start = time.time()

    print("\n====================================")
    print(f"Running Seed: {seed}")
    print("====================================")

    set_seed(seed)

    train_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=True,
        transform=ssl_transform
    )

    supervised_train_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=True,
        download=False,
        transform=supervised_transform
    )

    test_dataset = torchvision.datasets.CIFAR10(
        root="./data",
        train=False,
        download=True,
        transform=supervised_transform
    )

    train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
    supervised_train_loader = DataLoader(supervised_train_dataset, batch_size=128, shuffle=True, num_workers=2)
    supervised_test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)

    byol_encoder = train_byol(BYOL(), train_loader, epochs=100)
    simclr_encoder = train_simclr(SimCLR(), train_loader, epochs=100)

    byol_acc = train_probe(byol_encoder, supervised_train_loader, supervised_test_loader)
    simclr_acc = train_probe(simclr_encoder, supervised_train_loader, supervised_test_loader)

    byol_jac, byol_aug, byol_noise = compute_metrics(byol_encoder, supervised_test_loader)
    simclr_jac, simclr_aug, simclr_noise = compute_metrics(simclr_encoder, supervised_test_loader)

    seed_time = (time.time() - seed_start) / 60

    all_results.append({
        "Seed": seed,
        "BYOL_Jacobian": byol_jac,
        "SimCLR_Jacobian": simclr_jac,
        "BYOL_Aug": byol_aug,
        "SimCLR_Aug": simclr_aug,
        "BYOL_Noise": byol_noise,
        "SimCLR_Noise": simclr_noise,
        "BYOL_Acc": byol_acc,
        "SimCLR_Acc": simclr_acc,
        "Seed_Time_Min": seed_time
    })

    print(f"\nSeed {seed} finished in {seed_time:.2f} minutes.")

total_time = (time.time() - overall_start) / 60

results_df = pd.DataFrame(all_results)

print("\nPer-Seed Results:")
print(results_df)

print("\nMean Across Seeds:")
print(results_df.mean(numeric_only=True))

print("\nStd Across Seeds:")
print(results_df.std(numeric_only=True))

print(f"\nTotal Experiment Time: {total_time:.2f} minutes.")
# Out:
# ====================================
# Running Seed: 7
# ====================================
# 100%|██████████| 170M/170M [00:12<00:00, 13.7MB/s]
# [BYOL] Epoch 001/100 | Loss: 0.7444
# [BYOL] Epoch 002/100 | Loss: 0.5814
# [BYOL] Epoch 003/100 | Loss: 0.5174
# [BYOL] Epoch 004/100 | Loss: 0.4833
# [BYOL] Epoch 005/100 | Loss: 0.4619
# [BYOL] Epoch 006/100 | Loss: 0.4492
# [BYOL] Epoch 007/100 | Loss: 0.4404
# [BYOL] Epoch 008/100 | Loss: 0.4332
# [BYOL] Epoch 009/100 | Loss: 0.4275
# [BYOL] Epoch 010/100 | Loss: 0.4216
# [BYOL] Epoch 011/100 | Loss: 0.4192
# [BYOL] Epoch 012/100 | Loss: 0.4134
# [BYOL] Epoch 013/100 | Loss: 0.4091
# [BYOL] Epoch 014/100 | Loss: 0.4051
# [BYOL] Epoch 015/100 | Loss: 0.4046
# [BYOL] Epoch 016/100 | Loss: 0.4048
# [BYOL] Epoch 017/100 | Loss: 0.4032
# [BYOL] Epoch 018/100 | Loss: 0.4019
# [BYOL] Epoch 019/100 | Loss: 0.4020
# [BYOL] Epoch 020/100 | Loss: 0.4010
# [BYOL] Epoch 021/100 | Loss: 0.3993
# [BYOL] Epoch 022/100 | Loss: 0.3988
# [BYOL] Epoch 023/100 | Loss: 0.4026
# [BYOL] Epoch 024/100 | Loss: 0.4043
# [BYOL] Epoch 025/100 | Loss: 0.4015
# [BYOL] Epoch 026/100 | Loss: 0.4015
# [BYOL] Epoch 027/100 | Loss: 0.4018
# [BYOL] Epoch 028/100 | Loss: 0.3993
# [BYOL] Epoch 029/100 | Loss: 0.3991
# [BYOL] Epoch 030/100 | Loss: 0.3981
# [BYOL] Epoch 031/100 | Loss: 0.3960
# [BYOL] Epoch 032/100 | Loss: 0.3952
# [BYOL] Epoch 033/100 | Loss: 0.3947
# [BYOL] Epoch 034/100 | Loss: 0.3955
# [BYOL] Epoch 035/100 | Loss: 0.3934
# [BYOL] Epoch 036/100 | Loss: 0.3921
# [BYOL] Epoch 037/100 | Loss: 0.3918
# [BYOL] Epoch 038/100 | Loss: 0.3901
# [BYOL] Epoch 039/100 | Loss: 0.3889
# [BYOL] Epoch 040/100 | Loss: 0.3915
# [BYOL] Epoch 041/100 | Loss: 0.3880
# [BYOL] Epoch 042/100 | Loss: 0.3890
# [BYOL] Epoch 043/100 | Loss: 0.3885
# [BYOL] Epoch 044/100 | Loss: 0.3896
# [BYOL] Epoch 045/100 | Loss: 0.3884
# [BYOL] Epoch 046/100 | Loss: 0.3882
# [BYOL] Epoch 047/100 | Loss: 0.3869
# [BYOL] Epoch 048/100 | Loss: 0.3879
# [BYOL] Epoch 049/100 | Loss: 0.3874
# [BYOL] Epoch 050/100 | Loss: 0.3870
# [BYOL] Epoch 051/100 | Loss: 0.3868
# [BYOL] Epoch 052/100 | Loss: 0.3853
# [BYOL] Epoch 053/100 | Loss: 0.3841
# [BYOL] Epoch 054/100 | Loss: 0.3833
# [BYOL] Epoch 055/100 | Loss: 0.3828
# [BYOL] Epoch 056/100 | Loss: 0.3831
# [BYOL] Epoch 057/100 | Loss: 0.3833
# [BYOL] Epoch 058/100 | Loss: 0.3820
# [BYOL] Epoch 059/100 | Loss: 0.3822
# [BYOL] Epoch 060/100 | Loss: 0.3820
# [BYOL] Epoch 061/100 | Loss: 0.3818
# [BYOL] Epoch 062/100 | Loss: 0.3810
# [BYOL] Epoch 063/100 | Loss: 0.3811
# [BYOL] Epoch 064/100 | Loss: 0.3821
# [BYOL] Epoch 065/100 | Loss: 0.3805
# [BYOL] Epoch 066/100 | Loss: 0.3789
# [BYOL] Epoch 067/100 | Loss: 0.3793
# [BYOL] Epoch 068/100 | Loss: 0.3800
# [BYOL] Epoch 069/100 | Loss: 0.3794
# [BYOL] Epoch 070/100 | Loss: 0.3787
# [BYOL] Epoch 071/100 | Loss: 0.3796
# [BYOL] Epoch 072/100 | Loss: 0.3788
# [BYOL] Epoch 073/100 | Loss: 0.3770
# [BYOL] Epoch 074/100 | Loss: 0.3783
# [BYOL] Epoch 075/100 | Loss: 0.3788
# [BYOL] Epoch 076/100 | Loss: 0.3764
# [BYOL] Epoch 077/100 | Loss: 0.3778
# [BYOL] Epoch 078/100 | Loss: 0.3772
# [BYOL] Epoch 079/100 | Loss: 0.3776
# [BYOL] Epoch 080/100 | Loss: 0.3755
# [BYOL] Epoch 081/100 | Loss: 0.3767
# [BYOL] Epoch 082/100 | Loss: 0.3773
# [BYOL] Epoch 083/100 | Loss: 0.3787
# [BYOL] Epoch 084/100 | Loss: 0.3770
# [BYOL] Epoch 085/100 | Loss: 0.3763
# [BYOL] Epoch 086/100 | Loss: 0.3744
# [BYOL] Epoch 087/100 | Loss: 0.3762
# [BYOL] Epoch 088/100 | Loss: 0.3762
# [BYOL] Epoch 089/100 | Loss: 0.3752
# [BYOL] Epoch 090/100 | Loss: 0.3755
# [BYOL] Epoch 091/100 | Loss: 0.3765
# [BYOL] Epoch 092/100 | Loss: 0.3767
# [BYOL] Epoch 093/100 | Loss: 0.3762
# [BYOL] Epoch 094/100 | Loss: 0.3749
# [BYOL] Epoch 095/100 | Loss: 0.3754
# [BYOL] Epoch 096/100 | Loss: 0.3755
# [BYOL] Epoch 097/100 | Loss: 0.3745
# [BYOL] Epoch 098/100 | Loss: 0.3749
# [BYOL] Epoch 099/100 | Loss: 0.3749
# [BYOL] Epoch 100/100 | Loss: 0.3742
# [SimCLR] Epoch 001/100 | Loss: 4.6701
# [SimCLR] Epoch 002/100 | Loss: 4.4953
# [SimCLR] Epoch 003/100 | Loss: 4.4301
# [SimCLR] Epoch 004/100 | Loss: 4.3810
# [SimCLR] Epoch 005/100 | Loss: 4.3527
# [SimCLR] Epoch 006/100 | Loss: 4.3342
# [SimCLR] Epoch 007/100 | Loss: 4.3107
# [SimCLR] Epoch 008/100 | Loss: 4.2928
# [SimCLR] Epoch 009/100 | Loss: 4.2786
# [SimCLR] Epoch 010/100 | Loss: 4.2629
# [SimCLR] Epoch 011/100 | Loss: 4.2458
# [SimCLR] Epoch 012/100 | Loss: 4.2359
# [SimCLR] Epoch 013/100 | Loss: 4.2232
# [SimCLR] Epoch 014/100 | Loss: 4.2114
# [SimCLR] Epoch 015/100 | Loss: 4.2015
# [SimCLR] Epoch 016/100 | Loss: 4.2017
# [SimCLR] Epoch 017/100 | Loss: 4.1909
# [SimCLR] Epoch 018/100 | Loss: 4.1817
# [SimCLR] Epoch 019/100 | Loss: 4.1746
# [SimCLR] Epoch 020/100 | Loss: 4.1660
# [SimCLR] Epoch 021/100 | Loss: 4.1635
# [SimCLR] Epoch 022/100 | Loss: 4.1602
# [SimCLR] Epoch 023/100 | Loss: 4.1519
# [SimCLR] Epoch 024/100 | Loss: 4.1498
# [SimCLR] Epoch 025/100 | Loss: 4.1468
# [SimCLR] Epoch 026/100 | Loss: 4.1398
# [SimCLR] Epoch 027/100 | Loss: 4.1371
# [SimCLR] Epoch 028/100 | Loss: 4.1305
# [SimCLR] Epoch 029/100 | Loss: 4.1262
# [SimCLR] Epoch 030/100 | Loss: 4.1220
# [SimCLR] Epoch 031/100 | Loss: 4.1182
# [SimCLR] Epoch 032/100 | Loss: 4.1161
# [SimCLR] Epoch 033/100 | Loss: 4.1131
# [SimCLR] Epoch 034/100 | Loss: 4.1124
# [SimCLR] Epoch 035/100 | Loss: 4.1088
# [SimCLR] Epoch 036/100 | Loss: 4.1037
# [SimCLR] Epoch 037/100 | Loss: 4.1015
# [SimCLR] Epoch 038/100 | Loss: 4.1019
# [SimCLR] Epoch 039/100 | Loss: 4.0961
# [SimCLR] Epoch 040/100 | Loss: 4.0929
# [SimCLR] Epoch 041/100 | Loss: 4.0906
# [SimCLR] Epoch 042/100 | Loss: 4.0876
# [SimCLR] Epoch 043/100 | Loss: 4.0830
# [SimCLR] Epoch 044/100 | Loss: 4.0848
# [SimCLR] Epoch 045/100 | Loss: 4.0746
# [SimCLR] Epoch 046/100 | Loss: 4.0765
# [SimCLR] Epoch 047/100 | Loss: 4.0740
# [SimCLR] Epoch 048/100 | Loss: 4.0721
# [SimCLR] Epoch 049/100 | Loss: 4.0699
# [SimCLR] Epoch 050/100 | Loss: 4.0668
# [SimCLR] Epoch 051/100 | Loss: 4.0684
# [SimCLR] Epoch 052/100 | Loss: 4.0641
# [SimCLR] Epoch 053/100 | Loss: 4.0616
# [SimCLR] Epoch 054/100 | Loss: 4.0605
# [SimCLR] Epoch 055/100 | Loss: 4.0598
# [SimCLR] Epoch 056/100 | Loss: 4.0565
# [SimCLR] Epoch 057/100 | Loss: 4.0543
# [SimCLR] Epoch 058/100 | Loss: 4.0550
# [SimCLR] Epoch 059/100 | Loss: 4.0514
# [SimCLR] Epoch 060/100 | Loss: 4.0498
# [SimCLR] Epoch 061/100 | Loss: 4.0476
# [SimCLR] Epoch 062/100 | Loss: 4.0449
# [SimCLR] Epoch 063/100 | Loss: 4.0423
# [SimCLR] Epoch 064/100 | Loss: 4.0415
# [SimCLR] Epoch 065/100 | Loss: 4.0422
# [SimCLR] Epoch 066/100 | Loss: 4.0441
# [SimCLR] Epoch 067/100 | Loss: 4.0386
# [SimCLR] Epoch 068/100 | Loss: 4.0366
# [SimCLR] Epoch 069/100 | Loss: 4.0403
# [SimCLR] Epoch 070/100 | Loss: 4.0325
# [SimCLR] Epoch 071/100 | Loss: 4.0343
# [SimCLR] Epoch 072/100 | Loss: 4.0309
# [SimCLR] Epoch 073/100 | Loss: 4.0299
# [SimCLR] Epoch 074/100 | Loss: 4.0323
# [SimCLR] Epoch 075/100 | Loss: 4.0283
# [SimCLR] Epoch 076/100 | Loss: 4.0275
# [SimCLR] Epoch 077/100 | Loss: 4.0232
# [SimCLR] Epoch 078/100 | Loss: 4.0273
# [SimCLR] Epoch 079/100 | Loss: 4.0256
# [SimCLR] Epoch 080/100 | Loss: 4.0225
# [SimCLR] Epoch 081/100 | Loss: 4.0204
# [SimCLR] Epoch 082/100 | Loss: 4.0197
# [SimCLR] Epoch 083/100 | Loss: 4.0196
# [SimCLR] Epoch 084/100 | Loss: 4.0190
# [SimCLR] Epoch 085/100 | Loss: 4.0169
# [SimCLR] Epoch 086/100 | Loss: 4.0202
# [SimCLR] Epoch 087/100 | Loss: 4.0157
# [SimCLR] Epoch 088/100 | Loss: 4.0150
# [SimCLR] Epoch 089/100 | Loss: 4.0163
# [SimCLR] Epoch 090/100 | Loss: 4.0136
# [SimCLR] Epoch 091/100 | Loss: 4.0097
# [SimCLR] Epoch 092/100 | Loss: 4.0113
# [SimCLR] Epoch 093/100 | Loss: 4.0108
# [SimCLR] Epoch 094/100 | Loss: 4.0087
# [SimCLR] Epoch 095/100 | Loss: 4.0078
# [SimCLR] Epoch 096/100 | Loss: 4.0059
# [SimCLR] Epoch 097/100 | Loss: 4.0087
# [SimCLR] Epoch 098/100 | Loss: 4.0078
# [SimCLR] Epoch 099/100 | Loss: 4.0038
# [SimCLR] Epoch 100/100 | Loss: 4.0063
#
# Seed 7 finished in 153.96 minutes.
#
# ====================================
# Running Seed: 8
# ====================================
# [BYOL] Epoch 001/100 | Loss: 0.7482
# [BYOL] Epoch 002/100 | Loss: 0.5729
# [BYOL] Epoch 003/100 | Loss: 0.5125
# [BYOL] Epoch 004/100 | Loss: 0.4887
# [BYOL] Epoch 005/100 | Loss: 0.4739
# [BYOL] Epoch 006/100 | Loss: 0.4561
# [BYOL] Epoch 007/100 | Loss: 0.4491
# [BYOL] Epoch 008/100 | Loss: 0.4389
# [BYOL] Epoch 009/100 | Loss: 0.4327
# [BYOL] Epoch 010/100 | Loss: 0.4279
# [BYOL] Epoch 011/100 | Loss: 0.4216
# [BYOL] Epoch 012/100 | Loss: 0.4202
# [BYOL] Epoch 013/100 | Loss: 0.4152
# [BYOL] Epoch 014/100 | Loss: 0.4147
# [BYOL] Epoch 015/100 | Loss: 0.4105
# [BYOL] Epoch 016/100 | Loss: 0.4088
# [BYOL] Epoch 017/100 | Loss: 0.4078
# [BYOL] Epoch 018/100 | Loss: 0.4048
# [BYOL] Epoch 019/100 | Loss: 0.4046
# [BYOL] Epoch 020/100 | Loss: 0.4022
# [BYOL] Epoch 021/100 | Loss: 0.4029
# [BYOL] Epoch 022/100 | Loss: 0.4028
# [BYOL] Epoch 023/100 | Loss: 0.4021
# [BYOL] Epoch 024/100 | Loss: 0.3998
# [BYOL] Epoch 025/100 | Loss: 0.3992
# [BYOL] Epoch 026/100 | Loss: 0.4009
# [BYOL] Epoch 027/100 | Loss: 0.3980
# [BYOL] Epoch 028/100 | Loss: 0.3993
# [BYOL] Epoch 029/100 | Loss: 0.3988
# [BYOL] Epoch 030/100 | Loss: 0.3988
# [BYOL] Epoch 031/100 | Loss: 0.3980
# [BYOL] Epoch 032/100 | Loss: 0.3979
# [BYOL] Epoch 033/100 | Loss: 0.3978
# [BYOL] Epoch 034/100 | Loss: 0.3956
# [BYOL] Epoch 035/100 | Loss: 0.3969
# [BYOL] Epoch 036/100 | Loss: 0.3937
# [BYOL] Epoch 037/100 | Loss: 0.3944
# [BYOL] Epoch 038/100 | Loss: 0.3959
# [BYOL] Epoch 039/100 | Loss: 0.3951
# [BYOL] Epoch 040/100 | Loss: 0.3927
# [BYOL] Epoch 041/100 | Loss: 0.3936
# [BYOL] Epoch 042/100 | Loss: 0.3943
# [BYOL] Epoch 043/100 | Loss: 0.3897
# [BYOL] Epoch 044/100 | Loss: 0.3919
# [BYOL] Epoch 045/100 | Loss: 0.3911
# [BYOL] Epoch 046/100 | Loss: 0.3929
# [BYOL] Epoch 047/100 | Loss: 0.3906
# [BYOL] Epoch 048/100 | Loss: 0.3896
# [BYOL] Epoch 049/100 | Loss: 0.3909
# [BYOL] Epoch 050/100 | Loss: 0.3892
# [BYOL] Epoch 051/100 | Loss: 0.3904
# [BYOL] Epoch 052/100 | Loss: 0.3906
# [BYOL] Epoch 053/100 | Loss: 0.3908
# [BYOL] Epoch 054/100 | Loss: 0.3906
# [BYOL] Epoch 055/100 | Loss: 0.3904
# [BYOL] Epoch 056/100 | Loss: 0.3909
# [BYOL] Epoch 057/100 | Loss: 0.3919
# [BYOL] Epoch 058/100 | Loss: 0.3883
# [BYOL] Epoch 059/100 | Loss: 0.3903
# [BYOL] Epoch 060/100 | Loss: 0.3902
# [BYOL] Epoch 061/100 | Loss: 0.3898
# [BYOL] Epoch 062/100 | Loss: 0.3886
# [BYOL] Epoch 063/100 | Loss: 0.3906
# [BYOL] Epoch 064/100 | Loss: 0.3884
# [BYOL] Epoch 065/100 | Loss: 0.3891
# [BYOL] Epoch 066/100 | Loss: 0.3883
# [BYOL] Epoch 067/100 | Loss: 0.3887
# [BYOL] Epoch 068/100 | Loss: 0.3878
# [BYOL] Epoch 069/100 | Loss: 0.3879
# [BYOL] Epoch 070/100 | Loss: 0.3863
# [BYOL] Epoch 071/100 | Loss: 0.3876
# [BYOL] Epoch 072/100 | Loss: 0.3853
# [BYOL] Epoch 073/100 | Loss: 0.3848
# [BYOL] Epoch 074/100 | Loss: 0.3849
# [BYOL] Epoch 075/100 | Loss: 0.3846
# [BYOL] Epoch 076/100 | Loss: 0.3830
# [BYOL] Epoch 077/100 | Loss: 0.3836
# [BYOL] Epoch 078/100 | Loss: 0.3834
# [BYOL] Epoch 079/100 | Loss: 0.3829
# [BYOL] Epoch 080/100 | Loss: 0.3840
# [BYOL] Epoch 081/100 | Loss: 0.3812
# [BYOL] Epoch 082/100 | Loss: 0.3813
# [BYOL] Epoch 083/100 | Loss: 0.3828
# [BYOL] Epoch 084/100 | Loss: 0.3804
# [BYOL] Epoch 085/100 | Loss: 0.3794
# [BYOL] Epoch 086/100 | Loss: 0.3791
# [BYOL] Epoch 087/100 | Loss: 0.3819
# [BYOL] Epoch 088/100 | Loss: 0.3800
# [BYOL] Epoch 089/100 | Loss: 0.3781
# [BYOL] Epoch 090/100 | Loss: 0.3803
# [BYOL] Epoch 091/100 | Loss: 0.3796
# [BYOL] Epoch 092/100 | Loss: 0.3811
# [BYOL] Epoch 093/100 | Loss: 0.3804
# [BYOL] Epoch 094/100 | Loss: 0.3782
# [BYOL] Epoch 095/100 | Loss: 0.3782
# [BYOL] Epoch 096/100 | Loss: 0.3778
# [BYOL] Epoch 097/100 | Loss: 0.3775
# [BYOL] Epoch 098/100 | Loss: 0.3779
# [BYOL] Epoch 099/100 | Loss: 0.3777
# [BYOL] Epoch 100/100 | Loss: 0.3784
# [SimCLR] Epoch 001/100 | Loss: 4.6770
# [SimCLR] Epoch 002/100 | Loss: 4.5059
# [SimCLR] Epoch 003/100 | Loss: 4.4332
# [SimCLR] Epoch 004/100 | Loss: 4.3896
# [SimCLR] Epoch 005/100 | Loss: 4.3588
# [SimCLR] Epoch 006/100 | Loss: 4.3397
# [SimCLR] Epoch 007/100 | Loss: 4.3166
# [SimCLR] Epoch 008/100 | Loss: 4.2993
# [SimCLR] Epoch 009/100 | Loss: 4.2816
# [SimCLR] Epoch 010/100 | Loss: 4.2703
# [SimCLR] Epoch 011/100 | Loss: 4.2544
# [SimCLR] Epoch 012/100 | Loss: 4.2411
# [SimCLR] Epoch 013/100 | Loss: 4.2298
# [SimCLR] Epoch 014/100 | Loss: 4.2195
# [SimCLR] Epoch 015/100 | Loss: 4.2088
# [SimCLR] Epoch 016/100 | Loss: 4.1975
# [SimCLR] Epoch 017/100 | Loss: 4.1913
# [SimCLR] Epoch 018/100 | Loss: 4.1834
# [SimCLR] Epoch 019/100 | Loss: 4.1789
# [SimCLR] Epoch 020/100 | Loss: 4.1696
# [SimCLR] Epoch 021/100 | Loss: 4.1667
# [SimCLR] Epoch 022/100 | Loss: 4.1626
# [SimCLR] Epoch 023/100 | Loss: 4.1542
# [SimCLR] Epoch 024/100 | Loss: 4.1484
# [SimCLR] Epoch 025/100 | Loss: 4.1445
# [SimCLR] Epoch 026/100 | Loss: 4.1424
# [SimCLR] Epoch 027/100 | Loss: 4.1376
# [SimCLR] Epoch 028/100 | Loss: 4.1290
# [SimCLR] Epoch 029/100 | Loss: 4.1266
# [SimCLR] Epoch 030/100 | Loss: 4.1267
# [SimCLR] Epoch 031/100 | Loss: 4.1214
# [SimCLR] Epoch 032/100 | Loss: 4.1178
# [SimCLR] Epoch 033/100 | Loss: 4.1168
# [SimCLR] Epoch 034/100 | Loss: 4.1111
# [SimCLR] Epoch 035/100 | Loss: 4.1108
# [SimCLR] Epoch 036/100 | Loss: 4.1074
# [SimCLR] Epoch 037/100 | Loss: 4.1025
# [SimCLR] Epoch 038/100 | Loss: 4.0987
# [SimCLR] Epoch 039/100 | Loss: 4.0959
# [SimCLR] Epoch 040/100 | Loss: 4.0933
# [SimCLR] Epoch 041/100 | Loss: 4.0907
# [SimCLR] Epoch 042/100 | Loss: 4.0897
# [SimCLR] Epoch 043/100 | Loss: 4.0826
# [SimCLR] Epoch 044/100 | Loss: 4.0826
# [SimCLR] Epoch 045/100 | Loss: 4.0802
# [SimCLR] Epoch 046/100 | Loss: 4.0752
# [SimCLR] Epoch 047/100 | Loss: 4.0752
# [SimCLR] Epoch 048/100 | Loss: 4.0732
# [SimCLR] Epoch 049/100 | Loss: 4.0710
# [SimCLR] Epoch 050/100 | Loss: 4.0713
# [SimCLR] Epoch 051/100 | Loss: 4.0663
# [SimCLR] Epoch 052/100 | Loss: 4.0623
# [SimCLR] Epoch 053/100 | Loss: 4.0630
# [SimCLR] Epoch 054/100 | Loss: 4.0595
# [SimCLR] Epoch 055/100 | Loss: 4.0580
# [SimCLR] Epoch 056/100 | Loss: 4.0557
# [SimCLR] Epoch 057/100 | Loss: 4.0529
# [SimCLR] Epoch 058/100 | Loss: 4.0518
# [SimCLR] Epoch 059/100 | Loss: 4.0517
# [SimCLR] Epoch 060/100 | Loss: 4.0492
# [SimCLR] Epoch 061/100 | Loss: 4.0463
# [SimCLR] Epoch 062/100 | Loss: 4.0469
# [SimCLR] Epoch 063/100 | Loss: 4.0449
# [SimCLR] Epoch 064/100 | Loss: 4.0433
# [SimCLR] Epoch 065/100 | Loss: 4.0391
# [SimCLR] Epoch 066/100 | Loss: 4.0377
# [SimCLR] Epoch 067/100 | Loss: 4.0376
# [SimCLR] Epoch 068/100 | Loss: 4.0374
# [SimCLR] Epoch 069/100 | Loss: 4.0367
# [SimCLR] Epoch 070/100 | Loss: 4.0362
# [SimCLR] Epoch 071/100 | Loss: 4.0340
# [SimCLR] Epoch 072/100 | Loss: 4.0309
# [SimCLR] Epoch 073/100 | Loss: 4.0317
# [SimCLR] Epoch 074/100 | Loss: 4.0281
# [SimCLR] Epoch 075/100 | Loss: 4.0294
# [SimCLR] Epoch 076/100 | Loss: 4.0273
# [SimCLR] Epoch 077/100 | Loss: 4.0248
# [SimCLR] Epoch 078/100 | Loss: 4.0227
# [SimCLR] Epoch 079/100 | Loss: 4.0230
# [SimCLR] Epoch 080/100 | Loss: 4.0213
# [SimCLR] Epoch 081/100 | Loss: 4.0225
# [SimCLR] Epoch 082/100 | Loss: 4.0210
# [SimCLR] Epoch 083/100 | Loss: 4.0219
# [SimCLR] Epoch 084/100 | Loss: 4.0174
# [SimCLR] Epoch 085/100 | Loss: 4.0161
# [SimCLR] Epoch 086/100 | Loss: 4.0147
# [SimCLR] Epoch 087/100 | Loss: 4.0146
# [SimCLR] Epoch 088/100 | Loss: 4.0138
# [SimCLR] Epoch 089/100 | Loss: 4.0150
# [SimCLR] Epoch 090/100 | Loss: 4.0103
# [SimCLR] Epoch 091/100 | Loss: 4.0100
# [SimCLR] Epoch 092/100 | Loss: 4.0109
# [SimCLR] Epoch 093/100 | Loss: 4.0089
# [SimCLR] Epoch 094/100 | Loss: 4.0106
# [SimCLR] Epoch 095/100 | Loss: 4.0075
# [SimCLR] Epoch 096/100 | Loss: 4.0088
# [SimCLR] Epoch 097/100 | Loss: 4.0054
# [SimCLR] Epoch 098/100 | Loss: 4.0058
# [SimCLR] Epoch 099/100 | Loss: 4.0038
# [SimCLR] Epoch 100/100 | Loss: 4.0036
#
# Seed 8 finished in 151.01 minutes.
#
# ====================================
# Running Seed: 9
# ====================================
# [BYOL] Epoch 001/100 | Loss: 0.7968
# [BYOL] Epoch 002/100 | Loss: 0.6092
# [BYOL] Epoch 003/100 | Loss: 0.5479
# [BYOL] Epoch 004/100 | Loss: 0.5183
# [BYOL] Epoch 005/100 | Loss: 0.5022
# [BYOL] Epoch 006/100 | Loss: 0.4898
# [BYOL] Epoch 007/100 | Loss: 0.4813
# [BYOL] Epoch 008/100 | Loss: 0.4747
# [BYOL] Epoch 009/100 | Loss: 0.4684
# [BYOL] Epoch 010/100 | Loss: 0.4580
# [BYOL] Epoch 011/100 | Loss: 0.4512
# [BYOL] Epoch 012/100 | Loss: 0.4495
# [BYOL] Epoch 013/100 | Loss: 0.4444
# [BYOL] Epoch 014/100 | Loss: 0.4418
# [BYOL] Epoch 015/100 | Loss: 0.4387
# [BYOL] Epoch 016/100 | Loss: 0.4399
# [BYOL] Epoch 017/100 | Loss: 0.4370
# [BYOL] Epoch 018/100 | Loss: 0.4363
# [BYOL] Epoch 019/100 | Loss: 0.4321
# [BYOL] Epoch 020/100 | Loss: 0.4318
# [BYOL] Epoch 021/100 | Loss: 0.4337
# [BYOL] Epoch 022/100 | Loss: 0.4323
# [BYOL] Epoch 023/100 | Loss: 0.4314
# [BYOL] Epoch 024/100 | Loss: 0.4281
# [BYOL] Epoch 025/100 | Loss: 0.4277
# [BYOL] Epoch 026/100 | Loss: 0.4286
# [BYOL] Epoch 027/100 | Loss: 0.4270
# [BYOL] Epoch 028/100 | Loss: 0.4235
# [BYOL] Epoch 029/100 | Loss: 0.4239
# [BYOL] Epoch 030/100 | Loss: 0.4237
# [BYOL] Epoch 031/100 | Loss: 0.4230
# [BYOL] Epoch 032/100 | Loss: 0.4210
# [BYOL] Epoch 033/100 | Loss: 0.4195
# [BYOL] Epoch 034/100 | Loss: 0.4225
# [BYOL] Epoch 035/100 | Loss: 0.4182
# [BYOL] Epoch 036/100 | Loss: 0.4186
# [BYOL] Epoch 037/100 | Loss: 0.4181
# [BYOL] Epoch 038/100 | Loss: 0.4142
# [BYOL] Epoch 039/100 | Loss: 0.4152
# [BYOL] Epoch 040/100 | Loss: 0.4117
# [BYOL] Epoch 041/100 | Loss: 0.4123
# [BYOL] Epoch 042/100 | Loss: 0.4107
# [BYOL] Epoch 043/100 | Loss: 0.4115
# [BYOL] Epoch 044/100 | Loss: 0.4090
# [BYOL] Epoch 045/100 | Loss: 0.4098
# [BYOL] Epoch 046/100 | Loss: 0.4107
# [BYOL] Epoch 047/100 | Loss: 0.4114
# [BYOL] Epoch 048/100 | Loss: 0.4108
# [BYOL] Epoch 049/100 | Loss: 0.4102
# [BYOL] Epoch 050/100 | Loss: 0.4094
# [BYOL] Epoch 051/100 | Loss: 0.4105
# [BYOL] Epoch 052/100 | Loss: 0.4085
# [BYOL] Epoch 053/100 | Loss: 0.4092
# [BYOL] Epoch 054/100 | Loss: 0.4107
# [BYOL] Epoch 055/100 | Loss: 0.4112
# [BYOL] Epoch 056/100 | Loss: 0.4100
# [BYOL] Epoch 057/100 | Loss: 0.4101
# [BYOL] Epoch 058/100 | Loss: 0.4110
# [BYOL] Epoch 059/100 | Loss: 0.4081
# [BYOL] Epoch 060/100 | Loss: 0.4100
# [BYOL] Epoch 061/100 | Loss: 0.4093
# [BYOL] Epoch 062/100 | Loss: 0.4089
# [BYOL] Epoch 063/100 | Loss: 0.4062
# [BYOL] Epoch 064/100 | Loss: 0.4081
# [BYOL] Epoch 065/100 | Loss: 0.4075
# [BYOL] Epoch 066/100 | Loss: 0.4088
# [BYOL] Epoch 067/100 | Loss: 0.4076
# [BYOL] Epoch 068/100 | Loss: 0.4078
# [BYOL] Epoch 069/100 | Loss: 0.4072
# [BYOL] Epoch 070/100 | Loss: 0.4090
# [BYOL] Epoch 071/100 | Loss: 0.4068
# [BYOL] Epoch 072/100 | Loss: 0.4052
# [BYOL] Epoch 073/100 | Loss: 0.4048
# [BYOL] Epoch 074/100 | Loss: 0.4033
# [BYOL] Epoch 075/100 | Loss: 0.4050
# [BYOL] Epoch 076/100 | Loss: 0.4053
# [BYOL] Epoch 077/100 | Loss: 0.4050
# [BYOL] Epoch 078/100 | Loss: 0.4069
# [BYOL] Epoch 079/100 | Loss: 0.4052
# [BYOL] Epoch 080/100 | Loss: 0.4061
# [BYOL] Epoch 081/100 | Loss: 0.4041
# [BYOL] Epoch 082/100 | Loss: 0.4051
# [BYOL] Epoch 083/100 | Loss: 0.4044
# [BYOL] Epoch 084/100 | Loss: 0.4037
# [BYOL] Epoch 085/100 | Loss: 0.4037
# [BYOL] Epoch 086/100 | Loss: 0.4023
# [BYOL] Epoch 087/100 | Loss: 0.4015
# [BYOL] Epoch 088/100 | Loss: 0.4017
# [BYOL] Epoch 089/100 | Loss: 0.4030
# [BYOL] Epoch 090/100 | Loss: 0.4010
# [BYOL] Epoch 091/100 | Loss: 0.4015
# [BYOL] Epoch 092/100 | Loss: 0.4029
# [BYOL] Epoch 093/100 | Loss: 0.4004
# [BYOL] Epoch 094/100 | Loss: 0.4017
# [BYOL] Epoch 095/100 | Loss: 0.4022
# [BYOL] Epoch 096/100 | Loss: 0.4019
# [BYOL] Epoch 097/100 | Loss: 0.4004
# [BYOL] Epoch 098/100 | Loss: 0.3986
# [BYOL] Epoch 099/100 | Loss: 0.4010
# [BYOL] Epoch 100/100 | Loss: 0.4002
# [SimCLR] Epoch 001/100 | Loss: 4.6682
# [SimCLR] Epoch 002/100 | Loss: 4.4883
# [SimCLR] Epoch 003/100 | Loss: 4.4264
# [SimCLR] Epoch 004/100 | Loss: 4.3848
# [SimCLR] Epoch 005/100 | Loss: 4.3530
# [SimCLR] Epoch 006/100 | Loss: 4.3324
# [SimCLR] Epoch 007/100 | Loss: 4.3080
# [SimCLR] Epoch 008/100 | Loss: 4.2901
# [SimCLR] Epoch 009/100 | Loss: 4.2707
# [SimCLR] Epoch 010/100 | Loss: 4.2593
# [SimCLR] Epoch 011/100 | Loss: 4.2475
# [SimCLR] Epoch 012/100 | Loss: 4.2336
# [SimCLR] Epoch 013/100 | Loss: 4.2200
# [SimCLR] Epoch 014/100 | Loss: 4.2116
# [SimCLR] Epoch 015/100 | Loss: 4.2045
# [SimCLR] Epoch 016/100 | Loss: 4.1943
# [SimCLR] Epoch 017/100 | Loss: 4.1826
# [SimCLR] Epoch 018/100 | Loss: 4.1774
# [SimCLR] Epoch 019/100 | Loss: 4.1725
# [SimCLR] Epoch 020/100 | Loss: 4.1636
# [SimCLR] Epoch 021/100 | Loss: 4.1614
# [SimCLR] Epoch 022/100 | Loss: 4.1565
# [SimCLR] Epoch 023/100 | Loss: 4.1520
# [SimCLR] Epoch 024/100 | Loss: 4.1439
# [SimCLR] Epoch 025/100 | Loss: 4.1400
# [SimCLR] Epoch 026/100 | Loss: 4.1312
# [SimCLR] Epoch 027/100 | Loss: 4.1316
# [SimCLR] Epoch 028/100 | Loss: 4.1283
# [SimCLR] Epoch 029/100 | Loss: 4.1237
# [SimCLR] Epoch 030/100 | Loss: 4.1223
# [SimCLR] Epoch 031/100 | Loss: 4.1158
# [SimCLR] Epoch 032/100 | Loss: 4.1134
# [SimCLR] Epoch 033/100 | Loss: 4.1123
# [SimCLR] Epoch 034/100 | Loss: 4.1088
# [SimCLR] Epoch 035/100 | Loss: 4.1047
# [SimCLR] Epoch 036/100 | Loss: 4.1004
# [SimCLR] Epoch 037/100 | Loss: 4.0986
# [SimCLR] Epoch 038/100 | Loss: 4.0944
# [SimCLR] Epoch 039/100 | Loss: 4.0944
# [SimCLR] Epoch 040/100 | Loss: 4.0890
# [SimCLR] Epoch 041/100 | Loss: 4.0853
# [SimCLR] Epoch 042/100 | Loss: 4.0893
# [SimCLR] Epoch 043/100 | Loss: 4.0836
# [SimCLR] Epoch 044/100 | Loss: 4.0797
# [SimCLR] Epoch 045/100 | Loss: 4.0811
# [SimCLR] Epoch 046/100 | Loss: 4.0762
# [SimCLR] Epoch 047/100 | Loss: 4.0728
# [SimCLR] Epoch 048/100 | Loss: 4.0734
# [SimCLR] Epoch 049/100 | Loss: 4.0684
# [SimCLR] Epoch 050/100 | Loss: 4.0692
# [SimCLR] Epoch 051/100 | Loss: 4.0662
# [SimCLR] Epoch 052/100 | Loss: 4.0635
# [SimCLR] Epoch 053/100 | Loss: 4.0612
# [SimCLR] Epoch 054/100 | Loss: 4.0615
# [SimCLR] Epoch 055/100 | Loss: 4.0584
# [SimCLR] Epoch 056/100 | Loss: 4.0562
# [SimCLR] Epoch 057/100 | Loss: 4.0564
# [SimCLR] Epoch 058/100 | Loss: 4.0511
# [SimCLR] Epoch 059/100 | Loss: 4.0522
# [SimCLR] Epoch 060/100 | Loss: 4.0490
# [SimCLR] Epoch 061/100 | Loss: 4.0503
# [SimCLR] Epoch 062/100 | Loss: 4.0471
# [SimCLR] Epoch 063/100 | Loss: 4.0444
# [SimCLR] Epoch 064/100 | Loss: 4.0390
# [SimCLR] Epoch 065/100 | Loss: 4.0407
# [SimCLR] Epoch 066/100 | Loss: 4.0407
# [SimCLR] Epoch 067/100 | Loss: 4.0400
# [SimCLR] Epoch 068/100 | Loss: 4.0384
# [SimCLR] Epoch 069/100 | Loss: 4.0346
# [SimCLR] Epoch 070/100 | Loss: 4.0337
# [SimCLR] Epoch 071/100 | Loss: 4.0333
# [SimCLR] Epoch 072/100 | Loss: 4.0314
# [SimCLR] Epoch 073/100 | Loss: 4.0278
# [SimCLR] Epoch 074/100 | Loss: 4.0295
# [SimCLR] Epoch 075/100 | Loss: 4.0274
# [SimCLR] Epoch 076/100 | Loss: 4.0254
# [SimCLR] Epoch 077/100 | Loss: 4.0242
# [SimCLR] Epoch 078/100 | Loss: 4.0234
# [SimCLR] Epoch 079/100 | Loss: 4.0244
# [SimCLR] Epoch 080/100 | Loss: 4.0202
# [SimCLR] Epoch 081/100 | Loss: 4.0230
# [SimCLR] Epoch 082/100 | Loss: 4.0196
# [SimCLR] Epoch 083/100 | Loss: 4.0220
# [SimCLR] Epoch 084/100 | Loss: 4.0191
# [SimCLR] Epoch 085/100 | Loss: 4.0168
# [SimCLR] Epoch 086/100 | Loss: 4.0184
# [SimCLR] Epoch 087/100 | Loss: 4.0155
# [SimCLR] Epoch 088/100 | Loss: 4.0132
# [SimCLR] Epoch 089/100 | Loss: 4.0141
# [SimCLR] Epoch 090/100 | Loss: 4.0106
# [SimCLR] Epoch 091/100 | Loss: 4.0119
# [SimCLR] Epoch 092/100 | Loss: 4.0108
# [SimCLR] Epoch 093/100 | Loss: 4.0092
# [SimCLR] Epoch 094/100 | Loss: 4.0098
# [SimCLR] Epoch 095/100 | Loss: 4.0072
# [SimCLR] Epoch 096/100 | Loss: 4.0075
# [SimCLR] Epoch 097/100 | Loss: 4.0051
# [SimCLR] Epoch 098/100 | Loss: 4.0052
# [SimCLR] Epoch 099/100 | Loss: 4.0046
# [SimCLR] Epoch 100/100 | Loss: 4.0018
#
# Seed 9 finished in 149.62 minutes.
#
# Per-Seed Results:
#    Seed  BYOL_Jacobian  SimCLR_Jacobian   BYOL_Aug  SimCLR_Aug  BYOL_Noise  \
# 0     7      57.726341        76.654443  14.655105   16.837846   13.272981
# 1     8      56.303027        78.487070  13.627081   16.592493   12.186098
# 2     9      56.597913        79.457239  13.955205   16.963944   13.141546
#
#    SimCLR_Noise  BYOL_Acc  SimCLR_Acc  Seed_Time_Min
# 0     17.666337    0.6424      0.6931     153.963221
# 1     18.593357    0.6402      0.6894     151.014840
# 2     18.279577    0.6582      0.6930     149.624866
#
# Mean Across Seeds:
# Seed                 8.000000
# BYOL_Jacobian       56.875760
# SimCLR_Jacobian     78.199584
# BYOL_Aug            14.079130
# SimCLR_Aug          16.798094
# BYOL_Noise          12.866875
# SimCLR_Noise        18.179757
# BYOL_Acc             0.646933
# SimCLR_Acc           0.691833
# Seed_Time_Min      151.534309
# dtype: float64
#
# Std Across Seeds:
# Seed               1.000000
# BYOL_Jacobian      0.751236
# SimCLR_Jacobian    1.423342
# BYOL_Aug           0.525097
# SimCLR_Aug         0.188889
# BYOL_Noise         0.593222
# SimCLR_Noise       0.471503
# BYOL_Acc           0.009819
# SimCLR_Acc         0.002108
# Seed_Time_Min      2.215337
# dtype: float64
#
# Total Experiment Time: 454.60 minutes.

# %%
results_df.to_csv("/kaggle/working/results.csv", index=False)
