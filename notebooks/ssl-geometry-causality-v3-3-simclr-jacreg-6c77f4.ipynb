# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import numpy as np
import random
import pandas as pd
import time
import scipy.stats as stats

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def set_seed(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
# Out:
# Device: cuda

# %%
class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform
    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)

ssl_base_transform = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2,1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor()
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=ssl_transform
)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=T.ToTensor()
)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)
# Out:
# 100%|██████████| 170M/170M [00:48<00:00, 3.53MB/s]

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        backbone = resnet18(weights=None)
        backbone.fc = nn.Identity()
        self.backbone = backbone
    def forward(self, x):
        return self.backbone(x)

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, hidden_dim=2048, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )
    def forward(self, x):
        return self.net(x)

class BYOL(nn.Module):
    def __init__(self):
        super().__init__()
        self.online_encoder = Encoder()
        self.online_projector = MLP(512)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder = Encoder()
        self.target_projector = MLP(512)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for o, t in zip(self.online_encoder.parameters(),
                        self.target_encoder.parameters()):
            t.data = tau * t.data + (1 - tau) * o.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(
            self.online_projector(self.online_encoder(x1))
        )

        with torch.no_grad():
            t2 = self.target_projector(
                self.target_encoder(x2)
            )

        loss = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        return loss.mean()

# %%
class SimCLR(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.projector = MLP(512)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)

def nt_xent_loss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)

    sim = torch.mm(z, z.t()) / temperature
    mask = torch.eye(2*N, device=z.device).bool()
    sim.masked_fill_(mask, -9e15)

    positives = torch.cat([
        torch.arange(N,2*N),
        torch.arange(0,N)
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
def jacobian_penalty(model, x):
    x = x.clone().detach().requires_grad_(True)
    z = model(x)

    v = torch.randn_like(z)

    Jv = torch.autograd.grad(
        outputs=z,
        inputs=x,
        grad_outputs=v,
        create_graph=True
    )[0]

    return Jv.pow(2).sum(dim=[1,2,3]).mean()

# %%
def train_byol(model, epochs=100):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            loss = model(x1,x2)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            model.update_target()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[BYOL] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.online_encoder


def train_simclr(model, epochs=100, lambda_jac=0.0):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

    total_start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()
        model.train()
        total_loss = 0

        for (x1,x2), _ in train_loader:
            x1,x2 = x1.to(device), x2.to(device)

            z1 = model(x1)
            z2 = model(x2)
            loss = nt_xent_loss(z1,z2)

            if lambda_jac > 0:
                jac = jacobian_penalty(model, x1)
                loss = loss + lambda_jac * jac

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        epoch_time = (time.time() - epoch_start)/60
        total_time = (time.time() - total_start)/60

        print(f"[SimCLR] {epoch+1:03d}/{epochs} | "
              f"Loss: {total_loss/len(train_loader):.4f} | "
              f"Epoch Time: {epoch_time:.2f}m | "
              f"Total Time: {total_time:.2f}m")

    return model.encoder

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(512, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    return correct / total

# %%
# =========================================================
# Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(32, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4,0.4,0.4,0.1),
    T.RandomGrayscale(p=0.2),
])


def jacobian_frobenius(model, x):
    model.eval()
    x = x.clone().detach().requires_grad_(True)

    y = model(x)

    v = torch.randn_like(y)

    Jv = torch.autograd.grad(
        outputs=y,
        inputs=x,
        grad_outputs=v,
        create_graph=False,
        retain_graph=False
    )[0]

    # Proper per-sample Frobenius estimate
    per_sample = Jv.pow(2).flatten(1).sum(dim=1)

    return torch.sqrt(per_sample.mean())


def compute_metrics(encoder, loader):
    encoder = encoder.to(device)
    encoder.eval()

    jac_vals = []
    aug_vals = []
    noise_vals = []

    for i, (x, _) in enumerate(loader):
        if i == 5:  # limit batches
            break

        x = x.to(device)

        # ---- Jacobian ----
        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # ---- Augmentation Sensitivity ----
        x_aug = torch.stack([
            tensor_aug(img.cpu()) for img in x
        ]).to(device)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        # ---- Noise Sensitivity ----
        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x + noise)
            noise_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

    return (
        np.mean(jac_vals),
        np.mean(aug_vals),
        np.mean(noise_vals)
    )

# %%
# =========================================================
# Supervised Data (for Linear Probe)
# =========================================================

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=False,
    transform=T.ToTensor()
)

supervised_test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=False,
    transform=T.ToTensor()
)

supervised_train_loader = DataLoader(
    supervised_train_dataset,
    batch_size=128,
    shuffle=True,
    num_workers=2
)

supervised_test_loader = DataLoader(
    supervised_test_dataset,
    batch_size=128,
    shuffle=False,
    num_workers=2
)

print("Supervised loaders ready.")
# Out:
# Supervised loaders ready.

# %%
import os

# =========================================================
# CONFIG
# =========================================================

csv_path = "/kaggle/working/byol_simclr_results.csv"
target_seeds = [5, ]  
# =========================================================
# RESUME LOGIC
# =========================================================

if os.path.exists(csv_path):
    existing_df = pd.read_csv(csv_path)
    completed_seeds = set(existing_df["Seed"].unique())
    all_results = existing_df.to_dict("records")
    print("Loaded existing results. Completed seeds:", completed_seeds)
else:
    completed_seeds = set()
    all_results = []
    print("No existing CSV found. Starting fresh.")

seeds = [s for s in target_seeds if s not in completed_seeds]

print("Seeds to run now:", seeds)

global_start = time.time()

# =========================================================
# MAIN LOOP
# =========================================================

for seed in seeds:

    print("\n====================================")
    print(f"Running Seed: {seed}")
    print("====================================")

    seed_start = time.time()
    set_seed(seed)

    # ------------------------
    # Train Models
    # ------------------------

    byol_encoder = train_byol(BYOL(), epochs=100)

    simclr_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=0.0
    )

    simclr_jac_encoder = train_simclr(
        SimCLR(),
        epochs=100,
        lambda_jac=1e-3
    )

    # ------------------------
    # Compute Metrics
    # ------------------------

    byol_metrics = compute_metrics(byol_encoder, test_loader)
    simclr_metrics = compute_metrics(simclr_encoder, test_loader)
    simclr_jac_metrics = compute_metrics(simclr_jac_encoder, test_loader)

    # ------------------------
    # Linear Probe
    # ------------------------

    byol_acc = train_probe(
        byol_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_acc = train_probe(
        simclr_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    simclr_jac_acc = train_probe(
        simclr_jac_encoder,
        supervised_train_loader,
        supervised_test_loader
    )

    # ------------------------
    # Store Results
    # ------------------------

    seed_results = [
        {
            "Seed": seed,
            "Method": "BYOL",
            "Jacobian": byol_metrics[0],
            "Aug_Sensitivity": byol_metrics[1],
            "Noise_Sensitivity": byol_metrics[2],
            "Linear_Probe_Acc": byol_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR",
            "Jacobian": simclr_metrics[0],
            "Aug_Sensitivity": simclr_metrics[1],
            "Noise_Sensitivity": simclr_metrics[2],
            "Linear_Probe_Acc": simclr_acc
        },
        {
            "Seed": seed,
            "Method": "SimCLR+Jac",
            "Jacobian": simclr_jac_metrics[0],
            "Aug_Sensitivity": simclr_jac_metrics[1],
            "Noise_Sensitivity": simclr_jac_metrics[2],
            "Linear_Probe_Acc": simclr_jac_acc
        }
    ]

    all_results.extend(seed_results)

    # ------------------------
    # SAVE AFTER EACH SEED
    # ------------------------

    results_df = pd.DataFrame(all_results)
    results_df.to_csv(csv_path, index=False)

    print("Saved results to:", csv_path)

    # ------------------------
    # Running Summary
    # ------------------------

    summary = results_df.groupby("Method").mean(numeric_only=True)
    print("\nRunning Mean Summary:")
    print(summary)

    # ------------------------
    # GPU Cleanup
    # ------------------------

    del byol_encoder, simclr_encoder, simclr_jac_encoder
    torch.cuda.empty_cache()

    seed_time = (time.time() - seed_start) / 60
    print(f"\nSeed {seed} finished in {seed_time:.2f} minutes")

# =========================================================
# FINAL SUMMARY
# =========================================================

final_df = pd.read_csv(csv_path)

print("\n================ FINAL RESULTS ================")
print(final_df)

total_time = (time.time() - global_start) / 60
print(f"\nTotal experiment time (this session): {total_time:.2f} minutes")
# Out:
# No existing CSV found. Starting fresh.
# Seeds to run now: [5]
#
# ====================================
# Running Seed: 5
# ====================================
# [BYOL] 001/100 | Loss: 0.8223 | Epoch Time: 0.84m | Total Time: 0.84m
# [BYOL] 002/100 | Loss: 0.5989 | Epoch Time: 0.79m | Total Time: 1.63m
# [BYOL] 003/100 | Loss: 0.5374 | Epoch Time: 0.78m | Total Time: 2.41m
# [BYOL] 004/100 | Loss: 0.5035 | Epoch Time: 0.79m | Total Time: 3.20m
# [BYOL] 005/100 | Loss: 0.4832 | Epoch Time: 0.78m | Total Time: 3.98m
# [BYOL] 006/100 | Loss: 0.4736 | Epoch Time: 0.77m | Total Time: 4.75m
# [BYOL] 007/100 | Loss: 0.4650 | Epoch Time: 0.78m | Total Time: 5.53m
# [BYOL] 008/100 | Loss: 0.4619 | Epoch Time: 0.77m | Total Time: 6.30m
# [BYOL] 009/100 | Loss: 0.4542 | Epoch Time: 0.79m | Total Time: 7.09m
# [BYOL] 010/100 | Loss: 0.4480 | Epoch Time: 0.78m | Total Time: 7.87m
# [BYOL] 011/100 | Loss: 0.4450 | Epoch Time: 0.78m | Total Time: 8.65m
# [BYOL] 012/100 | Loss: 0.4419 | Epoch Time: 0.79m | Total Time: 9.44m
# [BYOL] 013/100 | Loss: 0.4385 | Epoch Time: 0.80m | Total Time: 10.24m
# [BYOL] 014/100 | Loss: 0.4370 | Epoch Time: 0.79m | Total Time: 11.02m
# [BYOL] 015/100 | Loss: 0.4332 | Epoch Time: 0.77m | Total Time: 11.79m
# [BYOL] 016/100 | Loss: 0.4308 | Epoch Time: 0.79m | Total Time: 12.58m
# [BYOL] 017/100 | Loss: 0.4316 | Epoch Time: 0.77m | Total Time: 13.35m
# [BYOL] 018/100 | Loss: 0.4311 | Epoch Time: 0.77m | Total Time: 14.12m
# [BYOL] 019/100 | Loss: 0.4305 | Epoch Time: 0.78m | Total Time: 14.90m
# [BYOL] 020/100 | Loss: 0.4290 | Epoch Time: 0.78m | Total Time: 15.68m
# [BYOL] 021/100 | Loss: 0.4290 | Epoch Time: 0.78m | Total Time: 16.46m
# [BYOL] 022/100 | Loss: 0.4268 | Epoch Time: 0.80m | Total Time: 17.26m
# [BYOL] 023/100 | Loss: 0.4269 | Epoch Time: 0.78m | Total Time: 18.05m
# [BYOL] 024/100 | Loss: 0.4259 | Epoch Time: 0.79m | Total Time: 18.84m
# [BYOL] 025/100 | Loss: 0.4235 | Epoch Time: 0.79m | Total Time: 19.63m
# [BYOL] 026/100 | Loss: 0.4193 | Epoch Time: 0.81m | Total Time: 20.44m
# [BYOL] 027/100 | Loss: 0.4210 | Epoch Time: 0.79m | Total Time: 21.23m
# [BYOL] 028/100 | Loss: 0.4187 | Epoch Time: 0.79m | Total Time: 22.02m
# [BYOL] 029/100 | Loss: 0.4199 | Epoch Time: 0.79m | Total Time: 22.80m
# [BYOL] 030/100 | Loss: 0.4167 | Epoch Time: 0.79m | Total Time: 23.59m
# [BYOL] 031/100 | Loss: 0.4159 | Epoch Time: 0.79m | Total Time: 24.39m
# [BYOL] 032/100 | Loss: 0.4141 | Epoch Time: 0.79m | Total Time: 25.18m
# [BYOL] 033/100 | Loss: 0.4130 | Epoch Time: 0.78m | Total Time: 25.96m
# [BYOL] 034/100 | Loss: 0.4107 | Epoch Time: 0.79m | Total Time: 26.75m
# [BYOL] 035/100 | Loss: 0.4096 | Epoch Time: 0.80m | Total Time: 27.55m
# [BYOL] 036/100 | Loss: 0.4099 | Epoch Time: 0.79m | Total Time: 28.34m
# [BYOL] 037/100 | Loss: 0.4095 | Epoch Time: 0.80m | Total Time: 29.14m
# [BYOL] 038/100 | Loss: 0.4093 | Epoch Time: 0.81m | Total Time: 29.95m
# [BYOL] 039/100 | Loss: 0.4085 | Epoch Time: 0.80m | Total Time: 30.75m
# [BYOL] 040/100 | Loss: 0.4068 | Epoch Time: 0.83m | Total Time: 31.58m
# [BYOL] 041/100 | Loss: 0.4054 | Epoch Time: 0.90m | Total Time: 32.48m
# [BYOL] 042/100 | Loss: 0.4062 | Epoch Time: 0.91m | Total Time: 33.39m
# [BYOL] 043/100 | Loss: 0.4049 | Epoch Time: 0.91m | Total Time: 34.30m
# [BYOL] 044/100 | Loss: 0.4040 | Epoch Time: 0.92m | Total Time: 35.22m
# [BYOL] 045/100 | Loss: 0.4037 | Epoch Time: 0.91m | Total Time: 36.13m
# [BYOL] 046/100 | Loss: 0.4028 | Epoch Time: 0.88m | Total Time: 37.01m
# [BYOL] 047/100 | Loss: 0.4038 | Epoch Time: 0.86m | Total Time: 37.87m
# [BYOL] 048/100 | Loss: 0.4024 | Epoch Time: 0.86m | Total Time: 38.73m
# [BYOL] 049/100 | Loss: 0.4010 | Epoch Time: 0.85m | Total Time: 39.58m
# [BYOL] 050/100 | Loss: 0.4009 | Epoch Time: 0.85m | Total Time: 40.44m
# [BYOL] 051/100 | Loss: 0.4005 | Epoch Time: 0.86m | Total Time: 41.29m
# [BYOL] 052/100 | Loss: 0.4001 | Epoch Time: 0.86m | Total Time: 42.16m
# [BYOL] 053/100 | Loss: 0.4014 | Epoch Time: 0.87m | Total Time: 43.02m
# [BYOL] 054/100 | Loss: 0.4011 | Epoch Time: 0.85m | Total Time: 43.88m
# [BYOL] 055/100 | Loss: 0.4006 | Epoch Time: 0.87m | Total Time: 44.75m
# [BYOL] 056/100 | Loss: 0.3984 | Epoch Time: 0.85m | Total Time: 45.59m
# [BYOL] 057/100 | Loss: 0.4019 | Epoch Time: 0.85m | Total Time: 46.45m
# [BYOL] 058/100 | Loss: 0.4001 | Epoch Time: 0.85m | Total Time: 47.30m
# [BYOL] 059/100 | Loss: 0.4019 | Epoch Time: 0.84m | Total Time: 48.14m
# [BYOL] 060/100 | Loss: 0.4004 | Epoch Time: 0.85m | Total Time: 48.99m
# [BYOL] 061/100 | Loss: 0.4001 | Epoch Time: 0.83m | Total Time: 49.82m
# [BYOL] 062/100 | Loss: 0.4016 | Epoch Time: 0.83m | Total Time: 50.65m
# [BYOL] 063/100 | Loss: 0.3998 | Epoch Time: 0.81m | Total Time: 51.46m
# [BYOL] 064/100 | Loss: 0.4001 | Epoch Time: 0.83m | Total Time: 52.29m
# [BYOL] 065/100 | Loss: 0.3996 | Epoch Time: 0.82m | Total Time: 53.11m
# [BYOL] 066/100 | Loss: 0.4003 | Epoch Time: 0.82m | Total Time: 53.93m
# [BYOL] 067/100 | Loss: 0.4010 | Epoch Time: 0.82m | Total Time: 54.75m
# [BYOL] 068/100 | Loss: 0.4009 | Epoch Time: 0.82m | Total Time: 55.58m
# [BYOL] 069/100 | Loss: 0.4019 | Epoch Time: 0.82m | Total Time: 56.40m
# [BYOL] 070/100 | Loss: 0.4012 | Epoch Time: 0.81m | Total Time: 57.22m
# [BYOL] 071/100 | Loss: 0.4001 | Epoch Time: 0.82m | Total Time: 58.04m
# [BYOL] 072/100 | Loss: 0.3992 | Epoch Time: 0.81m | Total Time: 58.85m
# [BYOL] 073/100 | Loss: 0.3987 | Epoch Time: 0.82m | Total Time: 59.67m
# [BYOL] 074/100 | Loss: 0.3990 | Epoch Time: 0.83m | Total Time: 60.50m
# [BYOL] 075/100 | Loss: 0.4005 | Epoch Time: 0.82m | Total Time: 61.32m
# [BYOL] 076/100 | Loss: 0.4014 | Epoch Time: 0.83m | Total Time: 62.15m
# [BYOL] 077/100 | Loss: 0.3974 | Epoch Time: 0.83m | Total Time: 62.97m
# [BYOL] 078/100 | Loss: 0.3988 | Epoch Time: 0.81m | Total Time: 63.78m
# [BYOL] 079/100 | Loss: 0.3989 | Epoch Time: 0.82m | Total Time: 64.60m
# [BYOL] 080/100 | Loss: 0.3952 | Epoch Time: 0.82m | Total Time: 65.42m
# [BYOL] 081/100 | Loss: 0.3997 | Epoch Time: 0.82m | Total Time: 66.24m
# [BYOL] 082/100 | Loss: 0.3971 | Epoch Time: 0.83m | Total Time: 67.07m
# [BYOL] 083/100 | Loss: 0.3973 | Epoch Time: 0.82m | Total Time: 67.88m
# [BYOL] 084/100 | Loss: 0.3981 | Epoch Time: 0.81m | Total Time: 68.69m
# [BYOL] 085/100 | Loss: 0.3952 | Epoch Time: 0.82m | Total Time: 69.52m
# [BYOL] 086/100 | Loss: 0.3970 | Epoch Time: 0.82m | Total Time: 70.33m
# [BYOL] 087/100 | Loss: 0.3952 | Epoch Time: 0.82m | Total Time: 71.15m
# [BYOL] 088/100 | Loss: 0.3950 | Epoch Time: 0.81m | Total Time: 71.96m
# [BYOL] 089/100 | Loss: 0.3941 | Epoch Time: 0.81m | Total Time: 72.78m
# [BYOL] 090/100 | Loss: 0.3951 | Epoch Time: 0.79m | Total Time: 73.57m
# [BYOL] 091/100 | Loss: 0.3931 | Epoch Time: 0.79m | Total Time: 74.36m
# [BYOL] 092/100 | Loss: 0.3947 | Epoch Time: 0.80m | Total Time: 75.16m
# [BYOL] 093/100 | Loss: 0.3955 | Epoch Time: 0.80m | Total Time: 75.96m
# [BYOL] 094/100 | Loss: 0.3924 | Epoch Time: 0.80m | Total Time: 76.76m
# [BYOL] 095/100 | Loss: 0.3938 | Epoch Time: 0.80m | Total Time: 77.56m
# [BYOL] 096/100 | Loss: 0.3947 | Epoch Time: 0.81m | Total Time: 78.37m
# [BYOL] 097/100 | Loss: 0.3908 | Epoch Time: 0.80m | Total Time: 79.17m
# [BYOL] 098/100 | Loss: 0.3920 | Epoch Time: 0.80m | Total Time: 79.97m
# [BYOL] 099/100 | Loss: 0.3927 | Epoch Time: 0.82m | Total Time: 80.78m
# [BYOL] 100/100 | Loss: 0.3923 | Epoch Time: 0.79m | Total Time: 81.58m
# [SimCLR] 001/100 | Loss: 4.6679 | Epoch Time: 0.87m | Total Time: 0.87m
# [SimCLR] 002/100 | Loss: 4.4878 | Epoch Time: 0.87m | Total Time: 1.73m
# [SimCLR] 003/100 | Loss: 4.4257 | Epoch Time: 0.86m | Total Time: 2.59m
# [SimCLR] 004/100 | Loss: 4.3823 | Epoch Time: 0.86m | Total Time: 3.45m
# [SimCLR] 005/100 | Loss: 4.3500 | Epoch Time: 0.86m | Total Time: 4.32m
# [SimCLR] 006/100 | Loss: 4.3272 | Epoch Time: 0.85m | Total Time: 5.17m
# [SimCLR] 007/100 | Loss: 4.3090 | Epoch Time: 0.87m | Total Time: 6.03m
# [SimCLR] 008/100 | Loss: 4.2901 | Epoch Time: 0.88m | Total Time: 6.91m
# [SimCLR] 009/100 | Loss: 4.2769 | Epoch Time: 0.85m | Total Time: 7.76m
# [SimCLR] 010/100 | Loss: 4.2584 | Epoch Time: 0.86m | Total Time: 8.63m
# [SimCLR] 011/100 | Loss: 4.2513 | Epoch Time: 0.86m | Total Time: 9.49m
# [SimCLR] 012/100 | Loss: 4.2355 | Epoch Time: 0.85m | Total Time: 10.34m
# [SimCLR] 013/100 | Loss: 4.2264 | Epoch Time: 0.87m | Total Time: 11.21m
# [SimCLR] 014/100 | Loss: 4.2146 | Epoch Time: 0.86m | Total Time: 12.06m
# [SimCLR] 015/100 | Loss: 4.2069 | Epoch Time: 0.85m | Total Time: 12.92m
# [SimCLR] 016/100 | Loss: 4.1993 | Epoch Time: 0.86m | Total Time: 13.78m
# [SimCLR] 017/100 | Loss: 4.1883 | Epoch Time: 0.86m | Total Time: 14.64m
# [SimCLR] 018/100 | Loss: 4.1831 | Epoch Time: 0.90m | Total Time: 15.54m
# [SimCLR] 019/100 | Loss: 4.1784 | Epoch Time: 0.86m | Total Time: 16.40m
# [SimCLR] 020/100 | Loss: 4.1696 | Epoch Time: 0.86m | Total Time: 17.26m
# [SimCLR] 021/100 | Loss: 4.1661 | Epoch Time: 0.85m | Total Time: 18.11m
# [SimCLR] 022/100 | Loss: 4.1616 | Epoch Time: 0.86m | Total Time: 18.96m
# [SimCLR] 023/100 | Loss: 4.1537 | Epoch Time: 0.86m | Total Time: 19.82m
# [SimCLR] 024/100 | Loss: 4.1487 | Epoch Time: 0.86m | Total Time: 20.68m
# [SimCLR] 025/100 | Loss: 4.1395 | Epoch Time: 0.85m | Total Time: 21.53m
# [SimCLR] 026/100 | Loss: 4.1407 | Epoch Time: 0.85m | Total Time: 22.38m
# [SimCLR] 027/100 | Loss: 4.1374 | Epoch Time: 0.86m | Total Time: 23.25m
# [SimCLR] 028/100 | Loss: 4.1292 | Epoch Time: 0.85m | Total Time: 24.10m
# [SimCLR] 029/100 | Loss: 4.1298 | Epoch Time: 0.86m | Total Time: 24.95m
# [SimCLR] 030/100 | Loss: 4.1233 | Epoch Time: 0.84m | Total Time: 25.79m
# [SimCLR] 031/100 | Loss: 4.1197 | Epoch Time: 0.85m | Total Time: 26.64m
# [SimCLR] 032/100 | Loss: 4.1196 | Epoch Time: 0.86m | Total Time: 27.50m
# [SimCLR] 033/100 | Loss: 4.1146 | Epoch Time: 0.85m | Total Time: 28.35m
# [SimCLR] 034/100 | Loss: 4.1080 | Epoch Time: 0.86m | Total Time: 29.21m
# [SimCLR] 035/100 | Loss: 4.1052 | Epoch Time: 0.86m | Total Time: 30.07m
# [SimCLR] 036/100 | Loss: 4.1039 | Epoch Time: 0.85m | Total Time: 30.92m
# [SimCLR] 037/100 | Loss: 4.1000 | Epoch Time: 0.85m | Total Time: 31.77m
# [SimCLR] 038/100 | Loss: 4.1029 | Epoch Time: 0.85m | Total Time: 32.62m
# [SimCLR] 039/100 | Loss: 4.0969 | Epoch Time: 0.84m | Total Time: 33.46m
# [SimCLR] 040/100 | Loss: 4.0936 | Epoch Time: 0.85m | Total Time: 34.31m
# [SimCLR] 041/100 | Loss: 4.0893 | Epoch Time: 0.85m | Total Time: 35.16m
# [SimCLR] 042/100 | Loss: 4.0899 | Epoch Time: 0.86m | Total Time: 36.02m
# [SimCLR] 043/100 | Loss: 4.0869 | Epoch Time: 0.85m | Total Time: 36.87m
# [SimCLR] 044/100 | Loss: 4.0823 | Epoch Time: 0.85m | Total Time: 37.72m
# [SimCLR] 045/100 | Loss: 4.0803 | Epoch Time: 0.85m | Total Time: 38.57m
# [SimCLR] 046/100 | Loss: 4.0792 | Epoch Time: 0.85m | Total Time: 39.43m
# [SimCLR] 047/100 | Loss: 4.0791 | Epoch Time: 0.85m | Total Time: 40.27m
# [SimCLR] 048/100 | Loss: 4.0702 | Epoch Time: 0.85m | Total Time: 41.12m
# [SimCLR] 049/100 | Loss: 4.0709 | Epoch Time: 0.86m | Total Time: 41.98m
# [SimCLR] 050/100 | Loss: 4.0713 | Epoch Time: 0.87m | Total Time: 42.85m
# [SimCLR] 051/100 | Loss: 4.0675 | Epoch Time: 0.86m | Total Time: 43.71m
# [SimCLR] 052/100 | Loss: 4.0674 | Epoch Time: 0.86m | Total Time: 44.57m
# [SimCLR] 053/100 | Loss: 4.0626 | Epoch Time: 0.85m | Total Time: 45.42m
# [SimCLR] 054/100 | Loss: 4.0613 | Epoch Time: 0.85m | Total Time: 46.27m
# [SimCLR] 055/100 | Loss: 4.0598 | Epoch Time: 0.85m | Total Time: 47.11m
# [SimCLR] 056/100 | Loss: 4.0592 | Epoch Time: 0.85m | Total Time: 47.97m
# [SimCLR] 057/100 | Loss: 4.0530 | Epoch Time: 0.85m | Total Time: 48.82m
# [SimCLR] 058/100 | Loss: 4.0524 | Epoch Time: 0.86m | Total Time: 49.68m
# [SimCLR] 059/100 | Loss: 4.0505 | Epoch Time: 0.85m | Total Time: 50.53m
# [SimCLR] 060/100 | Loss: 4.0511 | Epoch Time: 0.85m | Total Time: 51.38m
# [SimCLR] 061/100 | Loss: 4.0472 | Epoch Time: 0.85m | Total Time: 52.23m
# [SimCLR] 062/100 | Loss: 4.0465 | Epoch Time: 0.88m | Total Time: 53.10m
# [SimCLR] 063/100 | Loss: 4.0478 | Epoch Time: 0.86m | Total Time: 53.96m
# [SimCLR] 064/100 | Loss: 4.0419 | Epoch Time: 0.85m | Total Time: 54.81m
# [SimCLR] 065/100 | Loss: 4.0404 | Epoch Time: 0.85m | Total Time: 55.66m
# [SimCLR] 066/100 | Loss: 4.0382 | Epoch Time: 0.86m | Total Time: 56.53m
# [SimCLR] 067/100 | Loss: 4.0398 | Epoch Time: 0.86m | Total Time: 57.39m
# [SimCLR] 068/100 | Loss: 4.0337 | Epoch Time: 0.85m | Total Time: 58.23m
# [SimCLR] 069/100 | Loss: 4.0378 | Epoch Time: 0.85m | Total Time: 59.08m
# [SimCLR] 070/100 | Loss: 4.0339 | Epoch Time: 0.85m | Total Time: 59.93m
# [SimCLR] 071/100 | Loss: 4.0339 | Epoch Time: 0.84m | Total Time: 60.78m
# [SimCLR] 072/100 | Loss: 4.0347 | Epoch Time: 0.85m | Total Time: 61.62m
# [SimCLR] 073/100 | Loss: 4.0320 | Epoch Time: 0.86m | Total Time: 62.49m
# [SimCLR] 074/100 | Loss: 4.0295 | Epoch Time: 0.85m | Total Time: 63.34m
# [SimCLR] 075/100 | Loss: 4.0286 | Epoch Time: 0.86m | Total Time: 64.20m
# [SimCLR] 076/100 | Loss: 4.0244 | Epoch Time: 0.85m | Total Time: 65.05m
# [SimCLR] 077/100 | Loss: 4.0264 | Epoch Time: 0.85m | Total Time: 65.90m
# [SimCLR] 078/100 | Loss: 4.0229 | Epoch Time: 0.86m | Total Time: 66.76m
# [SimCLR] 079/100 | Loss: 4.0240 | Epoch Time: 0.86m | Total Time: 67.62m
# [SimCLR] 080/100 | Loss: 4.0219 | Epoch Time: 0.85m | Total Time: 68.47m
# [SimCLR] 081/100 | Loss: 4.0229 | Epoch Time: 0.85m | Total Time: 69.32m
# [SimCLR] 082/100 | Loss: 4.0203 | Epoch Time: 0.85m | Total Time: 70.17m
# [SimCLR] 083/100 | Loss: 4.0190 | Epoch Time: 0.84m | Total Time: 71.01m
# [SimCLR] 084/100 | Loss: 4.0181 | Epoch Time: 0.85m | Total Time: 71.86m
# [SimCLR] 085/100 | Loss: 4.0189 | Epoch Time: 0.84m | Total Time: 72.70m
# [SimCLR] 086/100 | Loss: 4.0148 | Epoch Time: 0.84m | Total Time: 73.53m
# [SimCLR] 087/100 | Loss: 4.0143 | Epoch Time: 0.84m | Total Time: 74.38m
# [SimCLR] 088/100 | Loss: 4.0120 | Epoch Time: 0.84m | Total Time: 75.22m
# [SimCLR] 089/100 | Loss: 4.0121 | Epoch Time: 0.84m | Total Time: 76.07m
# [SimCLR] 090/100 | Loss: 4.0103 | Epoch Time: 0.84m | Total Time: 76.91m
# [SimCLR] 091/100 | Loss: 4.0126 | Epoch Time: 0.84m | Total Time: 77.74m
# [SimCLR] 092/100 | Loss: 4.0071 | Epoch Time: 0.86m | Total Time: 78.60m
# [SimCLR] 093/100 | Loss: 4.0113 | Epoch Time: 0.86m | Total Time: 79.46m
# [SimCLR] 094/100 | Loss: 4.0090 | Epoch Time: 0.85m | Total Time: 80.31m
# [SimCLR] 095/100 | Loss: 4.0088 | Epoch Time: 0.84m | Total Time: 81.15m
# [SimCLR] 096/100 | Loss: 4.0050 | Epoch Time: 0.85m | Total Time: 81.99m
# [SimCLR] 097/100 | Loss: 4.0068 | Epoch Time: 0.84m | Total Time: 82.84m
# [SimCLR] 098/100 | Loss: 4.0050 | Epoch Time: 0.85m | Total Time: 83.68m
# [SimCLR] 099/100 | Loss: 4.0037 | Epoch Time: 0.85m | Total Time: 84.53m
# [SimCLR] 100/100 | Loss: 4.0028 | Epoch Time: 0.83m | Total Time: 85.36m
# [SimCLR] 001/100 | Loss: 4.7752 | Epoch Time: 1.44m | Total Time: 1.44m
# [SimCLR] 002/100 | Loss: 4.5034 | Epoch Time: 1.44m | Total Time: 2.87m
# [SimCLR] 003/100 | Loss: 4.4338 | Epoch Time: 1.44m | Total Time: 4.31m
# [SimCLR] 004/100 | Loss: 4.3947 | Epoch Time: 1.44m | Total Time: 5.75m
# [SimCLR] 005/100 | Loss: 4.3646 | Epoch Time: 1.44m | Total Time: 7.19m
# [SimCLR] 006/100 | Loss: 4.3339 | Epoch Time: 1.44m | Total Time: 8.63m
# [SimCLR] 007/100 | Loss: 4.3125 | Epoch Time: 1.43m | Total Time: 10.06m
# [SimCLR] 008/100 | Loss: 4.2910 | Epoch Time: 1.43m | Total Time: 11.50m
# [SimCLR] 009/100 | Loss: 4.2824 | Epoch Time: 1.43m | Total Time: 12.93m
# [SimCLR] 010/100 | Loss: 4.2658 | Epoch Time: 1.44m | Total Time: 14.37m
# [SimCLR] 011/100 | Loss: 4.2514 | Epoch Time: 1.45m | Total Time: 15.81m
# [SimCLR] 012/100 | Loss: 4.2408 | Epoch Time: 1.46m | Total Time: 17.27m
# [SimCLR] 013/100 | Loss: 4.2302 | Epoch Time: 1.45m | Total Time: 18.71m
# [SimCLR] 014/100 | Loss: 4.2231 | Epoch Time: 1.45m | Total Time: 20.16m
# [SimCLR] 015/100 | Loss: 4.2133 | Epoch Time: 1.46m | Total Time: 21.62m
# [SimCLR] 016/100 | Loss: 4.2040 | Epoch Time: 1.45m | Total Time: 23.07m
# [SimCLR] 017/100 | Loss: 4.1969 | Epoch Time: 1.45m | Total Time: 24.52m
# [SimCLR] 018/100 | Loss: 4.1934 | Epoch Time: 1.45m | Total Time: 25.97m
# [SimCLR] 019/100 | Loss: 4.1843 | Epoch Time: 1.45m | Total Time: 27.41m
# [SimCLR] 020/100 | Loss: 4.1799 | Epoch Time: 1.44m | Total Time: 28.85m
# [SimCLR] 021/100 | Loss: 4.1753 | Epoch Time: 1.44m | Total Time: 30.30m
# [SimCLR] 022/100 | Loss: 4.1688 | Epoch Time: 1.44m | Total Time: 31.74m
# [SimCLR] 023/100 | Loss: 4.1645 | Epoch Time: 1.44m | Total Time: 33.18m
# [SimCLR] 024/100 | Loss: 4.1597 | Epoch Time: 1.44m | Total Time: 34.61m
# [SimCLR] 025/100 | Loss: 4.1544 | Epoch Time: 1.44m | Total Time: 36.05m
# [SimCLR] 026/100 | Loss: 4.1556 | Epoch Time: 1.44m | Total Time: 37.49m
# [SimCLR] 027/100 | Loss: 4.1490 | Epoch Time: 1.44m | Total Time: 38.93m
# [SimCLR] 028/100 | Loss: 4.1471 | Epoch Time: 1.44m | Total Time: 40.37m
# [SimCLR] 029/100 | Loss: 4.1411 | Epoch Time: 1.44m | Total Time: 41.80m
# [SimCLR] 030/100 | Loss: 4.1366 | Epoch Time: 1.44m | Total Time: 43.24m
# [SimCLR] 031/100 | Loss: 4.1346 | Epoch Time: 1.43m | Total Time: 44.68m
# [SimCLR] 032/100 | Loss: 4.1335 | Epoch Time: 1.44m | Total Time: 46.11m
# [SimCLR] 033/100 | Loss: 4.1283 | Epoch Time: 1.44m | Total Time: 47.55m
# [SimCLR] 034/100 | Loss: 4.1274 | Epoch Time: 1.43m | Total Time: 48.98m
# [SimCLR] 035/100 | Loss: 4.1246 | Epoch Time: 1.44m | Total Time: 50.42m
# [SimCLR] 036/100 | Loss: 4.1238 | Epoch Time: 1.44m | Total Time: 51.86m
# [SimCLR] 037/100 | Loss: 4.1211 | Epoch Time: 1.44m | Total Time: 53.30m
# [SimCLR] 038/100 | Loss: 4.1154 | Epoch Time: 1.44m | Total Time: 54.73m
# [SimCLR] 039/100 | Loss: 4.1113 | Epoch Time: 1.44m | Total Time: 56.17m
# [SimCLR] 040/100 | Loss: 4.1116 | Epoch Time: 1.44m | Total Time: 57.61m
# [SimCLR] 041/100 | Loss: 4.1085 | Epoch Time: 1.44m | Total Time: 59.04m
# [SimCLR] 042/100 | Loss: 4.1017 | Epoch Time: 1.44m | Total Time: 60.48m
# [SimCLR] 043/100 | Loss: 4.1006 | Epoch Time: 1.44m | Total Time: 61.92m
# [SimCLR] 044/100 | Loss: 4.0983 | Epoch Time: 1.44m | Total Time: 63.35m
# [SimCLR] 045/100 | Loss: 4.0954 | Epoch Time: 1.44m | Total Time: 64.79m
# [SimCLR] 046/100 | Loss: 4.0958 | Epoch Time: 1.44m | Total Time: 66.23m
# [SimCLR] 047/100 | Loss: 4.0917 | Epoch Time: 1.44m | Total Time: 67.67m
# [SimCLR] 048/100 | Loss: 4.0888 | Epoch Time: 1.44m | Total Time: 69.11m
# [SimCLR] 049/100 | Loss: 4.0865 | Epoch Time: 1.44m | Total Time: 70.54m
# [SimCLR] 050/100 | Loss: 4.0858 | Epoch Time: 1.44m | Total Time: 71.98m
# [SimCLR] 051/100 | Loss: 4.0814 | Epoch Time: 1.44m | Total Time: 73.42m
# [SimCLR] 052/100 | Loss: 4.0791 | Epoch Time: 1.43m | Total Time: 74.86m
# [SimCLR] 053/100 | Loss: 4.0827 | Epoch Time: 1.43m | Total Time: 76.29m
# [SimCLR] 054/100 | Loss: 4.0788 | Epoch Time: 1.43m | Total Time: 77.72m
# [SimCLR] 055/100 | Loss: 4.0784 | Epoch Time: 1.43m | Total Time: 79.16m
# [SimCLR] 056/100 | Loss: 4.0756 | Epoch Time: 1.43m | Total Time: 80.59m
# [SimCLR] 057/100 | Loss: 4.0743 | Epoch Time: 1.44m | Total Time: 82.03m
# [SimCLR] 058/100 | Loss: 4.0755 | Epoch Time: 1.43m | Total Time: 83.46m
# [SimCLR] 059/100 | Loss: 4.0712 | Epoch Time: 1.44m | Total Time: 84.90m
# [SimCLR] 060/100 | Loss: 4.0721 | Epoch Time: 1.43m | Total Time: 86.33m
# [SimCLR] 061/100 | Loss: 4.0716 | Epoch Time: 1.44m | Total Time: 87.77m
# [SimCLR] 062/100 | Loss: 4.0679 | Epoch Time: 1.43m | Total Time: 89.20m
# [SimCLR] 063/100 | Loss: 4.0668 | Epoch Time: 1.43m | Total Time: 90.63m
# [SimCLR] 064/100 | Loss: 4.0642 | Epoch Time: 1.43m | Total Time: 92.07m
# [SimCLR] 065/100 | Loss: 4.0661 | Epoch Time: 1.43m | Total Time: 93.50m
# [SimCLR] 066/100 | Loss: 4.0644 | Epoch Time: 1.44m | Total Time: 94.93m
# [SimCLR] 067/100 | Loss: 4.0595 | Epoch Time: 1.43m | Total Time: 96.37m
# [SimCLR] 068/100 | Loss: 4.0619 | Epoch Time: 1.44m | Total Time: 97.80m
# [SimCLR] 069/100 | Loss: 4.0589 | Epoch Time: 1.43m | Total Time: 99.24m
# [SimCLR] 070/100 | Loss: 4.0555 | Epoch Time: 1.43m | Total Time: 100.67m
# [SimCLR] 071/100 | Loss: 4.0550 | Epoch Time: 1.43m | Total Time: 102.11m
# [SimCLR] 072/100 | Loss: 4.0560 | Epoch Time: 1.44m | Total Time: 103.54m
# [SimCLR] 073/100 | Loss: 4.0524 | Epoch Time: 1.44m | Total Time: 104.98m
# [SimCLR] 074/100 | Loss: 4.0535 | Epoch Time: 1.44m | Total Time: 106.42m
# [SimCLR] 075/100 | Loss: 4.0528 | Epoch Time: 1.44m | Total Time: 107.85m
# [SimCLR] 076/100 | Loss: 4.0533 | Epoch Time: 1.43m | Total Time: 109.29m
# [SimCLR] 077/100 | Loss: 4.0495 | Epoch Time: 1.43m | Total Time: 110.72m
# [SimCLR] 078/100 | Loss: 4.0480 | Epoch Time: 1.43m | Total Time: 112.15m
# [SimCLR] 079/100 | Loss: 4.0510 | Epoch Time: 1.43m | Total Time: 113.59m
# [SimCLR] 080/100 | Loss: 4.0474 | Epoch Time: 1.44m | Total Time: 115.02m
# [SimCLR] 081/100 | Loss: 4.0457 | Epoch Time: 1.43m | Total Time: 116.46m
# [SimCLR] 082/100 | Loss: 4.0440 | Epoch Time: 1.44m | Total Time: 117.89m
# [SimCLR] 083/100 | Loss: 4.0408 | Epoch Time: 1.44m | Total Time: 119.33m
# [SimCLR] 084/100 | Loss: 4.0446 | Epoch Time: 1.44m | Total Time: 120.76m
# [SimCLR] 085/100 | Loss: 4.0437 | Epoch Time: 1.44m | Total Time: 122.20m
# [SimCLR] 086/100 | Loss: 4.0436 | Epoch Time: 1.44m | Total Time: 123.64m
# [SimCLR] 087/100 | Loss: 4.0410 | Epoch Time: 1.44m | Total Time: 125.08m
# [SimCLR] 088/100 | Loss: 4.0423 | Epoch Time: 1.44m | Total Time: 126.51m
# [SimCLR] 089/100 | Loss: 4.0402 | Epoch Time: 1.44m | Total Time: 127.95m
# [SimCLR] 090/100 | Loss: 4.0395 | Epoch Time: 1.44m | Total Time: 129.39m
# [SimCLR] 091/100 | Loss: 4.0382 | Epoch Time: 1.44m | Total Time: 130.82m
# [SimCLR] 092/100 | Loss: 4.0383 | Epoch Time: 1.43m | Total Time: 132.26m
# [SimCLR] 093/100 | Loss: 4.0375 | Epoch Time: 1.43m | Total Time: 133.69m
# [SimCLR] 094/100 | Loss: 4.0328 | Epoch Time: 1.44m | Total Time: 135.13m
# [SimCLR] 095/100 | Loss: 4.0376 | Epoch Time: 1.44m | Total Time: 136.56m
# [SimCLR] 096/100 | Loss: 4.0334 | Epoch Time: 1.43m | Total Time: 137.99m
# [SimCLR] 097/100 | Loss: 4.0314 | Epoch Time: 1.44m | Total Time: 139.43m
# [SimCLR] 098/100 | Loss: 4.0321 | Epoch Time: 1.44m | Total Time: 140.87m
# [SimCLR] 099/100 | Loss: 4.0300 | Epoch Time: 1.44m | Total Time: 142.30m
# [SimCLR] 100/100 | Loss: 4.0307 | Epoch Time: 1.43m | Total Time: 143.74m
# Saved results to: /kaggle/working/byol_simclr_results.csv
#
# Running Mean Summary:
#             Seed   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# Method
# BYOL         5.0  58.849894        11.934261          12.663976
# SimCLR       5.0  86.131786        15.632587          17.653579
# SimCLR+Jac   5.0  65.770773        16.416672          16.363256
#
#             Linear_Probe_Acc
# Method
# BYOL                  0.6536
# SimCLR                0.6961
# SimCLR+Jac            0.6746
#
# Seed 5 finished in 313.37 minutes
#
# ================ FINAL RESULTS ================
#    Seed      Method   Jacobian  Aug_Sensitivity  Noise_Sensitivity  \
# 0     5        BYOL  58.849894        11.934261          12.663976
# 1     5      SimCLR  86.131786        15.632587          17.653579
# 2     5  SimCLR+Jac  65.770773        16.416672          16.363256
#
#    Linear_Probe_Acc
# 0            0.6536
# 1            0.6961
# 2            0.6746
#
# Total experiment time (this session): 313.38 minutes
