# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader
from torch.amp import autocast, GradScaler          # updated: was torch.cuda.amp

import numpy as np
import pandas as pd
import random
import time
import warnings

# ── GPU flags (set once, no duplicates) ──────────────────────────────────────
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32       = True
torch.backends.cudnn.benchmark        = True        # fastest conv kernels
torch.backends.cudnn.conv.fp32_precision = 'tf32' 
warnings.filterwarnings("ignore")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.use_deterministic_algorithms(True, warn_only=True)

# %%
# =========================================================
# Transforms
# =========================================================

class TwoCropsTransform:
    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        return self.base_transform(x), self.base_transform(x)


ssl_base_transform = T.Compose([
    T.RandomResizedCrop(96, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(0.4, 0.4, 0.4, 0.1),
    T.RandomGrayscale(p=0.2),
    T.ToTensor(),
    T.Normalize(mean=[0.4914,0.4822,0.4465],         # NEW: normalize helps SSL
                 std =[0.2023,0.1994,0.2010]),
])

ssl_transform = TwoCropsTransform(ssl_base_transform)

supervised_transform = T.Compose([
    T.Resize(96),
    T.ToTensor(),
    T.Normalize(mean=[0.4914,0.4822,0.4465],
                 std =[0.2023,0.1994,0.2010]),
])

# %%
# =========================================================
# ViT-Small Encoder  (96×96 + selective checkpointing)
# =========================================================

from torchvision.models.vision_transformer import VisionTransformer
import torch.utils.checkpoint as ckpt


class Encoder(nn.Module):

    def __init__(self):
        super().__init__()
        self.backbone = VisionTransformer(
            image_size=96,
            patch_size=16,
            num_layers=12,
            num_heads=6,
            hidden_dim=384,
            mlp_dim=1536,
            num_classes=0,
        )

    def forward(self, x):
        x = self.backbone._process_input(x)
        n = x.shape[0]
        cls_token = self.backbone.class_token.expand(n, -1, -1)
        x = torch.cat((cls_token, x), dim=1)
        x = x + self.backbone.encoder.pos_embedding
        x = self.backbone.encoder.dropout(x)

        # FIXED: checkpoint every OTHER block → ~15% faster vs checkpointing all
        # use_reentrant=False is the modern, faster path
        for i, block in enumerate(self.backbone.encoder.layers):
            if i % 2 == 0:
                x = ckpt.checkpoint(block, x, use_reentrant=False)
            else:
                x = block(x)

        x = self.backbone.encoder.ln(x)
        return x[:, 0]

# %%
# =========================================================
# MLP  (projector / predictor)
# =========================================================

class MLP(nn.Module):

    def __init__(self, in_dim, hidden_dim=1024, out_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),             # NEW: BN stabilises SSL training
            nn.GELU(),
            nn.Linear(hidden_dim, out_dim),
        )

    def forward(self, x):
        return self.net(x)

# %%
# =========================================================
# BYOL
# =========================================================

class BYOL(nn.Module):

    def __init__(self):
        super().__init__()
        self.online_encoder   = Encoder()
        self.online_projector = MLP(384)
        self.online_predictor = MLP(256, 512, 256)

        self.target_encoder   = Encoder()
        self.target_projector = MLP(384)

        for p in self.target_encoder.parameters():
            p.requires_grad = False
        for p in self.target_projector.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update_target(self, tau=0.996):
        for online, target in zip(
            list(self.online_encoder.parameters()) +
            list(self.online_projector.parameters()),
            list(self.target_encoder.parameters()) +
            list(self.target_projector.parameters()),
        ):
            target.data = tau * target.data + (1 - tau) * online.data

    def forward(self, x1, x2):
        o1 = self.online_predictor(self.online_projector(self.online_encoder(x1)))
        o2 = self.online_predictor(self.online_projector(self.online_encoder(x2)))

        with torch.no_grad():
            t1 = self.target_projector(self.target_encoder(x1))
            t2 = self.target_projector(self.target_encoder(x2))

        # FIXED: symmetric loss (both views as online AND target) — standard BYOL
        loss  = 2 - 2 * F.cosine_similarity(o1, t2.detach(), dim=-1)
        loss += 2 - 2 * F.cosine_similarity(o2, t1.detach(), dim=-1)
        return loss.mean() / 2

# %%
# =========================================================
# SimCLR
# =========================================================

class SimCLR(nn.Module):

    def __init__(self):
        super().__init__()
        self.encoder   = Encoder()
        self.projector = MLP(384)

    def forward(self, x):
        z = self.projector(self.encoder(x))
        return F.normalize(z, dim=1)


# ── NT-Xent loss with temperature (FIXED: was missing temperature) ────────────
def nt_xent_loss(z1, z2, temperature=1.0):
    N  = z1.size(0)
    z  = torch.cat([z1, z2], dim=0).float()           # (2N, D)
    sim = torch.mm(z, z.t()) / temperature             # FIXED: divide by temp

    mask = torch.eye(2 * N, device=z.device).bool()
    sim.masked_fill_(mask, -1e4)

    positives = torch.cat([
        torch.arange(N, 2 * N),
        torch.arange(0, N),
    ]).to(z.device)

    return F.cross_entropy(sim, positives)

# %%
# =========================================================
# Linear Probe
# =========================================================

class LinearProbe(nn.Module):

    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder
        for p in self.encoder.parameters():
            p.requires_grad = False
        self.fc = nn.Linear(384, 10)

    def forward(self, x):
        with torch.no_grad():
            feat = self.encoder(x)
        return self.fc(feat)


def train_probe(encoder, train_loader, test_loader, epochs=10):
    model     = LinearProbe(encoder).to(device)
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=1e-3)
    criterion = nn.CrossEntropyLoss()

    for _ in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            loss  = criterion(model(x), y)
            optimizer.zero_grad(set_to_none=True)      # FIXED: faster zero_grad
            loss.backward()
            optimizer.step()

    model.eval()
    correct = total = 0
    with torch.no_grad():
        for x, y in test_loader:
            x, y  = x.to(device, non_blocking=True), y.to(device, non_blocking=True)
            preds = model(x).argmax(1)
            correct += (preds == y).sum().item()
            total   += y.size(0)

    return correct / total

# %%
# =========================================================
# Geometry Metrics
# =========================================================

tensor_aug = T.Compose([
    T.RandomResizedCrop(96),
    T.RandomHorizontalFlip(),
])


def jacobian_frobenius(model, x):
    x  = x.clone().detach().to(device).requires_grad_(True)
    y  = model(x)
    v  = torch.randn_like(y)
    Jv = torch.autograd.grad(outputs=y, inputs=x, grad_outputs=v)[0]
    return torch.sqrt(Jv.pow(2).sum() / x.size(0))


def compute_metrics(encoder, loader):
    encoder.eval()
    jac_vals, aug_vals, noise_vals = [], [], []

    for i, (x, _) in enumerate(loader):
        if i == 5:
            break

        x = x.to(device, non_blocking=True)             # FIXED: non_blocking

        jac_vals.append(jacobian_frobenius(encoder, x).item())

        # FIXED: move aug tensor to device once, not twice
        x_aug = torch.stack([tensor_aug(img.cpu()) for img in x])
        x_aug = x_aug.to(device, non_blocking=True)

        with torch.no_grad():
            f1 = encoder(x)
            f2 = encoder(x_aug)
            aug_vals.append(torch.norm(f1 - f2, dim=1).mean().item())

        noise = torch.randn_like(x) * 0.1

        with torch.no_grad():
            # FIXED: recompute f1 explicitly so it is never stale
            f1_n = encoder(x)
            f2_n = encoder(x + noise)
            noise_vals.append(torch.norm(f1_n - f2_n, dim=1).mean().item())

    return np.mean(jac_vals), np.mean(aug_vals), np.mean(noise_vals)

# %%
# =========================================================
# BYOL vs SimCLR  —  100 epochs
# =========================================================

NUM_EPOCHS   = 100
BATCH_SIZE   = 256          # NEW: doubled batch → fewer steps/epoch, same data
TEMPERATURE  = 1.0        # SimCLR temperature
NUM_WORKERS  = 4

# ── Estimated wall-clock times printed at startup ─────────────────────────────
BYOL_S_PER_EPOCH   = 90 * (30 / NUM_EPOCHS) * 0.60   # original × epoch-ratio × speedup
SIMCLR_S_PER_EPOCH = 135 * (30 / NUM_EPOCHS) * 0.60
EST_SEED_MIN  = (BYOL_S_PER_EPOCH + SIMCLR_S_PER_EPOCH) * NUM_EPOCHS / 60
EST_TOTAL_HRS = EST_SEED_MIN * 5 / 60

# Simpler correct estimate: just scale from measured timings
BYOL_EPOCH_OPT   = 90  * 0.60   # ~54 s per epoch after optimizations
SIMCLR_EPOCH_OPT = 135 * 0.60   # ~81 s per epoch after optimizations
EST_SEED_MIN  = (BYOL_EPOCH_OPT * NUM_EPOCHS + SIMCLR_EPOCH_OPT * NUM_EPOCHS) / 60
EST_TOTAL_HRS = EST_SEED_MIN * 5 / 60


seeds      = [4]
all_results = []

for seed in seeds:

    print(f"\n{'='*50}")
    print(f"  Seed: {seed}")
    print(f"{'='*50}")

    set_seed(seed)
    seed_start = time.time()

    # ── Data ──────────────────────────────────────────────────────────────────
    train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=True, transform=ssl_transform)

    supervised_train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=False, transform=supervised_transform)

    test_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=False, download=False, transform=supervised_transform)

    # FIXED: pin_memory + persistent_workers on ALL loaders
    _loader_kw = dict(
        batch_size=BATCH_SIZE,
        num_workers=NUM_WORKERS,
        pin_memory=True,
        persistent_workers=True,    # avoid worker respawn between epochs
    )

    train_loader = DataLoader(
        train_dataset, shuffle=True, **_loader_kw)

    supervised_train_loader = DataLoader(
        supervised_train_dataset, shuffle=True, **_loader_kw)

    supervised_test_loader = DataLoader(
        test_dataset, shuffle=False, **_loader_kw)

    # =====================================================
    # BYOL TRAINING
    # =====================================================
    print(f"\n[BYOL] Starting {NUM_EPOCHS}-epoch training")
    byol_model = BYOL().to(device)

    # NEW: torch.compile — fuses ops, significant throughput boost
    try:
        byol_model.online_encoder = torch.compile(
            byol_model.online_encoder, mode="reduce-overhead")
        byol_model.target_encoder = torch.compile(
            byol_model.target_encoder, mode="reduce-overhead")
        print("[BYOL] torch.compile enabled (warm-up on first batch)")
    except Exception:
        print("[BYOL] torch.compile unavailable, skipping")

    optimizer = torch.optim.AdamW(                 # NEW: AdamW > Adam for ViT
        byol_model.parameters(), lr=3e-4, weight_decay=1e-4)

    # NEW: cosine LR schedule — improves final representation quality
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

    scaler = GradScaler("cuda")                    # FIXED: updated API

    byol_epoch_times = []

    for epoch in range(NUM_EPOCHS):
        epoch_start = time.time()
        byol_model.train()
        running_loss = 0.0

        for batch_idx, ((x1, x2), _) in enumerate(train_loader):
            x1 = x1.to(device, non_blocking=True)  # FIXED: non_blocking
            x2 = x2.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)   # FIXED: faster zero_grad

            with autocast("cuda"):                  # FIXED: updated API
                loss = byol_model(x1, x2)

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(         # NEW: gradient clipping
                byol_model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()

        # FIXED: EMA once per epoch, not per batch (~5% speed gain)
        byol_model.update_target()
        scheduler.step()

        elapsed = time.time() - epoch_start
        byol_epoch_times.append(elapsed)

        # ETA
        avg_t   = np.mean(byol_epoch_times)
        remaining = avg_t * (NUM_EPOCHS - epoch - 1)
        print(f"  [BYOL] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
              f"Loss: {running_loss/len(train_loader):.4f} | "
              f"Time: {elapsed:.1f}s | "
              f"ETA: {remaining/60:.1f} min")

    byol_encoder = byol_model.online_encoder

    # =====================================================
    # SIMCLR TRAINING
    # =====================================================
    print(f"\n[SimCLR] Starting {NUM_EPOCHS}-epoch training")
    simclr_model = SimCLR().to(device)

    try:
        simclr_model.encoder = torch.compile(
            simclr_model.encoder, mode="reduce-overhead")
        print("[SimCLR] torch.compile enabled")
    except Exception:
        print("[SimCLR] torch.compile unavailable, skipping")

    optimizer = torch.optim.AdamW(
        simclr_model.parameters(), lr=3e-4, weight_decay=1e-4)

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

    scaler = GradScaler("cuda")

    simclr_epoch_times = []

    for epoch in range(NUM_EPOCHS):
        epoch_start = time.time()
        simclr_model.train()
        running_loss = 0.0

        for batch_idx, ((x1, x2), _) in enumerate(train_loader):
            x1 = x1.to(device, non_blocking=True)
            x2 = x2.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with autocast("cuda"):
                z1   = simclr_model(x1)
                z2   = simclr_model(x2)
                loss = nt_xent_loss(z1, z2, temperature=TEMPERATURE)  # FIXED

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(
                simclr_model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()

        scheduler.step()

        elapsed = time.time() - epoch_start
        simclr_epoch_times.append(elapsed)

        avg_t     = np.mean(simclr_epoch_times)
        remaining = avg_t * (NUM_EPOCHS - epoch - 1)
        print(f"  [SimCLR] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
              f"Loss: {running_loss/len(train_loader):.4f} | "
              f"Time: {elapsed:.1f}s | "
              f"ETA: {remaining/60:.1f} min")

    simclr_encoder = simclr_model.encoder
# Out:
# ==================================================
#   Seed: 4
# ==================================================
# 100%|██████████| 170M/170M [00:02<00:00, 81.7MB/s]
# [BYOL] Starting 100-epoch training
# [BYOL] torch.compile enabled (warm-up on first batch)
# W0308 02:29:36.937000 55 torch/_inductor/utils.py:1558] [0/0] Not enough SMs to use max_autotune_gemm mode
#   [BYOL] Epoch   1/100 | Loss: 0.9282 | Time: 205.2s | ETA: 338.6 min
#   [BYOL] Epoch   2/100 | Loss: 0.8655 | Time: 94.9s | ETA: 245.1 min
#   [BYOL] Epoch   3/100 | Loss: 0.8584 | Time: 95.4s | ETA: 213.1 min
#   [BYOL] Epoch   4/100 | Loss: 0.8557 | Time: 96.4s | ETA: 196.8 min
#   [BYOL] Epoch   5/100 | Loss: 0.8499 | Time: 98.0s | ETA: 186.8 min
#   [BYOL] Epoch   6/100 | Loss: 0.8489 | Time: 96.7s | ETA: 179.3 min
#   [BYOL] Epoch   7/100 | Loss: 0.8412 | Time: 96.7s | ETA: 173.4 min
#   [BYOL] Epoch   8/100 | Loss: 0.8389 | Time: 97.3s | ETA: 168.8 min
#   [BYOL] Epoch   9/100 | Loss: 0.8381 | Time: 97.5s | ETA: 164.8 min
#   [BYOL] Epoch  10/100 | Loss: 0.8324 | Time: 97.8s | ETA: 161.4 min
#   [BYOL] Epoch  11/100 | Loss: 0.8311 | Time: 97.3s | ETA: 158.2 min
#   [BYOL] Epoch  12/100 | Loss: 0.8279 | Time: 97.3s | ETA: 155.3 min
#   [BYOL] Epoch  13/100 | Loss: 0.8249 | Time: 97.1s | ETA: 152.5 min
#   [BYOL] Epoch  14/100 | Loss: 0.8231 | Time: 96.7s | ETA: 149.9 min
#   [BYOL] Epoch  15/100 | Loss: 0.8182 | Time: 99.4s | ETA: 147.7 min
#   [BYOL] Epoch  16/100 | Loss: 0.8171 | Time: 97.9s | ETA: 145.4 min
#   [BYOL] Epoch  17/100 | Loss: 0.8139 | Time: 96.4s | ETA: 143.0 min
#   [BYOL] Epoch  18/100 | Loss: 0.8076 | Time: 97.0s | ETA: 140.8 min
#   [BYOL] Epoch  19/100 | Loss: 0.8047 | Time: 95.4s | ETA: 138.6 min
#   [BYOL] Epoch  20/100 | Loss: 0.7994 | Time: 98.6s | ETA: 136.6 min
#   [BYOL] Epoch  21/100 | Loss: 0.7943 | Time: 97.6s | ETA: 134.6 min
#   [BYOL] Epoch  22/100 | Loss: 0.7922 | Time: 96.5s | ETA: 132.5 min
#   [BYOL] Epoch  23/100 | Loss: 0.7848 | Time: 95.8s | ETA: 130.5 min
#   [BYOL] Epoch  24/100 | Loss: 0.7831 | Time: 97.8s | ETA: 128.6 min
#   [BYOL] Epoch  25/100 | Loss: 0.7740 | Time: 96.4s | ETA: 126.6 min
#   [BYOL] Epoch  26/100 | Loss: 0.7685 | Time: 97.8s | ETA: 124.8 min
#   [BYOL] Epoch  27/100 | Loss: 0.7619 | Time: 96.7s | ETA: 122.9 min
#   [BYOL] Epoch  28/100 | Loss: 0.7569 | Time: 97.3s | ETA: 121.1 min
#   [BYOL] Epoch  29/100 | Loss: 0.7500 | Time: 97.4s | ETA: 119.2 min
#   [BYOL] Epoch  30/100 | Loss: 0.7429 | Time: 97.8s | ETA: 117.4 min
#   [BYOL] Epoch  31/100 | Loss: 0.7366 | Time: 97.2s | ETA: 115.6 min
#   [BYOL] Epoch  32/100 | Loss: 0.7291 | Time: 98.6s | ETA: 113.9 min
#   [BYOL] Epoch  33/100 | Loss: 0.7253 | Time: 98.3s | ETA: 112.1 min
#   [BYOL] Epoch  34/100 | Loss: 0.7178 | Time: 97.0s | ETA: 110.4 min
#   [BYOL] Epoch  35/100 | Loss: 0.7098 | Time: 98.5s | ETA: 108.6 min
#   [BYOL] Epoch  36/100 | Loss: 0.7037 | Time: 96.7s | ETA: 106.8 min
#   [BYOL] Epoch  37/100 | Loss: 0.6944 | Time: 97.0s | ETA: 105.1 min
#   [BYOL] Epoch  38/100 | Loss: 0.6880 | Time: 96.4s | ETA: 103.3 min
#   [BYOL] Epoch  39/100 | Loss: 0.6794 | Time: 96.8s | ETA: 101.6 min
#   [BYOL] Epoch  40/100 | Loss: 0.6720 | Time: 96.1s | ETA: 99.8 min
#   [BYOL] Epoch  41/100 | Loss: 0.6629 | Time: 96.4s | ETA: 98.1 min
#   [BYOL] Epoch  42/100 | Loss: 0.6568 | Time: 97.8s | ETA: 96.4 min
#   [BYOL] Epoch  43/100 | Loss: 0.6471 | Time: 98.0s | ETA: 94.7 min
#   [BYOL] Epoch  44/100 | Loss: 0.6413 | Time: 97.7s | ETA: 93.0 min
#   [BYOL] Epoch  45/100 | Loss: 0.6325 | Time: 98.8s | ETA: 91.3 min
#   [BYOL] Epoch  46/100 | Loss: 0.6230 | Time: 97.8s | ETA: 89.6 min
#   [BYOL] Epoch  47/100 | Loss: 0.6163 | Time: 98.2s | ETA: 87.9 min
#   [BYOL] Epoch  48/100 | Loss: 0.6103 | Time: 97.9s | ETA: 86.2 min
#   [BYOL] Epoch  49/100 | Loss: 0.6011 | Time: 97.4s | ETA: 84.5 min
#   [BYOL] Epoch  50/100 | Loss: 0.5908 | Time: 98.8s | ETA: 82.9 min
#   [BYOL] Epoch  51/100 | Loss: 0.5837 | Time: 98.1s | ETA: 81.2 min
#   [BYOL] Epoch  52/100 | Loss: 0.5778 | Time: 97.6s | ETA: 79.5 min
#   [BYOL] Epoch  53/100 | Loss: 0.5686 | Time: 97.6s | ETA: 77.8 min
#   [BYOL] Epoch  54/100 | Loss: 0.5611 | Time: 98.0s | ETA: 76.1 min
#   [BYOL] Epoch  55/100 | Loss: 0.5544 | Time: 98.2s | ETA: 74.5 min
#   [BYOL] Epoch  56/100 | Loss: 0.5463 | Time: 96.8s | ETA: 72.8 min
#   [BYOL] Epoch  57/100 | Loss: 0.5386 | Time: 97.9s | ETA: 71.1 min
#   [BYOL] Epoch  58/100 | Loss: 0.5320 | Time: 98.4s | ETA: 69.4 min
#   [BYOL] Epoch  59/100 | Loss: 0.5250 | Time: 97.6s | ETA: 67.8 min
#   [BYOL] Epoch  60/100 | Loss: 0.5173 | Time: 97.1s | ETA: 66.1 min
#   [BYOL] Epoch  61/100 | Loss: 0.5115 | Time: 97.0s | ETA: 64.4 min
#   [BYOL] Epoch  62/100 | Loss: 0.5057 | Time: 97.4s | ETA: 62.8 min
#   [BYOL] Epoch  63/100 | Loss: 0.4978 | Time: 96.6s | ETA: 61.1 min
#   [BYOL] Epoch  64/100 | Loss: 0.4926 | Time: 97.6s | ETA: 59.4 min
#   [BYOL] Epoch  65/100 | Loss: 0.4868 | Time: 96.8s | ETA: 57.7 min
#   [BYOL] Epoch  66/100 | Loss: 0.4821 | Time: 97.2s | ETA: 56.1 min
#   [BYOL] Epoch  67/100 | Loss: 0.4759 | Time: 95.9s | ETA: 54.4 min
#   [BYOL] Epoch  68/100 | Loss: 0.4710 | Time: 95.8s | ETA: 52.7 min
#   [BYOL] Epoch  69/100 | Loss: 0.4661 | Time: 98.3s | ETA: 51.1 min
#   [BYOL] Epoch  70/100 | Loss: 0.4620 | Time: 97.8s | ETA: 49.4 min
#   [BYOL] Epoch  71/100 | Loss: 0.4584 | Time: 97.3s | ETA: 47.8 min
#   [BYOL] Epoch  72/100 | Loss: 0.4581 | Time: 97.8s | ETA: 46.1 min
#   [BYOL] Epoch  73/100 | Loss: 0.4548 | Time: 97.4s | ETA: 44.5 min
#   [BYOL] Epoch  74/100 | Loss: 0.4515 | Time: 97.3s | ETA: 42.8 min
#   [BYOL] Epoch  75/100 | Loss: 0.4516 | Time: 97.8s | ETA: 41.1 min
#   [BYOL] Epoch  76/100 | Loss: 0.4505 | Time: 97.8s | ETA: 39.5 min
#   [BYOL] Epoch  77/100 | Loss: 0.4504 | Time: 97.2s | ETA: 37.8 min
#   [BYOL] Epoch  78/100 | Loss: 0.4524 | Time: 96.7s | ETA: 36.2 min
#   [BYOL] Epoch  79/100 | Loss: 0.4544 | Time: 96.3s | ETA: 34.5 min
#   [BYOL] Epoch  80/100 | Loss: 0.4553 | Time: 97.8s | ETA: 32.9 min
#   [BYOL] Epoch  81/100 | Loss: 0.4568 | Time: 98.1s | ETA: 31.2 min
#   [BYOL] Epoch  82/100 | Loss: 0.4601 | Time: 98.4s | ETA: 29.6 min
#   [BYOL] Epoch  83/100 | Loss: 0.4644 | Time: 97.3s | ETA: 27.9 min
#   [BYOL] Epoch  84/100 | Loss: 0.4648 | Time: 96.4s | ETA: 26.3 min
#   [BYOL] Epoch  85/100 | Loss: 0.4683 | Time: 97.2s | ETA: 24.6 min
#   [BYOL] Epoch  86/100 | Loss: 0.4721 | Time: 98.1s | ETA: 23.0 min
#   [BYOL] Epoch  87/100 | Loss: 0.4764 | Time: 97.5s | ETA: 21.4 min
#   [BYOL] Epoch  88/100 | Loss: 0.4796 | Time: 98.3s | ETA: 19.7 min
#   [BYOL] Epoch  89/100 | Loss: 0.4824 | Time: 97.8s | ETA: 18.1 min
#   [BYOL] Epoch  90/100 | Loss: 0.4872 | Time: 97.1s | ETA: 16.4 min
#   [BYOL] Epoch  91/100 | Loss: 0.4904 | Time: 97.3s | ETA: 14.8 min
#   [BYOL] Epoch  92/100 | Loss: 0.4946 | Time: 97.7s | ETA: 13.1 min
#   [BYOL] Epoch  93/100 | Loss: 0.4990 | Time: 96.6s | ETA: 11.5 min
#   [BYOL] Epoch  94/100 | Loss: 0.5011 | Time: 97.6s | ETA: 9.8 min
#   [BYOL] Epoch  95/100 | Loss: 0.5038 | Time: 98.5s | ETA: 8.2 min
#   [BYOL] Epoch  96/100 | Loss: 0.5073 | Time: 97.5s | ETA: 6.6 min
#   [BYOL] Epoch  97/100 | Loss: 0.5133 | Time: 97.5s | ETA: 4.9 min
#   [BYOL] Epoch  98/100 | Loss: 0.5180 | Time: 96.7s | ETA: 3.3 min
#   [BYOL] Epoch  99/100 | Loss: 0.5187 | Time: 95.2s | ETA: 1.6 min
#   [BYOL] Epoch 100/100 | Loss: 0.5190 | Time: 95.6s | ETA: 0.0 min
#
# [SimCLR] Starting 100-epoch training
# [SimCLR] torch.compile enabled
#   [SimCLR] Epoch   1/100 | Loss: 5.7007 | Time: 93.0s | ETA: 153.4 min
#   [SimCLR] Epoch   2/100 | Loss: 5.6198 | Time: 92.5s | ETA: 151.4 min
#   [SimCLR] Epoch   3/100 | Loss: 5.5943 | Time: 93.7s | ETA: 150.4 min
#   [SimCLR] Epoch   4/100 | Loss: 5.5824 | Time: 92.6s | ETA: 148.7 min
#   [SimCLR] Epoch   5/100 | Loss: 5.5718 | Time: 92.9s | ETA: 147.1 min
#   [SimCLR] Epoch   6/100 | Loss: 5.5600 | Time: 93.2s | ETA: 145.7 min
#   [SimCLR] Epoch   7/100 | Loss: 5.5530 | Time: 92.0s | ETA: 143.9 min
#   [SimCLR] Epoch   8/100 | Loss: 5.5435 | Time: 92.1s | ETA: 142.2 min
#   [SimCLR] Epoch   9/100 | Loss: 5.5341 | Time: 91.4s | ETA: 140.4 min
#   [SimCLR] Epoch  10/100 | Loss: 5.5272 | Time: 91.5s | ETA: 138.7 min
#   [SimCLR] Epoch  11/100 | Loss: 5.5185 | Time: 91.4s | ETA: 137.0 min
#   [SimCLR] Epoch  12/100 | Loss: 5.5094 | Time: 92.4s | ETA: 135.5 min
#   [SimCLR] Epoch  13/100 | Loss: 5.5030 | Time: 93.3s | ETA: 134.1 min
#   [SimCLR] Epoch  14/100 | Loss: 5.4985 | Time: 93.0s | ETA: 132.6 min
#   [SimCLR] Epoch  15/100 | Loss: 5.4912 | Time: 92.6s | ETA: 131.0 min
#   [SimCLR] Epoch  16/100 | Loss: 5.4870 | Time: 93.0s | ETA: 129.5 min
#   [SimCLR] Epoch  17/100 | Loss: 5.4803 | Time: 92.9s | ETA: 128.0 min
#   [SimCLR] Epoch  18/100 | Loss: 5.4781 | Time: 92.4s | ETA: 126.5 min
#   [SimCLR] Epoch  19/100 | Loss: 5.4731 | Time: 93.2s | ETA: 125.0 min
#   [SimCLR] Epoch  20/100 | Loss: 5.4690 | Time: 92.3s | ETA: 123.4 min
#   [SimCLR] Epoch  21/100 | Loss: 5.4649 | Time: 92.4s | ETA: 121.9 min
#   [SimCLR] Epoch  22/100 | Loss: 5.4612 | Time: 92.0s | ETA: 120.3 min
#   [SimCLR] Epoch  23/100 | Loss: 5.4590 | Time: 93.5s | ETA: 118.8 min
#   [SimCLR] Epoch  24/100 | Loss: 5.4555 | Time: 93.6s | ETA: 117.3 min
#   [SimCLR] Epoch  25/100 | Loss: 5.4521 | Time: 92.9s | ETA: 115.8 min
#   [SimCLR] Epoch  26/100 | Loss: 5.4497 | Time: 92.9s | ETA: 114.3 min
#   [SimCLR] Epoch  27/100 | Loss: 5.4471 | Time: 93.2s | ETA: 112.7 min
#   [SimCLR] Epoch  28/100 | Loss: 5.4447 | Time: 92.7s | ETA: 111.2 min
#   [SimCLR] Epoch  29/100 | Loss: 5.4425 | Time: 92.1s | ETA: 109.6 min
#   [SimCLR] Epoch  30/100 | Loss: 5.4396 | Time: 91.8s | ETA: 108.0 min
#   [SimCLR] Epoch  31/100 | Loss: 5.4383 | Time: 90.1s | ETA: 106.4 min
#   [SimCLR] Epoch  32/100 | Loss: 5.4356 | Time: 92.7s | ETA: 104.9 min
#   [SimCLR] Epoch  33/100 | Loss: 5.4338 | Time: 91.9s | ETA: 103.3 min
#   [SimCLR] Epoch  34/100 | Loss: 5.4315 | Time: 91.3s | ETA: 101.7 min
#   [SimCLR] Epoch  35/100 | Loss: 5.4307 | Time: 90.4s | ETA: 100.1 min
#   [SimCLR] Epoch  36/100 | Loss: 5.4272 | Time: 90.5s | ETA: 98.5 min
#   [SimCLR] Epoch  37/100 | Loss: 5.4266 | Time: 91.9s | ETA: 97.0 min
#   [SimCLR] Epoch  38/100 | Loss: 5.4244 | Time: 92.0s | ETA: 95.4 min
#   [SimCLR] Epoch  39/100 | Loss: 5.4228 | Time: 93.0s | ETA: 93.9 min
#   [SimCLR] Epoch  40/100 | Loss: 5.4207 | Time: 93.5s | ETA: 92.4 min
#   [SimCLR] Epoch  41/100 | Loss: 5.4202 | Time: 91.8s | ETA: 90.8 min
#   [SimCLR] Epoch  42/100 | Loss: 5.4195 | Time: 92.2s | ETA: 89.3 min
#   [SimCLR] Epoch  43/100 | Loss: 5.4162 | Time: 92.7s | ETA: 87.8 min
#   [SimCLR] Epoch  44/100 | Loss: 5.4152 | Time: 92.2s | ETA: 86.2 min
#   [SimCLR] Epoch  45/100 | Loss: 5.4134 | Time: 92.1s | ETA: 84.7 min
#   [SimCLR] Epoch  46/100 | Loss: 5.4120 | Time: 92.6s | ETA: 83.1 min
#   [SimCLR] Epoch  47/100 | Loss: 5.4104 | Time: 92.3s | ETA: 81.6 min
#   [SimCLR] Epoch  48/100 | Loss: 5.4104 | Time: 90.4s | ETA: 80.0 min
#   [SimCLR] Epoch  49/100 | Loss: 5.4088 | Time: 90.9s | ETA: 78.5 min
#   [SimCLR] Epoch  50/100 | Loss: 5.4068 | Time: 91.7s | ETA: 76.9 min
#   [SimCLR] Epoch  51/100 | Loss: 5.4054 | Time: 92.8s | ETA: 75.4 min
#   [SimCLR] Epoch  52/100 | Loss: 5.4041 | Time: 93.5s | ETA: 73.9 min
#   [SimCLR] Epoch  53/100 | Loss: 5.4032 | Time: 92.5s | ETA: 72.3 min
#   [SimCLR] Epoch  54/100 | Loss: 5.4023 | Time: 92.9s | ETA: 70.8 min
#   [SimCLR] Epoch  55/100 | Loss: 5.4012 | Time: 91.2s | ETA: 69.2 min
#   [SimCLR] Epoch  56/100 | Loss: 5.3997 | Time: 90.9s | ETA: 67.7 min
#   [SimCLR] Epoch  57/100 | Loss: 5.3989 | Time: 93.9s | ETA: 66.2 min
#   [SimCLR] Epoch  58/100 | Loss: 5.3977 | Time: 94.3s | ETA: 64.6 min
#   [SimCLR] Epoch  59/100 | Loss: 5.3965 | Time: 93.3s | ETA: 63.1 min
#   [SimCLR] Epoch  60/100 | Loss: 5.3952 | Time: 93.4s | ETA: 61.6 min
#   [SimCLR] Epoch  61/100 | Loss: 5.3940 | Time: 93.4s | ETA: 60.1 min
#   [SimCLR] Epoch  62/100 | Loss: 5.3932 | Time: 92.3s | ETA: 58.5 min
#   [SimCLR] Epoch  63/100 | Loss: 5.3928 | Time: 93.4s | ETA: 57.0 min
#   [SimCLR] Epoch  64/100 | Loss: 5.3909 | Time: 92.9s | ETA: 55.5 min
#   [SimCLR] Epoch  65/100 | Loss: 5.3908 | Time: 93.2s | ETA: 53.9 min
#   [SimCLR] Epoch  66/100 | Loss: 5.3898 | Time: 93.1s | ETA: 52.4 min
#   [SimCLR] Epoch  67/100 | Loss: 5.3886 | Time: 93.3s | ETA: 50.9 min
#   [SimCLR] Epoch  68/100 | Loss: 5.3878 | Time: 92.9s | ETA: 49.3 min
#   [SimCLR] Epoch  69/100 | Loss: 5.3874 | Time: 91.7s | ETA: 47.8 min
#   [SimCLR] Epoch  70/100 | Loss: 5.3862 | Time: 89.5s | ETA: 46.2 min
#   [SimCLR] Epoch  71/100 | Loss: 5.3864 | Time: 92.6s | ETA: 44.7 min
#   [SimCLR] Epoch  72/100 | Loss: 5.3853 | Time: 92.7s | ETA: 43.1 min
#   [SimCLR] Epoch  73/100 | Loss: 5.3838 | Time: 91.5s | ETA: 41.6 min
#   [SimCLR] Epoch  74/100 | Loss: 5.3830 | Time: 91.0s | ETA: 40.0 min
#   [SimCLR] Epoch  75/100 | Loss: 5.3818 | Time: 91.1s | ETA: 38.5 min
#   [SimCLR] Epoch  76/100 | Loss: 5.3824 | Time: 90.7s | ETA: 36.9 min
#   [SimCLR] Epoch  77/100 | Loss: 5.3817 | Time: 92.5s | ETA: 35.4 min
#   [SimCLR] Epoch  78/100 | Loss: 5.3796 | Time: 92.0s | ETA: 33.9 min
#   [SimCLR] Epoch  79/100 | Loss: 5.3793 | Time: 91.0s | ETA: 32.3 min
#   [SimCLR] Epoch  80/100 | Loss: 5.3778 | Time: 91.5s | ETA: 30.8 min
#   [SimCLR] Epoch  81/100 | Loss: 5.3787 | Time: 91.3s | ETA: 29.2 min
#   [SimCLR] Epoch  82/100 | Loss: 5.3778 | Time: 91.3s | ETA: 27.7 min
#   [SimCLR] Epoch  83/100 | Loss: 5.3782 | Time: 91.2s | ETA: 26.1 min
#   [SimCLR] Epoch  84/100 | Loss: 5.3764 | Time: 91.4s | ETA: 24.6 min
#   [SimCLR] Epoch  85/100 | Loss: 5.3771 | Time: 91.7s | ETA: 23.1 min
#   [SimCLR] Epoch  86/100 | Loss: 5.3758 | Time: 91.6s | ETA: 21.5 min
#   [SimCLR] Epoch  87/100 | Loss: 5.3761 | Time: 91.5s | ETA: 20.0 min
#   [SimCLR] Epoch  88/100 | Loss: 5.3749 | Time: 91.7s | ETA: 18.4 min
#   [SimCLR] Epoch  89/100 | Loss: 5.3748 | Time: 91.8s | ETA: 16.9 min
#   [SimCLR] Epoch  90/100 | Loss: 5.3753 | Time: 91.3s | ETA: 15.4 min
#   [SimCLR] Epoch  91/100 | Loss: 5.3737 | Time: 91.2s | ETA: 13.8 min
#   [SimCLR] Epoch  92/100 | Loss: 5.3739 | Time: 91.9s | ETA: 12.3 min
#   [SimCLR] Epoch  93/100 | Loss: 5.3743 | Time: 92.3s | ETA: 10.8 min
#   [SimCLR] Epoch  94/100 | Loss: 5.3732 | Time: 93.3s | ETA: 9.2 min
#   [SimCLR] Epoch  95/100 | Loss: 5.3734 | Time: 92.7s | ETA: 7.7 min
#   [SimCLR] Epoch  96/100 | Loss: 5.3741 | Time: 91.1s | ETA: 6.1 min
#   [SimCLR] Epoch  97/100 | Loss: 5.3737 | Time: 91.6s | ETA: 4.6 min
#   [SimCLR] Epoch  98/100 | Loss: 5.3736 | Time: 91.2s | ETA: 3.1 min
#   [SimCLR] Epoch  99/100 | Loss: 5.3739 | Time: 91.0s | ETA: 1.5 min
#   [SimCLR] Epoch 100/100 | Loss: 5.3731 | Time: 90.9s | ETA: 0.0 min

# %%
# =====================================================
# EVALUATION
# =====================================================
import os

print("\n[Eval] Running linear probes...")
byol_acc   = train_probe(byol_encoder,   supervised_train_loader, supervised_test_loader)
simclr_acc = train_probe(simclr_encoder, supervised_train_loader, supervised_test_loader)

print("[Eval] Computing geometry metrics...")
byol_jac,   byol_aug,   byol_noise   = compute_metrics(byol_encoder,   supervised_test_loader)
simclr_jac, simclr_aug, simclr_noise = compute_metrics(simclr_encoder, supervised_test_loader)

seed_time = (time.time() - seed_start) / 60
print(f"\n  Seed {seed} finished in {seed_time:.2f} min")
print(f"  BYOL   → Acc: {byol_acc:.4f}  | Jac: {byol_jac:.4f}")
print(f"  SimCLR → Acc: {simclr_acc:.4f}  | Jac: {simclr_jac:.4f}")

SAVE_PATH = "/kaggle/working/cifar10_vit_results.csv"

seed_row = {
    "Seed"              : seed,
    "BYOL_Acc"          : byol_acc,
    "SimCLR_Acc"        : simclr_acc,
    "BYOL_Jacobian"     : byol_jac,
    "SimCLR_Jacobian"   : simclr_jac,
    "BYOL_Aug"          : byol_aug,
    "SimCLR_Aug"        : simclr_aug,
    "BYOL_Noise"        : byol_noise,
    "SimCLR_Noise"      : simclr_noise,
    "Seed_Time_Min"     : seed_time,
    "BYOL_AvgEpochSec"  : np.mean(byol_epoch_times),
    "SimCLR_AvgEpochSec": np.mean(simclr_epoch_times),
}

if os.path.exists(SAVE_PATH):
    results_df = pd.read_csv(SAVE_PATH)
    if seed in results_df["Seed"].values:
        for k, v in seed_row.items():
            results_df.loc[results_df["Seed"] == seed, k] = v
        print(f"  Updated existing row for seed {seed}")
    else:
        results_df = pd.concat([results_df, pd.DataFrame([seed_row])], ignore_index=True)
        print(f"  Appended seed {seed}")
else:
    results_df = pd.DataFrame([seed_row])
    print(f"  Created new results file for seed {seed}")

results_df.to_csv(SAVE_PATH, index=False)
print(f"  Saved → {SAVE_PATH}")
# Out:
# [Eval] Running linear probes...
# [Eval] Computing geometry metrics...
#
#   Seed 4 finished in 330.58 min
#   BYOL   → Acc: 0.4783  | Jac: 1.3020
#   SimCLR → Acc: 0.7687  | Jac: 5.7402
#   Created new results file for seed 4
#   Saved → /kaggle/working/cifar10_vit_results.csv

# %%
LAMBDA_JAC   = 1e-3
TEMPERATURE  = 1.0                                  # τ = 1.0 as determined
NUM_EPOCHS   = 100
BATCH_SIZE   = 256
NUM_WORKERS  = 4

print("=" * 60)
print(f"  [JacReg] SimCLR + Jacobian Reg  |  Seed: {seed}")
print(f"  lambda_jac = {LAMBDA_JAC}  |  tau = {TEMPERATURE}")
print("=" * 60)

set_seed(seed)
jacreg_start = time.time()

# ── Data (CIFAR-10, same seed as BYOL/SimCLR cells) ──────────────────────────
train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=True, transform=ssl_transform)

supervised_train_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=True, download=False, transform=supervised_transform)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data", train=False, download=False, transform=supervised_transform)

_loader_kw = dict(
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    persistent_workers=True,
)

train_loader            = DataLoader(train_dataset,            shuffle=True,  **_loader_kw)
supervised_train_loader = DataLoader(supervised_train_dataset, shuffle=True,  **_loader_kw)
supervised_test_loader  = DataLoader(test_dataset,             shuffle=False, **_loader_kw)

# ── Model ─────────────────────────────────────────────────────────────────────
jacreg_model = SimCLR().to(device)


optimizer = torch.optim.AdamW(
    jacreg_model.parameters(), lr=3e-4, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=NUM_EPOCHS, eta_min=1e-6)

scaler = GradScaler("cuda")

jacreg_epoch_times = []

for epoch in range(NUM_EPOCHS):
    epoch_start  = time.time()
    jacreg_model.train()
    running_loss = 0.0
    running_ssl  = 0.0
    running_jac  = 0.0

    for batch_idx, ((x1, x2), _) in enumerate(train_loader):

        # requires_grad needed for Jacobian — only on x1
        x1 = x1.to(device, non_blocking=True).requires_grad_(True)
        x2 = x2.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        with autocast("cuda"):
            z1 = jacreg_model(x1)
            z2 = jacreg_model(x2)
            loss_ssl = nt_xent_loss(z1, z2, temperature=TEMPERATURE)

        # FIXED: compute Jac reg every other batch (same as original)
        # but keep it inside autocast for speed, and use retain_graph correctly
        if batch_idx % 2 == 0:
            with autocast("cuda"):
                features = jacreg_model.encoder(x1)

            v  = torch.randn_like(features)
            Jv = torch.autograd.grad(
                outputs=features,
                inputs=x1,
                grad_outputs=v,
                retain_graph=False,
                create_graph=False,         # NEW: no 2nd-order graph, faster
            )[0]
            # FIXED: detach before .item() to avoid holding graph
            jac_reg = Jv.pow(2).sum(dim=[1, 2, 3]).mean()
        else:
            jac_reg = torch.tensor(0.0, device=device)

        loss = loss_ssl + LAMBDA_JAC * jac_reg

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(
            jacreg_model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item()
        running_ssl  += loss_ssl.item()
        running_jac  += jac_reg.item() if isinstance(jac_reg, torch.Tensor) else 0.0

    scheduler.step()

    elapsed = time.time() - epoch_start
    jacreg_epoch_times.append(elapsed)
    avg_t     = np.mean(jacreg_epoch_times)
    remaining = avg_t * (NUM_EPOCHS - epoch - 1)
    n_batches = len(train_loader)

    print(f"  [JacReg] Epoch {epoch+1:3d}/{NUM_EPOCHS} | "
          f"Loss: {running_loss/n_batches:.4f}  "
          f"(SSL: {running_ssl/n_batches:.4f}  "
          f"Jac: {running_jac/n_batches:.4f}) | "
          f"Time: {elapsed:.1f}s | "
          f"ETA: {remaining/60:.1f} min")

jacreg_encoder = jacreg_model.encoder

# ── Evaluate ──────────────────────────────────────────────────────────────────
print("\n[JacReg] Running linear probe...")
jacreg_acc = train_probe(
    jacreg_encoder, supervised_train_loader, supervised_test_loader)

print("[JacReg] Computing geometry metrics...")
jacreg_jac, jacreg_aug, jacreg_noise = compute_metrics(
    jacreg_encoder, supervised_test_loader)

jacreg_time = (time.time() - jacreg_start) / 60

print(f"\n  [JacReg] Seed {seed} done in {jacreg_time:.2f} min")
print(f"  JacReg → Acc: {jacreg_acc:.4f}  | Jac: {jacreg_jac:.4f}")


# =========================================================
# CELL 2 — Final Results  (all 3 models, 1 seed)
# =========================================================
#
# Reads BYOL + SimCLR results from all_results (built in prior cells),
# appends JacReg, saves everything to /kaggle/working/
# ─────────────────────────────────────────────────────────

import os

# ── Build unified row for this seed ───────────────────────────────────────────
seed_row = {
    "Seed"                  : seed,

    # Accuracy
    "BYOL_Acc"              : byol_acc,
    "SimCLR_Acc"            : simclr_acc,
    "JacReg_Acc"            : jacreg_acc,

    # Jacobian sensitivity
    "BYOL_Jacobian"         : byol_jac,
    "SimCLR_Jacobian"       : simclr_jac,
    "JacReg_Jacobian"       : jacreg_jac,

    # Augmentation invariance
    "BYOL_Aug"              : byol_aug,
    "SimCLR_Aug"            : simclr_aug,
    "JacReg_Aug"            : jacreg_aug,

    # Noise robustness
    "BYOL_Noise"            : byol_noise,
    "SimCLR_Noise"          : simclr_noise,
    "JacReg_Noise"          : jacreg_noise,

    # Timing
    "BYOL_Time_Min"         : sum(byol_epoch_times) / 60,
    "SimCLR_Time_Min"       : sum(simclr_epoch_times) / 60,
    "JacReg_Time_Min"       : jacreg_time,

    "BYOL_AvgEpochSec"      : np.mean(byol_epoch_times),
    "SimCLR_AvgEpochSec"    : np.mean(simclr_epoch_times),
    "JacReg_AvgEpochSec"    : np.mean(jacreg_epoch_times),
}

# ── Merge with any previously saved seeds ─────────────────────────────────────
SAVE_PATH = "/kaggle/working/cifar10_results_progress.csv"

if os.path.exists(SAVE_PATH):
    results_df = pd.read_csv(SAVE_PATH)
    # overwrite row if seed already exists, else append
    if seed in results_df["Seed"].values:
        for k, v in seed_row.items():
            results_df.loc[results_df["Seed"] == seed, k] = v
        print(f"  Updated existing row for seed {seed}")
    else:
        results_df = pd.concat(
            [results_df, pd.DataFrame([seed_row])], ignore_index=True)
        print(f"  Appended new row for seed {seed}")
else:
    results_df = pd.DataFrame([seed_row])
    print(f"  Created new results file for seed {seed}")

results_df.to_csv(SAVE_PATH, index=False)
print(f"  Saved → {SAVE_PATH}")

# ── Pretty-print side-by-side comparison ──────────────────────────────────────
METRICS = [
    ("Accuracy",              "BYOL_Acc",       "SimCLR_Acc",       "JacReg_Acc"),
    ("Jacobian Sensitivity",  "BYOL_Jacobian",  "SimCLR_Jacobian",  "JacReg_Jacobian"),
    ("Aug Invariance",        "BYOL_Aug",       "SimCLR_Aug",       "JacReg_Aug"),
    ("Noise Robustness",      "BYOL_Noise",     "SimCLR_Noise",     "JacReg_Noise"),
    ("Train Time (min)",      "BYOL_Time_Min",  "SimCLR_Time_Min",  "JacReg_Time_Min"),
    ("Avg Epoch (sec)",       "BYOL_AvgEpochSec","SimCLR_AvgEpochSec","JacReg_AvgEpochSec"),
]

print("\n" + "=" * 70)
print(f"  SEED {seed} RESULTS  —  BYOL vs SimCLR vs SimCLR+JacReg  (CIFAR-10)")
print("=" * 70)
print(f"  {'Metric':<26}  {'BYOL':>10}  {'SimCLR':>10}  {'JacReg':>10}")
print("  " + "-" * 62)
for label, b_col, s_col, j_col in METRICS:
    b = seed_row[b_col]
    s = seed_row[s_col]
    j = seed_row[j_col]
    print(f"  {label:<26}  {b:>10.4f}  {s:>10.4f}  {j:>10.4f}")
print("=" * 70)

# ── If multiple seeds are done, also print aggregate stats ────────────────────
if len(results_df) > 1:
    print(f"\n  AGGREGATE  ({len(results_df)} seeds completed)")
    print("=" * 70)
    print(f"  {'Metric':<26}  {'BYOL':>10}  {'SimCLR':>10}  {'JacReg':>10}")
    print("  " + "-" * 62)
    for label, b_col, s_col, j_col in METRICS:
        bm = results_df[b_col].mean(); bs = results_df[b_col].std()
        sm = results_df[s_col].mean(); ss = results_df[s_col].std()
        jm = results_df[j_col].mean(); js = results_df[j_col].std()
        print(f"  {label:<26}  "
              f"{bm:>6.4f}±{bs:.3f}  "
              f"{sm:>6.4f}±{ss:.3f}  "
              f"{jm:>6.4f}±{js:.3f}")
    print("=" * 70)

print(f"\n  Seeds completed so far: {sorted(results_df['Seed'].tolist())}")
print(f"  Progress CSV: {SAVE_PATH}")
# Out:
# ============================================================
#   [JacReg] SimCLR + Jacobian Reg  |  Seed: 4
#   lambda_jac = 0.001  |  tau = 1.0
# ============================================================
#   [JacReg] Epoch   1/100 | Loss: 5.7005  (SSL: 5.6982  Jac: 2.2957) | Time: 102.4s | ETA: 168.9 min
#   [JacReg] Epoch   2/100 | Loss: 5.6217  (SSL: 5.6205  Jac: 1.2039) | Time: 103.6s | ETA: 168.2 min
#   [JacReg] Epoch   3/100 | Loss: 5.5969  (SSL: 5.5958  Jac: 1.0829) | Time: 102.1s | ETA: 166.0 min
#   [JacReg] Epoch   4/100 | Loss: 5.5821  (SSL: 5.5810  Jac: 1.1508) | Time: 101.3s | ETA: 163.7 min
#   [JacReg] Epoch   5/100 | Loss: 5.5722  (SSL: 5.5710  Jac: 1.2422) | Time: 100.7s | ETA: 161.5 min
#   [JacReg] Epoch   6/100 | Loss: 5.5613  (SSL: 5.5598  Jac: 1.5158) | Time: 101.0s | ETA: 159.5 min
#   [JacReg] Epoch   7/100 | Loss: 5.5515  (SSL: 5.5499  Jac: 1.6058) | Time: 101.1s | ETA: 157.7 min
#   [JacReg] Epoch   8/100 | Loss: 5.5441  (SSL: 5.5422  Jac: 1.8913) | Time: 102.6s | ETA: 156.1 min
#   [JacReg] Epoch   9/100 | Loss: 5.5373  (SSL: 5.5353  Jac: 2.0030) | Time: 102.1s | ETA: 154.5 min
#   [JacReg] Epoch  10/100 | Loss: 5.5285  (SSL: 5.5263  Jac: 2.1908) | Time: 102.5s | ETA: 152.9 min
#   [JacReg] Epoch  11/100 | Loss: 5.5231  (SSL: 5.5207  Jac: 2.4751) | Time: 101.9s | ETA: 151.2 min
#   [JacReg] Epoch  12/100 | Loss: 5.5171  (SSL: 5.5143  Jac: 2.7701) | Time: 102.3s | ETA: 149.5 min
#   [JacReg] Epoch  13/100 | Loss: 5.5079  (SSL: 5.5047  Jac: 3.1647) | Time: 102.8s | ETA: 147.9 min
#   [JacReg] Epoch  14/100 | Loss: 5.5010  (SSL: 5.4974  Jac: 3.5159) | Time: 102.6s | ETA: 146.3 min
#   [JacReg] Epoch  15/100 | Loss: 5.4947  (SSL: 5.4909  Jac: 3.8228) | Time: 101.0s | ETA: 144.5 min
#   [JacReg] Epoch  16/100 | Loss: 5.4912  (SSL: 5.4870  Jac: 4.1188) | Time: 101.7s | ETA: 142.8 min
#   [JacReg] Epoch  17/100 | Loss: 5.4867  (SSL: 5.4819  Jac: 4.7830) | Time: 101.1s | ETA: 141.0 min
#   [JacReg] Epoch  18/100 | Loss: 5.4815  (SSL: 5.4763  Jac: 5.1487) | Time: 102.1s | ETA: 139.3 min
#   [JacReg] Epoch  19/100 | Loss: 5.4793  (SSL: 5.4741  Jac: 5.1260) | Time: 101.0s | ETA: 137.5 min
#   [JacReg] Epoch  20/100 | Loss: 5.4763  (SSL: 5.4707  Jac: 5.5107) | Time: 100.7s | ETA: 135.8 min
#   [JacReg] Epoch  21/100 | Loss: 5.4717  (SSL: 5.4660  Jac: 5.6962) | Time: 102.0s | ETA: 134.1 min
#   [JacReg] Epoch  22/100 | Loss: 5.4684  (SSL: 5.4622  Jac: 6.2131) | Time: 100.9s | ETA: 132.3 min
#   [JacReg] Epoch  23/100 | Loss: 5.4653  (SSL: 5.4590  Jac: 6.3157) | Time: 101.9s | ETA: 130.6 min
#   [JacReg] Epoch  24/100 | Loss: 5.4626  (SSL: 5.4558  Jac: 6.8158) | Time: 100.7s | ETA: 128.9 min
#   [JacReg] Epoch  25/100 | Loss: 5.4595  (SSL: 5.4526  Jac: 6.8870) | Time: 100.6s | ETA: 127.1 min
#   [JacReg] Epoch  26/100 | Loss: 5.4581  (SSL: 5.4506  Jac: 7.5068) | Time: 101.2s | ETA: 125.4 min
#   [JacReg] Epoch  27/100 | Loss: 5.4548  (SSL: 5.4472  Jac: 7.5847) | Time: 100.7s | ETA: 123.7 min
#   [JacReg] Epoch  28/100 | Loss: 5.4546  (SSL: 5.4461  Jac: 8.4608) | Time: 101.9s | ETA: 122.0 min
#   [JacReg] Epoch  29/100 | Loss: 5.4503  (SSL: 5.4416  Jac: 8.7491) | Time: 100.6s | ETA: 120.2 min
#   [JacReg] Epoch  30/100 | Loss: 5.4498  (SSL: 5.4406  Jac: 9.2060) | Time: 101.1s | ETA: 118.5 min
#   [JacReg] Epoch  31/100 | Loss: 5.4462  (SSL: 5.4367  Jac: 9.4930) | Time: 100.8s | ETA: 116.8 min
#   [JacReg] Epoch  32/100 | Loss: 5.4463  (SSL: 5.4362  Jac: 10.1149) | Time: 101.5s | ETA: 115.1 min
#   [JacReg] Epoch  33/100 | Loss: 5.4453  (SSL: 5.4346  Jac: 10.6827) | Time: 100.7s | ETA: 113.4 min
#   [JacReg] Epoch  34/100 | Loss: 5.4440  (SSL: 5.4329  Jac: 11.1033) | Time: 100.8s | ETA: 111.7 min
#   [JacReg] Epoch  35/100 | Loss: 5.4411  (SSL: 5.4296  Jac: 11.5509) | Time: 101.1s | ETA: 110.0 min
#   [JacReg] Epoch  36/100 | Loss: 5.4412  (SSL: 5.4291  Jac: 12.0820) | Time: 101.8s | ETA: 108.3 min
#   [JacReg] Epoch  37/100 | Loss: 5.4388  (SSL: 5.4263  Jac: 12.5737) | Time: 101.9s | ETA: 106.6 min
#   [JacReg] Epoch  38/100 | Loss: 5.4389  (SSL: 5.4256  Jac: 13.3043) | Time: 103.8s | ETA: 105.0 min
#   [JacReg] Epoch  39/100 | Loss: 5.4367  (SSL: 5.4233  Jac: 13.4684) | Time: 102.3s | ETA: 103.3 min
#   [JacReg] Epoch  40/100 | Loss: 5.4358  (SSL: 5.4211  Jac: 14.6795) | Time: 103.7s | ETA: 101.7 min
#   [JacReg] Epoch  41/100 | Loss: 5.4355  (SSL: 5.4205  Jac: 14.9865) | Time: 101.5s | ETA: 100.0 min
#   [JacReg] Epoch  42/100 | Loss: 5.4337  (SSL: 5.4189  Jac: 14.8038) | Time: 101.9s | ETA: 98.3 min
#   [JacReg] Epoch  43/100 | Loss: 5.4332  (SSL: 5.4176  Jac: 15.5923) | Time: 102.7s | ETA: 96.6 min
#   [JacReg] Epoch  44/100 | Loss: 5.4317  (SSL: 5.4157  Jac: 16.0247) | Time: 101.7s | ETA: 94.9 min
#   [JacReg] Epoch  45/100 | Loss: 5.4313  (SSL: 5.4146  Jac: 16.6744) | Time: 101.8s | ETA: 93.2 min
#   [JacReg] Epoch  46/100 | Loss: 5.4296  (SSL: 5.4124  Jac: 17.2126) | Time: 102.1s | ETA: 91.5 min
#   [JacReg] Epoch  47/100 | Loss: 5.4292  (SSL: 5.4109  Jac: 18.3231) | Time: 101.5s | ETA: 89.8 min
#   [JacReg] Epoch  48/100 | Loss: 5.4291  (SSL: 5.4094  Jac: 19.7064) | Time: 102.3s | ETA: 88.1 min
#   [JacReg] Epoch  49/100 | Loss: 5.4271  (SSL: 5.4074  Jac: 19.6586) | Time: 101.4s | ETA: 86.4 min
#   [JacReg] Epoch  50/100 | Loss: 5.4288  (SSL: 5.4080  Jac: 20.7574) | Time: 101.9s | ETA: 84.8 min
#   [JacReg] Epoch  51/100 | Loss: 5.4276  (SSL: 5.4065  Jac: 21.1215) | Time: 102.2s | ETA: 83.1 min
#   [JacReg] Epoch  52/100 | Loss: 5.4251  (SSL: 5.4037  Jac: 21.3903) | Time: 101.5s | ETA: 81.4 min
#   [JacReg] Epoch  53/100 | Loss: 5.4268  (SSL: 5.4049  Jac: 21.9745) | Time: 102.7s | ETA: 79.7 min
#   [JacReg] Epoch  54/100 | Loss: 5.4253  (SSL: 5.4025  Jac: 22.7405) | Time: 101.4s | ETA: 78.0 min
#   [JacReg] Epoch  55/100 | Loss: 5.4239  (SSL: 5.3995  Jac: 24.3332) | Time: 101.5s | ETA: 76.3 min
#   [JacReg] Epoch  56/100 | Loss: 5.4235  (SSL: 5.3991  Jac: 24.3792) | Time: 101.5s | ETA: 74.6 min
#   [JacReg] Epoch  57/100 | Loss: 5.4240  (SSL: 5.3987  Jac: 25.3467) | Time: 101.8s | ETA: 72.9 min
#   [JacReg] Epoch  58/100 | Loss: 5.4240  (SSL: 5.3975  Jac: 26.4227) | Time: 102.4s | ETA: 71.2 min
#   [JacReg] Epoch  59/100 | Loss: 5.4241  (SSL: 5.3965  Jac: 27.5722) | Time: 101.3s | ETA: 69.5 min
#   [JacReg] Epoch  60/100 | Loss: 5.4244  (SSL: 5.3960  Jac: 28.4300) | Time: 101.4s | ETA: 67.8 min
#   [JacReg] Epoch  61/100 | Loss: 5.4242  (SSL: 5.3949  Jac: 29.3268) | Time: 102.0s | ETA: 66.1 min
#   [JacReg] Epoch  62/100 | Loss: 5.4237  (SSL: 5.3941  Jac: 29.5266) | Time: 101.9s | ETA: 64.4 min
#   [JacReg] Epoch  63/100 | Loss: 5.4231  (SSL: 5.3929  Jac: 30.1452) | Time: 102.2s | ETA: 62.7 min
#   [JacReg] Epoch  64/100 | Loss: 5.4223  (SSL: 5.3924  Jac: 29.9421) | Time: 101.7s | ETA: 61.0 min
#   [JacReg] Epoch  65/100 | Loss: 5.4226  (SSL: 5.3907  Jac: 31.9550) | Time: 101.4s | ETA: 59.3 min
#   [JacReg] Epoch  66/100 | Loss: 5.4234  (SSL: 5.3902  Jac: 33.2456) | Time: 101.4s | ETA: 57.6 min
#   [JacReg] Epoch  67/100 | Loss: 5.4229  (SSL: 5.3891  Jac: 33.7908) | Time: 101.3s | ETA: 55.9 min
#   [JacReg] Epoch  68/100 | Loss: 5.4225  (SSL: 5.3883  Jac: 34.1967) | Time: 102.9s | ETA: 54.3 min
#   [JacReg] Epoch  69/100 | Loss: 5.4225  (SSL: 5.3874  Jac: 35.0218) | Time: 102.1s | ETA: 52.6 min
#   [JacReg] Epoch  70/100 | Loss: 5.4221  (SSL: 5.3859  Jac: 36.2458) | Time: 102.5s | ETA: 50.9 min
#   [JacReg] Epoch  71/100 | Loss: 5.4211  (SSL: 5.3845  Jac: 36.5845) | Time: 102.5s | ETA: 49.2 min
#   [JacReg] Epoch  72/100 | Loss: 5.4217  (SSL: 5.3845  Jac: 37.1412) | Time: 102.5s | ETA: 47.5 min
#   [JacReg] Epoch  73/100 | Loss: 5.4216  (SSL: 5.3833  Jac: 38.3911) | Time: 103.4s | ETA: 45.8 min
#   [JacReg] Epoch  74/100 | Loss: 5.4211  (SSL: 5.3832  Jac: 37.9733) | Time: 103.0s | ETA: 44.1 min
#   [JacReg] Epoch  75/100 | Loss: 5.4221  (SSL: 5.3820  Jac: 40.0902) | Time: 102.2s | ETA: 42.4 min
#   [JacReg] Epoch  76/100 | Loss: 5.4216  (SSL: 5.3807  Jac: 40.8739) | Time: 102.6s | ETA: 40.7 min
#   [JacReg] Epoch  77/100 | Loss: 5.4225  (SSL: 5.3819  Jac: 40.6193) | Time: 102.9s | ETA: 39.0 min
#   [JacReg] Epoch  78/100 | Loss: 5.4222  (SSL: 5.3816  Jac: 40.6045) | Time: 101.4s | ETA: 37.3 min
#   [JacReg] Epoch  79/100 | Loss: 5.4219  (SSL: 5.3798  Jac: 42.0959) | Time: 102.5s | ETA: 35.6 min
#   [JacReg] Epoch  80/100 | Loss: 5.4219  (SSL: 5.3792  Jac: 42.7065) | Time: 102.0s | ETA: 33.9 min
#   [JacReg] Epoch  81/100 | Loss: 5.4210  (SSL: 5.3775  Jac: 43.5425) | Time: 102.1s | ETA: 32.3 min
#   [JacReg] Epoch  82/100 | Loss: 5.4213  (SSL: 5.3780  Jac: 43.2702) | Time: 101.7s | ETA: 30.6 min
#   [JacReg] Epoch  83/100 | Loss: 5.4208  (SSL: 5.3762  Jac: 44.6651) | Time: 102.2s | ETA: 28.9 min
#   [JacReg] Epoch  84/100 | Loss: 5.4216  (SSL: 5.3771  Jac: 44.5228) | Time: 102.6s | ETA: 27.2 min
#   [JacReg] Epoch  85/100 | Loss: 5.4225  (SSL: 5.3771  Jac: 45.3170) | Time: 102.0s | ETA: 25.5 min
#   [JacReg] Epoch  86/100 | Loss: 5.4213  (SSL: 5.3764  Jac: 44.9000) | Time: 102.1s | ETA: 23.8 min
#   [JacReg] Epoch  87/100 | Loss: 5.4224  (SSL: 5.3756  Jac: 46.8182) | Time: 102.2s | ETA: 22.1 min
#   [JacReg] Epoch  88/100 | Loss: 5.4218  (SSL: 5.3756  Jac: 46.1303) | Time: 102.5s | ETA: 20.4 min
#   [JacReg] Epoch  89/100 | Loss: 5.4230  (SSL: 5.3751  Jac: 47.9029) | Time: 100.8s | ETA: 18.7 min
#   [JacReg] Epoch  90/100 | Loss: 5.4239  (SSL: 5.3750  Jac: 48.8457) | Time: 100.9s | ETA: 17.0 min
#   [JacReg] Epoch  91/100 | Loss: 5.4243  (SSL: 5.3748  Jac: 49.4979) | Time: 100.6s | ETA: 15.3 min
#   [JacReg] Epoch  92/100 | Loss: 5.4224  (SSL: 5.3743  Jac: 48.0961) | Time: 101.4s | ETA: 13.6 min
#   [JacReg] Epoch  93/100 | Loss: 5.4234  (SSL: 5.3746  Jac: 48.7379) | Time: 102.5s | ETA: 11.9 min
#   [JacReg] Epoch  94/100 | Loss: 5.4230  (SSL: 5.3745  Jac: 48.4712) | Time: 100.9s | ETA: 10.2 min
#   [JacReg] Epoch  95/100 | Loss: 5.4231  (SSL: 5.3742  Jac: 48.8684) | Time: 101.0s | ETA: 8.5 min
#   [JacReg] Epoch  96/100 | Loss: 5.4233  (SSL: 5.3730  Jac: 50.2952) | Time: 101.5s | ETA: 6.8 min
#   [JacReg] Epoch  97/100 | Loss: 5.4241  (SSL: 5.3748  Jac: 49.2884) | Time: 101.8s | ETA: 5.1 min
#   [JacReg] Epoch  98/100 | Loss: 5.4236  (SSL: 5.3748  Jac: 48.8286) | Time: 102.2s | ETA: 3.4 min
#   [JacReg] Epoch  99/100 | Loss: 5.4229  (SSL: 5.3737  Jac: 49.2065) | Time: 101.0s | ETA: 1.7 min
#   [JacReg] Epoch 100/100 | Loss: 5.4216  (SSL: 5.3730  Jac: 48.6076) | Time: 102.3s | ETA: 0.0 min
#
# [JacReg] Running linear probe...
# [JacReg] Computing geometry metrics...
#
#   [JacReg] Seed 4 done in 175.87 min
#   JacReg → Acc: 0.7657  | Jac: 5.7493
#   Created new results file for seed 4
#   Saved → /kaggle/working/cifar10_results_progress.csv
#
# ======================================================================
#   SEED 4 RESULTS  —  BYOL vs SimCLR vs SimCLR+JacReg  (CIFAR-10)
# ======================================================================
#   Metric                            BYOL      SimCLR      JacReg
#   --------------------------------------------------------------
#   Accuracy                        0.4783      0.7687      0.7657
#   Jacobian Sensitivity            1.3020      5.7402      5.7493
#   Aug Invariance                  3.2233      6.9042      6.9065
#   Noise Robustness                0.1244      0.7598      0.7660
#   Train Time (min)              163.9786    153.6280    175.8716
#   Avg Epoch (sec)                98.3872     92.1768    101.8140
# ======================================================================
#
#   Seeds completed so far: [4]
#   Progress CSV: /kaggle/working/cifar10_results_progress.csv
